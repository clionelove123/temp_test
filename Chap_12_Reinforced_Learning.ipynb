# %% [markdown]
# <a href="https://colab.research.google.com/github/clionelove123/temp_test/blob/main/Chap_12_Reinforced_Learning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# -*- coding: utf-8 -*-

# %matplotlib
# %matplotlib inline
import os
os.chdir('/content')

# !python Chap_12_Reinforced_Learning_Training.py
# Out:
# Using matplotlib backend: <object object at 0x7fdcf795b450>
# 2023-05-16 08:53:51.839219: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-05-16 08:53:53.259894: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2023-05-16 08:53:55.314790: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-05-16 08:53:55.906115: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-05-16 08:53:55.906467: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-05-16 08:53:55.919181: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-05-16 08:53:55.919483: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-05-16 08:53:55.919679: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-05-16 08:53:58.856340: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-05-16 08:53:58.856634: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-05-16 08:53:58.856804: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-05-16 08:53:58.856924: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:47] Overriding orig_value setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# 2023-05-16 08:53:58.856961: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1635] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13678 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5
# 트레이닝을 시작합니다.
# /content/Chap_12_Reinforced_Learning_Training.py:168: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   self.gameOver = np.empty(self.maxMemory, dtype = np.bool)
# 2023-05-16 08:54:02.853521: I tensorflow/compiler/xla/service/service.cc:169] XLA service 0x405f7940 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2023-05-16 08:54:02.853574: I tensorflow/compiler/xla/service/service.cc:177]   StreamExecutor device (0): Tesla T4, Compute Capability 7.5
# 2023-05-16 08:54:03.631882: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:424] Loaded cuDNN version 8700
# 2023-05-16 08:54:04.201975: I ./tensorflow/compiler/jit/device_compiler.h:180] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# WARNING:tensorflow:5 out of the last 5 calls to <function _BaseOptimizer._update_step_xla at 0x7f1cec085000> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# W0516 08:54:04.480200 139764739086144 polymorphic_function.py:156] 5 out of the last 5 calls to <function _BaseOptimizer._update_step_xla at 0x7f1cec085000> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:6 out of the last 6 calls to <function _BaseOptimizer._update_step_xla at 0x7f1cec085000> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# W0516 08:54:04.560726 139764739086144 polymorphic_function.py:156] 6 out of the last 6 calls to <function _BaseOptimizer._update_step_xla at 0x7f1cec085000> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 반복(Epoch): 0, 에러(err): 0.0132, 승리횟수(Win count): 0, 승리비율(Win ratio): 0.0000
# 반복(Epoch): 1, 에러(err): 0.0817, 승리횟수(Win count): 1, 승리비율(Win ratio): 50.0000
# /content/model.ckpt-1 경로에 파라미터가 저장되었습니다
# 반복(Epoch): 2, 에러(err): 0.0994, 승리횟수(Win count): 2, 승리비율(Win ratio): 66.6667
# 반복(Epoch): 3, 에러(err): 0.2106, 승리횟수(Win count): 3, 승리비율(Win ratio): 75.0000
# 반복(Epoch): 4, 에러(err): 0.1724, 승리횟수(Win count): 4, 승리비율(Win ratio): 80.0000
# 반복(Epoch): 5, 에러(err): 0.3168, 승리횟수(Win count): 5, 승리비율(Win ratio): 83.3333
# 반복(Epoch): 6, 에러(err): 0.1823, 승리횟수(Win count): 5, 승리비율(Win ratio): 71.4286
# 반복(Epoch): 7, 에러(err): 0.3152, 승리횟수(Win count): 5, 승리비율(Win ratio): 62.5000
# 반복(Epoch): 8, 에러(err): 0.3777, 승리횟수(Win count): 5, 승리비율(Win ratio): 55.5556
# 반복(Epoch): 9, 에러(err): 0.3469, 승리횟수(Win count): 5, 승리비율(Win ratio): 50.0000
# 반복(Epoch): 10, 에러(err): 0.4082, 승리횟수(Win count): 5, 승리비율(Win ratio): 45.4545
# 반복(Epoch): 11, 에러(err): 0.5034, 승리횟수(Win count): 5, 승리비율(Win ratio): 41.6667
# 반복(Epoch): 12, 에러(err): 0.3978, 승리횟수(Win count): 5, 승리비율(Win ratio): 38.4615
# 반복(Epoch): 13, 에러(err): 0.4648, 승리횟수(Win count): 5, 승리비율(Win ratio): 35.7143
# 반복(Epoch): 14, 에러(err): 0.3749, 승리횟수(Win count): 5, 승리비율(Win ratio): 33.3333
# 반복(Epoch): 15, 에러(err): 0.4187, 승리횟수(Win count): 6, 승리비율(Win ratio): 37.5000
# 반복(Epoch): 16, 에러(err): 0.4705, 승리횟수(Win count): 6, 승리비율(Win ratio): 35.2941
# 반복(Epoch): 17, 에러(err): 0.4281, 승리횟수(Win count): 6, 승리비율(Win ratio): 33.3333
# 반복(Epoch): 18, 에러(err): 0.4272, 승리횟수(Win count): 6, 승리비율(Win ratio): 31.5789
# 반복(Epoch): 19, 에러(err): 0.3907, 승리횟수(Win count): 6, 승리비율(Win ratio): 30.0000
# 반복(Epoch): 20, 에러(err): 0.3971, 승리횟수(Win count): 7, 승리비율(Win ratio): 33.3333
# 반복(Epoch): 21, 에러(err): 0.4547, 승리횟수(Win count): 7, 승리비율(Win ratio): 31.8182
# 반복(Epoch): 22, 에러(err): 0.4179, 승리횟수(Win count): 8, 승리비율(Win ratio): 34.7826
# 반복(Epoch): 23, 에러(err): 0.4421, 승리횟수(Win count): 9, 승리비율(Win ratio): 37.5000
# 반복(Epoch): 24, 에러(err): 0.4187, 승리횟수(Win count): 9, 승리비율(Win ratio): 36.0000
# 반복(Epoch): 25, 에러(err): 0.4749, 승리횟수(Win count): 9, 승리비율(Win ratio): 34.6154
# 반복(Epoch): 26, 에러(err): 0.4592, 승리횟수(Win count): 9, 승리비율(Win ratio): 33.3333
# 반복(Epoch): 27, 에러(err): 0.5031, 승리횟수(Win count): 9, 승리비율(Win ratio): 32.1429
# 반복(Epoch): 28, 에러(err): 0.4586, 승리횟수(Win count): 9, 승리비율(Win ratio): 31.0345
# 반복(Epoch): 29, 에러(err): 0.3318, 승리횟수(Win count): 9, 승리비율(Win ratio): 30.0000
# 반복(Epoch): 30, 에러(err): 0.3209, 승리횟수(Win count): 9, 승리비율(Win ratio): 29.0323
# 반복(Epoch): 31, 에러(err): 0.3347, 승리횟수(Win count): 9, 승리비율(Win ratio): 28.1250
# 반복(Epoch): 32, 에러(err): 0.3016, 승리횟수(Win count): 10, 승리비율(Win ratio): 30.3030
# 반복(Epoch): 33, 에러(err): 0.4042, 승리횟수(Win count): 10, 승리비율(Win ratio): 29.4118
# 반복(Epoch): 34, 에러(err): 0.4100, 승리횟수(Win count): 10, 승리비율(Win ratio): 28.5714
# 반복(Epoch): 35, 에러(err): 0.3180, 승리횟수(Win count): 11, 승리비율(Win ratio): 30.5556
# 반복(Epoch): 36, 에러(err): 0.3825, 승리횟수(Win count): 11, 승리비율(Win ratio): 29.7297
# 반복(Epoch): 37, 에러(err): 0.2503, 승리횟수(Win count): 11, 승리비율(Win ratio): 28.9474
# 반복(Epoch): 38, 에러(err): 0.3373, 승리횟수(Win count): 11, 승리비율(Win ratio): 28.2051
# 반복(Epoch): 39, 에러(err): 0.4738, 승리횟수(Win count): 11, 승리비율(Win ratio): 27.5000
# 반복(Epoch): 40, 에러(err): 0.3259, 승리횟수(Win count): 11, 승리비율(Win ratio): 26.8293
# 반복(Epoch): 41, 에러(err): 0.2859, 승리횟수(Win count): 11, 승리비율(Win ratio): 26.1905
# 반복(Epoch): 42, 에러(err): 0.3576, 승리횟수(Win count): 11, 승리비율(Win ratio): 25.5814
# 반복(Epoch): 43, 에러(err): 0.2754, 승리횟수(Win count): 11, 승리비율(Win ratio): 25.0000
# 반복(Epoch): 44, 에러(err): 0.3478, 승리횟수(Win count): 11, 승리비율(Win ratio): 24.4444
# 반복(Epoch): 45, 에러(err): 0.3322, 승리횟수(Win count): 12, 승리비율(Win ratio): 26.0870
# 반복(Epoch): 46, 에러(err): 0.3962, 승리횟수(Win count): 13, 승리비율(Win ratio): 27.6596
# 반복(Epoch): 47, 에러(err): 0.2497, 승리횟수(Win count): 13, 승리비율(Win ratio): 27.0833
# 반복(Epoch): 48, 에러(err): 0.2449, 승리횟수(Win count): 14, 승리비율(Win ratio): 28.5714
# 반복(Epoch): 49, 에러(err): 0.3130, 승리횟수(Win count): 15, 승리비율(Win ratio): 30.0000
# 반복(Epoch): 50, 에러(err): 0.3582, 승리횟수(Win count): 16, 승리비율(Win ratio): 31.3725
# 반복(Epoch): 51, 에러(err): 0.2892, 승리횟수(Win count): 16, 승리비율(Win ratio): 30.7692
# 반복(Epoch): 52, 에러(err): 0.2712, 승리횟수(Win count): 17, 승리비율(Win ratio): 32.0755
# 반복(Epoch): 53, 에러(err): 0.2669, 승리횟수(Win count): 17, 승리비율(Win ratio): 31.4815
# 반복(Epoch): 54, 에러(err): 0.2612, 승리횟수(Win count): 17, 승리비율(Win ratio): 30.9091
# 반복(Epoch): 55, 에러(err): 0.2203, 승리횟수(Win count): 18, 승리비율(Win ratio): 32.1429
# 반복(Epoch): 56, 에러(err): 0.2837, 승리횟수(Win count): 18, 승리비율(Win ratio): 31.5789
# 반복(Epoch): 57, 에러(err): 0.2929, 승리횟수(Win count): 18, 승리비율(Win ratio): 31.0345
# 반복(Epoch): 58, 에러(err): 0.2811, 승리횟수(Win count): 19, 승리비율(Win ratio): 32.2034
# 반복(Epoch): 59, 에러(err): 0.2388, 승리횟수(Win count): 19, 승리비율(Win ratio): 31.6667
# 반복(Epoch): 60, 에러(err): 0.3261, 승리횟수(Win count): 19, 승리비율(Win ratio): 31.1475
# 반복(Epoch): 61, 에러(err): 0.3191, 승리횟수(Win count): 20, 승리비율(Win ratio): 32.2581
# 반복(Epoch): 62, 에러(err): 0.2356, 승리횟수(Win count): 21, 승리비율(Win ratio): 33.3333
# 반복(Epoch): 63, 에러(err): 0.3723, 승리횟수(Win count): 21, 승리비율(Win ratio): 32.8125
# 반복(Epoch): 64, 에러(err): 0.2072, 승리횟수(Win count): 21, 승리비율(Win ratio): 32.3077
# 반복(Epoch): 65, 에러(err): 0.2277, 승리횟수(Win count): 21, 승리비율(Win ratio): 31.8182
# 반복(Epoch): 66, 에러(err): 0.2390, 승리횟수(Win count): 21, 승리비율(Win ratio): 31.3433
# 반복(Epoch): 67, 에러(err): 0.2214, 승리횟수(Win count): 21, 승리비율(Win ratio): 30.8824
# 반복(Epoch): 68, 에러(err): 0.2427, 승리횟수(Win count): 21, 승리비율(Win ratio): 30.4348
# 반복(Epoch): 69, 에러(err): 0.2914, 승리횟수(Win count): 21, 승리비율(Win ratio): 30.0000
# 반복(Epoch): 70, 에러(err): 0.2556, 승리횟수(Win count): 21, 승리비율(Win ratio): 29.5775
# 반복(Epoch): 71, 에러(err): 0.2195, 승리횟수(Win count): 22, 승리비율(Win ratio): 30.5556
# 반복(Epoch): 72, 에러(err): 0.2131, 승리횟수(Win count): 23, 승리비율(Win ratio): 31.5068
# 반복(Epoch): 73, 에러(err): 0.2618, 승리횟수(Win count): 23, 승리비율(Win ratio): 31.0811
# 반복(Epoch): 74, 에러(err): 0.2946, 승리횟수(Win count): 23, 승리비율(Win ratio): 30.6667
# 반복(Epoch): 75, 에러(err): 0.2224, 승리횟수(Win count): 23, 승리비율(Win ratio): 30.2632
# 반복(Epoch): 76, 에러(err): 0.2241, 승리횟수(Win count): 24, 승리비율(Win ratio): 31.1688
# 반복(Epoch): 77, 에러(err): 0.2873, 승리횟수(Win count): 24, 승리비율(Win ratio): 30.7692
# 반복(Epoch): 78, 에러(err): 0.2458, 승리횟수(Win count): 24, 승리비율(Win ratio): 30.3797
# 반복(Epoch): 79, 에러(err): 0.2236, 승리횟수(Win count): 25, 승리비율(Win ratio): 31.2500
# 반복(Epoch): 80, 에러(err): 0.2663, 승리횟수(Win count): 26, 승리비율(Win ratio): 32.0988
# 반복(Epoch): 81, 에러(err): 0.2180, 승리횟수(Win count): 27, 승리비율(Win ratio): 32.9268
# 반복(Epoch): 82, 에러(err): 0.2382, 승리횟수(Win count): 27, 승리비율(Win ratio): 32.5301
# 반복(Epoch): 83, 에러(err): 0.3291, 승리횟수(Win count): 27, 승리비율(Win ratio): 32.1429
# 반복(Epoch): 84, 에러(err): 0.2832, 승리횟수(Win count): 28, 승리비율(Win ratio): 32.9412
# 반복(Epoch): 85, 에러(err): 0.2818, 승리횟수(Win count): 29, 승리비율(Win ratio): 33.7209
# 반복(Epoch): 86, 에러(err): 0.2519, 승리횟수(Win count): 29, 승리비율(Win ratio): 33.3333
# 반복(Epoch): 87, 에러(err): 0.2281, 승리횟수(Win count): 29, 승리비율(Win ratio): 32.9545
# 반복(Epoch): 88, 에러(err): 0.2108, 승리횟수(Win count): 29, 승리비율(Win ratio): 32.5843
# 반복(Epoch): 89, 에러(err): 0.2828, 승리횟수(Win count): 30, 승리비율(Win ratio): 33.3333
# 반복(Epoch): 90, 에러(err): 0.2390, 승리횟수(Win count): 30, 승리비율(Win ratio): 32.9670
# 반복(Epoch): 91, 에러(err): 0.2683, 승리횟수(Win count): 31, 승리비율(Win ratio): 33.6957
# 반복(Epoch): 92, 에러(err): 0.1916, 승리횟수(Win count): 32, 승리비율(Win ratio): 34.4086
# 반복(Epoch): 93, 에러(err): 0.3180, 승리횟수(Win count): 32, 승리비율(Win ratio): 34.0426
# 반복(Epoch): 94, 에러(err): 0.2369, 승리횟수(Win count): 33, 승리비율(Win ratio): 34.7368
# 반복(Epoch): 95, 에러(err): 0.2687, 승리횟수(Win count): 34, 승리비율(Win ratio): 35.4167
# 반복(Epoch): 96, 에러(err): 0.2102, 승리횟수(Win count): 34, 승리비율(Win ratio): 35.0515
# 반복(Epoch): 97, 에러(err): 0.2763, 승리횟수(Win count): 34, 승리비율(Win ratio): 34.6939
# 반복(Epoch): 98, 에러(err): 0.3539, 승리횟수(Win count): 35, 승리비율(Win ratio): 35.3535
# 반복(Epoch): 99, 에러(err): 0.2742, 승리횟수(Win count): 35, 승리비율(Win ratio): 35.0000
# 반복(Epoch): 100, 에러(err): 0.2123, 승리횟수(Win count): 35, 승리비율(Win ratio): 34.6535
# 반복(Epoch): 101, 에러(err): 0.2753, 승리횟수(Win count): 35, 승리비율(Win ratio): 34.3137
# /content/model.ckpt-101 경로에 파라미터가 저장되었습니다
# 반복(Epoch): 102, 에러(err): 0.2121, 승리횟수(Win count): 35, 승리비율(Win ratio): 33.9806
# 반복(Epoch): 103, 에러(err): 0.2625, 승리횟수(Win count): 35, 승리비율(Win ratio): 33.6538
# 반복(Epoch): 104, 에러(err): 0.2299, 승리횟수(Win count): 35, 승리비율(Win ratio): 33.3333
# 반복(Epoch): 105, 에러(err): 0.2847, 승리횟수(Win count): 36, 승리비율(Win ratio): 33.9623
# 반복(Epoch): 106, 에러(err): 0.2041, 승리횟수(Win count): 36, 승리비율(Win ratio): 33.6449
# 반복(Epoch): 107, 에러(err): 0.2492, 승리횟수(Win count): 36, 승리비율(Win ratio): 33.3333
# 반복(Epoch): 108, 에러(err): 0.2488, 승리횟수(Win count): 36, 승리비율(Win ratio): 33.0275
# 반복(Epoch): 109, 에러(err): 0.2158, 승리횟수(Win count): 36, 승리비율(Win ratio): 32.7273
# 반복(Epoch): 110, 에러(err): 0.2092, 승리횟수(Win count): 36, 승리비율(Win ratio): 32.4324
# 반복(Epoch): 111, 에러(err): 0.2789, 승리횟수(Win count): 37, 승리비율(Win ratio): 33.0357
# 반복(Epoch): 112, 에러(err): 0.2626, 승리횟수(Win count): 38, 승리비율(Win ratio): 33.6283
# 반복(Epoch): 113, 에러(err): 0.2343, 승리횟수(Win count): 39, 승리비율(Win ratio): 34.2105
# 반복(Epoch): 114, 에러(err): 0.2944, 승리횟수(Win count): 40, 승리비율(Win ratio): 34.7826
# 반복(Epoch): 115, 에러(err): 0.2230, 승리횟수(Win count): 40, 승리비율(Win ratio): 34.4828
# 반복(Epoch): 116, 에러(err): 0.2346, 승리횟수(Win count): 41, 승리비율(Win ratio): 35.0427
# 반복(Epoch): 117, 에러(err): 0.2953, 승리횟수(Win count): 41, 승리비율(Win ratio): 34.7458
# 반복(Epoch): 118, 에러(err): 0.2258, 승리횟수(Win count): 42, 승리비율(Win ratio): 35.2941
# 반복(Epoch): 119, 에러(err): 0.2512, 승리횟수(Win count): 42, 승리비율(Win ratio): 35.0000
# 반복(Epoch): 120, 에러(err): 0.2277, 승리횟수(Win count): 42, 승리비율(Win ratio): 34.7107
# 반복(Epoch): 121, 에러(err): 0.2332, 승리횟수(Win count): 42, 승리비율(Win ratio): 34.4262
# 반복(Epoch): 122, 에러(err): 0.2113, 승리횟수(Win count): 43, 승리비율(Win ratio): 34.9593
# 반복(Epoch): 123, 에러(err): 0.1863, 승리횟수(Win count): 43, 승리비율(Win ratio): 34.6774
# 반복(Epoch): 124, 에러(err): 0.2644, 승리횟수(Win count): 43, 승리비율(Win ratio): 34.4000
# 반복(Epoch): 125, 에러(err): 0.2813, 승리횟수(Win count): 43, 승리비율(Win ratio): 34.1270
# 반복(Epoch): 126, 에러(err): 0.1873, 승리횟수(Win count): 43, 승리비율(Win ratio): 33.8583
# 반복(Epoch): 127, 에러(err): 0.2343, 승리횟수(Win count): 44, 승리비율(Win ratio): 34.3750
# 반복(Epoch): 128, 에러(err): 0.2059, 승리횟수(Win count): 44, 승리비율(Win ratio): 34.1085
# 반복(Epoch): 129, 에러(err): 0.2968, 승리횟수(Win count): 45, 승리비율(Win ratio): 34.6154
# 반복(Epoch): 130, 에러(err): 0.1976, 승리횟수(Win count): 46, 승리비율(Win ratio): 35.1145
# 반복(Epoch): 131, 에러(err): 0.2873, 승리횟수(Win count): 47, 승리비율(Win ratio): 35.6061
# 반복(Epoch): 132, 에러(err): 0.1999, 승리횟수(Win count): 47, 승리비율(Win ratio): 35.3383
# 반복(Epoch): 133, 에러(err): 0.2067, 승리횟수(Win count): 47, 승리비율(Win ratio): 35.0746
# 반복(Epoch): 134, 에러(err): 0.1883, 승리횟수(Win count): 47, 승리비율(Win ratio): 34.8148
# 반복(Epoch): 135, 에러(err): 0.2984, 승리횟수(Win count): 48, 승리비율(Win ratio): 35.2941
# 반복(Epoch): 136, 에러(err): 0.2090, 승리횟수(Win count): 48, 승리비율(Win ratio): 35.0365
# 반복(Epoch): 137, 에러(err): 0.2700, 승리횟수(Win count): 49, 승리비율(Win ratio): 35.5072
# 반복(Epoch): 138, 에러(err): 0.1956, 승리횟수(Win count): 49, 승리비율(Win ratio): 35.2518
# 반복(Epoch): 139, 에러(err): 0.2470, 승리횟수(Win count): 49, 승리비율(Win ratio): 35.0000
# 반복(Epoch): 140, 에러(err): 0.2379, 승리횟수(Win count): 50, 승리비율(Win ratio): 35.4610
# 반복(Epoch): 141, 에러(err): 0.1982, 승리횟수(Win count): 50, 승리비율(Win ratio): 35.2113
# 반복(Epoch): 142, 에러(err): 0.1458, 승리횟수(Win count): 50, 승리비율(Win ratio): 34.9650
# 반복(Epoch): 143, 에러(err): 0.2511, 승리횟수(Win count): 50, 승리비율(Win ratio): 34.7222
# 반복(Epoch): 144, 에러(err): 0.1946, 승리횟수(Win count): 50, 승리비율(Win ratio): 34.4828
# 반복(Epoch): 145, 에러(err): 0.1962, 승리횟수(Win count): 50, 승리비율(Win ratio): 34.2466
# 반복(Epoch): 146, 에러(err): 0.1856, 승리횟수(Win count): 50, 승리비율(Win ratio): 34.0136
# 반복(Epoch): 147, 에러(err): 0.1955, 승리횟수(Win count): 50, 승리비율(Win ratio): 33.7838
# 반복(Epoch): 148, 에러(err): 0.1759, 승리횟수(Win count): 51, 승리비율(Win ratio): 34.2282
# 반복(Epoch): 149, 에러(err): 0.1658, 승리횟수(Win count): 52, 승리비율(Win ratio): 34.6667
# 반복(Epoch): 150, 에러(err): 0.1945, 승리횟수(Win count): 52, 승리비율(Win ratio): 34.4371
# 반복(Epoch): 151, 에러(err): 0.2992, 승리횟수(Win count): 53, 승리비율(Win ratio): 34.8684
# 반복(Epoch): 152, 에러(err): 0.1583, 승리횟수(Win count): 53, 승리비율(Win ratio): 34.6405
# 반복(Epoch): 153, 에러(err): 0.2152, 승리횟수(Win count): 54, 승리비율(Win ratio): 35.0649
# 반복(Epoch): 154, 에러(err): 0.1299, 승리횟수(Win count): 54, 승리비율(Win ratio): 34.8387
# 반복(Epoch): 155, 에러(err): 0.2072, 승리횟수(Win count): 55, 승리비율(Win ratio): 35.2564
# 반복(Epoch): 156, 에러(err): 0.1514, 승리횟수(Win count): 56, 승리비율(Win ratio): 35.6688
# 반복(Epoch): 157, 에러(err): 0.2170, 승리횟수(Win count): 56, 승리비율(Win ratio): 35.4430
# 반복(Epoch): 158, 에러(err): 0.1739, 승리횟수(Win count): 56, 승리비율(Win ratio): 35.2201
# 반복(Epoch): 159, 에러(err): 0.2038, 승리횟수(Win count): 56, 승리비율(Win ratio): 35.0000
# 반복(Epoch): 160, 에러(err): 0.2076, 승리횟수(Win count): 56, 승리비율(Win ratio): 34.7826
# 반복(Epoch): 161, 에러(err): 0.1957, 승리횟수(Win count): 56, 승리비율(Win ratio): 34.5679
# 반복(Epoch): 162, 에러(err): 0.1551, 승리횟수(Win count): 57, 승리비율(Win ratio): 34.9693
# 반복(Epoch): 163, 에러(err): 0.1446, 승리횟수(Win count): 58, 승리비율(Win ratio): 35.3659
# 반복(Epoch): 164, 에러(err): 0.1672, 승리횟수(Win count): 59, 승리비율(Win ratio): 35.7576
# 반복(Epoch): 165, 에러(err): 0.1661, 승리횟수(Win count): 59, 승리비율(Win ratio): 35.5422
# 반복(Epoch): 166, 에러(err): 0.1830, 승리횟수(Win count): 60, 승리비율(Win ratio): 35.9281
# 반복(Epoch): 167, 에러(err): 0.1476, 승리횟수(Win count): 61, 승리비율(Win ratio): 36.3095
# 반복(Epoch): 168, 에러(err): 0.2033, 승리횟수(Win count): 61, 승리비율(Win ratio): 36.0947
# 반복(Epoch): 169, 에러(err): 0.2128, 승리횟수(Win count): 61, 승리비율(Win ratio): 35.8824
# 반복(Epoch): 170, 에러(err): 0.1367, 승리횟수(Win count): 61, 승리비율(Win ratio): 35.6725
# 반복(Epoch): 171, 에러(err): 0.1697, 승리횟수(Win count): 61, 승리비율(Win ratio): 35.4651
# 반복(Epoch): 172, 에러(err): 0.1282, 승리횟수(Win count): 62, 승리비율(Win ratio): 35.8382
# 반복(Epoch): 173, 에러(err): 0.1650, 승리횟수(Win count): 63, 승리비율(Win ratio): 36.2069
# 반복(Epoch): 174, 에러(err): 0.1706, 승리횟수(Win count): 64, 승리비율(Win ratio): 36.5714
# 반복(Epoch): 175, 에러(err): 0.2161, 승리횟수(Win count): 64, 승리비율(Win ratio): 36.3636
# 반복(Epoch): 176, 에러(err): 0.2192, 승리횟수(Win count): 64, 승리비율(Win ratio): 36.1582
# 반복(Epoch): 177, 에러(err): 0.2242, 승리횟수(Win count): 64, 승리비율(Win ratio): 35.9551
# 반복(Epoch): 178, 에러(err): 0.1555, 승리횟수(Win count): 64, 승리비율(Win ratio): 35.7542
# 반복(Epoch): 179, 에러(err): 0.2423, 승리횟수(Win count): 65, 승리비율(Win ratio): 36.1111
# 반복(Epoch): 180, 에러(err): 0.1684, 승리횟수(Win count): 65, 승리비율(Win ratio): 35.9116
# 반복(Epoch): 181, 에러(err): 0.1471, 승리횟수(Win count): 65, 승리비율(Win ratio): 35.7143
# 반복(Epoch): 182, 에러(err): 0.1271, 승리횟수(Win count): 65, 승리비율(Win ratio): 35.5191
# 반복(Epoch): 183, 에러(err): 0.1180, 승리횟수(Win count): 65, 승리비율(Win ratio): 35.3261
# 반복(Epoch): 184, 에러(err): 0.1433, 승리횟수(Win count): 66, 승리비율(Win ratio): 35.6757
# 반복(Epoch): 185, 에러(err): 0.1347, 승리횟수(Win count): 67, 승리비율(Win ratio): 36.0215
# 반복(Epoch): 186, 에러(err): 0.1490, 승리횟수(Win count): 68, 승리비율(Win ratio): 36.3636
# 반복(Epoch): 187, 에러(err): 0.1143, 승리횟수(Win count): 68, 승리비율(Win ratio): 36.1702
# 반복(Epoch): 188, 에러(err): 0.1693, 승리횟수(Win count): 69, 승리비율(Win ratio): 36.5079
# 반복(Epoch): 189, 에러(err): 0.1313, 승리횟수(Win count): 70, 승리비율(Win ratio): 36.8421
# 반복(Epoch): 190, 에러(err): 0.1687, 승리횟수(Win count): 70, 승리비율(Win ratio): 36.6492
# 반복(Epoch): 191, 에러(err): 0.1123, 승리횟수(Win count): 71, 승리비율(Win ratio): 36.9792
# 반복(Epoch): 192, 에러(err): 0.1019, 승리횟수(Win count): 72, 승리비율(Win ratio): 37.3057
# 반복(Epoch): 193, 에러(err): 0.2032, 승리횟수(Win count): 72, 승리비율(Win ratio): 37.1134
# 반복(Epoch): 194, 에러(err): 0.1989, 승리횟수(Win count): 72, 승리비율(Win ratio): 36.9231
# 반복(Epoch): 195, 에러(err): 0.1850, 승리횟수(Win count): 72, 승리비율(Win ratio): 36.7347
# 반복(Epoch): 196, 에러(err): 0.1351, 승리횟수(Win count): 72, 승리비율(Win ratio): 36.5482
# 반복(Epoch): 197, 에러(err): 0.3111, 승리횟수(Win count): 72, 승리비율(Win ratio): 36.3636
# 반복(Epoch): 198, 에러(err): 0.1530, 승리횟수(Win count): 72, 승리비율(Win ratio): 36.1809
# 반복(Epoch): 199, 에러(err): 0.1880, 승리횟수(Win count): 73, 승리비율(Win ratio): 36.5000
# 반복(Epoch): 200, 에러(err): 0.1247, 승리횟수(Win count): 73, 승리비율(Win ratio): 36.3184
# 반복(Epoch): 201, 에러(err): 0.3266, 승리횟수(Win count): 73, 승리비율(Win ratio): 36.1386
# /content/model.ckpt-201 경로에 파라미터가 저장되었습니다
# 반복(Epoch): 202, 에러(err): 0.2314, 승리횟수(Win count): 74, 승리비율(Win ratio): 36.4532
# 반복(Epoch): 203, 에러(err): 0.2076, 승리횟수(Win count): 75, 승리비율(Win ratio): 36.7647
# 반복(Epoch): 204, 에러(err): 0.2668, 승리횟수(Win count): 76, 승리비율(Win ratio): 37.0732
# 반복(Epoch): 205, 에러(err): 0.1842, 승리횟수(Win count): 77, 승리비율(Win ratio): 37.3786
# 반복(Epoch): 206, 에러(err): 0.2066, 승리횟수(Win count): 77, 승리비율(Win ratio): 37.1981
# 반복(Epoch): 207, 에러(err): 0.1913, 승리횟수(Win count): 78, 승리비율(Win ratio): 37.5000
# 반복(Epoch): 208, 에러(err): 0.2893, 승리횟수(Win count): 78, 승리비율(Win ratio): 37.3206
# 반복(Epoch): 209, 에러(err): 0.1991, 승리횟수(Win count): 78, 승리비율(Win ratio): 37.1429
# 반복(Epoch): 210, 에러(err): 0.2145, 승리횟수(Win count): 78, 승리비율(Win ratio): 36.9668
# 반복(Epoch): 211, 에러(err): 0.2873, 승리횟수(Win count): 79, 승리비율(Win ratio): 37.2642
# 반복(Epoch): 212, 에러(err): 0.2078, 승리횟수(Win count): 80, 승리비율(Win ratio): 37.5587
# 반복(Epoch): 213, 에러(err): 0.3016, 승리횟수(Win count): 80, 승리비율(Win ratio): 37.3832
# 반복(Epoch): 214, 에러(err): 0.2670, 승리횟수(Win count): 80, 승리비율(Win ratio): 37.2093
# 반복(Epoch): 215, 에러(err): 0.1410, 승리횟수(Win count): 81, 승리비율(Win ratio): 37.5000
# 반복(Epoch): 216, 에러(err): 0.2749, 승리횟수(Win count): 81, 승리비율(Win ratio): 37.3272
# 반복(Epoch): 217, 에러(err): 0.1810, 승리횟수(Win count): 82, 승리비율(Win ratio): 37.6147
# 반복(Epoch): 218, 에러(err): 0.1849, 승리횟수(Win count): 83, 승리비율(Win ratio): 37.8995
# 반복(Epoch): 219, 에러(err): 0.2716, 승리횟수(Win count): 84, 승리비율(Win ratio): 38.1818
# 반복(Epoch): 220, 에러(err): 0.2226, 승리횟수(Win count): 84, 승리비율(Win ratio): 38.0090
# 반복(Epoch): 221, 에러(err): 0.1703, 승리횟수(Win count): 84, 승리비율(Win ratio): 37.8378
# 반복(Epoch): 222, 에러(err): 0.2708, 승리횟수(Win count): 85, 승리비율(Win ratio): 38.1166
# 반복(Epoch): 223, 에러(err): 0.1674, 승리횟수(Win count): 85, 승리비율(Win ratio): 37.9464
# 반복(Epoch): 224, 에러(err): 0.2292, 승리횟수(Win count): 85, 승리비율(Win ratio): 37.7778
# 반복(Epoch): 225, 에러(err): 0.1360, 승리횟수(Win count): 86, 승리비율(Win ratio): 38.0531
# 반복(Epoch): 226, 에러(err): 0.1848, 승리횟수(Win count): 87, 승리비율(Win ratio): 38.3260
# 반복(Epoch): 227, 에러(err): 0.2222, 승리횟수(Win count): 87, 승리비율(Win ratio): 38.1579
# 반복(Epoch): 228, 에러(err): 0.2939, 승리횟수(Win count): 87, 승리비율(Win ratio): 37.9913
# 반복(Epoch): 229, 에러(err): 0.0961, 승리횟수(Win count): 88, 승리비율(Win ratio): 38.2609
# 반복(Epoch): 230, 에러(err): 0.2108, 승리횟수(Win count): 89, 승리비율(Win ratio): 38.5281
# 반복(Epoch): 231, 에러(err): 0.1542, 승리횟수(Win count): 90, 승리비율(Win ratio): 38.7931
# 반복(Epoch): 232, 에러(err): 0.1379, 승리횟수(Win count): 91, 승리비율(Win ratio): 39.0558
# 반복(Epoch): 233, 에러(err): 0.1376, 승리횟수(Win count): 92, 승리비율(Win ratio): 39.3162
# 반복(Epoch): 234, 에러(err): 0.2241, 승리횟수(Win count): 92, 승리비율(Win ratio): 39.1489
# 반복(Epoch): 235, 에러(err): 0.2939, 승리횟수(Win count): 92, 승리비율(Win ratio): 38.9831
# 반복(Epoch): 236, 에러(err): 0.1939, 승리횟수(Win count): 93, 승리비율(Win ratio): 39.2405
# 반복(Epoch): 237, 에러(err): 0.1862, 승리횟수(Win count): 94, 승리비율(Win ratio): 39.4958
# 반복(Epoch): 238, 에러(err): 0.1782, 승리횟수(Win count): 95, 승리비율(Win ratio): 39.7490
# 반복(Epoch): 239, 에러(err): 0.1121, 승리횟수(Win count): 95, 승리비율(Win ratio): 39.5833
# 반복(Epoch): 240, 에러(err): 0.2462, 승리횟수(Win count): 96, 승리비율(Win ratio): 39.8340
# 반복(Epoch): 241, 에러(err): 0.0957, 승리횟수(Win count): 97, 승리비율(Win ratio): 40.0826
# 반복(Epoch): 242, 에러(err): 0.1775, 승리횟수(Win count): 97, 승리비율(Win ratio): 39.9177
# 반복(Epoch): 243, 에러(err): 0.1827, 승리횟수(Win count): 98, 승리비율(Win ratio): 40.1639
# 반복(Epoch): 244, 에러(err): 0.1609, 승리횟수(Win count): 99, 승리비율(Win ratio): 40.4082
# 반복(Epoch): 245, 에러(err): 0.1705, 승리횟수(Win count): 99, 승리비율(Win ratio): 40.2439
# 반복(Epoch): 246, 에러(err): 0.1689, 승리횟수(Win count): 99, 승리비율(Win ratio): 40.0810
# 반복(Epoch): 247, 에러(err): 0.1449, 승리횟수(Win count): 100, 승리비율(Win ratio): 40.3226
# 반복(Epoch): 248, 에러(err): 0.1361, 승리횟수(Win count): 101, 승리비율(Win ratio): 40.5622
# 반복(Epoch): 249, 에러(err): 0.1630, 승리횟수(Win count): 102, 승리비율(Win ratio): 40.8000
# 반복(Epoch): 250, 에러(err): 0.0926, 승리횟수(Win count): 103, 승리비율(Win ratio): 41.0359
# 반복(Epoch): 251, 에러(err): 0.0803, 승리횟수(Win count): 104, 승리비율(Win ratio): 41.2698
# 반복(Epoch): 252, 에러(err): 0.2436, 승리횟수(Win count): 105, 승리비율(Win ratio): 41.5020
# 반복(Epoch): 253, 에러(err): 0.1462, 승리횟수(Win count): 105, 승리비율(Win ratio): 41.3386
# 반복(Epoch): 254, 에러(err): 0.0759, 승리횟수(Win count): 105, 승리비율(Win ratio): 41.1765
# 반복(Epoch): 255, 에러(err): 0.1892, 승리횟수(Win count): 105, 승리비율(Win ratio): 41.0156
# 반복(Epoch): 256, 에러(err): 0.1546, 승리횟수(Win count): 106, 승리비율(Win ratio): 41.2451
# 반복(Epoch): 257, 에러(err): 0.1903, 승리횟수(Win count): 107, 승리비율(Win ratio): 41.4729
# 반복(Epoch): 258, 에러(err): 0.1871, 승리횟수(Win count): 108, 승리비율(Win ratio): 41.6988
# 반복(Epoch): 259, 에러(err): 0.1801, 승리횟수(Win count): 109, 승리비율(Win ratio): 41.9231
# 반복(Epoch): 260, 에러(err): 0.2054, 승리횟수(Win count): 110, 승리비율(Win ratio): 42.1456
# 반복(Epoch): 261, 에러(err): 0.1247, 승리횟수(Win count): 111, 승리비율(Win ratio): 42.3664
# 반복(Epoch): 262, 에러(err): 0.1863, 승리횟수(Win count): 111, 승리비율(Win ratio): 42.2053
# 반복(Epoch): 263, 에러(err): 0.1969, 승리횟수(Win count): 111, 승리비율(Win ratio): 42.0455
# 반복(Epoch): 264, 에러(err): 0.4360, 승리횟수(Win count): 112, 승리비율(Win ratio): 42.2642
# 반복(Epoch): 265, 에러(err): 0.2702, 승리횟수(Win count): 113, 승리비율(Win ratio): 42.4812
# 반복(Epoch): 266, 에러(err): 0.2837, 승리횟수(Win count): 114, 승리비율(Win ratio): 42.6966
# 반복(Epoch): 267, 에러(err): 0.1438, 승리횟수(Win count): 115, 승리비율(Win ratio): 42.9104
# 반복(Epoch): 268, 에러(err): 0.1775, 승리횟수(Win count): 116, 승리비율(Win ratio): 43.1227
# 반복(Epoch): 269, 에러(err): 0.3612, 승리횟수(Win count): 117, 승리비율(Win ratio): 43.3333
# 반복(Epoch): 270, 에러(err): 0.2871, 승리횟수(Win count): 118, 승리비율(Win ratio): 43.5424
# 반복(Epoch): 271, 에러(err): 0.1663, 승리횟수(Win count): 118, 승리비율(Win ratio): 43.3824
# 반복(Epoch): 272, 에러(err): 0.1083, 승리횟수(Win count): 119, 승리비율(Win ratio): 43.5897
# 반복(Epoch): 273, 에러(err): 0.3076, 승리횟수(Win count): 120, 승리비율(Win ratio): 43.7956
# 반복(Epoch): 274, 에러(err): 0.1278, 승리횟수(Win count): 120, 승리비율(Win ratio): 43.6364
# 반복(Epoch): 275, 에러(err): 0.1127, 승리횟수(Win count): 121, 승리비율(Win ratio): 43.8406
# 반복(Epoch): 276, 에러(err): 0.2647, 승리횟수(Win count): 122, 승리비율(Win ratio): 44.0433
# 반복(Epoch): 277, 에러(err): 0.2774, 승리횟수(Win count): 123, 승리비율(Win ratio): 44.2446
# 반복(Epoch): 278, 에러(err): 0.2431, 승리횟수(Win count): 124, 승리비율(Win ratio): 44.4444
# 반복(Epoch): 279, 에러(err): 0.1869, 승리횟수(Win count): 125, 승리비율(Win ratio): 44.6429
# 반복(Epoch): 280, 에러(err): 0.2080, 승리횟수(Win count): 126, 승리비율(Win ratio): 44.8399
# 반복(Epoch): 281, 에러(err): 0.1213, 승리횟수(Win count): 126, 승리비율(Win ratio): 44.6809
# 반복(Epoch): 282, 에러(err): 0.2576, 승리횟수(Win count): 127, 승리비율(Win ratio): 44.8763
# 반복(Epoch): 283, 에러(err): 0.2232, 승리횟수(Win count): 128, 승리비율(Win ratio): 45.0704
# 반복(Epoch): 284, 에러(err): 0.1536, 승리횟수(Win count): 129, 승리비율(Win ratio): 45.2632
# 반복(Epoch): 285, 에러(err): 0.2112, 승리횟수(Win count): 130, 승리비율(Win ratio): 45.4545
# 반복(Epoch): 286, 에러(err): 0.2703, 승리횟수(Win count): 131, 승리비율(Win ratio): 45.6446
# 반복(Epoch): 287, 에러(err): 0.1964, 승리횟수(Win count): 132, 승리비율(Win ratio): 45.8333
# 반복(Epoch): 288, 에러(err): 0.1366, 승리횟수(Win count): 132, 승리비율(Win ratio): 45.6747
# 반복(Epoch): 289, 에러(err): 0.0868, 승리횟수(Win count): 133, 승리비율(Win ratio): 45.8621
# 반복(Epoch): 290, 에러(err): 0.1374, 승리횟수(Win count): 134, 승리비율(Win ratio): 46.0481
# 반복(Epoch): 291, 에러(err): 0.2488, 승리횟수(Win count): 134, 승리비율(Win ratio): 45.8904
# 반복(Epoch): 292, 에러(err): 0.1050, 승리횟수(Win count): 135, 승리비율(Win ratio): 46.0751
# 반복(Epoch): 293, 에러(err): 0.1108, 승리횟수(Win count): 136, 승리비율(Win ratio): 46.2585
# 반복(Epoch): 294, 에러(err): 0.2143, 승리횟수(Win count): 137, 승리비율(Win ratio): 46.4407
# 반복(Epoch): 295, 에러(err): 0.2422, 승리횟수(Win count): 138, 승리비율(Win ratio): 46.6216
# 반복(Epoch): 296, 에러(err): 0.0831, 승리횟수(Win count): 139, 승리비율(Win ratio): 46.8013
# 반복(Epoch): 297, 에러(err): 0.0817, 승리횟수(Win count): 140, 승리비율(Win ratio): 46.9799
# 반복(Epoch): 298, 에러(err): 0.1631, 승리횟수(Win count): 141, 승리비율(Win ratio): 47.1572
# 반복(Epoch): 299, 에러(err): 0.1057, 승리횟수(Win count): 142, 승리비율(Win ratio): 47.3333
# 반복(Epoch): 300, 에러(err): 0.1823, 승리횟수(Win count): 142, 승리비율(Win ratio): 47.1761
# 반복(Epoch): 301, 에러(err): 0.1097, 승리횟수(Win count): 143, 승리비율(Win ratio): 47.3510
# /content/model.ckpt-301 경로에 파라미터가 저장되었습니다
# 반복(Epoch): 302, 에러(err): 0.1192, 승리횟수(Win count): 144, 승리비율(Win ratio): 47.5248
# 반복(Epoch): 303, 에러(err): 0.0773, 승리횟수(Win count): 145, 승리비율(Win ratio): 47.6974
# 반복(Epoch): 304, 에러(err): 0.0978, 승리횟수(Win count): 146, 승리비율(Win ratio): 47.8689
# 반복(Epoch): 305, 에러(err): 0.0795, 승리횟수(Win count): 146, 승리비율(Win ratio): 47.7124
# 반복(Epoch): 306, 에러(err): 0.0774, 승리횟수(Win count): 147, 승리비율(Win ratio): 47.8827
# 반복(Epoch): 307, 에러(err): 0.0938, 승리횟수(Win count): 148, 승리비율(Win ratio): 48.0519
# 반복(Epoch): 308, 에러(err): 0.0722, 승리횟수(Win count): 149, 승리비율(Win ratio): 48.2201
# 반복(Epoch): 309, 에러(err): 0.2179, 승리횟수(Win count): 150, 승리비율(Win ratio): 48.3871
# 반복(Epoch): 310, 에러(err): 0.1188, 승리횟수(Win count): 151, 승리비율(Win ratio): 48.5531
# 반복(Epoch): 311, 에러(err): 0.0886, 승리횟수(Win count): 152, 승리비율(Win ratio): 48.7179
# 반복(Epoch): 312, 에러(err): 0.0928, 승리횟수(Win count): 153, 승리비율(Win ratio): 48.8818
# 반복(Epoch): 313, 에러(err): 0.0965, 승리횟수(Win count): 154, 승리비율(Win ratio): 49.0446
# 반복(Epoch): 314, 에러(err): 0.1080, 승리횟수(Win count): 155, 승리비율(Win ratio): 49.2063
# 반복(Epoch): 315, 에러(err): 0.1306, 승리횟수(Win count): 156, 승리비율(Win ratio): 49.3671
# 반복(Epoch): 316, 에러(err): 0.0879, 승리횟수(Win count): 157, 승리비율(Win ratio): 49.5268
# 반복(Epoch): 317, 에러(err): 0.0956, 승리횟수(Win count): 157, 승리비율(Win ratio): 49.3711
# 반복(Epoch): 318, 에러(err): 0.0990, 승리횟수(Win count): 157, 승리비율(Win ratio): 49.2163
# 반복(Epoch): 319, 에러(err): 0.1368, 승리횟수(Win count): 158, 승리비율(Win ratio): 49.3750
# 반복(Epoch): 320, 에러(err): 0.1021, 승리횟수(Win count): 159, 승리비율(Win ratio): 49.5327
# 반복(Epoch): 321, 에러(err): 0.2117, 승리횟수(Win count): 160, 승리비율(Win ratio): 49.6894
# 반복(Epoch): 322, 에러(err): 0.0700, 승리횟수(Win count): 161, 승리비율(Win ratio): 49.8452
# 반복(Epoch): 323, 에러(err): 0.0664, 승리횟수(Win count): 162, 승리비율(Win ratio): 50.0000
# 반복(Epoch): 324, 에러(err): 0.1238, 승리횟수(Win count): 163, 승리비율(Win ratio): 50.1538
# 반복(Epoch): 325, 에러(err): 0.0383, 승리횟수(Win count): 164, 승리비율(Win ratio): 50.3067
# 반복(Epoch): 326, 에러(err): 0.1096, 승리횟수(Win count): 165, 승리비율(Win ratio): 50.4587
# 반복(Epoch): 327, 에러(err): 0.0444, 승리횟수(Win count): 166, 승리비율(Win ratio): 50.6098
# 반복(Epoch): 328, 에러(err): 0.0808, 승리횟수(Win count): 167, 승리비율(Win ratio): 50.7599
# 반복(Epoch): 329, 에러(err): 0.0755, 승리횟수(Win count): 167, 승리비율(Win ratio): 50.6061
# 반복(Epoch): 330, 에러(err): 0.1170, 승리횟수(Win count): 168, 승리비율(Win ratio): 50.7553
# 반복(Epoch): 331, 에러(err): 0.1400, 승리횟수(Win count): 169, 승리비율(Win ratio): 50.9036
# 반복(Epoch): 332, 에러(err): 0.1845, 승리횟수(Win count): 170, 승리비율(Win ratio): 51.0511
# 반복(Epoch): 333, 에러(err): 0.0519, 승리횟수(Win count): 171, 승리비율(Win ratio): 51.1976
# 반복(Epoch): 334, 에러(err): 0.0729, 승리횟수(Win count): 172, 승리비율(Win ratio): 51.3433
# 반복(Epoch): 335, 에러(err): 0.1485, 승리횟수(Win count): 173, 승리비율(Win ratio): 51.4881
# 반복(Epoch): 336, 에러(err): 0.1897, 승리횟수(Win count): 174, 승리비율(Win ratio): 51.6320
# 반복(Epoch): 337, 에러(err): 0.0937, 승리횟수(Win count): 175, 승리비율(Win ratio): 51.7751
# 반복(Epoch): 338, 에러(err): 0.1162, 승리횟수(Win count): 176, 승리비율(Win ratio): 51.9174
# 반복(Epoch): 339, 에러(err): 0.1068, 승리횟수(Win count): 177, 승리비율(Win ratio): 52.0588
# 반복(Epoch): 340, 에러(err): 0.0705, 승리횟수(Win count): 178, 승리비율(Win ratio): 52.1994
# 반복(Epoch): 341, 에러(err): 0.2103, 승리횟수(Win count): 179, 승리비율(Win ratio): 52.3392
# 반복(Epoch): 342, 에러(err): 0.1455, 승리횟수(Win count): 180, 승리비율(Win ratio): 52.4781
# 반복(Epoch): 343, 에러(err): 0.1372, 승리횟수(Win count): 181, 승리비율(Win ratio): 52.6163
# 반복(Epoch): 344, 에러(err): 0.0944, 승리횟수(Win count): 182, 승리비율(Win ratio): 52.7536
# 반복(Epoch): 345, 에러(err): 0.1427, 승리횟수(Win count): 183, 승리비율(Win ratio): 52.8902
# 반복(Epoch): 346, 에러(err): 0.0570, 승리횟수(Win count): 184, 승리비율(Win ratio): 53.0259
# 반복(Epoch): 347, 에러(err): 0.0578, 승리횟수(Win count): 185, 승리비율(Win ratio): 53.1609
# 반복(Epoch): 348, 에러(err): 0.0572, 승리횟수(Win count): 186, 승리비율(Win ratio): 53.2951
# 반복(Epoch): 349, 에러(err): 0.0573, 승리횟수(Win count): 187, 승리비율(Win ratio): 53.4286
# 반복(Epoch): 350, 에러(err): 0.0336, 승리횟수(Win count): 188, 승리비율(Win ratio): 53.5613
# 반복(Epoch): 351, 에러(err): 0.0484, 승리횟수(Win count): 189, 승리비율(Win ratio): 53.6932
# 반복(Epoch): 352, 에러(err): 0.0461, 승리횟수(Win count): 190, 승리비율(Win ratio): 53.8244
# 반복(Epoch): 353, 에러(err): 0.0443, 승리횟수(Win count): 191, 승리비율(Win ratio): 53.9548
# 반복(Epoch): 354, 에러(err): 0.0351, 승리횟수(Win count): 192, 승리비율(Win ratio): 54.0845
# 반복(Epoch): 355, 에러(err): 0.0786, 승리횟수(Win count): 193, 승리비율(Win ratio): 54.2135
# 반복(Epoch): 356, 에러(err): 0.0767, 승리횟수(Win count): 194, 승리비율(Win ratio): 54.3417
# 반복(Epoch): 357, 에러(err): 0.0218, 승리횟수(Win count): 195, 승리비율(Win ratio): 54.4693
# 반복(Epoch): 358, 에러(err): 0.0664, 승리횟수(Win count): 196, 승리비율(Win ratio): 54.5961
# 반복(Epoch): 359, 에러(err): 0.0751, 승리횟수(Win count): 197, 승리비율(Win ratio): 54.7222
# 반복(Epoch): 360, 에러(err): 0.0459, 승리횟수(Win count): 197, 승리비율(Win ratio): 54.5706
# 반복(Epoch): 361, 에러(err): 0.0415, 승리횟수(Win count): 197, 승리비율(Win ratio): 54.4199
# 반복(Epoch): 362, 에러(err): 0.1053, 승리횟수(Win count): 198, 승리비율(Win ratio): 54.5455
# 반복(Epoch): 363, 에러(err): 0.2134, 승리횟수(Win count): 199, 승리비율(Win ratio): 54.6703
# 반복(Epoch): 364, 에러(err): 0.1244, 승리횟수(Win count): 200, 승리비율(Win ratio): 54.7945
# 반복(Epoch): 365, 에러(err): 0.1120, 승리횟수(Win count): 201, 승리비율(Win ratio): 54.9180
# 반복(Epoch): 366, 에러(err): 0.1248, 승리횟수(Win count): 202, 승리비율(Win ratio): 55.0409
# 반복(Epoch): 367, 에러(err): 0.0461, 승리횟수(Win count): 203, 승리비율(Win ratio): 55.1630
# 반복(Epoch): 368, 에러(err): 0.1883, 승리횟수(Win count): 204, 승리비율(Win ratio): 55.2846
# 반복(Epoch): 369, 에러(err): 0.1506, 승리횟수(Win count): 205, 승리비율(Win ratio): 55.4054
# 반복(Epoch): 370, 에러(err): 0.0814, 승리횟수(Win count): 206, 승리비율(Win ratio): 55.5256
# 반복(Epoch): 371, 에러(err): 0.0360, 승리횟수(Win count): 207, 승리비율(Win ratio): 55.6452
# 반복(Epoch): 372, 에러(err): 0.0714, 승리횟수(Win count): 208, 승리비율(Win ratio): 55.7641
# 반복(Epoch): 373, 에러(err): 0.0699, 승리횟수(Win count): 209, 승리비율(Win ratio): 55.8824
# 반복(Epoch): 374, 에러(err): 0.0315, 승리횟수(Win count): 210, 승리비율(Win ratio): 56.0000
# 반복(Epoch): 375, 에러(err): 0.1217, 승리횟수(Win count): 210, 승리비율(Win ratio): 55.8511
# 반복(Epoch): 376, 에러(err): 0.1310, 승리횟수(Win count): 211, 승리비율(Win ratio): 55.9682
# 반복(Epoch): 377, 에러(err): 0.1164, 승리횟수(Win count): 212, 승리비율(Win ratio): 56.0847
# 반복(Epoch): 378, 에러(err): 0.0773, 승리횟수(Win count): 213, 승리비율(Win ratio): 56.2005
# 반복(Epoch): 379, 에러(err): 0.1446, 승리횟수(Win count): 214, 승리비율(Win ratio): 56.3158
# 반복(Epoch): 380, 에러(err): 0.1637, 승리횟수(Win count): 215, 승리비율(Win ratio): 56.4304
# 반복(Epoch): 381, 에러(err): 0.0762, 승리횟수(Win count): 216, 승리비율(Win ratio): 56.5445
# 반복(Epoch): 382, 에러(err): 0.0608, 승리횟수(Win count): 217, 승리비율(Win ratio): 56.6580
# 반복(Epoch): 383, 에러(err): 0.0550, 승리횟수(Win count): 218, 승리비율(Win ratio): 56.7708
# 반복(Epoch): 384, 에러(err): 0.0321, 승리횟수(Win count): 219, 승리비율(Win ratio): 56.8831
# 반복(Epoch): 385, 에러(err): 0.0403, 승리횟수(Win count): 220, 승리비율(Win ratio): 56.9948
# 반복(Epoch): 386, 에러(err): 0.0558, 승리횟수(Win count): 221, 승리비율(Win ratio): 57.1059
# 반복(Epoch): 387, 에러(err): 0.0331, 승리횟수(Win count): 222, 승리비율(Win ratio): 57.2165
# 반복(Epoch): 388, 에러(err): 0.0349, 승리횟수(Win count): 223, 승리비율(Win ratio): 57.3265
# 반복(Epoch): 389, 에러(err): 0.0771, 승리횟수(Win count): 224, 승리비율(Win ratio): 57.4359
# 반복(Epoch): 390, 에러(err): 0.0249, 승리횟수(Win count): 224, 승리비율(Win ratio): 57.2890
# 반복(Epoch): 391, 에러(err): 0.0289, 승리횟수(Win count): 225, 승리비율(Win ratio): 57.3980
# 반복(Epoch): 392, 에러(err): 0.0393, 승리횟수(Win count): 226, 승리비율(Win ratio): 57.5064
# 반복(Epoch): 393, 에러(err): 0.0404, 승리횟수(Win count): 227, 승리비율(Win ratio): 57.6142
# 반복(Epoch): 394, 에러(err): 0.0434, 승리횟수(Win count): 228, 승리비율(Win ratio): 57.7215
# 반복(Epoch): 395, 에러(err): 0.0834, 승리횟수(Win count): 229, 승리비율(Win ratio): 57.8283
# 반복(Epoch): 396, 에러(err): 0.0267, 승리횟수(Win count): 230, 승리비율(Win ratio): 57.9345
# 반복(Epoch): 397, 에러(err): 0.0551, 승리횟수(Win count): 231, 승리비율(Win ratio): 58.0402
# 반복(Epoch): 398, 에러(err): 0.0507, 승리횟수(Win count): 232, 승리비율(Win ratio): 58.1454
# 반복(Epoch): 399, 에러(err): 0.0282, 승리횟수(Win count): 233, 승리비율(Win ratio): 58.2500
# 반복(Epoch): 400, 에러(err): 0.0235, 승리횟수(Win count): 234, 승리비율(Win ratio): 58.3541
# 반복(Epoch): 401, 에러(err): 0.0311, 승리횟수(Win count): 235, 승리비율(Win ratio): 58.4577
# /content/model.ckpt-401 경로에 파라미터가 저장되었습니다
# 반복(Epoch): 402, 에러(err): 0.0363, 승리횟수(Win count): 236, 승리비율(Win ratio): 58.5608
# 반복(Epoch): 403, 에러(err): 0.0631, 승리횟수(Win count): 237, 승리비율(Win ratio): 58.6634
# 반복(Epoch): 404, 에러(err): 0.0335, 승리횟수(Win count): 238, 승리비율(Win ratio): 58.7654
# 반복(Epoch): 405, 에러(err): 0.0477, 승리횟수(Win count): 239, 승리비율(Win ratio): 58.8670
# 반복(Epoch): 406, 에러(err): 0.0320, 승리횟수(Win count): 240, 승리비율(Win ratio): 58.9681
# 반복(Epoch): 407, 에러(err): 0.0170, 승리횟수(Win count): 241, 승리비율(Win ratio): 59.0686
# 반복(Epoch): 408, 에러(err): 0.0397, 승리횟수(Win count): 242, 승리비율(Win ratio): 59.1687
# 반복(Epoch): 409, 에러(err): 0.0203, 승리횟수(Win count): 243, 승리비율(Win ratio): 59.2683
# 반복(Epoch): 410, 에러(err): 0.0123, 승리횟수(Win count): 244, 승리비율(Win ratio): 59.3674
# 반복(Epoch): 411, 에러(err): 0.0118, 승리횟수(Win count): 245, 승리비율(Win ratio): 59.4660
# 반복(Epoch): 412, 에러(err): 0.0281, 승리횟수(Win count): 246, 승리비율(Win ratio): 59.5642
# 반복(Epoch): 413, 에러(err): 0.0182, 승리횟수(Win count): 247, 승리비율(Win ratio): 59.6618
# 반복(Epoch): 414, 에러(err): 0.0166, 승리횟수(Win count): 248, 승리비율(Win ratio): 59.7590
# 반복(Epoch): 415, 에러(err): 0.0171, 승리횟수(Win count): 249, 승리비율(Win ratio): 59.8558
# 반복(Epoch): 416, 에러(err): 0.0118, 승리횟수(Win count): 250, 승리비율(Win ratio): 59.9520
# 반복(Epoch): 417, 에러(err): 0.0182, 승리횟수(Win count): 251, 승리비율(Win ratio): 60.0478
# 반복(Epoch): 418, 에러(err): 0.0102, 승리횟수(Win count): 252, 승리비율(Win ratio): 60.1432
# 반복(Epoch): 419, 에러(err): 0.0103, 승리횟수(Win count): 253, 승리비율(Win ratio): 60.2381
# 반복(Epoch): 420, 에러(err): 0.0120, 승리횟수(Win count): 254, 승리비율(Win ratio): 60.3325
# 반복(Epoch): 421, 에러(err): 0.0094, 승리횟수(Win count): 255, 승리비율(Win ratio): 60.4265
# 반복(Epoch): 422, 에러(err): 0.0146, 승리횟수(Win count): 256, 승리비율(Win ratio): 60.5201
# 반복(Epoch): 423, 에러(err): 0.0389, 승리횟수(Win count): 257, 승리비율(Win ratio): 60.6132
# 반복(Epoch): 424, 에러(err): 0.0087, 승리횟수(Win count): 258, 승리비율(Win ratio): 60.7059
# 반복(Epoch): 425, 에러(err): 0.0086, 승리횟수(Win count): 259, 승리비율(Win ratio): 60.7981
# 반복(Epoch): 426, 에러(err): 0.0078, 승리횟수(Win count): 260, 승리비율(Win ratio): 60.8899
# 반복(Epoch): 427, 에러(err): 0.0057, 승리횟수(Win count): 261, 승리비율(Win ratio): 60.9813
# 반복(Epoch): 428, 에러(err): 0.0072, 승리횟수(Win count): 262, 승리비율(Win ratio): 61.0723
# 반복(Epoch): 429, 에러(err): 0.0064, 승리횟수(Win count): 263, 승리비율(Win ratio): 61.1628
# 반복(Epoch): 430, 에러(err): 0.0211, 승리횟수(Win count): 264, 승리비율(Win ratio): 61.2529
# 반복(Epoch): 431, 에러(err): 0.0116, 승리횟수(Win count): 265, 승리비율(Win ratio): 61.3426
# 반복(Epoch): 432, 에러(err): 0.0112, 승리횟수(Win count): 266, 승리비율(Win ratio): 61.4319
# 반복(Epoch): 433, 에러(err): 0.0101, 승리횟수(Win count): 267, 승리비율(Win ratio): 61.5207
# 반복(Epoch): 434, 에러(err): 0.0068, 승리횟수(Win count): 268, 승리비율(Win ratio): 61.6092
# 반복(Epoch): 435, 에러(err): 0.0106, 승리횟수(Win count): 269, 승리비율(Win ratio): 61.6972
# 반복(Epoch): 436, 에러(err): 0.0128, 승리횟수(Win count): 270, 승리비율(Win ratio): 61.7849
# 반복(Epoch): 437, 에러(err): 0.0163, 승리횟수(Win count): 271, 승리비율(Win ratio): 61.8721
# 반복(Epoch): 438, 에러(err): 0.0226, 승리횟수(Win count): 272, 승리비율(Win ratio): 61.9590
# 반복(Epoch): 439, 에러(err): 0.0098, 승리횟수(Win count): 273, 승리비율(Win ratio): 62.0455
# 반복(Epoch): 440, 에러(err): 0.0088, 승리횟수(Win count): 274, 승리비율(Win ratio): 62.1315
# 반복(Epoch): 441, 에러(err): 0.0153, 승리횟수(Win count): 275, 승리비율(Win ratio): 62.2172
# 반복(Epoch): 442, 에러(err): 0.0122, 승리횟수(Win count): 276, 승리비율(Win ratio): 62.3025
# 반복(Epoch): 443, 에러(err): 0.0125, 승리횟수(Win count): 277, 승리비율(Win ratio): 62.3874
# 반복(Epoch): 444, 에러(err): 0.0085, 승리횟수(Win count): 277, 승리비율(Win ratio): 62.2472
# 반복(Epoch): 445, 에러(err): 0.0110, 승리횟수(Win count): 278, 승리비율(Win ratio): 62.3318
# 반복(Epoch): 446, 에러(err): 0.0285, 승리횟수(Win count): 279, 승리비율(Win ratio): 62.4161
# 반복(Epoch): 447, 에러(err): 0.0266, 승리횟수(Win count): 280, 승리비율(Win ratio): 62.5000
# 반복(Epoch): 448, 에러(err): 0.0103, 승리횟수(Win count): 281, 승리비율(Win ratio): 62.5835
# 반복(Epoch): 449, 에러(err): 0.0143, 승리횟수(Win count): 282, 승리비율(Win ratio): 62.6667
# 반복(Epoch): 450, 에러(err): 0.0075, 승리횟수(Win count): 283, 승리비율(Win ratio): 62.7494
# 반복(Epoch): 451, 에러(err): 0.0068, 승리횟수(Win count): 284, 승리비율(Win ratio): 62.8319
# 반복(Epoch): 452, 에러(err): 0.0059, 승리횟수(Win count): 285, 승리비율(Win ratio): 62.9139
# 반복(Epoch): 453, 에러(err): 0.0060, 승리횟수(Win count): 286, 승리비율(Win ratio): 62.9956
# 반복(Epoch): 454, 에러(err): 0.0087, 승리횟수(Win count): 287, 승리비율(Win ratio): 63.0769
# 반복(Epoch): 455, 에러(err): 0.0083, 승리횟수(Win count): 288, 승리비율(Win ratio): 63.1579
# 반복(Epoch): 456, 에러(err): 0.0059, 승리횟수(Win count): 289, 승리비율(Win ratio): 63.2385
# 반복(Epoch): 457, 에러(err): 0.0039, 승리횟수(Win count): 290, 승리비율(Win ratio): 63.3188
# 반복(Epoch): 458, 에러(err): 0.0122, 승리횟수(Win count): 291, 승리비율(Win ratio): 63.3987
# 반복(Epoch): 459, 에러(err): 0.0129, 승리횟수(Win count): 292, 승리비율(Win ratio): 63.4783
# 반복(Epoch): 460, 에러(err): 0.0076, 승리횟수(Win count): 293, 승리비율(Win ratio): 63.5575
# 반복(Epoch): 461, 에러(err): 0.0221, 승리횟수(Win count): 294, 승리비율(Win ratio): 63.6364
# 반복(Epoch): 462, 에러(err): 0.0104, 승리횟수(Win count): 295, 승리비율(Win ratio): 63.7149
# 반복(Epoch): 463, 에러(err): 0.0136, 승리횟수(Win count): 296, 승리비율(Win ratio): 63.7931
# 반복(Epoch): 464, 에러(err): 0.0076, 승리횟수(Win count): 297, 승리비율(Win ratio): 63.8710
# 반복(Epoch): 465, 에러(err): 0.0118, 승리횟수(Win count): 298, 승리비율(Win ratio): 63.9485
# 반복(Epoch): 466, 에러(err): 0.0135, 승리횟수(Win count): 299, 승리비율(Win ratio): 64.0257
# 반복(Epoch): 467, 에러(err): 0.0090, 승리횟수(Win count): 300, 승리비율(Win ratio): 64.1026
# 반복(Epoch): 468, 에러(err): 0.0077, 승리횟수(Win count): 301, 승리비율(Win ratio): 64.1791
# 반복(Epoch): 469, 에러(err): 0.0056, 승리횟수(Win count): 302, 승리비율(Win ratio): 64.2553
# 반복(Epoch): 470, 에러(err): 0.0064, 승리횟수(Win count): 303, 승리비율(Win ratio): 64.3312
# 반복(Epoch): 471, 에러(err): 0.0051, 승리횟수(Win count): 304, 승리비율(Win ratio): 64.4068
# 반복(Epoch): 472, 에러(err): 0.0040, 승리횟수(Win count): 305, 승리비율(Win ratio): 64.4820
# 반복(Epoch): 473, 에러(err): 0.0046, 승리횟수(Win count): 306, 승리비율(Win ratio): 64.5570
# 반복(Epoch): 474, 에러(err): 0.0045, 승리횟수(Win count): 307, 승리비율(Win ratio): 64.6316
# 반복(Epoch): 475, 에러(err): 0.0068, 승리횟수(Win count): 308, 승리비율(Win ratio): 64.7059
# 반복(Epoch): 476, 에러(err): 0.0032, 승리횟수(Win count): 309, 승리비율(Win ratio): 64.7799
# 반복(Epoch): 477, 에러(err): 0.0069, 승리횟수(Win count): 310, 승리비율(Win ratio): 64.8536
# 반복(Epoch): 478, 에러(err): 0.0035, 승리횟수(Win count): 311, 승리비율(Win ratio): 64.9269
# 반복(Epoch): 479, 에러(err): 0.0086, 승리횟수(Win count): 312, 승리비율(Win ratio): 65.0000
# 반복(Epoch): 480, 에러(err): 0.0106, 승리횟수(Win count): 313, 승리비율(Win ratio): 65.0728
# 반복(Epoch): 481, 에러(err): 0.0067, 승리횟수(Win count): 314, 승리비율(Win ratio): 65.1452
# 반복(Epoch): 482, 에러(err): 0.0071, 승리횟수(Win count): 315, 승리비율(Win ratio): 65.2174
# 반복(Epoch): 483, 에러(err): 0.0055, 승리횟수(Win count): 316, 승리비율(Win ratio): 65.2893
# 반복(Epoch): 484, 에러(err): 0.0061, 승리횟수(Win count): 317, 승리비율(Win ratio): 65.3608
# 반복(Epoch): 485, 에러(err): 0.0039, 승리횟수(Win count): 318, 승리비율(Win ratio): 65.4321
# 반복(Epoch): 486, 에러(err): 0.0062, 승리횟수(Win count): 319, 승리비율(Win ratio): 65.5031
# 반복(Epoch): 487, 에러(err): 0.0182, 승리횟수(Win count): 320, 승리비율(Win ratio): 65.5738
# 반복(Epoch): 488, 에러(err): 0.0064, 승리횟수(Win count): 321, 승리비율(Win ratio): 65.6442
# 반복(Epoch): 489, 에러(err): 0.0094, 승리횟수(Win count): 322, 승리비율(Win ratio): 65.7143
# 반복(Epoch): 490, 에러(err): 0.0074, 승리횟수(Win count): 323, 승리비율(Win ratio): 65.7841
# 반복(Epoch): 491, 에러(err): 0.0110, 승리횟수(Win count): 324, 승리비율(Win ratio): 65.8537
# 반복(Epoch): 492, 에러(err): 0.0096, 승리횟수(Win count): 325, 승리비율(Win ratio): 65.9229
# 반복(Epoch): 493, 에러(err): 0.0073, 승리횟수(Win count): 326, 승리비율(Win ratio): 65.9919
# 반복(Epoch): 494, 에러(err): 0.0043, 승리횟수(Win count): 327, 승리비율(Win ratio): 66.0606
# 반복(Epoch): 495, 에러(err): 0.0055, 승리횟수(Win count): 328, 승리비율(Win ratio): 66.1290
# 반복(Epoch): 496, 에러(err): 0.0079, 승리횟수(Win count): 329, 승리비율(Win ratio): 66.1972
# 반복(Epoch): 497, 에러(err): 0.0106, 승리횟수(Win count): 330, 승리비율(Win ratio): 66.2651
# 반복(Epoch): 498, 에러(err): 0.0071, 승리횟수(Win count): 331, 승리비율(Win ratio): 66.3327
# 반복(Epoch): 499, 에러(err): 0.0073, 승리횟수(Win count): 332, 승리비율(Win ratio): 66.4000
# 반복(Epoch): 500, 에러(err): 0.0037, 승리횟수(Win count): 333, 승리비율(Win ratio): 66.4671
# 트레이닝 완료
# /content/model.ckpt-500 경로에 파라미터가 저장되었습니다

# %%
from Chap_12_Reinforced_Learning_Training import CatchEnvironment, DQN
from IPython import display
import matplotlib.patches as patches
import pylab as pl
import time
import tensorflow as tf
import os

# %%
# 설정값들을 정의합니다.
gridSize = 10
maxGames = 30
DQN_model = DQN()
env = CatchEnvironment(gridSize)
winCount = 0
loseCount = 0
numberOfGames = 0

# %%
# 현재 상태를 그리기 위한 drawState 함수를 정의합니다.
def drawState(fruitRow, fruitColumn, basket, gridSize):
  # 과일이 몇번째 세로축에 있는지 정의합니다.
  fruitX = fruitColumn 
  # 과일이 몇번째 가로축에 있는지 정의합니다.
  fruitY = (gridSize - fruitRow + 1)
  # 승리 횟수, 패배 횟수, 전체 게임 횟수를 화면 상단에 출력합니다.
  statusTitle = "Wins: " + str(winCount) + "  Losses: " + str(loseCount) + "  TotalGame: " + str(numberOfGames)
  axis.set_title(statusTitle, fontsize=30)
  for p in [
    # 배경의 위치를 지정합니다.
    patches.Rectangle(
        ((ground - 1), (ground)), 11, 10,
        facecolor="#000000"      # Black
    ),
    # 바구니의 위치를 지정합니다.
    patches.Rectangle(
        (basket - 1, ground), 2, 0.5,
        facecolor="#FF0000"     # Red
    ),
    # 과일의 위치를 지정합니다.
    patches.Rectangle(
        (fruitX - 0.5, fruitY - 0.5), 1, 1,
        facecolor="#0000FF"       # Blue
    ),   
    ]:
      axis.add_patch(p)
  display.clear_output(wait=True)
  display.display(pl.gcf())

# %%
# 저장된 파라미터를 불러옵니다.
ckpt = tf.train.Checkpoint(model=DQN_model)
latest_ckpt = tf.train.latest_checkpoint(os.getcwd())
#latest_ckpt = '/content/model.ckpt-201'

ckpt.restore(latest_ckpt)

print('저장된 파라미터를 불러왔습니다!')
# Out:
# 저장된 파라미터를 불러왔습니다!

# %%
# GIF를 만들기위해 설치합니다.
# !pip install imageio

# !mkdir '/content/generated_output/'

import glob
import imageio
import matplotlib.pyplot as plt
import PIL

def display_image(epoch_no):
  return PIL.Image.open('/content/generated_output/image_at_epoch_{:04d}.png'.format(epoch_no))
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: imageio in /usr/local/lib/python3.10/dist-packages (2.25.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from imageio) (1.22.4)
# Requirement already satisfied: pillow>=8.3.2 in /usr/local/lib/python3.10/dist-packages (from imageio) (8.4.0)

# %%
# 화면을 그리기 위한 설정들을 정의합니다.
ground = 1
plot = pl.figure(figsize=(12,12))
axis = plot.add_subplot(111, aspect='equal')
axis.set_xlim([-1, 12])
axis.set_ylim([0, 12])

frame = 1

# maxGames 횟수만큼 게임을 플레이합니다.
while (numberOfGames < maxGames):
  numberOfGames = numberOfGames + 1

  # 최초의 상태를 정의합니다.
  isGameOver = False
  fruitRow, fruitColumn, basket = env.reset()
  currentState = env.observe()
  drawState(fruitRow, fruitColumn, basket, gridSize)

  while (isGameOver != True):
    # 현재 상태를 DQN의 입력값으로 넣고 구한 Q값중 가장 큰 Q값을 갖는 행동을 취합니다.
    q = DQN_model(currentState).numpy()
    action = q.argmax()

    # 행동을 취하고 다음 상태로 넘어갑니다.
    nextState, reward, gameOver, stateInfo = env.act(action)    
    fruitRow = stateInfo[0]
    fruitColumn = stateInfo[1]
    basket = stateInfo[2]
     
    # 과일을 받아내면 winCount를 1 늘리고 과일을 받아내지 못하면 loseCount를 1 늘립니다.
    if (reward == 1):
      winCount = winCount + 1
    elif (reward == -1):
      loseCount = loseCount + 1

    currentState = nextState
    isGameOver = gameOver
    drawState(fruitRow, fruitColumn, basket, gridSize)
    # 다음 행동을 취하기 전에 0.05초의 일시정지를 줍니다.
#    time.sleep(5)
    plt.savefig('/content/generated_output/image_at_frame_{:04d}.png'.format(frame))
    frame = frame+1

# 최종 출력결과 이미지를 하나로 정리합니다.
display.clear_output(wait=True)

# %%
anim_file = '/content/generated_output/dcgan.gif'

with imageio.get_writer(anim_file, mode='I') as writer:
  filenames = glob.glob('/content/generated_output/image*.png')
  filenames = sorted(filenames)
  last = -1
  for i,filename in enumerate(filenames):
    frame = 2*(i**0.5)
    if round(frame) > round(last):
      last = frame
    else:
      continue
    image = imageio.imread(filename)
    writer.append_data(image)
  image = imageio.imread(filename)
  writer.append_data(image)

import IPython
if IPython.version_info > (6,2,0,''):
  display.Image(filename=anim_file)
# Out:
# <ipython-input-8-7c43f235b718>:13: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   image = imageio.imread(filename)
# <ipython-input-8-7c43f235b718>:15: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   image = imageio.imread(filename)

# %%
from google.colab import files

files.download(anim_file)
# !zip -r /content/file.zip /content/generated_output
files.download("/content/file.zip")
# Out:
#   adding: content/generated_output/ (stored 0%)
#   adding: content/generated_output/image_at_frame_0178.png (deflated 35%)
#   adding: content/generated_output/image_at_frame_0028.png (deflated 36%)
#   adding: content/generated_output/image_at_frame_0011.png (deflated 37%)
#   adding: content/generated_output/image_at_frame_0086.png (deflated 36%)
#   adding: content/generated_output/image_at_frame_0147.png (deflated 35%)
#   adding: content/generated_output/image_at_frame_0076.png (deflated 35%)
#   adding: content/generated_output/image_at_frame_0220.png (deflated 34%)
#   adding: content/generated_output/image_at_frame_0153.png (deflated 35%)
#   adding: content/generated_output/image_at_frame_0215.png (deflated 35%)
#   adding: content/generated_output/image_at_frame_0206.png (deflated 35%)
#   adding: content/generated_output/image_at_frame_0129.png (deflated 35%)
#   adding: content/generated_output/image_at_frame_0135.png (deflated 35%)
#   adding: content/generated_output/image_at_frame_0044.png (deflated 36%)
#   adding: content/generated_output/image_at_frame_0074.png (deflated 35%)
#   adding: content/generated_output/image_at_frame_0145.png (deflated 35%)
#   adding: content/generated_output/image_at_frame_0042.png (deflated 36%)
#   adding: content/generated_output/image_at_frame_0021.png (deflated 35%)
#   adding: content/generated_output/image_at_frame_0120.png (deflated 35%)
#   adding: content/generated_output/image_at_frame_0184.png (deflated 34%)
#   adding: content/generated_output/image_at_frame_0070.png (deflated 35%)
#   adding: content/generated_output/image_at_frame_0195.png (deflated 35%)
#   adding: content/generated_output/image_at_frame_0080.png (deflated 36%)
#   adding: content/generated_output/image_at_frame_0060.png (deflated 36%)
#   adding: content/generated_output/image_at_frame_0058.png (deflated 36%)
#   adding: content/generated_output/image_at_frame_0018.png (deflated 35%)
#   adding: content/generated_output/image_at_frame_0152.png (deflated 35%)
#   adding: content/generated_output/image_at_frame_0217.png (deflated 34%)
#   adding: content/generated_output/image_at_frame_0087.png (deflated 37%)
#   adding: content/generated_output/image_at_frame_0075.png (deflated 35%)
#   adding: content/generated_output/image_at_frame_0061.png (deflated 35%)
#   adding: content/generated_output/image_at_frame_0073.png (deflated 35%)
#   adding: content/generated_output/image_at_frame_0068.png (deflated 36%)
#   adding: content/generated_output/image_at_frame_0006.png (deflated 37%)
#   adding: content/generated_output/image_at_frame_0171.png (deflated 35%)
#   adding: content/generated_output/image_at_frame_0209.png (deflated 35%)
#   adding: content/generated_output/image_at_frame_0148.png (deflated 35%)
#   adding: content/generated_output/image_at_frame_0179.png (deflated 35%)
#   adding: content/generated_output/image_at_frame_0036.png (deflated 37%)
#   adding: content/generated_output/image_at_frame_0142.png (deflated 36%)
#   adding: content/generated_output/image_at_frame_0233.png (deflated 34%)
#   adding: content/generated_output/image_at_frame_0071.png (deflated 36%)
#   adding: content/generated_output/image_at_frame_0234.png (deflated 34%)
#   adding: content/generated_output/image_at_frame_0201.png (deflated 35%)
#   adding: content/generated_output/image_at_frame_0218.png (deflated 34%)
#   adding: content/generated_output/image_at_frame_0113.png (deflated 35%)
#   adding: content/generated_output/image_at_frame_0043.png (deflated 36%)
#   adding: content/generated_output/image_at_frame_0165.png (deflated 36%)
#   adding: content/generated_output/image_at_frame_0187.png (deflated 35%)
#   adding: content/generated_output/image_at_frame_0065.png (deflated 35%)
#   adding: content/generated_output/image_at_frame_0167.png (deflated 36%)
#   adding: content/generated_output/image_at_frame_0041.png (deflated 36%)
#   adding: content/generated_output/image_at_frame_0008.png (deflated 37%)
#   adding: content/generated_output/image_at_frame_0170.png (deflated 35%)
#   adding: content/generated_output/image_at_frame_0067.png (deflated 35%)
#   adding: content/generated_output/image_at_frame_0123.png (deflated 35%)
#   adding: content/generated_output/image_at_frame_0054.png (deflated 36%)
#   adding: content/generated_output/image_at_frame_0208.png (deflated 34%)
#   adding: content/generated_output/image_at_frame_0193.png (deflated 35%)
#   adding: content/generated_output/image_at_frame_0004.png (deflated 37%)
#   adding: content/generated_output/image_at_frame_0197.png (deflated 35%)
#   adding: content/generated_output/image_at_frame_0185.png (deflated 35%)
#   adding: content/generated_output/image_at_frame_0237.png (deflated 34%)
#   adding: content/generated_output/image_at_frame_0039.png (deflated 36%)
#   adding: content/generated_output/image_at_frame_0057.png (deflated 36%)
#   adding: content/generated_output/image_at_frame_0121.png (deflated 35%)
#   adding: content/generated_output/image_at_frame_0169.png (deflated 35%)
#   adding: content/generated_output/image_at_frame_0204.png (deflated 35%)
#   adding: content/generated_output/image_at_frame_0136.png (deflated 37%)
#   adding: content/generated_output/image_at_frame_0026.png (deflated 36%)
#   adding: content/generated_output/image_at_frame_0002.png (deflated 37%)
#   adding: content/generated_output/image_at_frame_0181.png (deflated 35%)
#   adding: content/generated_output/image_at_frame_0146.png (deflated 35%)
#   adding: content/generated_output/image_at_frame_0072.png (deflated 36%)
#   adding: content/generated_output/image_at_frame_0031.png (deflated 37%)
#   adding: content/generated_output/image_at_frame_0103.png (deflated 36%)
#   adding: content/generated_output/image_at_frame_0007.png (deflated 37%)
#   adding: content/generated_output/image_at_frame_0182.png (deflated 35%)
#   adding: content/generated_output/image_at_frame_0127.png (deflated 35%)
#   adding: content/generated_output/image_at_frame_0192.png (deflated 35%)
#   adding: content/generated_output/image_at_frame_0158.png (deflated 35%)
#   adding: content/generated_output/image_at_frame_0139.png (deflated 36%)
#   adding: content/generated_output/image_at_frame_0022.png (deflated 36%)
#   adding: content/generated_output/image_at_frame_0198.png (deflated 35%)
#   adding: content/generated_output/image_at_frame_0001.png (deflated 37%)
#   adding: content/generated_output/image_at_frame_0180.png (deflated 35%)
#   adding: content/generated_output/image_at_frame_0140.png (deflated 36%)
#   adding: content/generated_output/image_at_frame_0238.png (deflated 34%)
#   adding: content/generated_output/image_at_frame_0035.png (deflated 36%)
#   adding: content/generated_output/image_at_frame_0020.png (deflated 36%)
#   adding: content/generated_output/image_at_frame_0235.png (deflated 34%)
#   adding: content/generated_output/image_at_frame_0186.png (deflated 35%)
#   adding: content/generated_output/image_at_frame_0225.png (deflated 34%)
#   adding: content/generated_output/image_at_frame_0052.png (deflated 36%)
#   adding: content/generated_output/image_at_frame_0232.png (deflated 34%)
#   adding: content/generated_output/image_at_frame_0009.png (deflated 37%)
#   adding: content/generated_output/image_at_frame_0173.png (deflated 35%)
#   adding: content/generated_output/image_at_frame_0005.png (deflated 37%)
#   adding: content/generated_output/image_at_frame_0222.png (deflated 34%)
#   adding: content/generated_output/image_at_frame_0191.png (deflated 34%)
#   adding: content/generated_output/image_at_frame_0046.png (deflated 36%)
#   adding: content/generated_output/image_at_frame_0168.png (deflated 36%)
#   adding: content/generated_output/image_at_frame_0143.png (deflated 36%)
#   adding: content/generated_output/image_at_frame_0161.png (deflated 36%)
#   adding: content/generated_output/image_at_frame_0203.png (deflated 35%)
#   adding: content/generated_output/image_at_frame_0062.png (deflated 36%)
#   adding: content/generated_output/image_at_frame_0130.png (deflated 35%)
#   adding: content/generated_output/image_at_frame_0199.png (deflated 35%)
#   adding: content/generated_output/image_at_frame_0111.png (deflated 36%)
#   adding: content/generated_output/image_at_frame_0188.png (deflated 35%)
#   adding: content/generated_output/image_at_frame_0229.png (deflated 34%)
#   adding: content/generated_output/image_at_frame_0172.png (deflated 35%)
#   adding: content/generated_output/image_at_frame_0112.png (deflated 35%)
#   adding: content/generated_output/image_at_frame_0226.png (deflated 34%)
#   adding: content/generated_output/image_at_frame_0108.png (deflated 35%)
#   adding: content/generated_output/image_at_frame_0174.png (deflated 35%)
#   adding: content/generated_output/image_at_frame_0109.png (deflated 35%)
#   adding: content/generated_output/image_at_frame_0125.png (deflated 35%)
#   adding: content/generated_output/image_at_frame_0083.png (deflated 37%)
#   adding: content/generated_output/image_at_frame_0163.png (deflated 36%)
#   adding: content/generated_output/image_at_frame_0177.png (deflated 35%)
#   adding: content/generated_output/image_at_frame_0107.png (deflated 36%)
#   adding: content/generated_output/image_at_frame_0105.png (deflated 35%)
#   adding: content/generated_output/image_at_frame_0051.png (deflated 37%)
#   adding: content/generated_output/image_at_frame_0189.png (deflated 35%)
#   adding: content/generated_output/image_at_frame_0115.png (deflated 35%)
#   adding: content/generated_output/image_at_frame_0131.png (deflated 35%)
#   adding: content/generated_output/image_at_frame_0091.png (deflated 36%)
#   adding: content/generated_output/image_at_frame_0106.png (deflated 36%)
#   adding: content/generated_output/image_at_frame_0090.png (deflated 36%)
#   adding: content/generated_output/image_at_frame_0104.png (deflated 35%)
#   adding: content/generated_output/image_at_frame_0079.png (deflated 35%)
#   adding: content/generated_output/image_at_frame_0162.png (deflated 36%)
#   adding: content/generated_output/image_at_frame_0141.png (deflated 36%)
#   adding: content/generated_output/image_at_frame_0003.png (deflated 37%)
#   adding: content/generated_output/image_at_frame_0149.png (deflated 35%)
#   adding: content/generated_output/image_at_frame_0034.png (deflated 36%)
#   adding: content/generated_output/image_at_frame_0015.png (deflated 37%)
#   adding: content/generated_output/image_at_frame_0190.png (deflated 34%)
#   adding: content/generated_output/image_at_frame_0144.png (deflated 35%)
#   adding: content/generated_output/image_at_frame_0213.png (deflated 35%)
#   adding: content/generated_output/image_at_frame_0211.png (deflated 35%)
#   adding: content/generated_output/image_at_frame_0124.png (deflated 35%)
#   adding: content/generated_output/image_at_frame_0040.png (deflated 37%)
#   adding: content/generated_output/image_at_frame_0118.png (deflated 36%)
#   adding: content/generated_output/image_at_frame_0095.png (deflated 36%)
#   adding: content/generated_output/image_at_frame_0219.png (deflated 34%)
#   adding: content/generated_output/image_at_frame_0047.png (deflated 36%)
#   adding: content/generated_output/image_at_frame_0037.png (deflated 37%)
#   adding: content/generated_output/image_at_frame_0048.png (deflated 36%)
#   adding: content/generated_output/image_at_frame_0150.png (deflated 35%)
#   adding: content/generated_output/image_at_frame_0023.png (deflated 35%)
#   adding: content/generated_output/image_at_frame_0228.png (deflated 34%)
#   adding: content/generated_output/image_at_frame_0025.png (deflated 36%)
#   adding: content/generated_output/image_at_frame_0159.png (deflated 35%)
#   adding: content/generated_output/image_at_frame_0156.png (deflated 35%)
#   adding: content/generated_output/image_at_frame_0128.png (deflated 34%)
#   adding: content/generated_output/image_at_frame_0133.png (deflated 35%)
#   adding: content/generated_output/image_at_frame_0078.png (deflated 35%)
#   adding: content/generated_output/image_at_frame_0094.png (deflated 35%)
#   adding: content/generated_output/image_at_frame_0212.png (deflated 35%)
#   adding: content/generated_output/image_at_frame_0166.png (deflated 36%)
#   adding: content/generated_output/image_at_frame_0084.png (deflated 36%)
#   adding: content/generated_output/image_at_frame_0081.png (deflated 37%)
#   adding: content/generated_output/image_at_frame_0164.png (deflated 36%)
#   adding: content/generated_output/image_at_frame_0205.png (deflated 35%)
#   adding: content/generated_output/image_at_frame_0045.png (deflated 36%)
#   adding: content/generated_output/image_at_frame_0196.png (deflated 35%)
#   adding: content/generated_output/image_at_frame_0064.png (deflated 36%)
#   adding: content/generated_output/image_at_frame_0066.png (deflated 35%)
#   adding: content/generated_output/image_at_frame_0088.png (deflated 36%)
#   adding: content/generated_output/image_at_frame_0017.png (deflated 35%)
#   adding: content/generated_output/image_at_frame_0085.png (deflated 37%)
#   adding: content/generated_output/image_at_frame_0053.png (deflated 36%)
#   adding: content/generated_output/image_at_frame_0055.png (deflated 36%)
#   adding: content/generated_output/image_at_frame_0014.png (deflated 37%)
#   adding: content/generated_output/image_at_frame_0176.png (deflated 35%)
#   adding: content/generated_output/image_at_frame_0160.png (deflated 35%)
#   adding: content/generated_output/image_at_frame_0114.png (deflated 36%)
#   adding: content/generated_output/image_at_frame_0227.png (deflated 34%)
#   adding: content/generated_output/image_at_frame_0122.png (deflated 35%)
#   adding: content/generated_output/image_at_frame_0240.png (deflated 34%)
#   adding: content/generated_output/image_at_frame_0019.png (deflated 35%)
#   adding: content/generated_output/image_at_frame_0210.png (deflated 35%)
#   adding: content/generated_output/image_at_frame_0093.png (deflated 36%)
#   adding: content/generated_output/image_at_frame_0200.png (deflated 35%)
#   adding: content/generated_output/image_at_frame_0216.png (deflated 35%)
#   adding: content/generated_output/image_at_frame_0056.png (deflated 37%)
#   adding: content/generated_output/image_at_frame_0132.png (deflated 35%)
#   adding: content/generated_output/image_at_frame_0137.png (deflated 36%)
#   adding: content/generated_output/image_at_frame_0110.png (deflated 35%)
#   adding: content/generated_output/image_at_frame_0013.png (deflated 37%)
#   adding: content/generated_output/dcgan.gif (deflated 19%)
#   adding: content/generated_output/image_at_frame_0050.png (deflated 37%)
#   adding: content/generated_output/image_at_frame_0100.png (deflated 36%)
#   adding: content/generated_output/image_at_frame_0221.png (deflated 34%)
#   adding: content/generated_output/image_at_frame_0239.png (deflated 34%)
#   adding: content/generated_output/image_at_frame_0138.png (deflated 36%)
#   adding: content/generated_output/image_at_frame_0214.png (deflated 35%)
#   adding: content/generated_output/image_at_frame_0012.png (deflated 37%)
#   adding: content/generated_output/image_at_frame_0194.png (deflated 35%)
#   adding: content/generated_output/image_at_frame_0098.png (deflated 35%)
#   adding: content/generated_output/image_at_frame_0224.png (deflated 34%)
#   adding: content/generated_output/image_at_frame_0126.png (deflated 35%)
#   adding: content/generated_output/image_at_frame_0154.png (deflated 35%)
#   adding: content/generated_output/image_at_frame_0082.png (deflated 37%)
#   adding: content/generated_output/image_at_frame_0089.png (deflated 36%)
#   adding: content/generated_output/image_at_frame_0223.png (deflated 34%)
#   adding: content/generated_output/image_at_frame_0119.png (deflated 36%)
#   adding: content/generated_output/image_at_frame_0032.png (deflated 36%)
#   adding: content/generated_output/image_at_frame_0099.png (deflated 35%)
#   adding: content/generated_output/image_at_frame_0175.png (deflated 35%)
#   adding: content/generated_output/image_at_frame_0038.png (deflated 36%)
#   adding: content/generated_output/image_at_frame_0059.png (deflated 36%)
#   adding: content/generated_output/image_at_frame_0029.png (deflated 36%)
#   adding: content/generated_output/image_at_frame_0157.png (deflated 35%)
#   adding: content/generated_output/image_at_frame_0097.png (deflated 36%)
#   adding: content/generated_output/image_at_frame_0151.png (deflated 35%)
#   adding: content/generated_output/image_at_frame_0016.png (deflated 36%)
#   adding: content/generated_output/image_at_frame_0117.png (deflated 35%)
#   adding: content/generated_output/image_at_frame_0027.png (deflated 36%)
#   adding: content/generated_output/image_at_frame_0063.png (deflated 36%)
#   adding: content/generated_output/image_at_frame_0116.png (deflated 36%)
#   adding: content/generated_output/image_at_frame_0033.png (deflated 36%)
#   adding: content/generated_output/image_at_frame_0134.png (deflated 35%)
#   adding: content/generated_output/image_at_frame_0207.png (deflated 35%)
#   adding: content/generated_output/image_at_frame_0202.png (deflated 35%)
#   adding: content/generated_output/image_at_frame_0231.png (deflated 34%)
#   adding: content/generated_output/image_at_frame_0102.png (deflated 35%)
#   adding: content/generated_output/image_at_frame_0010.png (deflated 37%)
#   adding: content/generated_output/image_at_frame_0236.png (deflated 34%)
#   adding: content/generated_output/image_at_frame_0101.png (deflated 35%)
#   adding: content/generated_output/image_at_frame_0183.png (deflated 35%)
#   adding: content/generated_output/image_at_frame_0155.png (deflated 35%)
#   adding: content/generated_output/image_at_frame_0230.png (deflated 34%)
#   adding: content/generated_output/image_at_frame_0049.png (deflated 37%)
#   adding: content/generated_output/image_at_frame_0096.png (deflated 35%)
#   adding: content/generated_output/image_at_frame_0030.png (deflated 36%)
#   adding: content/generated_output/image_at_frame_0077.png (deflated 35%)
#   adding: content/generated_output/image_at_frame_0069.png (deflated 35%)
#   adding: content/generated_output/image_at_frame_0092.png (deflated 36%)
#   adding: content/generated_output/image_at_frame_0024.png (deflated 36%)
