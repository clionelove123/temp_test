# %% [markdown]
# <a href="https://colab.research.google.com/github/clionelove123/temp_test/blob/main/Chap_11_GAN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# -*- coding: utf-8 -*-
# GAN(Generative Adversarial Networks)을 이용한 MNIST 데이터 생성 - Keras API를 이용한 구현
# Reference : https://github.com/TengdaHan/GAN-TensorFlow

import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
import os

# %%
# MNIST 데이터를 다운로드 합니다.
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.mnist.load_data()
# 이미지들을 float32 데이터 타입으로 변경합니다.
x_train, x_test = x_train.astype('float32'), x_test.astype('float32')
# 28*28 형태의 이미지를 784차원으로 flattening 합니다.
x_train, x_test = x_train.reshape([-1, 784]), x_test.reshape([-1, 784])
# [0, 255] 사이의 값을 [0, 1]사이의 값으로 Normalize합니다.
x_train, x_test = x_train / 255., x_test / 255.

# 생성된 MNIST 이미지를 8x8 Grid로 보여주는 plot 함수를 정의합니다.
def plot(samples):
  fig = plt.figure(figsize=(8, 8))
  gs = gridspec.GridSpec(8, 8)
  gs.update(wspace=0.05, hspace=0.05)

  for i, sample in enumerate(samples):
    ax = plt.subplot(gs[i])
    plt.axis('off')
    plt.imshow(sample.reshape(28, 28))

  return fig

# 학습에 필요한 설정값들을 선언합니다.
num_epoch = 100000
batch_size = 64
num_input = 28 * 28
num_latent_variable = 100   # 잠재 변수 z의 차원
num_hidden = 128
learning_rate = 0.001
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 [==============================] - 0s 0us/step

# %%
# tf.data API를 이용해서 데이터를 섞고 batch 형태로 가져옵니다.
train_data = tf.data.Dataset.from_tensor_slices(x_train)
train_data = train_data.repeat().shuffle(60000).batch(batch_size)
train_data_iter = iter(train_data)

def random_normal_intializer(stddev):
  return tf.keras.initializers.RandomNormal(mean=0.0, stddev=stddev, seed=None)

# %%
# tf.keras.Model을 이용해서 Generator 모델을 정의합니다.
# Inputs:
#   X : 인풋 Latent Variable
# Outputs:
#   generated_mnist_image : 생성된 MNIST 이미지
class Generator(tf.keras.Model):
  def __init__(self):
    super(Generator, self).__init__()
    # 100 -> 128 -> 784
    # 히든 레이어 파라미터
    self.hidden_layer_1 = tf.keras.layers.Dense(num_hidden,
                                                activation='relu',
                                                kernel_initializer=random_normal_intializer(5e-2),
                                                bias_initializer=tf.keras.initializers.Constant(value=0.1))
    # 아웃풋 레이어 파라미터
    self.output_layer = tf.keras.layers.Dense(num_input,
                                              activation='sigmoid',
                                              kernel_initializer=random_normal_intializer(5e-2),
                                              bias_initializer=tf.keras.initializers.Constant(value=0.1))

  def call(self, x):
    hidden_layer = self.hidden_layer_1(x)
    generated_mnist_image = self.output_layer(hidden_layer)

    return generated_mnist_image

# %%
# tf.keras.Model을 이용해서 Discriminator 모델을 정의합니다.
# Inputs:
#   X : 인풋 이미지
# Outputs:
#   predicted_value : Discriminator가 판단한 True(1) or Fake(0)
#   logits : sigmoid를 씌우기전의 출력값
class Discriminator(tf.keras.Model):
  def __init__(self):
    super(Discriminator, self).__init__()
    # 784 -> 128 -> 1
    # 히든 레이어 파라미터
    self.hidden_layer_1 = tf.keras.layers.Dense(num_hidden,
                                                activation='relu',
                                                kernel_initializer=random_normal_intializer(5e-2),
                                                bias_initializer=tf.keras.initializers.Constant(value=0.1))
    # 아웃풋 레이어 파라미터
    self.output_layer = tf.keras.layers.Dense(1,
                                              activation=None,
                                              kernel_initializer=random_normal_intializer(5e-2),
                                              bias_initializer=tf.keras.initializers.Constant(value=0.1))

  def call(self, x):
    hidden_layer = self.hidden_layer_1(x)
    logits = self.output_layer(hidden_layer)
    predicted_value = tf.nn.sigmoid(logits)

    return predicted_value, logits

# %%
# Generator의 손실 함수를 정의합니다.
@tf.function
def generator_loss(D_fake_logits):
  return tf.reduce_mean(tf.nn.sigmoid_cross_entropy_with_logits(logits=D_fake_logits, labels=tf.ones_like(D_fake_logits)))         # log(D(G(z))

# Discriminator의 손실 함수를 정의합니다.
@tf.function
def discriminator_loss(D_real_logits, D_fake_logits):
  d_loss_real = tf.reduce_mean(tf.nn.sigmoid_cross_entropy_with_logits(logits=D_real_logits, labels=tf.ones_like(D_real_logits)))  # log(D(x))
  d_loss_fake = tf.reduce_mean(tf.nn.sigmoid_cross_entropy_with_logits(logits=D_fake_logits, labels=tf.zeros_like(D_fake_logits)))  # log(1-D(G(z)))
  d_loss = d_loss_real + d_loss_fake  # log(D(x)) + log(1-D(G(z)))

  return d_loss

# %%
# 생성자(Generator) 모델을 선언합니다.
Generator_model = Generator()

# 구분자(Discriminator) 모델을 선언합니다.
Discriminator_model = Discriminator()

# Discriminator와 Generator를 위한 Optimizer들을 정의합니다.
discriminator_optimizer = tf.optimizers.Adam(learning_rate)
generator_optimizer = tf.optimizers.Adam(learning_rate)

# Discriminator 최적화를 위한 function을 정의합니다.
@tf.function
def d_train_step(discriminator_model, real_image, fake_image):
  with tf.GradientTape() as disc_tape:
    D_real, D_real_logits = discriminator_model(real_image)  # D(x)
    D_fake, D_fake_logits = discriminator_model(fake_image)  # D(G(z))
    loss = discriminator_loss(D_real_logits, D_fake_logits)
  gradients = disc_tape.gradient(loss, discriminator_model.trainable_variables)
  discriminator_optimizer.apply_gradients(zip(gradients, discriminator_model.trainable_variables))

# Generator 최적화를 위한 function을 정의합니다.
@tf.function
def g_train_step(generator_model, discriminator_model, z):
  with tf.GradientTape() as gen_tape:
    G = generator_model(z)
    D_fake, D_fake_logits = discriminator_model(G)  # D(G(z))
    loss = generator_loss(D_fake_logits)
  gradients = gen_tape.gradient(loss, generator_model.trainable_variables)
  generator_optimizer.apply_gradients(zip(gradients, generator_model.trainable_variables))

# %%
# 생성된 이미지들을 저장할 generated_output 폴더를 생성합니다.
num_img = 0
if not os.path.exists('generated_output/'):
  os.makedirs('generated_output/')

# num_epoch 횟수만큼 최적화를 수행합니다.
for i in range(num_epoch):
  # MNIST 이미지를 batch_size만큼 불러옵니다.
  batch_X = next(train_data_iter)

  # Latent Variable의 인풋으로 사용할 noise를 Uniform Distribution에서 batch_size 개수만큼 샘플링합니다.
  batch_noise = np.random.uniform(-1., 1., [batch_size, 100]).astype('float32')

  # 500번 반복할때마다 생성된 이미지를 저장합니다.
  if i % 500 == 0:
    samples = Generator_model(np.random.uniform(-1., 1., [64, 100]).astype('float32')).numpy()
    fig = plot(samples)
    plt.savefig('generated_output/%s.png' % str(num_img).zfill(3), bbox_inches='tight')
    num_img += 1
    plt.close(fig)

  # Discriminator 최적화를 수행하고 Discriminator의 손실함수를 return합니다.
  _, d_loss_print = d_train_step(Discriminator_model, batch_X, Generator_model(batch_noise)), discriminator_loss(Discriminator_model(batch_X)[1], Discriminator_model(Generator_model(batch_noise))[1])

  # Generator 최적화를 수행하고 Generator 손실함수를 return합니다.
  _, g_loss_print = g_train_step(Generator_model, Discriminator_model, batch_noise), generator_loss(Discriminator_model(Generator_model(batch_noise))[1])

  # 100번 반복할때마다 Discriminator의 손실함수와 Generator 손실함수를 출력합니다.
  if i % 100 == 0:
    print('반복(Epoch): %d, Generator 손실함수(g_loss): %f, Discriminator 손실함수(d_loss): %f' % (i, g_loss_print, d_loss_print))
# Out:
# 반복(Epoch): 0, Generator 손실함수(g_loss): 1.346558, Discriminator 손실함수(d_loss): 1.038735
# 반복(Epoch): 100, Generator 손실함수(g_loss): 1.861370, Discriminator 손실함수(d_loss): 0.603278
# 반복(Epoch): 200, Generator 손실함수(g_loss): 2.954395, Discriminator 손실함수(d_loss): 0.199885
# 반복(Epoch): 300, Generator 손실함수(g_loss): 4.500752, Discriminator 손실함수(d_loss): 0.018111
# 반복(Epoch): 400, Generator 손실함수(g_loss): 4.379302, Discriminator 손실함수(d_loss): 0.020138
# 반복(Epoch): 500, Generator 손실함수(g_loss): 3.957320, Discriminator 손실함수(d_loss): 0.055520
# 반복(Epoch): 600, Generator 손실함수(g_loss): 5.551964, Discriminator 손실함수(d_loss): 0.007457
# 반복(Epoch): 700, Generator 손실함수(g_loss): 5.742839, Discriminator 손실함수(d_loss): 0.005435
# 반복(Epoch): 800, Generator 손실함수(g_loss): 6.472796, Discriminator 손실함수(d_loss): 0.012303
# 반복(Epoch): 900, Generator 손실함수(g_loss): 5.693531, Discriminator 손실함수(d_loss): 0.008433
# 반복(Epoch): 1000, Generator 손실함수(g_loss): 7.424587, Discriminator 손실함수(d_loss): 0.027113
# 반복(Epoch): 1100, Generator 손실함수(g_loss): 7.786241, Discriminator 손실함수(d_loss): 0.003788
# 반복(Epoch): 1200, Generator 손실함수(g_loss): 6.454037, Discriminator 손실함수(d_loss): 0.011795
# 반복(Epoch): 1300, Generator 손실함수(g_loss): 5.382829, Discriminator 손실함수(d_loss): 0.024303
# 반복(Epoch): 1400, Generator 손실함수(g_loss): 5.558596, Discriminator 손실함수(d_loss): 0.015727
# 반복(Epoch): 1500, Generator 손실함수(g_loss): 5.407050, Discriminator 손실함수(d_loss): 0.043248
# 반복(Epoch): 1600, Generator 손실함수(g_loss): 4.478807, Discriminator 손실함수(d_loss): 0.038208
# 반복(Epoch): 1700, Generator 손실함수(g_loss): 5.838466, Discriminator 손실함수(d_loss): 0.019737
# 반복(Epoch): 1800, Generator 손실함수(g_loss): 4.150563, Discriminator 손실함수(d_loss): 0.022975
# 반복(Epoch): 1900, Generator 손실함수(g_loss): 5.289398, Discriminator 손실함수(d_loss): 0.008386
# 반복(Epoch): 2000, Generator 손실함수(g_loss): 4.843237, Discriminator 손실함수(d_loss): 0.039259
# 반복(Epoch): 2100, Generator 손실함수(g_loss): 4.656426, Discriminator 손실함수(d_loss): 0.054644
# 반복(Epoch): 2200, Generator 손실함수(g_loss): 4.030415, Discriminator 손실함수(d_loss): 0.032027
# 반복(Epoch): 2300, Generator 손실함수(g_loss): 3.609272, Discriminator 손실함수(d_loss): 0.072176
# 반복(Epoch): 2400, Generator 손실함수(g_loss): 3.953616, Discriminator 손실함수(d_loss): 0.081023
# 반복(Epoch): 2500, Generator 손실함수(g_loss): 3.851469, Discriminator 손실함수(d_loss): 0.075074
# 반복(Epoch): 2600, Generator 손실함수(g_loss): 4.297545, Discriminator 손실함수(d_loss): 0.059925
# 반복(Epoch): 2700, Generator 손실함수(g_loss): 3.914394, Discriminator 손실함수(d_loss): 0.075876
# 반복(Epoch): 2800, Generator 손실함수(g_loss): 4.615508, Discriminator 손실함수(d_loss): 0.038910
# 반복(Epoch): 2900, Generator 손실함수(g_loss): 4.533071, Discriminator 손실함수(d_loss): 0.024287
# 반복(Epoch): 3000, Generator 손실함수(g_loss): 4.043452, Discriminator 손실함수(d_loss): 0.104824
# 반복(Epoch): 3100, Generator 손실함수(g_loss): 5.324023, Discriminator 손실함수(d_loss): 0.050128
# 반복(Epoch): 3200, Generator 손실함수(g_loss): 4.399410, Discriminator 손실함수(d_loss): 0.108732
# 반복(Epoch): 3300, Generator 손실함수(g_loss): 4.016629, Discriminator 손실함수(d_loss): 0.170062
# 반복(Epoch): 3400, Generator 손실함수(g_loss): 4.327034, Discriminator 손실함수(d_loss): 0.074312
# 반복(Epoch): 3500, Generator 손실함수(g_loss): 5.176530, Discriminator 손실함수(d_loss): 0.073755
# 반복(Epoch): 3600, Generator 손실함수(g_loss): 4.396399, Discriminator 손실함수(d_loss): 0.064438
# 반복(Epoch): 3700, Generator 손실함수(g_loss): 4.916481, Discriminator 손실함수(d_loss): 0.132197
# 반복(Epoch): 3800, Generator 손실함수(g_loss): 3.498954, Discriminator 손실함수(d_loss): 0.086908
# 반복(Epoch): 3900, Generator 손실함수(g_loss): 4.556223, Discriminator 손실함수(d_loss): 0.086765
# 반복(Epoch): 4000, Generator 손실함수(g_loss): 4.235206, Discriminator 손실함수(d_loss): 0.101600
# 반복(Epoch): 4100, Generator 손실함수(g_loss): 4.065228, Discriminator 손실함수(d_loss): 0.213951
# 반복(Epoch): 4200, Generator 손실함수(g_loss): 4.093986, Discriminator 손실함수(d_loss): 0.193640
# 반복(Epoch): 4300, Generator 손실함수(g_loss): 4.486948, Discriminator 손실함수(d_loss): 0.189363
# 반복(Epoch): 4400, Generator 손실함수(g_loss): 3.787540, Discriminator 손실함수(d_loss): 0.123106
# 반복(Epoch): 4500, Generator 손실함수(g_loss): 4.780861, Discriminator 손실함수(d_loss): 0.161490
# 반복(Epoch): 4600, Generator 손실함수(g_loss): 3.583107, Discriminator 손실함수(d_loss): 0.272428
# 반복(Epoch): 4700, Generator 손실함수(g_loss): 3.655390, Discriminator 손실함수(d_loss): 0.249546
# 반복(Epoch): 4800, Generator 손실함수(g_loss): 4.570264, Discriminator 손실함수(d_loss): 0.234414
# 반복(Epoch): 4900, Generator 손실함수(g_loss): 5.237871, Discriminator 손실함수(d_loss): 0.216694
# 반복(Epoch): 5000, Generator 손실함수(g_loss): 4.303976, Discriminator 손실함수(d_loss): 0.247149
# 반복(Epoch): 5100, Generator 손실함수(g_loss): 4.165698, Discriminator 손실함수(d_loss): 0.250778
# 반복(Epoch): 5200, Generator 손실함수(g_loss): 3.221746, Discriminator 손실함수(d_loss): 0.243397
# 반복(Epoch): 5300, Generator 손실함수(g_loss): 2.976321, Discriminator 손실함수(d_loss): 0.481967
# 반복(Epoch): 5400, Generator 손실함수(g_loss): 2.773522, Discriminator 손실함수(d_loss): 0.322707
# 반복(Epoch): 5500, Generator 손실함수(g_loss): 3.817205, Discriminator 손실함수(d_loss): 0.363526
# 반복(Epoch): 5600, Generator 손실함수(g_loss): 4.146937, Discriminator 손실함수(d_loss): 0.178468
# 반복(Epoch): 5700, Generator 손실함수(g_loss): 4.054697, Discriminator 손실함수(d_loss): 0.474008
# 반복(Epoch): 5800, Generator 손실함수(g_loss): 3.213411, Discriminator 손실함수(d_loss): 0.304148
# 반복(Epoch): 5900, Generator 손실함수(g_loss): 3.717742, Discriminator 손실함수(d_loss): 0.255708
# 반복(Epoch): 6000, Generator 손실함수(g_loss): 3.271686, Discriminator 손실함수(d_loss): 0.320994
# 반복(Epoch): 6100, Generator 손실함수(g_loss): 3.415986, Discriminator 손실함수(d_loss): 0.233005
# 반복(Epoch): 6200, Generator 손실함수(g_loss): 2.920129, Discriminator 손실함수(d_loss): 0.372505
# 반복(Epoch): 6300, Generator 손실함수(g_loss): 4.117963, Discriminator 손실함수(d_loss): 0.526042
# 반복(Epoch): 6400, Generator 손실함수(g_loss): 3.578321, Discriminator 손실함수(d_loss): 0.222942
# 반복(Epoch): 6500, Generator 손실함수(g_loss): 4.245347, Discriminator 손실함수(d_loss): 0.147533
# 반복(Epoch): 6600, Generator 손실함수(g_loss): 3.164286, Discriminator 손실함수(d_loss): 0.518824
# 반복(Epoch): 6700, Generator 손실함수(g_loss): 2.437047, Discriminator 손실함수(d_loss): 0.561650
# 반복(Epoch): 6800, Generator 손실함수(g_loss): 3.113118, Discriminator 손실함수(d_loss): 0.453290
# 반복(Epoch): 6900, Generator 손실함수(g_loss): 2.684449, Discriminator 손실함수(d_loss): 0.410850
# 반복(Epoch): 7000, Generator 손실함수(g_loss): 2.853399, Discriminator 손실함수(d_loss): 0.435099
# 반복(Epoch): 7100, Generator 손실함수(g_loss): 3.885696, Discriminator 손실함수(d_loss): 0.200804
# 반복(Epoch): 7200, Generator 손실함수(g_loss): 2.637904, Discriminator 손실함수(d_loss): 0.506044
# 반복(Epoch): 7300, Generator 손실함수(g_loss): 2.459375, Discriminator 손실함수(d_loss): 0.483718
# 반복(Epoch): 7400, Generator 손실함수(g_loss): 2.711951, Discriminator 손실함수(d_loss): 0.476682
# 반복(Epoch): 7500, Generator 손실함수(g_loss): 2.389466, Discriminator 손실함수(d_loss): 0.568779
# 반복(Epoch): 7600, Generator 손실함수(g_loss): 2.947613, Discriminator 손실함수(d_loss): 0.502182
# 반복(Epoch): 7700, Generator 손실함수(g_loss): 2.454670, Discriminator 손실함수(d_loss): 0.559298
# 반복(Epoch): 7800, Generator 손실함수(g_loss): 2.498016, Discriminator 손실함수(d_loss): 0.314667
# 반복(Epoch): 7900, Generator 손실함수(g_loss): 2.573845, Discriminator 손실함수(d_loss): 0.613762
# 반복(Epoch): 8000, Generator 손실함수(g_loss): 3.663142, Discriminator 손실함수(d_loss): 0.460815
# 반복(Epoch): 8100, Generator 손실함수(g_loss): 3.132073, Discriminator 손실함수(d_loss): 0.480698
# 반복(Epoch): 8200, Generator 손실함수(g_loss): 3.547306, Discriminator 손실함수(d_loss): 0.310969
# 반복(Epoch): 8300, Generator 손실함수(g_loss): 2.793954, Discriminator 손실함수(d_loss): 0.641389
# 반복(Epoch): 8400, Generator 손실함수(g_loss): 3.509943, Discriminator 손실함수(d_loss): 0.749278
# 반복(Epoch): 8500, Generator 손실함수(g_loss): 3.308811, Discriminator 손실함수(d_loss): 0.414530
# 반복(Epoch): 8600, Generator 손실함수(g_loss): 3.168805, Discriminator 손실함수(d_loss): 0.423079
# 반복(Epoch): 8700, Generator 손실함수(g_loss): 3.671292, Discriminator 손실함수(d_loss): 0.361707
# 반복(Epoch): 8800, Generator 손실함수(g_loss): 2.774751, Discriminator 손실함수(d_loss): 0.359494
# 반복(Epoch): 8900, Generator 손실함수(g_loss): 3.009902, Discriminator 손실함수(d_loss): 0.495150
# 반복(Epoch): 9000, Generator 손실함수(g_loss): 2.819814, Discriminator 손실함수(d_loss): 0.610086
# 반복(Epoch): 9100, Generator 손실함수(g_loss): 2.475053, Discriminator 손실함수(d_loss): 0.879185
# 반복(Epoch): 9200, Generator 손실함수(g_loss): 3.970353, Discriminator 손실함수(d_loss): 0.383316
# 반복(Epoch): 9300, Generator 손실함수(g_loss): 2.679745, Discriminator 손실함수(d_loss): 0.499817
# 반복(Epoch): 9400, Generator 손실함수(g_loss): 2.876217, Discriminator 손실함수(d_loss): 0.422561
# 반복(Epoch): 9500, Generator 손실함수(g_loss): 2.872691, Discriminator 손실함수(d_loss): 0.373892
# 반복(Epoch): 9600, Generator 손실함수(g_loss): 2.987130, Discriminator 손실함수(d_loss): 0.420065
# 반복(Epoch): 9700, Generator 손실함수(g_loss): 2.159621, Discriminator 손실함수(d_loss): 0.932793
# 반복(Epoch): 9800, Generator 손실함수(g_loss): 2.632760, Discriminator 손실함수(d_loss): 0.402525
# 반복(Epoch): 9900, Generator 손실함수(g_loss): 2.489100, Discriminator 손실함수(d_loss): 0.668446
# 반복(Epoch): 10000, Generator 손실함수(g_loss): 2.530758, Discriminator 손실함수(d_loss): 0.610994
# 반복(Epoch): 10100, Generator 손실함수(g_loss): 2.260957, Discriminator 손실함수(d_loss): 0.691949
# 반복(Epoch): 10200, Generator 손실함수(g_loss): 1.810109, Discriminator 손실함수(d_loss): 0.815001
# 반복(Epoch): 10300, Generator 손실함수(g_loss): 3.398372, Discriminator 손실함수(d_loss): 0.573723
# 반복(Epoch): 10400, Generator 손실함수(g_loss): 3.378226, Discriminator 손실함수(d_loss): 0.327652
# 반복(Epoch): 10500, Generator 손실함수(g_loss): 2.491126, Discriminator 손실함수(d_loss): 0.416494
# 반복(Epoch): 10600, Generator 손실함수(g_loss): 2.425359, Discriminator 손실함수(d_loss): 0.647439
# 반복(Epoch): 10700, Generator 손실함수(g_loss): 2.973538, Discriminator 손실함수(d_loss): 0.621577
# 반복(Epoch): 10800, Generator 손실함수(g_loss): 2.780356, Discriminator 손실함수(d_loss): 0.564513
# 반복(Epoch): 10900, Generator 손실함수(g_loss): 2.312540, Discriminator 손실함수(d_loss): 0.636662
# 반복(Epoch): 11000, Generator 손실함수(g_loss): 2.409007, Discriminator 손실함수(d_loss): 0.661157
# 반복(Epoch): 11100, Generator 손실함수(g_loss): 2.727647, Discriminator 손실함수(d_loss): 0.510907
# 반복(Epoch): 11200, Generator 손실함수(g_loss): 2.356890, Discriminator 손실함수(d_loss): 0.543807
# 반복(Epoch): 11300, Generator 손실함수(g_loss): 2.820599, Discriminator 손실함수(d_loss): 0.679156
# 반복(Epoch): 11400, Generator 손실함수(g_loss): 2.402077, Discriminator 손실함수(d_loss): 0.649610
# 반복(Epoch): 11500, Generator 손실함수(g_loss): 2.633137, Discriminator 손실함수(d_loss): 0.681330
# 반복(Epoch): 11600, Generator 손실함수(g_loss): 2.569089, Discriminator 손실함수(d_loss): 0.740729
# 반복(Epoch): 11700, Generator 손실함수(g_loss): 2.176417, Discriminator 손실함수(d_loss): 1.086325
# 반복(Epoch): 11800, Generator 손실함수(g_loss): 2.173208, Discriminator 손실함수(d_loss): 0.649010
# 반복(Epoch): 11900, Generator 손실함수(g_loss): 2.288386, Discriminator 손실함수(d_loss): 0.749615
# 반복(Epoch): 12000, Generator 손실함수(g_loss): 2.032546, Discriminator 손실함수(d_loss): 0.924654
# 반복(Epoch): 12100, Generator 손실함수(g_loss): 2.297616, Discriminator 손실함수(d_loss): 0.633501
# 반복(Epoch): 12200, Generator 손실함수(g_loss): 2.423754, Discriminator 손실함수(d_loss): 0.756622
# 반복(Epoch): 12300, Generator 손실함수(g_loss): 2.503290, Discriminator 손실함수(d_loss): 0.409650
# 반복(Epoch): 12400, Generator 손실함수(g_loss): 2.293664, Discriminator 손실함수(d_loss): 0.663152
# 반복(Epoch): 12500, Generator 손실함수(g_loss): 1.824206, Discriminator 손실함수(d_loss): 1.273988
# 반복(Epoch): 12600, Generator 손실함수(g_loss): 2.026494, Discriminator 손실함수(d_loss): 0.475337
# 반복(Epoch): 12700, Generator 손실함수(g_loss): 2.371497, Discriminator 손실함수(d_loss): 0.723186
# 반복(Epoch): 12800, Generator 손실함수(g_loss): 2.217037, Discriminator 손실함수(d_loss): 0.753957
# 반복(Epoch): 12900, Generator 손실함수(g_loss): 2.878201, Discriminator 손실함수(d_loss): 0.627748
# 반복(Epoch): 13000, Generator 손실함수(g_loss): 1.956377, Discriminator 손실함수(d_loss): 0.876121
# 반복(Epoch): 13100, Generator 손실함수(g_loss): 2.440938, Discriminator 손실함수(d_loss): 0.751065
# 반복(Epoch): 13200, Generator 손실함수(g_loss): 1.950920, Discriminator 손실함수(d_loss): 0.742377
# 반복(Epoch): 13300, Generator 손실함수(g_loss): 2.393252, Discriminator 손실함수(d_loss): 0.489585
# 반복(Epoch): 13400, Generator 손실함수(g_loss): 1.882268, Discriminator 손실함수(d_loss): 0.691986
# 반복(Epoch): 13500, Generator 손실함수(g_loss): 2.622393, Discriminator 손실함수(d_loss): 0.576443
# 반복(Epoch): 13600, Generator 손실함수(g_loss): 2.225465, Discriminator 손실함수(d_loss): 0.610544
# 반복(Epoch): 13700, Generator 손실함수(g_loss): 2.221547, Discriminator 손실함수(d_loss): 0.830925
# 반복(Epoch): 13800, Generator 손실함수(g_loss): 1.813620, Discriminator 손실함수(d_loss): 0.529846
# 반복(Epoch): 13900, Generator 손실함수(g_loss): 2.112634, Discriminator 손실함수(d_loss): 0.733980
# 반복(Epoch): 14000, Generator 손실함수(g_loss): 1.968479, Discriminator 손실함수(d_loss): 0.831554
# 반복(Epoch): 14100, Generator 손실함수(g_loss): 2.248194, Discriminator 손실함수(d_loss): 0.624563
# 반복(Epoch): 14200, Generator 손실함수(g_loss): 2.207762, Discriminator 손실함수(d_loss): 0.613947
# 반복(Epoch): 14300, Generator 손실함수(g_loss): 2.244094, Discriminator 손실함수(d_loss): 0.496677
# 반복(Epoch): 14400, Generator 손실함수(g_loss): 2.160330, Discriminator 손실함수(d_loss): 0.707983
# 반복(Epoch): 14500, Generator 손실함수(g_loss): 1.923782, Discriminator 손실함수(d_loss): 0.530313
# 반복(Epoch): 14600, Generator 손실함수(g_loss): 2.224201, Discriminator 손실함수(d_loss): 0.690888
# 반복(Epoch): 14700, Generator 손실함수(g_loss): 2.490623, Discriminator 손실함수(d_loss): 0.564198
# 반복(Epoch): 14800, Generator 손실함수(g_loss): 2.393365, Discriminator 손실함수(d_loss): 0.732773
# 반복(Epoch): 14900, Generator 손실함수(g_loss): 1.969958, Discriminator 손실함수(d_loss): 0.622359
# 반복(Epoch): 15000, Generator 손실함수(g_loss): 2.233154, Discriminator 손실함수(d_loss): 0.688610
# 반복(Epoch): 15100, Generator 손실함수(g_loss): 2.016393, Discriminator 손실함수(d_loss): 0.611902
# 반복(Epoch): 15200, Generator 손실함수(g_loss): 2.058631, Discriminator 손실함수(d_loss): 0.655263
# 반복(Epoch): 15300, Generator 손실함수(g_loss): 1.880308, Discriminator 손실함수(d_loss): 0.801469
# 반복(Epoch): 15400, Generator 손실함수(g_loss): 2.307204, Discriminator 손실함수(d_loss): 0.600309
# 반복(Epoch): 15500, Generator 손실함수(g_loss): 2.426501, Discriminator 손실함수(d_loss): 0.593866
# 반복(Epoch): 15600, Generator 손실함수(g_loss): 2.125948, Discriminator 손실함수(d_loss): 0.811995
# 반복(Epoch): 15700, Generator 손실함수(g_loss): 2.429358, Discriminator 손실함수(d_loss): 0.578382
# 반복(Epoch): 15800, Generator 손실함수(g_loss): 2.134689, Discriminator 손실함수(d_loss): 0.521555
# 반복(Epoch): 15900, Generator 손실함수(g_loss): 2.257839, Discriminator 손실함수(d_loss): 0.721861
# 반복(Epoch): 16000, Generator 손실함수(g_loss): 2.292596, Discriminator 손실함수(d_loss): 0.618762
# 반복(Epoch): 16100, Generator 손실함수(g_loss): 2.140194, Discriminator 손실함수(d_loss): 0.873963
# 반복(Epoch): 16200, Generator 손실함수(g_loss): 2.495703, Discriminator 손실함수(d_loss): 0.789143
# 반복(Epoch): 16300, Generator 손실함수(g_loss): 2.135655, Discriminator 손실함수(d_loss): 0.559369
# 반복(Epoch): 16400, Generator 손실함수(g_loss): 2.035642, Discriminator 손실함수(d_loss): 0.619089
# 반복(Epoch): 16500, Generator 손실함수(g_loss): 2.110292, Discriminator 손실함수(d_loss): 0.760492
# 반복(Epoch): 16600, Generator 손실함수(g_loss): 1.617459, Discriminator 손실함수(d_loss): 0.827168
# 반복(Epoch): 16700, Generator 손실함수(g_loss): 2.067965, Discriminator 손실함수(d_loss): 0.776385
# 반복(Epoch): 16800, Generator 손실함수(g_loss): 1.859024, Discriminator 손실함수(d_loss): 0.791502
# 반복(Epoch): 16900, Generator 손실함수(g_loss): 1.911769, Discriminator 손실함수(d_loss): 1.025550
# 반복(Epoch): 17000, Generator 손실함수(g_loss): 1.797835, Discriminator 손실함수(d_loss): 0.784569
# 반복(Epoch): 17100, Generator 손실함수(g_loss): 2.565407, Discriminator 손실함수(d_loss): 0.609733
# 반복(Epoch): 17200, Generator 손실함수(g_loss): 1.634597, Discriminator 손실함수(d_loss): 0.766909
# 반복(Epoch): 17300, Generator 손실함수(g_loss): 1.846710, Discriminator 손실함수(d_loss): 0.798207
# 반복(Epoch): 17400, Generator 손실함수(g_loss): 2.156676, Discriminator 손실함수(d_loss): 0.735610
# 반복(Epoch): 17500, Generator 손실함수(g_loss): 2.509728, Discriminator 손실함수(d_loss): 0.650809
# 반복(Epoch): 17600, Generator 손실함수(g_loss): 1.515764, Discriminator 손실함수(d_loss): 0.893864
# 반복(Epoch): 17700, Generator 손실함수(g_loss): 1.960733, Discriminator 손실함수(d_loss): 1.012912
# 반복(Epoch): 17800, Generator 손실함수(g_loss): 2.192041, Discriminator 손실함수(d_loss): 0.599208
# 반복(Epoch): 17900, Generator 손실함수(g_loss): 2.012122, Discriminator 손실함수(d_loss): 0.730598
# 반복(Epoch): 18000, Generator 손실함수(g_loss): 2.068145, Discriminator 손실함수(d_loss): 0.622051
# 반복(Epoch): 18100, Generator 손실함수(g_loss): 2.219579, Discriminator 손실함수(d_loss): 0.624581
# 반복(Epoch): 18200, Generator 손실함수(g_loss): 1.885137, Discriminator 손실함수(d_loss): 0.667759
# 반복(Epoch): 18300, Generator 손실함수(g_loss): 1.993788, Discriminator 손실함수(d_loss): 0.626805
# 반복(Epoch): 18400, Generator 손실함수(g_loss): 1.991534, Discriminator 손실함수(d_loss): 0.748186
# 반복(Epoch): 18500, Generator 손실함수(g_loss): 2.321336, Discriminator 손실함수(d_loss): 0.549804
# 반복(Epoch): 18600, Generator 손실함수(g_loss): 2.039540, Discriminator 손실함수(d_loss): 0.697200
# 반복(Epoch): 18700, Generator 손실함수(g_loss): 2.221240, Discriminator 손실함수(d_loss): 0.512458
# 반복(Epoch): 18800, Generator 손실함수(g_loss): 2.200770, Discriminator 손실함수(d_loss): 0.700996
# 반복(Epoch): 18900, Generator 손실함수(g_loss): 2.351782, Discriminator 손실함수(d_loss): 0.722008
# 반복(Epoch): 19000, Generator 손실함수(g_loss): 2.080861, Discriminator 손실함수(d_loss): 0.723505
# 반복(Epoch): 19100, Generator 손실함수(g_loss): 1.560604, Discriminator 손실함수(d_loss): 0.942235
# 반복(Epoch): 19200, Generator 손실함수(g_loss): 1.849597, Discriminator 손실함수(d_loss): 0.601765
# 반복(Epoch): 19300, Generator 손실함수(g_loss): 2.390778, Discriminator 손실함수(d_loss): 0.586758
# 반복(Epoch): 19400, Generator 손실함수(g_loss): 2.034740, Discriminator 손실함수(d_loss): 0.594037
# 반복(Epoch): 19500, Generator 손실함수(g_loss): 1.909500, Discriminator 손실함수(d_loss): 0.685872
# 반복(Epoch): 19600, Generator 손실함수(g_loss): 2.193354, Discriminator 손실함수(d_loss): 0.713867
# 반복(Epoch): 19700, Generator 손실함수(g_loss): 1.673980, Discriminator 손실함수(d_loss): 0.851263
# 반복(Epoch): 19800, Generator 손실함수(g_loss): 2.397125, Discriminator 손실함수(d_loss): 0.782065
# 반복(Epoch): 19900, Generator 손실함수(g_loss): 2.088501, Discriminator 손실함수(d_loss): 0.682595
# 반복(Epoch): 20000, Generator 손실함수(g_loss): 2.087370, Discriminator 손실함수(d_loss): 0.517782
# 반복(Epoch): 20100, Generator 손실함수(g_loss): 1.884578, Discriminator 손실함수(d_loss): 0.963468
# 반복(Epoch): 20200, Generator 손실함수(g_loss): 2.052592, Discriminator 손실함수(d_loss): 0.883038
# 반복(Epoch): 20300, Generator 손실함수(g_loss): 1.620342, Discriminator 손실함수(d_loss): 0.831441
# 반복(Epoch): 20400, Generator 손실함수(g_loss): 1.713852, Discriminator 손실함수(d_loss): 0.830669
# 반복(Epoch): 20500, Generator 손실함수(g_loss): 1.968135, Discriminator 손실함수(d_loss): 0.777637
# 반복(Epoch): 20600, Generator 손실함수(g_loss): 1.685048, Discriminator 손실함수(d_loss): 0.775706
# 반복(Epoch): 20700, Generator 손실함수(g_loss): 1.865125, Discriminator 손실함수(d_loss): 0.792238
# 반복(Epoch): 20800, Generator 손실함수(g_loss): 2.095014, Discriminator 손실함수(d_loss): 0.582477
# 반복(Epoch): 20900, Generator 손실함수(g_loss): 2.078218, Discriminator 손실함수(d_loss): 0.668201
# 반복(Epoch): 21000, Generator 손실함수(g_loss): 1.836809, Discriminator 손실함수(d_loss): 0.789226
# 반복(Epoch): 21100, Generator 손실함수(g_loss): 1.658117, Discriminator 손실함수(d_loss): 0.675973
# 반복(Epoch): 21200, Generator 손실함수(g_loss): 1.552452, Discriminator 손실함수(d_loss): 0.805772
# 반복(Epoch): 21300, Generator 손실함수(g_loss): 1.747533, Discriminator 손실함수(d_loss): 0.700710
# 반복(Epoch): 21400, Generator 손실함수(g_loss): 1.528471, Discriminator 손실함수(d_loss): 0.933616
# 반복(Epoch): 21500, Generator 손실함수(g_loss): 1.672826, Discriminator 손실함수(d_loss): 0.816889
# 반복(Epoch): 21600, Generator 손실함수(g_loss): 2.037079, Discriminator 손실함수(d_loss): 0.761665
# 반복(Epoch): 21700, Generator 손실함수(g_loss): 1.632024, Discriminator 손실함수(d_loss): 0.659282
# 반복(Epoch): 21800, Generator 손실함수(g_loss): 1.896761, Discriminator 손실함수(d_loss): 0.855929
# 반복(Epoch): 21900, Generator 손실함수(g_loss): 1.543793, Discriminator 손실함수(d_loss): 0.894072
# 반복(Epoch): 22000, Generator 손실함수(g_loss): 1.479755, Discriminator 손실함수(d_loss): 0.707329
# 반복(Epoch): 22100, Generator 손실함수(g_loss): 1.473843, Discriminator 손실함수(d_loss): 0.941800
# 반복(Epoch): 22200, Generator 손실함수(g_loss): 2.072639, Discriminator 손실함수(d_loss): 0.538587
# 반복(Epoch): 22300, Generator 손실함수(g_loss): 2.234416, Discriminator 손실함수(d_loss): 0.616413
# 반복(Epoch): 22400, Generator 손실함수(g_loss): 1.802743, Discriminator 손실함수(d_loss): 0.785674
# 반복(Epoch): 22500, Generator 손실함수(g_loss): 1.895632, Discriminator 손실함수(d_loss): 1.001171
# 반복(Epoch): 22600, Generator 손실함수(g_loss): 1.736320, Discriminator 손실함수(d_loss): 0.929942
# 반복(Epoch): 22700, Generator 손실함수(g_loss): 1.832108, Discriminator 손실함수(d_loss): 0.629228
# 반복(Epoch): 22800, Generator 손실함수(g_loss): 1.968933, Discriminator 손실함수(d_loss): 0.645280
# 반복(Epoch): 22900, Generator 손실함수(g_loss): 1.685500, Discriminator 손실함수(d_loss): 0.801531
# 반복(Epoch): 23000, Generator 손실함수(g_loss): 2.257147, Discriminator 손실함수(d_loss): 0.868119
# 반복(Epoch): 23100, Generator 손실함수(g_loss): 2.040603, Discriminator 손실함수(d_loss): 0.795442
# 반복(Epoch): 23200, Generator 손실함수(g_loss): 2.195305, Discriminator 손실함수(d_loss): 0.550930
# 반복(Epoch): 23300, Generator 손실함수(g_loss): 1.635037, Discriminator 손실함수(d_loss): 1.022146
# 반복(Epoch): 23400, Generator 손실함수(g_loss): 2.640893, Discriminator 손실함수(d_loss): 0.617232
# 반복(Epoch): 23500, Generator 손실함수(g_loss): 1.785728, Discriminator 손실함수(d_loss): 0.682157
# 반복(Epoch): 23600, Generator 손실함수(g_loss): 2.070121, Discriminator 손실함수(d_loss): 0.662897
# 반복(Epoch): 23700, Generator 손실함수(g_loss): 1.950292, Discriminator 손실함수(d_loss): 0.739532
# 반복(Epoch): 23800, Generator 손실함수(g_loss): 1.649950, Discriminator 손실함수(d_loss): 1.192707
# 반복(Epoch): 23900, Generator 손실함수(g_loss): 1.895761, Discriminator 손실함수(d_loss): 0.787623
# 반복(Epoch): 24000, Generator 손실함수(g_loss): 1.873843, Discriminator 손실함수(d_loss): 0.904418
# 반복(Epoch): 24100, Generator 손실함수(g_loss): 1.697005, Discriminator 손실함수(d_loss): 0.871761
# 반복(Epoch): 24200, Generator 손실함수(g_loss): 1.748492, Discriminator 손실함수(d_loss): 0.827759
# 반복(Epoch): 24300, Generator 손실함수(g_loss): 1.789885, Discriminator 손실함수(d_loss): 0.651806
# 반복(Epoch): 24400, Generator 손실함수(g_loss): 1.764628, Discriminator 손실함수(d_loss): 0.761370
# 반복(Epoch): 24500, Generator 손실함수(g_loss): 1.677564, Discriminator 손실함수(d_loss): 0.940458
# 반복(Epoch): 24600, Generator 손실함수(g_loss): 1.713477, Discriminator 손실함수(d_loss): 1.096145
# 반복(Epoch): 24700, Generator 손실함수(g_loss): 1.443364, Discriminator 손실함수(d_loss): 0.935004
# 반복(Epoch): 24800, Generator 손실함수(g_loss): 2.058673, Discriminator 손실함수(d_loss): 0.604258
# 반복(Epoch): 24900, Generator 손실함수(g_loss): 1.823884, Discriminator 손실함수(d_loss): 0.788893
# 반복(Epoch): 25000, Generator 손실함수(g_loss): 1.895920, Discriminator 손실함수(d_loss): 0.813883
# 반복(Epoch): 25100, Generator 손실함수(g_loss): 1.901800, Discriminator 손실함수(d_loss): 0.592191
# 반복(Epoch): 25200, Generator 손실함수(g_loss): 1.835671, Discriminator 손실함수(d_loss): 0.726706
# 반복(Epoch): 25300, Generator 손실함수(g_loss): 2.047550, Discriminator 손실함수(d_loss): 0.853947
# 반복(Epoch): 25400, Generator 손실함수(g_loss): 1.791203, Discriminator 손실함수(d_loss): 0.814973
# 반복(Epoch): 25500, Generator 손실함수(g_loss): 1.760432, Discriminator 손실함수(d_loss): 0.801244
# 반복(Epoch): 25600, Generator 손실함수(g_loss): 1.604228, Discriminator 손실함수(d_loss): 0.872567
# 반복(Epoch): 25700, Generator 손실함수(g_loss): 1.769862, Discriminator 손실함수(d_loss): 0.847885
# 반복(Epoch): 25800, Generator 손실함수(g_loss): 1.581551, Discriminator 손실함수(d_loss): 0.896342
# 반복(Epoch): 25900, Generator 손실함수(g_loss): 1.623274, Discriminator 손실함수(d_loss): 1.039099
# 반복(Epoch): 26000, Generator 손실함수(g_loss): 2.181902, Discriminator 손실함수(d_loss): 0.861322
# 반복(Epoch): 26100, Generator 손실함수(g_loss): 1.848796, Discriminator 손실함수(d_loss): 0.775248
# 반복(Epoch): 26200, Generator 손실함수(g_loss): 1.678365, Discriminator 손실함수(d_loss): 0.680086
# 반복(Epoch): 26300, Generator 손실함수(g_loss): 1.744621, Discriminator 손실함수(d_loss): 0.850000
# 반복(Epoch): 26400, Generator 손실함수(g_loss): 1.769732, Discriminator 손실함수(d_loss): 0.801971
# 반복(Epoch): 26500, Generator 손실함수(g_loss): 1.600349, Discriminator 손실함수(d_loss): 0.845847
# 반복(Epoch): 26600, Generator 손실함수(g_loss): 1.628543, Discriminator 손실함수(d_loss): 0.853866
# 반복(Epoch): 26700, Generator 손실함수(g_loss): 1.606228, Discriminator 손실함수(d_loss): 0.789248
# 반복(Epoch): 26800, Generator 손실함수(g_loss): 1.800507, Discriminator 손실함수(d_loss): 0.972914
# 반복(Epoch): 26900, Generator 손실함수(g_loss): 2.068890, Discriminator 손실함수(d_loss): 0.901909
# 반복(Epoch): 27000, Generator 손실함수(g_loss): 1.884523, Discriminator 손실함수(d_loss): 0.662589
# 반복(Epoch): 27100, Generator 손실함수(g_loss): 1.829354, Discriminator 손실함수(d_loss): 0.666720
# 반복(Epoch): 27200, Generator 손실함수(g_loss): 1.993862, Discriminator 손실함수(d_loss): 0.705950
# 반복(Epoch): 27300, Generator 손실함수(g_loss): 1.790326, Discriminator 손실함수(d_loss): 0.733036
# 반복(Epoch): 27400, Generator 손실함수(g_loss): 2.033360, Discriminator 손실함수(d_loss): 0.602677
# 반복(Epoch): 27500, Generator 손실함수(g_loss): 1.605740, Discriminator 손실함수(d_loss): 0.831795
# 반복(Epoch): 27600, Generator 손실함수(g_loss): 1.703606, Discriminator 손실함수(d_loss): 0.864568
# 반복(Epoch): 27700, Generator 손실함수(g_loss): 2.061234, Discriminator 손실함수(d_loss): 0.696337
# 반복(Epoch): 27800, Generator 손실함수(g_loss): 1.924754, Discriminator 손실함수(d_loss): 0.927867
# 반복(Epoch): 27900, Generator 손실함수(g_loss): 1.755436, Discriminator 손실함수(d_loss): 0.816653
# 반복(Epoch): 28000, Generator 손실함수(g_loss): 1.650380, Discriminator 손실함수(d_loss): 0.717118
# 반복(Epoch): 28100, Generator 손실함수(g_loss): 1.743589, Discriminator 손실함수(d_loss): 0.808937
# 반복(Epoch): 28200, Generator 손실함수(g_loss): 2.026038, Discriminator 손실함수(d_loss): 0.612922
# 반복(Epoch): 28300, Generator 손실함수(g_loss): 1.439833, Discriminator 손실함수(d_loss): 0.894978
# 반복(Epoch): 28400, Generator 손실함수(g_loss): 1.629657, Discriminator 손실함수(d_loss): 0.735651
# 반복(Epoch): 28500, Generator 손실함수(g_loss): 1.773203, Discriminator 손실함수(d_loss): 0.932688
# 반복(Epoch): 28600, Generator 손실함수(g_loss): 1.637389, Discriminator 손실함수(d_loss): 0.672860
# 반복(Epoch): 28700, Generator 손실함수(g_loss): 1.799106, Discriminator 손실함수(d_loss): 0.939463
# 반복(Epoch): 28800, Generator 손실함수(g_loss): 1.670923, Discriminator 손실함수(d_loss): 0.775877
# 반복(Epoch): 28900, Generator 손실함수(g_loss): 2.132309, Discriminator 손실함수(d_loss): 0.621612
# 반복(Epoch): 29000, Generator 손실함수(g_loss): 1.846598, Discriminator 손실함수(d_loss): 0.704888
# 반복(Epoch): 29100, Generator 손실함수(g_loss): 1.662555, Discriminator 손실함수(d_loss): 0.829625
# 반복(Epoch): 29200, Generator 손실함수(g_loss): 1.435009, Discriminator 손실함수(d_loss): 0.885813
# 반복(Epoch): 29300, Generator 손실함수(g_loss): 1.756351, Discriminator 손실함수(d_loss): 0.878075
# 반복(Epoch): 29400, Generator 손실함수(g_loss): 1.584057, Discriminator 손실함수(d_loss): 0.692842
# 반복(Epoch): 29500, Generator 손실함수(g_loss): 1.633837, Discriminator 손실함수(d_loss): 0.703543
# 반복(Epoch): 29600, Generator 손실함수(g_loss): 1.933138, Discriminator 손실함수(d_loss): 0.684313
# 반복(Epoch): 29700, Generator 손실함수(g_loss): 1.582473, Discriminator 손실함수(d_loss): 0.813274
# 반복(Epoch): 29800, Generator 손실함수(g_loss): 1.706016, Discriminator 손실함수(d_loss): 0.675472
# 반복(Epoch): 29900, Generator 손실함수(g_loss): 1.681481, Discriminator 손실함수(d_loss): 0.772682
# 반복(Epoch): 30000, Generator 손실함수(g_loss): 1.870703, Discriminator 손실함수(d_loss): 0.692914
# 반복(Epoch): 30100, Generator 손실함수(g_loss): 1.473622, Discriminator 손실함수(d_loss): 0.841404
# 반복(Epoch): 30200, Generator 손실함수(g_loss): 1.831820, Discriminator 손실함수(d_loss): 0.801497
# 반복(Epoch): 30300, Generator 손실함수(g_loss): 1.934184, Discriminator 손실함수(d_loss): 0.687676
# 반복(Epoch): 30400, Generator 손실함수(g_loss): 1.753799, Discriminator 손실함수(d_loss): 0.769551
# 반복(Epoch): 30500, Generator 손실함수(g_loss): 1.707268, Discriminator 손실함수(d_loss): 0.826609
# 반복(Epoch): 30600, Generator 손실함수(g_loss): 1.595193, Discriminator 손실함수(d_loss): 0.776877
# 반복(Epoch): 30700, Generator 손실함수(g_loss): 1.652575, Discriminator 손실함수(d_loss): 0.724087
# 반복(Epoch): 30800, Generator 손실함수(g_loss): 1.655461, Discriminator 손실함수(d_loss): 0.659269
# 반복(Epoch): 30900, Generator 손실함수(g_loss): 1.857030, Discriminator 손실함수(d_loss): 0.734710
# 반복(Epoch): 31000, Generator 손실함수(g_loss): 2.086280, Discriminator 손실함수(d_loss): 0.794294
# 반복(Epoch): 31100, Generator 손실함수(g_loss): 1.837408, Discriminator 손실함수(d_loss): 0.827858
# 반복(Epoch): 31200, Generator 손실함수(g_loss): 1.559430, Discriminator 손실함수(d_loss): 1.024630
# 반복(Epoch): 31300, Generator 손실함수(g_loss): 1.608721, Discriminator 손실함수(d_loss): 0.742050
# 반복(Epoch): 31400, Generator 손실함수(g_loss): 1.715953, Discriminator 손실함수(d_loss): 0.723524
# 반복(Epoch): 31500, Generator 손실함수(g_loss): 1.749473, Discriminator 손실함수(d_loss): 0.788978
# 반복(Epoch): 31600, Generator 손실함수(g_loss): 1.719993, Discriminator 손실함수(d_loss): 0.860340
# 반복(Epoch): 31700, Generator 손실함수(g_loss): 1.670421, Discriminator 손실함수(d_loss): 0.897547
# 반복(Epoch): 31800, Generator 손실함수(g_loss): 1.567866, Discriminator 손실함수(d_loss): 0.766916
# 반복(Epoch): 31900, Generator 손실함수(g_loss): 1.788254, Discriminator 손실함수(d_loss): 0.619807
# 반복(Epoch): 32000, Generator 손실함수(g_loss): 1.644232, Discriminator 손실함수(d_loss): 0.743337
# 반복(Epoch): 32100, Generator 손실함수(g_loss): 1.561950, Discriminator 손실함수(d_loss): 0.770310
# 반복(Epoch): 32200, Generator 손실함수(g_loss): 1.861481, Discriminator 손실함수(d_loss): 0.749045
# 반복(Epoch): 32300, Generator 손실함수(g_loss): 1.817617, Discriminator 손실함수(d_loss): 0.779073
# 반복(Epoch): 32400, Generator 손실함수(g_loss): 1.472977, Discriminator 손실함수(d_loss): 0.841459
# 반복(Epoch): 32500, Generator 손실함수(g_loss): 1.543567, Discriminator 손실함수(d_loss): 0.802476
# 반복(Epoch): 32600, Generator 손실함수(g_loss): 1.671283, Discriminator 손실함수(d_loss): 0.982248
# 반복(Epoch): 32700, Generator 손실함수(g_loss): 1.507292, Discriminator 손실함수(d_loss): 0.920464
# 반복(Epoch): 32800, Generator 손실함수(g_loss): 1.949492, Discriminator 손실함수(d_loss): 0.603290
# 반복(Epoch): 32900, Generator 손실함수(g_loss): 1.576638, Discriminator 손실함수(d_loss): 0.860497
# 반복(Epoch): 33000, Generator 손실함수(g_loss): 1.891496, Discriminator 손실함수(d_loss): 0.733015
# 반복(Epoch): 33100, Generator 손실함수(g_loss): 2.057675, Discriminator 손실함수(d_loss): 0.567114
# 반복(Epoch): 33200, Generator 손실함수(g_loss): 1.714997, Discriminator 손실함수(d_loss): 0.849954
# 반복(Epoch): 33300, Generator 손실함수(g_loss): 1.639591, Discriminator 손실함수(d_loss): 0.817960
# 반복(Epoch): 33400, Generator 손실함수(g_loss): 2.173595, Discriminator 손실함수(d_loss): 0.703757
# 반복(Epoch): 33500, Generator 손실함수(g_loss): 2.025659, Discriminator 손실함수(d_loss): 0.748429
# 반복(Epoch): 33600, Generator 손실함수(g_loss): 1.846820, Discriminator 손실함수(d_loss): 0.682700
# 반복(Epoch): 33700, Generator 손실함수(g_loss): 1.644604, Discriminator 손실함수(d_loss): 0.885184
# 반복(Epoch): 33800, Generator 손실함수(g_loss): 1.895400, Discriminator 손실함수(d_loss): 0.626969
# 반복(Epoch): 33900, Generator 손실함수(g_loss): 1.557677, Discriminator 손실함수(d_loss): 0.919487
# 반복(Epoch): 34000, Generator 손실함수(g_loss): 1.601480, Discriminator 손실함수(d_loss): 0.899967
# 반복(Epoch): 34100, Generator 손실함수(g_loss): 1.636584, Discriminator 손실함수(d_loss): 0.766050
# 반복(Epoch): 34200, Generator 손실함수(g_loss): 1.628675, Discriminator 손실함수(d_loss): 0.810082
# 반복(Epoch): 34300, Generator 손실함수(g_loss): 1.930815, Discriminator 손실함수(d_loss): 0.766446
# 반복(Epoch): 34400, Generator 손실함수(g_loss): 1.805462, Discriminator 손실함수(d_loss): 0.810922
# 반복(Epoch): 34500, Generator 손실함수(g_loss): 1.768126, Discriminator 손실함수(d_loss): 0.587389
# 반복(Epoch): 34600, Generator 손실함수(g_loss): 1.704664, Discriminator 손실함수(d_loss): 0.626828
# 반복(Epoch): 34700, Generator 손실함수(g_loss): 1.868598, Discriminator 손실함수(d_loss): 0.633920
# 반복(Epoch): 34800, Generator 손실함수(g_loss): 1.740810, Discriminator 손실함수(d_loss): 0.910093
# 반복(Epoch): 34900, Generator 손실함수(g_loss): 1.516662, Discriminator 손실함수(d_loss): 0.805961
# 반복(Epoch): 35000, Generator 손실함수(g_loss): 2.013756, Discriminator 손실함수(d_loss): 0.635355
# 반복(Epoch): 35100, Generator 손실함수(g_loss): 1.658638, Discriminator 손실함수(d_loss): 0.880771
# 반복(Epoch): 35200, Generator 손실함수(g_loss): 1.533615, Discriminator 손실함수(d_loss): 0.752338
# 반복(Epoch): 35300, Generator 손실함수(g_loss): 1.771341, Discriminator 손실함수(d_loss): 0.766444
# 반복(Epoch): 35400, Generator 손실함수(g_loss): 1.615099, Discriminator 손실함수(d_loss): 0.871743
# 반복(Epoch): 35500, Generator 손실함수(g_loss): 1.847816, Discriminator 손실함수(d_loss): 0.782157
# 반복(Epoch): 35600, Generator 손실함수(g_loss): 2.013337, Discriminator 손실함수(d_loss): 0.757575
# 반복(Epoch): 35700, Generator 손실함수(g_loss): 1.931193, Discriminator 손실함수(d_loss): 0.768825
# 반복(Epoch): 35800, Generator 손실함수(g_loss): 1.741675, Discriminator 손실함수(d_loss): 0.852332
# 반복(Epoch): 35900, Generator 손실함수(g_loss): 1.616693, Discriminator 손실함수(d_loss): 0.663352
# 반복(Epoch): 36000, Generator 손실함수(g_loss): 1.571612, Discriminator 손실함수(d_loss): 0.732836
# 반복(Epoch): 36100, Generator 손실함수(g_loss): 1.909246, Discriminator 손실함수(d_loss): 0.766017
# 반복(Epoch): 36200, Generator 손실함수(g_loss): 1.514120, Discriminator 손실함수(d_loss): 0.802341
# 반복(Epoch): 36300, Generator 손실함수(g_loss): 2.205306, Discriminator 손실함수(d_loss): 0.731677
# 반복(Epoch): 36400, Generator 손실함수(g_loss): 1.751102, Discriminator 손실함수(d_loss): 0.700135
# 반복(Epoch): 36500, Generator 손실함수(g_loss): 1.746018, Discriminator 손실함수(d_loss): 0.830994
# 반복(Epoch): 36600, Generator 손실함수(g_loss): 1.853843, Discriminator 손실함수(d_loss): 0.724934
# 반복(Epoch): 36700, Generator 손실함수(g_loss): 2.161965, Discriminator 손실함수(d_loss): 0.751996
# 반복(Epoch): 36800, Generator 손실함수(g_loss): 1.855765, Discriminator 손실함수(d_loss): 0.572383
# 반복(Epoch): 36900, Generator 손실함수(g_loss): 1.822881, Discriminator 손실함수(d_loss): 0.788886
# 반복(Epoch): 37000, Generator 손실함수(g_loss): 1.905071, Discriminator 손실함수(d_loss): 0.788630
# 반복(Epoch): 37100, Generator 손실함수(g_loss): 1.838616, Discriminator 손실함수(d_loss): 0.843344
# 반복(Epoch): 37200, Generator 손실함수(g_loss): 1.791821, Discriminator 손실함수(d_loss): 0.792649
# 반복(Epoch): 37300, Generator 손실함수(g_loss): 1.689160, Discriminator 손실함수(d_loss): 0.910049
# 반복(Epoch): 37400, Generator 손실함수(g_loss): 1.940950, Discriminator 손실함수(d_loss): 0.813042
# 반복(Epoch): 37500, Generator 손실함수(g_loss): 1.499463, Discriminator 손실함수(d_loss): 0.759423
# 반복(Epoch): 37600, Generator 손실함수(g_loss): 2.158020, Discriminator 손실함수(d_loss): 0.815923
# 반복(Epoch): 37700, Generator 손실함수(g_loss): 1.765746, Discriminator 손실함수(d_loss): 0.612033
# 반복(Epoch): 37800, Generator 손실함수(g_loss): 1.906748, Discriminator 손실함수(d_loss): 0.824237
# 반복(Epoch): 37900, Generator 손실함수(g_loss): 1.755641, Discriminator 손실함수(d_loss): 0.794087
# 반복(Epoch): 38000, Generator 손실함수(g_loss): 1.836185, Discriminator 손실함수(d_loss): 0.645706
# 반복(Epoch): 38100, Generator 손실함수(g_loss): 1.859644, Discriminator 손실함수(d_loss): 0.619710
# 반복(Epoch): 38200, Generator 손실함수(g_loss): 1.862109, Discriminator 손실함수(d_loss): 0.846841
# 반복(Epoch): 38300, Generator 손실함수(g_loss): 1.613514, Discriminator 손실함수(d_loss): 0.868780
# 반복(Epoch): 38400, Generator 손실함수(g_loss): 1.779051, Discriminator 손실함수(d_loss): 0.757242
# 반복(Epoch): 38500, Generator 손실함수(g_loss): 2.165154, Discriminator 손실함수(d_loss): 0.787203
# 반복(Epoch): 38600, Generator 손실함수(g_loss): 1.797014, Discriminator 손실함수(d_loss): 0.741062
# 반복(Epoch): 38700, Generator 손실함수(g_loss): 1.713088, Discriminator 손실함수(d_loss): 0.782619
# 반복(Epoch): 38800, Generator 손실함수(g_loss): 2.269155, Discriminator 손실함수(d_loss): 0.698711
# 반복(Epoch): 38900, Generator 손실함수(g_loss): 1.764656, Discriminator 손실함수(d_loss): 1.106505
# 반복(Epoch): 39000, Generator 손실함수(g_loss): 2.146250, Discriminator 손실함수(d_loss): 0.602305
# 반복(Epoch): 39100, Generator 손실함수(g_loss): 1.649284, Discriminator 손실함수(d_loss): 0.945033
# 반복(Epoch): 39200, Generator 손실함수(g_loss): 1.693515, Discriminator 손실함수(d_loss): 0.839036
# 반복(Epoch): 39300, Generator 손실함수(g_loss): 1.782854, Discriminator 손실함수(d_loss): 0.839315
# 반복(Epoch): 39400, Generator 손실함수(g_loss): 1.900053, Discriminator 손실함수(d_loss): 0.747803
# 반복(Epoch): 39500, Generator 손실함수(g_loss): 2.022771, Discriminator 손실함수(d_loss): 0.719467
# 반복(Epoch): 39600, Generator 손실함수(g_loss): 1.823801, Discriminator 손실함수(d_loss): 0.828111
# 반복(Epoch): 39700, Generator 손실함수(g_loss): 1.767245, Discriminator 손실함수(d_loss): 0.778919
# 반복(Epoch): 39800, Generator 손실함수(g_loss): 1.740041, Discriminator 손실함수(d_loss): 0.728244
# 반복(Epoch): 39900, Generator 손실함수(g_loss): 1.905697, Discriminator 손실함수(d_loss): 0.694098
# 반복(Epoch): 40000, Generator 손실함수(g_loss): 1.899432, Discriminator 손실함수(d_loss): 0.727273
# 반복(Epoch): 40100, Generator 손실함수(g_loss): 1.725749, Discriminator 손실함수(d_loss): 0.706968
# 반복(Epoch): 40200, Generator 손실함수(g_loss): 1.660418, Discriminator 손실함수(d_loss): 0.913807
# 반복(Epoch): 40300, Generator 손실함수(g_loss): 1.796844, Discriminator 손실함수(d_loss): 0.852494
# 반복(Epoch): 40400, Generator 손실함수(g_loss): 1.951242, Discriminator 손실함수(d_loss): 0.742036
# 반복(Epoch): 40500, Generator 손실함수(g_loss): 1.713509, Discriminator 손실함수(d_loss): 0.907544
# 반복(Epoch): 40600, Generator 손실함수(g_loss): 2.132399, Discriminator 손실함수(d_loss): 0.580088
# 반복(Epoch): 40700, Generator 손실함수(g_loss): 1.723848, Discriminator 손실함수(d_loss): 0.815935
# 반복(Epoch): 40800, Generator 손실함수(g_loss): 1.617514, Discriminator 손실함수(d_loss): 0.878115
# 반복(Epoch): 40900, Generator 손실함수(g_loss): 1.721416, Discriminator 손실함수(d_loss): 0.728350
# 반복(Epoch): 41000, Generator 손실함수(g_loss): 1.627350, Discriminator 손실함수(d_loss): 0.795956
# 반복(Epoch): 41100, Generator 손실함수(g_loss): 1.695053, Discriminator 손실함수(d_loss): 0.771639
# 반복(Epoch): 41200, Generator 손실함수(g_loss): 2.213298, Discriminator 손실함수(d_loss): 0.561807
# 반복(Epoch): 41300, Generator 손실함수(g_loss): 1.765280, Discriminator 손실함수(d_loss): 0.660777
# 반복(Epoch): 41400, Generator 손실함수(g_loss): 1.751415, Discriminator 손실함수(d_loss): 0.773222
# 반복(Epoch): 41500, Generator 손실함수(g_loss): 1.851002, Discriminator 손실함수(d_loss): 0.787134
# 반복(Epoch): 41600, Generator 손실함수(g_loss): 2.001543, Discriminator 손실함수(d_loss): 0.697703
# 반복(Epoch): 41700, Generator 손실함수(g_loss): 1.836443, Discriminator 손실함수(d_loss): 0.758021
# 반복(Epoch): 41800, Generator 손실함수(g_loss): 2.166873, Discriminator 손실함수(d_loss): 0.803993
# 반복(Epoch): 41900, Generator 손실함수(g_loss): 2.026464, Discriminator 손실함수(d_loss): 0.597998
# 반복(Epoch): 42000, Generator 손실함수(g_loss): 1.769827, Discriminator 손실함수(d_loss): 0.805665
# 반복(Epoch): 42100, Generator 손실함수(g_loss): 1.882820, Discriminator 손실함수(d_loss): 0.669921
# 반복(Epoch): 42200, Generator 손실함수(g_loss): 1.931693, Discriminator 손실함수(d_loss): 0.775824
# 반복(Epoch): 42300, Generator 손실함수(g_loss): 1.982754, Discriminator 손실함수(d_loss): 0.717210
# 반복(Epoch): 42400, Generator 손실함수(g_loss): 1.485957, Discriminator 손실함수(d_loss): 0.892703
# 반복(Epoch): 42500, Generator 손실함수(g_loss): 1.818163, Discriminator 손실함수(d_loss): 0.787736
# 반복(Epoch): 42600, Generator 손실함수(g_loss): 1.707897, Discriminator 손실함수(d_loss): 0.981546
# 반복(Epoch): 42700, Generator 손실함수(g_loss): 2.105989, Discriminator 손실함수(d_loss): 0.632689
# 반복(Epoch): 42800, Generator 손실함수(g_loss): 1.808705, Discriminator 손실함수(d_loss): 1.023529
# 반복(Epoch): 42900, Generator 손실함수(g_loss): 1.699830, Discriminator 손실함수(d_loss): 0.862500
# 반복(Epoch): 43000, Generator 손실함수(g_loss): 1.834484, Discriminator 손실함수(d_loss): 0.694653
# 반복(Epoch): 43100, Generator 손실함수(g_loss): 2.251053, Discriminator 손실함수(d_loss): 0.664705
# 반복(Epoch): 43200, Generator 손실함수(g_loss): 1.978062, Discriminator 손실함수(d_loss): 0.686577
# 반복(Epoch): 43300, Generator 손실함수(g_loss): 1.918064, Discriminator 손실함수(d_loss): 0.688843
# 반복(Epoch): 43400, Generator 손실함수(g_loss): 1.845714, Discriminator 손실함수(d_loss): 0.603259
# 반복(Epoch): 43500, Generator 손실함수(g_loss): 1.877202, Discriminator 손실함수(d_loss): 0.829842
# 반복(Epoch): 43600, Generator 손실함수(g_loss): 1.850363, Discriminator 손실함수(d_loss): 0.745579
# 반복(Epoch): 43700, Generator 손실함수(g_loss): 2.079926, Discriminator 손실함수(d_loss): 0.650381
# 반복(Epoch): 43800, Generator 손실함수(g_loss): 2.083898, Discriminator 손실함수(d_loss): 0.740879
# 반복(Epoch): 43900, Generator 손실함수(g_loss): 1.781692, Discriminator 손실함수(d_loss): 0.776371
# 반복(Epoch): 44000, Generator 손실함수(g_loss): 1.881206, Discriminator 손실함수(d_loss): 0.927084
# 반복(Epoch): 44100, Generator 손실함수(g_loss): 1.884509, Discriminator 손실함수(d_loss): 0.764654
# 반복(Epoch): 44200, Generator 손실함수(g_loss): 1.664089, Discriminator 손실함수(d_loss): 0.747575
# 반복(Epoch): 44300, Generator 손실함수(g_loss): 1.668869, Discriminator 손실함수(d_loss): 0.838330
# 반복(Epoch): 44400, Generator 손실함수(g_loss): 2.405447, Discriminator 손실함수(d_loss): 0.491914
# 반복(Epoch): 44500, Generator 손실함수(g_loss): 1.771852, Discriminator 손실함수(d_loss): 0.718883
# 반복(Epoch): 44600, Generator 손실함수(g_loss): 2.203644, Discriminator 손실함수(d_loss): 0.529578
# 반복(Epoch): 44700, Generator 손실함수(g_loss): 1.587541, Discriminator 손실함수(d_loss): 0.744292
# 반복(Epoch): 44800, Generator 손실함수(g_loss): 1.825136, Discriminator 손실함수(d_loss): 0.817148
# 반복(Epoch): 44900, Generator 손실함수(g_loss): 1.933973, Discriminator 손실함수(d_loss): 0.763881
# 반복(Epoch): 45000, Generator 손실함수(g_loss): 2.086047, Discriminator 손실함수(d_loss): 0.894020
# 반복(Epoch): 45100, Generator 손실함수(g_loss): 2.035244, Discriminator 손실함수(d_loss): 0.591602
# 반복(Epoch): 45200, Generator 손실함수(g_loss): 2.079606, Discriminator 손실함수(d_loss): 0.679389
# 반복(Epoch): 45300, Generator 손실함수(g_loss): 1.584661, Discriminator 손실함수(d_loss): 0.915309
# 반복(Epoch): 45400, Generator 손실함수(g_loss): 1.441065, Discriminator 손실함수(d_loss): 0.911195
# 반복(Epoch): 45500, Generator 손실함수(g_loss): 2.092711, Discriminator 손실함수(d_loss): 0.790311
# 반복(Epoch): 45600, Generator 손실함수(g_loss): 1.843520, Discriminator 손실함수(d_loss): 0.736198
# 반복(Epoch): 45700, Generator 손실함수(g_loss): 2.216341, Discriminator 손실함수(d_loss): 0.650260
# 반복(Epoch): 45800, Generator 손실함수(g_loss): 1.985801, Discriminator 손실함수(d_loss): 0.712560
# 반복(Epoch): 45900, Generator 손실함수(g_loss): 2.241087, Discriminator 손실함수(d_loss): 0.703870
# 반복(Epoch): 46000, Generator 손실함수(g_loss): 1.809030, Discriminator 손실함수(d_loss): 0.691747
# 반복(Epoch): 46100, Generator 손실함수(g_loss): 1.901404, Discriminator 손실함수(d_loss): 0.686030
# 반복(Epoch): 46200, Generator 손실함수(g_loss): 2.127923, Discriminator 손실함수(d_loss): 0.740690
# 반복(Epoch): 46300, Generator 손실함수(g_loss): 1.709279, Discriminator 손실함수(d_loss): 0.879945
# 반복(Epoch): 46400, Generator 손실함수(g_loss): 1.712000, Discriminator 손실함수(d_loss): 0.754827
# 반복(Epoch): 46500, Generator 손실함수(g_loss): 1.817300, Discriminator 손실함수(d_loss): 0.709885
# 반복(Epoch): 46600, Generator 손실함수(g_loss): 2.226805, Discriminator 손실함수(d_loss): 0.814757
# 반복(Epoch): 46700, Generator 손실함수(g_loss): 1.748213, Discriminator 손실함수(d_loss): 0.750921
# 반복(Epoch): 46800, Generator 손실함수(g_loss): 1.879249, Discriminator 손실함수(d_loss): 0.733937
# 반복(Epoch): 46900, Generator 손실함수(g_loss): 1.879482, Discriminator 손실함수(d_loss): 0.748445
# 반복(Epoch): 47000, Generator 손실함수(g_loss): 2.075025, Discriminator 손실함수(d_loss): 0.588069
# 반복(Epoch): 47100, Generator 손실함수(g_loss): 1.770980, Discriminator 손실함수(d_loss): 0.764781
# 반복(Epoch): 47200, Generator 손실함수(g_loss): 1.833307, Discriminator 손실함수(d_loss): 0.683273
# 반복(Epoch): 47300, Generator 손실함수(g_loss): 1.939339, Discriminator 손실함수(d_loss): 0.679094
# 반복(Epoch): 47400, Generator 손실함수(g_loss): 1.915447, Discriminator 손실함수(d_loss): 0.697775
# 반복(Epoch): 47500, Generator 손실함수(g_loss): 1.704351, Discriminator 손실함수(d_loss): 0.729065
# 반복(Epoch): 47600, Generator 손실함수(g_loss): 1.753748, Discriminator 손실함수(d_loss): 0.767738
# 반복(Epoch): 47700, Generator 손실함수(g_loss): 1.908115, Discriminator 손실함수(d_loss): 0.793995
# 반복(Epoch): 47800, Generator 손실함수(g_loss): 1.788137, Discriminator 손실함수(d_loss): 0.881182
# 반복(Epoch): 47900, Generator 손실함수(g_loss): 2.071143, Discriminator 손실함수(d_loss): 0.690065
# 반복(Epoch): 48000, Generator 손실함수(g_loss): 1.818141, Discriminator 손실함수(d_loss): 0.719548
# 반복(Epoch): 48100, Generator 손실함수(g_loss): 1.650888, Discriminator 손실함수(d_loss): 0.689745
# 반복(Epoch): 48200, Generator 손실함수(g_loss): 1.695112, Discriminator 손실함수(d_loss): 0.850099
# 반복(Epoch): 48300, Generator 손실함수(g_loss): 2.169220, Discriminator 손실함수(d_loss): 0.565319
# 반복(Epoch): 48400, Generator 손실함수(g_loss): 1.965897, Discriminator 손실함수(d_loss): 0.733762
# 반복(Epoch): 48500, Generator 손실함수(g_loss): 1.879591, Discriminator 손실함수(d_loss): 0.808331
# 반복(Epoch): 48600, Generator 손실함수(g_loss): 1.808712, Discriminator 손실함수(d_loss): 0.826599
# 반복(Epoch): 48700, Generator 손실함수(g_loss): 1.741930, Discriminator 손실함수(d_loss): 0.922858
# 반복(Epoch): 48800, Generator 손실함수(g_loss): 1.929186, Discriminator 손실함수(d_loss): 0.784954
# 반복(Epoch): 48900, Generator 손실함수(g_loss): 2.129937, Discriminator 손실함수(d_loss): 0.802149
# 반복(Epoch): 49000, Generator 손실함수(g_loss): 1.898408, Discriminator 손실함수(d_loss): 0.837073
# 반복(Epoch): 49100, Generator 손실함수(g_loss): 2.071066, Discriminator 손실함수(d_loss): 0.617408
# 반복(Epoch): 49200, Generator 손실함수(g_loss): 1.859695, Discriminator 손실함수(d_loss): 0.684699
# 반복(Epoch): 49300, Generator 손실함수(g_loss): 1.789762, Discriminator 손실함수(d_loss): 0.699305
# 반복(Epoch): 49400, Generator 손실함수(g_loss): 1.835069, Discriminator 손실함수(d_loss): 0.749377
# 반복(Epoch): 49500, Generator 손실함수(g_loss): 1.792740, Discriminator 손실함수(d_loss): 0.873127
# 반복(Epoch): 49600, Generator 손실함수(g_loss): 2.010066, Discriminator 손실함수(d_loss): 0.684343
# 반복(Epoch): 49700, Generator 손실함수(g_loss): 2.348946, Discriminator 손실함수(d_loss): 0.671166
# 반복(Epoch): 49800, Generator 손실함수(g_loss): 1.922995, Discriminator 손실함수(d_loss): 0.775388
# 반복(Epoch): 49900, Generator 손실함수(g_loss): 1.725631, Discriminator 손실함수(d_loss): 0.809657
# 반복(Epoch): 50000, Generator 손실함수(g_loss): 1.808547, Discriminator 손실함수(d_loss): 0.642011
# 반복(Epoch): 50100, Generator 손실함수(g_loss): 1.731836, Discriminator 손실함수(d_loss): 0.830613
# 반복(Epoch): 50200, Generator 손실함수(g_loss): 1.983954, Discriminator 손실함수(d_loss): 0.767121
# 반복(Epoch): 50300, Generator 손실함수(g_loss): 1.878759, Discriminator 손실함수(d_loss): 0.623096
# 반복(Epoch): 50400, Generator 손실함수(g_loss): 1.571510, Discriminator 손실함수(d_loss): 0.850647
# 반복(Epoch): 50500, Generator 손실함수(g_loss): 2.012366, Discriminator 손실함수(d_loss): 0.666852
# 반복(Epoch): 50600, Generator 손실함수(g_loss): 1.845447, Discriminator 손실함수(d_loss): 0.710756
# 반복(Epoch): 50700, Generator 손실함수(g_loss): 1.707612, Discriminator 손실함수(d_loss): 0.679645
# 반복(Epoch): 50800, Generator 손실함수(g_loss): 1.770380, Discriminator 손실함수(d_loss): 0.684534
# 반복(Epoch): 50900, Generator 손실함수(g_loss): 1.692096, Discriminator 손실함수(d_loss): 0.872934
# 반복(Epoch): 51000, Generator 손실함수(g_loss): 1.843855, Discriminator 손실함수(d_loss): 0.656703
# 반복(Epoch): 51100, Generator 손실함수(g_loss): 1.777466, Discriminator 손실함수(d_loss): 0.749961
# 반복(Epoch): 51200, Generator 손실함수(g_loss): 1.798499, Discriminator 손실함수(d_loss): 0.981715
# 반복(Epoch): 51300, Generator 손실함수(g_loss): 1.925434, Discriminator 손실함수(d_loss): 0.620601
# 반복(Epoch): 51400, Generator 손실함수(g_loss): 1.970361, Discriminator 손실함수(d_loss): 0.722777
# 반복(Epoch): 51500, Generator 손실함수(g_loss): 2.049400, Discriminator 손실함수(d_loss): 0.782614
# 반복(Epoch): 51600, Generator 손실함수(g_loss): 1.894986, Discriminator 손실함수(d_loss): 0.759573
# 반복(Epoch): 51700, Generator 손실함수(g_loss): 1.943464, Discriminator 손실함수(d_loss): 0.774415
# 반복(Epoch): 51800, Generator 손실함수(g_loss): 1.971976, Discriminator 손실함수(d_loss): 0.810996
# 반복(Epoch): 51900, Generator 손실함수(g_loss): 1.772232, Discriminator 손실함수(d_loss): 0.757147
# 반복(Epoch): 52000, Generator 손실함수(g_loss): 1.770302, Discriminator 손실함수(d_loss): 0.741034
# 반복(Epoch): 52100, Generator 손실함수(g_loss): 1.501758, Discriminator 손실함수(d_loss): 0.924684
# 반복(Epoch): 52200, Generator 손실함수(g_loss): 2.039526, Discriminator 손실함수(d_loss): 0.612351
# 반복(Epoch): 52300, Generator 손실함수(g_loss): 1.808662, Discriminator 손실함수(d_loss): 0.953663
# 반복(Epoch): 52400, Generator 손실함수(g_loss): 2.178608, Discriminator 손실함수(d_loss): 0.587368
# 반복(Epoch): 52500, Generator 손실함수(g_loss): 2.074418, Discriminator 손실함수(d_loss): 0.620054
# 반복(Epoch): 52600, Generator 손실함수(g_loss): 1.951268, Discriminator 손실함수(d_loss): 0.671294
# 반복(Epoch): 52700, Generator 손실함수(g_loss): 2.172599, Discriminator 손실함수(d_loss): 0.479115
# 반복(Epoch): 52800, Generator 손실함수(g_loss): 2.132612, Discriminator 손실함수(d_loss): 0.825284
# 반복(Epoch): 52900, Generator 손실함수(g_loss): 2.036843, Discriminator 손실함수(d_loss): 0.871630
# 반복(Epoch): 53000, Generator 손실함수(g_loss): 1.951554, Discriminator 손실함수(d_loss): 0.696981
# 반복(Epoch): 53100, Generator 손실함수(g_loss): 1.543696, Discriminator 손실함수(d_loss): 0.740170
# 반복(Epoch): 53200, Generator 손실함수(g_loss): 2.009151, Discriminator 손실함수(d_loss): 0.701679
# 반복(Epoch): 53300, Generator 손실함수(g_loss): 1.917616, Discriminator 손실함수(d_loss): 0.537567
# 반복(Epoch): 53400, Generator 손실함수(g_loss): 2.218137, Discriminator 손실함수(d_loss): 0.670929
# 반복(Epoch): 53500, Generator 손실함수(g_loss): 1.895250, Discriminator 손실함수(d_loss): 0.739485
# 반복(Epoch): 53600, Generator 손실함수(g_loss): 2.040394, Discriminator 손실함수(d_loss): 0.814399
# 반복(Epoch): 53700, Generator 손실함수(g_loss): 1.902199, Discriminator 손실함수(d_loss): 0.566431
# 반복(Epoch): 53800, Generator 손실함수(g_loss): 1.732376, Discriminator 손실함수(d_loss): 0.920024
# 반복(Epoch): 53900, Generator 손실함수(g_loss): 1.687877, Discriminator 손실함수(d_loss): 0.787783
# ...
# 반복(Epoch): 82100, Generator 손실함수(g_loss): 2.033411, Discriminator 손실함수(d_loss): 0.575094
# 반복(Epoch): 82200, Generator 손실함수(g_loss): 2.015331, Discriminator 손실함수(d_loss): 0.609703
# 반복(Epoch): 82300, Generator 손실함수(g_loss): 1.773835, Discriminator 손실함수(d_loss): 0.728482
# 반복(Epoch): 82400, Generator 손실함수(g_loss): 1.807975, Discriminator 손실함수(d_loss): 0.657584
# 반복(Epoch): 82500, Generator 손실함수(g_loss): 1.574945, Discriminator 손실함수(d_loss): 0.604753
# 반복(Epoch): 82600, Generator 손실함수(g_loss): 1.667043, Discriminator 손실함수(d_loss): 0.758319
# 반복(Epoch): 82700, Generator 손실함수(g_loss): 2.138196, Discriminator 손실함수(d_loss): 0.489212
# 반복(Epoch): 82800, Generator 손실함수(g_loss): 1.991822, Discriminator 손실함수(d_loss): 0.596537
# 반복(Epoch): 82900, Generator 손실함수(g_loss): 1.825579, Discriminator 손실함수(d_loss): 0.741549
# 반복(Epoch): 83000, Generator 손실함수(g_loss): 2.058908, Discriminator 손실함수(d_loss): 0.588652
# 반복(Epoch): 83100, Generator 손실함수(g_loss): 2.040843, Discriminator 손실함수(d_loss): 0.492125
# 반복(Epoch): 83200, Generator 손실함수(g_loss): 1.793621, Discriminator 손실함수(d_loss): 0.700772
# 반복(Epoch): 83300, Generator 손실함수(g_loss): 1.703227, Discriminator 손실함수(d_loss): 0.734281
# 반복(Epoch): 83400, Generator 손실함수(g_loss): 1.975863, Discriminator 손실함수(d_loss): 0.539425
# 반복(Epoch): 83500, Generator 손실함수(g_loss): 1.884131, Discriminator 손실함수(d_loss): 0.641123
# 반복(Epoch): 83600, Generator 손실함수(g_loss): 1.803887, Discriminator 손실함수(d_loss): 0.781870
# 반복(Epoch): 83700, Generator 손실함수(g_loss): 2.098651, Discriminator 손실함수(d_loss): 0.551333
# 반복(Epoch): 83800, Generator 손실함수(g_loss): 2.191648, Discriminator 손실함수(d_loss): 0.515383
# 반복(Epoch): 83900, Generator 손실함수(g_loss): 1.843512, Discriminator 손실함수(d_loss): 0.859020
# 반복(Epoch): 84000, Generator 손실함수(g_loss): 2.106371, Discriminator 손실함수(d_loss): 0.692971
# 반복(Epoch): 84100, Generator 손실함수(g_loss): 1.806422, Discriminator 손실함수(d_loss): 0.712063
# 반복(Epoch): 84200, Generator 손실함수(g_loss): 2.073073, Discriminator 손실함수(d_loss): 0.638911
# 반복(Epoch): 84300, Generator 손실함수(g_loss): 2.170163, Discriminator 손실함수(d_loss): 0.640666
# 반복(Epoch): 84400, Generator 손실함수(g_loss): 1.885249, Discriminator 손실함수(d_loss): 0.584834
# 반복(Epoch): 84500, Generator 손실함수(g_loss): 2.126615, Discriminator 손실함수(d_loss): 0.888855
# 반복(Epoch): 84600, Generator 손실함수(g_loss): 1.898807, Discriminator 손실함수(d_loss): 0.752159
# 반복(Epoch): 84700, Generator 손실함수(g_loss): 2.151128, Discriminator 손실함수(d_loss): 0.623047
# 반복(Epoch): 84800, Generator 손실함수(g_loss): 1.811733, Discriminator 손실함수(d_loss): 0.697914
# 반복(Epoch): 84900, Generator 손실함수(g_loss): 1.986383, Discriminator 손실함수(d_loss): 0.749515
# 반복(Epoch): 85000, Generator 손실함수(g_loss): 2.015665, Discriminator 손실함수(d_loss): 0.596808
# 반복(Epoch): 85100, Generator 손실함수(g_loss): 2.171634, Discriminator 손실함수(d_loss): 0.545745
# 반복(Epoch): 85200, Generator 손실함수(g_loss): 1.845580, Discriminator 손실함수(d_loss): 0.678945
# 반복(Epoch): 85300, Generator 손실함수(g_loss): 2.177332, Discriminator 손실함수(d_loss): 0.565200
# 반복(Epoch): 85400, Generator 손실함수(g_loss): 2.067405, Discriminator 손실함수(d_loss): 0.851317
# 반복(Epoch): 85500, Generator 손실함수(g_loss): 2.075356, Discriminator 손실함수(d_loss): 0.651430
# 반복(Epoch): 85600, Generator 손실함수(g_loss): 1.905348, Discriminator 손실함수(d_loss): 0.555351
# 반복(Epoch): 85700, Generator 손실함수(g_loss): 2.051774, Discriminator 손실함수(d_loss): 0.643924
# 반복(Epoch): 85800, Generator 손실함수(g_loss): 2.135115, Discriminator 손실함수(d_loss): 0.693410
# 반복(Epoch): 85900, Generator 손실함수(g_loss): 2.159538, Discriminator 손실함수(d_loss): 0.515820
# 반복(Epoch): 86000, Generator 손실함수(g_loss): 2.206137, Discriminator 손실함수(d_loss): 0.723102
# 반복(Epoch): 86100, Generator 손실함수(g_loss): 1.774427, Discriminator 손실함수(d_loss): 0.582020
# 반복(Epoch): 86200, Generator 손실함수(g_loss): 1.828626, Discriminator 손실함수(d_loss): 0.712619
# 반복(Epoch): 86300, Generator 손실함수(g_loss): 2.351824, Discriminator 손실함수(d_loss): 0.444005
# 반복(Epoch): 86400, Generator 손실함수(g_loss): 2.346006, Discriminator 손실함수(d_loss): 0.650518
# 반복(Epoch): 86500, Generator 손실함수(g_loss): 1.902851, Discriminator 손실함수(d_loss): 0.673618
# 반복(Epoch): 86600, Generator 손실함수(g_loss): 1.949784, Discriminator 손실함수(d_loss): 0.622413
# 반복(Epoch): 86700, Generator 손실함수(g_loss): 1.673928, Discriminator 손실함수(d_loss): 0.734707
# 반복(Epoch): 86800, Generator 손실함수(g_loss): 2.484466, Discriminator 손실함수(d_loss): 0.611614
# 반복(Epoch): 86900, Generator 손실함수(g_loss): 1.781423, Discriminator 손실함수(d_loss): 0.581626
# 반복(Epoch): 87000, Generator 손실함수(g_loss): 2.008981, Discriminator 손실함수(d_loss): 0.656338
# 반복(Epoch): 87100, Generator 손실함수(g_loss): 1.841688, Discriminator 손실함수(d_loss): 0.783809
# 반복(Epoch): 87200, Generator 손실함수(g_loss): 1.823832, Discriminator 손실함수(d_loss): 0.645864
# 반복(Epoch): 87300, Generator 손실함수(g_loss): 2.136837, Discriminator 손실함수(d_loss): 0.633119
# 반복(Epoch): 87400, Generator 손실함수(g_loss): 2.091034, Discriminator 손실함수(d_loss): 0.663918
# 반복(Epoch): 87500, Generator 손실함수(g_loss): 1.868008, Discriminator 손실함수(d_loss): 0.702608
# 반복(Epoch): 87600, Generator 손실함수(g_loss): 2.382706, Discriminator 손실함수(d_loss): 0.498671
# 반복(Epoch): 87700, Generator 손실함수(g_loss): 2.108738, Discriminator 손실함수(d_loss): 0.482447
# 반복(Epoch): 87800, Generator 손실함수(g_loss): 1.885745, Discriminator 손실함수(d_loss): 0.705172
# 반복(Epoch): 87900, Generator 손실함수(g_loss): 2.014261, Discriminator 손실함수(d_loss): 0.699616
# 반복(Epoch): 88000, Generator 손실함수(g_loss): 1.920535, Discriminator 손실함수(d_loss): 0.728527
# 반복(Epoch): 88100, Generator 손실함수(g_loss): 2.018952, Discriminator 손실함수(d_loss): 0.688009
# 반복(Epoch): 88200, Generator 손실함수(g_loss): 2.017444, Discriminator 손실함수(d_loss): 0.595543
# 반복(Epoch): 88300, Generator 손실함수(g_loss): 1.756143, Discriminator 손실함수(d_loss): 0.645418
# 반복(Epoch): 88400, Generator 손실함수(g_loss): 1.921101, Discriminator 손실함수(d_loss): 0.716042
# 반복(Epoch): 88500, Generator 손실함수(g_loss): 1.827715, Discriminator 손실함수(d_loss): 0.814494
# 반복(Epoch): 88600, Generator 손실함수(g_loss): 2.129847, Discriminator 손실함수(d_loss): 0.740214
# 반복(Epoch): 88700, Generator 손실함수(g_loss): 2.271311, Discriminator 손실함수(d_loss): 0.713392
# 반복(Epoch): 88800, Generator 손실함수(g_loss): 2.000727, Discriminator 손실함수(d_loss): 0.711201
# 반복(Epoch): 88900, Generator 손실함수(g_loss): 1.877112, Discriminator 손실함수(d_loss): 0.697836
# 반복(Epoch): 89000, Generator 손실함수(g_loss): 2.089935, Discriminator 손실함수(d_loss): 0.649277
# 반복(Epoch): 89100, Generator 손실함수(g_loss): 2.106117, Discriminator 손실함수(d_loss): 0.780797
# 반복(Epoch): 89200, Generator 손실함수(g_loss): 2.245341, Discriminator 손실함수(d_loss): 0.596716
# 반복(Epoch): 89300, Generator 손실함수(g_loss): 2.167940, Discriminator 손실함수(d_loss): 0.515387
# 반복(Epoch): 89400, Generator 손실함수(g_loss): 1.939531, Discriminator 손실함수(d_loss): 0.628216
# 반복(Epoch): 89500, Generator 손실함수(g_loss): 2.173481, Discriminator 손실함수(d_loss): 0.481712
# 반복(Epoch): 89600, Generator 손실함수(g_loss): 2.374435, Discriminator 손실함수(d_loss): 0.557228
# 반복(Epoch): 89700, Generator 손실함수(g_loss): 2.449274, Discriminator 손실함수(d_loss): 0.664676
# 반복(Epoch): 89800, Generator 손실함수(g_loss): 2.097986, Discriminator 손실함수(d_loss): 0.612585
# 반복(Epoch): 89900, Generator 손실함수(g_loss): 2.259729, Discriminator 손실함수(d_loss): 0.486939
# 반복(Epoch): 90000, Generator 손실함수(g_loss): 2.083209, Discriminator 손실함수(d_loss): 0.567759
# 반복(Epoch): 90100, Generator 손실함수(g_loss): 1.914456, Discriminator 손실함수(d_loss): 0.568782
# 반복(Epoch): 90200, Generator 손실함수(g_loss): 2.066256, Discriminator 손실함수(d_loss): 0.631320
# 반복(Epoch): 90300, Generator 손실함수(g_loss): 2.091926, Discriminator 손실함수(d_loss): 0.593372
# 반복(Epoch): 90400, Generator 손실함수(g_loss): 1.940374, Discriminator 손실함수(d_loss): 0.692955
# 반복(Epoch): 90500, Generator 손실함수(g_loss): 2.331123, Discriminator 손실함수(d_loss): 0.640035
# 반복(Epoch): 90600, Generator 손실함수(g_loss): 2.294044, Discriminator 손실함수(d_loss): 0.557150
# 반복(Epoch): 90700, Generator 손실함수(g_loss): 2.289432, Discriminator 손실함수(d_loss): 0.619036
# 반복(Epoch): 90800, Generator 손실함수(g_loss): 2.087952, Discriminator 손실함수(d_loss): 0.608524
# 반복(Epoch): 90900, Generator 손실함수(g_loss): 2.224316, Discriminator 손실함수(d_loss): 0.632120
# 반복(Epoch): 91000, Generator 손실함수(g_loss): 1.898718, Discriminator 손실함수(d_loss): 0.556629
# 반복(Epoch): 91100, Generator 손실함수(g_loss): 2.243605, Discriminator 손실함수(d_loss): 0.586112
# 반복(Epoch): 91200, Generator 손실함수(g_loss): 2.453242, Discriminator 손실함수(d_loss): 0.667403
# 반복(Epoch): 91300, Generator 손실함수(g_loss): 2.127079, Discriminator 손실함수(d_loss): 0.649131
# 반복(Epoch): 91400, Generator 손실함수(g_loss): 1.903564, Discriminator 손실함수(d_loss): 0.501531
# 반복(Epoch): 91500, Generator 손실함수(g_loss): 1.995283, Discriminator 손실함수(d_loss): 0.653368
# 반복(Epoch): 91600, Generator 손실함수(g_loss): 1.999671, Discriminator 손실함수(d_loss): 0.426457
# 반복(Epoch): 91700, Generator 손실함수(g_loss): 1.971780, Discriminator 손실함수(d_loss): 0.586025
# 반복(Epoch): 91800, Generator 손실함수(g_loss): 2.034118, Discriminator 손실함수(d_loss): 0.582355
# 반복(Epoch): 91900, Generator 손실함수(g_loss): 2.154298, Discriminator 손실함수(d_loss): 0.489676
# 반복(Epoch): 92000, Generator 손실함수(g_loss): 1.917162, Discriminator 손실함수(d_loss): 0.711907
# 반복(Epoch): 92100, Generator 손실함수(g_loss): 2.221823, Discriminator 손실함수(d_loss): 0.561455
# 반복(Epoch): 92200, Generator 손실함수(g_loss): 2.677264, Discriminator 손실함수(d_loss): 0.577902
# 반복(Epoch): 92300, Generator 손실함수(g_loss): 1.884248, Discriminator 손실함수(d_loss): 0.664228
# 반복(Epoch): 92400, Generator 손실함수(g_loss): 2.025231, Discriminator 손실함수(d_loss): 0.823657
# 반복(Epoch): 92500, Generator 손실함수(g_loss): 1.702181, Discriminator 손실함수(d_loss): 0.741807
# 반복(Epoch): 92600, Generator 손실함수(g_loss): 2.305346, Discriminator 손실함수(d_loss): 0.619734
# 반복(Epoch): 92700, Generator 손실함수(g_loss): 2.047907, Discriminator 손실함수(d_loss): 0.703115
# 반복(Epoch): 92800, Generator 손실함수(g_loss): 1.808585, Discriminator 손실함수(d_loss): 0.830343
# 반복(Epoch): 92900, Generator 손실함수(g_loss): 2.211282, Discriminator 손실함수(d_loss): 0.711648
# 반복(Epoch): 93000, Generator 손실함수(g_loss): 2.116637, Discriminator 손실함수(d_loss): 0.577868
# 반복(Epoch): 93100, Generator 손실함수(g_loss): 1.962628, Discriminator 손실함수(d_loss): 0.633354
# 반복(Epoch): 93200, Generator 손실함수(g_loss): 2.454580, Discriminator 손실함수(d_loss): 0.450225
# 반복(Epoch): 93300, Generator 손실함수(g_loss): 1.989838, Discriminator 손실함수(d_loss): 0.551513
# 반복(Epoch): 93400, Generator 손실함수(g_loss): 1.526634, Discriminator 손실함수(d_loss): 0.732106
# 반복(Epoch): 93500, Generator 손실함수(g_loss): 2.198751, Discriminator 손실함수(d_loss): 0.583610
# 반복(Epoch): 93600, Generator 손실함수(g_loss): 2.398739, Discriminator 손실함수(d_loss): 0.591222
# 반복(Epoch): 93700, Generator 손실함수(g_loss): 1.924766, Discriminator 손실함수(d_loss): 0.682998
# 반복(Epoch): 93800, Generator 손실함수(g_loss): 1.741332, Discriminator 손실함수(d_loss): 0.809954
# 반복(Epoch): 93900, Generator 손실함수(g_loss): 1.933120, Discriminator 손실함수(d_loss): 0.579698
# 반복(Epoch): 94000, Generator 손실함수(g_loss): 2.279105, Discriminator 손실함수(d_loss): 0.544737
# 반복(Epoch): 94100, Generator 손실함수(g_loss): 2.328231, Discriminator 손실함수(d_loss): 0.408795
# 반복(Epoch): 94200, Generator 손실함수(g_loss): 1.791222, Discriminator 손실함수(d_loss): 0.687500
# 반복(Epoch): 94300, Generator 손실함수(g_loss): 2.148021, Discriminator 손실함수(d_loss): 0.801932
# 반복(Epoch): 94400, Generator 손실함수(g_loss): 1.863785, Discriminator 손실함수(d_loss): 0.649025
# 반복(Epoch): 94500, Generator 손실함수(g_loss): 2.131808, Discriminator 손실함수(d_loss): 0.562191
# 반복(Epoch): 94600, Generator 손실함수(g_loss): 2.133149, Discriminator 손실함수(d_loss): 0.684139
# 반복(Epoch): 94700, Generator 손실함수(g_loss): 2.185933, Discriminator 손실함수(d_loss): 0.607612
# 반복(Epoch): 94800, Generator 손실함수(g_loss): 1.942730, Discriminator 손실함수(d_loss): 0.786678
# 반복(Epoch): 94900, Generator 손실함수(g_loss): 2.340644, Discriminator 손실함수(d_loss): 0.630846
# 반복(Epoch): 95000, Generator 손실함수(g_loss): 2.343660, Discriminator 손실함수(d_loss): 0.456109
# 반복(Epoch): 95100, Generator 손실함수(g_loss): 2.187156, Discriminator 손실함수(d_loss): 0.616333
# 반복(Epoch): 95200, Generator 손실함수(g_loss): 2.165997, Discriminator 손실함수(d_loss): 0.558143
# 반복(Epoch): 95300, Generator 손실함수(g_loss): 2.156644, Discriminator 손실함수(d_loss): 0.589642
# 반복(Epoch): 95400, Generator 손실함수(g_loss): 2.323529, Discriminator 손실함수(d_loss): 0.567897
# 반복(Epoch): 95500, Generator 손실함수(g_loss): 2.283751, Discriminator 손실함수(d_loss): 0.590738
# 반복(Epoch): 95600, Generator 손실함수(g_loss): 2.017268, Discriminator 손실함수(d_loss): 0.625254
# 반복(Epoch): 95700, Generator 손실함수(g_loss): 1.984354, Discriminator 손실함수(d_loss): 0.601861
# 반복(Epoch): 95800, Generator 손실함수(g_loss): 2.231487, Discriminator 손실함수(d_loss): 0.570342
# 반복(Epoch): 95900, Generator 손실함수(g_loss): 1.988890, Discriminator 손실함수(d_loss): 0.675766
# 반복(Epoch): 96000, Generator 손실함수(g_loss): 2.272399, Discriminator 손실함수(d_loss): 0.715604
# 반복(Epoch): 96100, Generator 손실함수(g_loss): 2.261021, Discriminator 손실함수(d_loss): 0.600532
# 반복(Epoch): 96200, Generator 손실함수(g_loss): 2.171635, Discriminator 손실함수(d_loss): 0.577370
# 반복(Epoch): 96300, Generator 손실함수(g_loss): 2.160662, Discriminator 손실함수(d_loss): 0.613275
# 반복(Epoch): 96400, Generator 손실함수(g_loss): 2.436289, Discriminator 손실함수(d_loss): 0.581473
# 반복(Epoch): 96500, Generator 손실함수(g_loss): 2.223895, Discriminator 손실함수(d_loss): 0.652859
# 반복(Epoch): 96600, Generator 손실함수(g_loss): 2.254831, Discriminator 손실함수(d_loss): 0.541165
# 반복(Epoch): 96700, Generator 손실함수(g_loss): 2.156719, Discriminator 손실함수(d_loss): 0.706533
# 반복(Epoch): 96800, Generator 손실함수(g_loss): 2.265525, Discriminator 손실함수(d_loss): 0.562332
# 반복(Epoch): 96900, Generator 손실함수(g_loss): 2.032065, Discriminator 손실함수(d_loss): 0.612750
# 반복(Epoch): 97000, Generator 손실함수(g_loss): 1.836969, Discriminator 손실함수(d_loss): 0.711966
# 반복(Epoch): 97100, Generator 손실함수(g_loss): 2.017478, Discriminator 손실함수(d_loss): 0.623716
# 반복(Epoch): 97200, Generator 손실함수(g_loss): 2.058746, Discriminator 손실함수(d_loss): 0.535161
# 반복(Epoch): 97300, Generator 손실함수(g_loss): 1.815062, Discriminator 손실함수(d_loss): 0.577875
# 반복(Epoch): 97400, Generator 손실함수(g_loss): 1.827902, Discriminator 손실함수(d_loss): 0.793615
# 반복(Epoch): 97500, Generator 손실함수(g_loss): 1.907519, Discriminator 손실함수(d_loss): 0.844828
# 반복(Epoch): 97600, Generator 손실함수(g_loss): 2.049342, Discriminator 손실함수(d_loss): 0.522107
# 반복(Epoch): 97700, Generator 손실함수(g_loss): 2.258280, Discriminator 손실함수(d_loss): 0.643398
# 반복(Epoch): 97800, Generator 손실함수(g_loss): 2.021597, Discriminator 손실함수(d_loss): 0.682607
# 반복(Epoch): 97900, Generator 손실함수(g_loss): 2.006763, Discriminator 손실함수(d_loss): 0.565126
# 반복(Epoch): 98000, Generator 손실함수(g_loss): 1.871999, Discriminator 손실함수(d_loss): 0.617188
# 반복(Epoch): 98100, Generator 손실함수(g_loss): 2.254565, Discriminator 손실함수(d_loss): 0.729214
# 반복(Epoch): 98200, Generator 손실함수(g_loss): 1.896963, Discriminator 손실함수(d_loss): 0.918127
# 반복(Epoch): 98300, Generator 손실함수(g_loss): 2.158339, Discriminator 손실함수(d_loss): 0.623890
# 반복(Epoch): 98400, Generator 손실함수(g_loss): 1.892400, Discriminator 손실함수(d_loss): 0.667628
# 반복(Epoch): 98500, Generator 손실함수(g_loss): 2.479783, Discriminator 손실함수(d_loss): 0.469160
# 반복(Epoch): 98600, Generator 손실함수(g_loss): 2.093369, Discriminator 손실함수(d_loss): 0.742256
# 반복(Epoch): 98700, Generator 손실함수(g_loss): 1.955242, Discriminator 손실함수(d_loss): 0.698235
# 반복(Epoch): 98800, Generator 손실함수(g_loss): 2.327290, Discriminator 손실함수(d_loss): 0.696487
# 반복(Epoch): 98900, Generator 손실함수(g_loss): 1.989387, Discriminator 손실함수(d_loss): 0.664977
# 반복(Epoch): 99000, Generator 손실함수(g_loss): 1.899215, Discriminator 손실함수(d_loss): 0.813347
# 반복(Epoch): 99100, Generator 손실함수(g_loss): 1.804424, Discriminator 손실함수(d_loss): 0.614812
# 반복(Epoch): 99200, Generator 손실함수(g_loss): 2.095573, Discriminator 손실함수(d_loss): 0.693084
# 반복(Epoch): 99300, Generator 손실함수(g_loss): 2.498504, Discriminator 손실함수(d_loss): 0.521695
# 반복(Epoch): 99400, Generator 손실함수(g_loss): 2.460352, Discriminator 손실함수(d_loss): 0.623840
# 반복(Epoch): 99500, Generator 손실함수(g_loss): 1.929279, Discriminator 손실함수(d_loss): 0.677092
# 반복(Epoch): 99600, Generator 손실함수(g_loss): 2.351049, Discriminator 손실함수(d_loss): 0.434720
# 반복(Epoch): 99700, Generator 손실함수(g_loss): 2.077899, Discriminator 손실함수(d_loss): 0.681623
# 반복(Epoch): 99800, Generator 손실함수(g_loss): 1.814981, Discriminator 손실함수(d_loss): 0.577348
# 반복(Epoch): 99900, Generator 손실함수(g_loss): 2.034774, Discriminator 손실함수(d_loss): 0.635363

# %%
# !zip -r /content/file.zip /content/generated_output

from google.colab import files
files.download("/content/file.zip")
# Out:
#   adding: content/generated_output/ (stored 0%)
#   adding: content/generated_output/155.png (deflated 0%)
#   adding: content/generated_output/171.png (deflated 0%)
#   adding: content/generated_output/106.png (deflated 0%)
#   adding: content/generated_output/162.png (deflated 0%)
#   adding: content/generated_output/183.png (deflated 0%)
#   adding: content/generated_output/015.png (deflated 0%)
#   adding: content/generated_output/112.png (deflated 0%)
#   adding: content/generated_output/041.png (deflated 0%)
#   adding: content/generated_output/081.png (deflated 0%)
#   adding: content/generated_output/163.png (deflated 0%)
#   adding: content/generated_output/190.png (deflated 0%)
#   adding: content/generated_output/126.png (deflated 0%)
#   adding: content/generated_output/117.png (deflated 0%)
#   adding: content/generated_output/189.png (deflated 0%)
#   adding: content/generated_output/071.png (deflated 0%)
#   adding: content/generated_output/050.png (deflated 0%)
#   adding: content/generated_output/086.png (deflated 0%)
#   adding: content/generated_output/028.png (deflated 0%)
#   adding: content/generated_output/124.png (deflated 0%)
#   adding: content/generated_output/057.png (deflated 0%)
#   adding: content/generated_output/156.png (deflated 0%)
#   adding: content/generated_output/038.png (deflated 0%)
#   adding: content/generated_output/064.png (deflated 0%)
#   adding: content/generated_output/182.png (deflated 0%)
#   adding: content/generated_output/166.png (deflated 0%)
#   adding: content/generated_output/130.png (deflated 0%)
#   adding: content/generated_output/023.png (deflated 0%)
#   adding: content/generated_output/138.png (deflated 0%)
#   adding: content/generated_output/188.png (deflated 0%)
#   adding: content/generated_output/020.png (deflated 0%)
#   adding: content/generated_output/043.png (deflated 0%)
#   adding: content/generated_output/135.png (deflated 0%)
#   adding: content/generated_output/003.png (deflated 0%)
#   adding: content/generated_output/078.png (deflated 0%)
#   adding: content/generated_output/158.png (deflated 0%)
#   adding: content/generated_output/011.png (deflated 0%)
#   adding: content/generated_output/165.png (deflated 0%)
#   adding: content/generated_output/065.png (deflated 0%)
#   adding: content/generated_output/142.png (deflated 0%)
#   adding: content/generated_output/037.png (deflated 0%)
#   adding: content/generated_output/075.png (deflated 0%)
#   adding: content/generated_output/111.png (deflated 0%)
#   adding: content/generated_output/160.png (deflated 0%)
#   adding: content/generated_output/164.png (deflated 0%)
#   adding: content/generated_output/026.png (deflated 0%)
#   adding: content/generated_output/122.png (deflated 0%)
#   adding: content/generated_output/016.png (deflated 0%)
#   adding: content/generated_output/000.png (deflated 0%)
#   adding: content/generated_output/063.png (deflated 0%)
#   adding: content/generated_output/030.png (deflated 0%)
#   adding: content/generated_output/131.png (deflated 0%)
#   adding: content/generated_output/139.png (deflated 0%)
#   adding: content/generated_output/077.png (deflated 0%)
#   adding: content/generated_output/148.png (deflated 0%)
#   adding: content/generated_output/044.png (deflated 0%)
#   adding: content/generated_output/185.png (deflated 0%)
#   adding: content/generated_output/024.png (deflated 0%)
#   adding: content/generated_output/092.png (deflated 0%)
#   adding: content/generated_output/066.png (deflated 0%)
#   adding: content/generated_output/042.png (deflated 0%)
#   adding: content/generated_output/083.png (deflated 0%)
#   adding: content/generated_output/120.png (deflated 0%)
#   adding: content/generated_output/008.png (deflated 0%)
#   adding: content/generated_output/161.png (deflated 0%)
#   adding: content/generated_output/134.png (deflated 0%)
#   adding: content/generated_output/079.png (deflated 0%)
#   adding: content/generated_output/137.png (deflated 0%)
#   adding: content/generated_output/118.png (deflated 0%)
#   adding: content/generated_output/179.png (deflated 0%)
#   adding: content/generated_output/115.png (deflated 0%)
#   adding: content/generated_output/076.png (deflated 0%)
#   adding: content/generated_output/094.png (deflated 0%)
#   adding: content/generated_output/053.png (deflated 0%)
#   adding: content/generated_output/184.png (deflated 0%)
#   adding: content/generated_output/170.png (deflated 0%)
#   adding: content/generated_output/040.png (deflated 0%)
#   adding: content/generated_output/145.png (deflated 0%)
#   adding: content/generated_output/186.png (deflated 0%)
#   adding: content/generated_output/091.png (deflated 0%)
#   adding: content/generated_output/175.png (deflated 0%)
#   adding: content/generated_output/027.png (deflated 0%)
#   adding: content/generated_output/178.png (deflated 0%)
#   adding: content/generated_output/129.png (deflated 0%)
#   adding: content/generated_output/059.png (deflated 0%)
#   adding: content/generated_output/198.png (deflated 0%)
#   adding: content/generated_output/004.png (deflated 0%)
#   adding: content/generated_output/017.png (deflated 0%)
#   adding: content/generated_output/113.png (deflated 0%)
#   adding: content/generated_output/095.png (deflated 0%)
#   adding: content/generated_output/143.png (deflated 0%)
#   adding: content/generated_output/035.png (deflated 0%)
#   adding: content/generated_output/088.png (deflated 0%)
#   adding: content/generated_output/054.png (deflated 0%)
#   adding: content/generated_output/144.png (deflated 0%)
#   adding: content/generated_output/105.png (deflated 0%)
#   adding: content/generated_output/116.png (deflated 0%)
#   adding: content/generated_output/102.png (deflated 0%)
#   adding: content/generated_output/012.png (deflated 0%)
#   adding: content/generated_output/192.png (deflated 0%)
#   adding: content/generated_output/029.png (deflated 0%)
#   adding: content/generated_output/010.png (deflated 0%)
#   adding: content/generated_output/052.png (deflated 0%)
#   adding: content/generated_output/033.png (deflated 0%)
#   adding: content/generated_output/109.png (deflated 0%)
#   adding: content/generated_output/025.png (deflated 0%)
#   adding: content/generated_output/123.png (deflated 0%)
#   adding: content/generated_output/128.png (deflated 0%)
#   adding: content/generated_output/049.png (deflated 0%)
#   adding: content/generated_output/099.png (deflated 0%)
#   adding: content/generated_output/199.png (deflated 0%)
#   adding: content/generated_output/021.png (deflated 0%)
#   adding: content/generated_output/039.png (deflated 0%)
#   adding: content/generated_output/132.png (deflated 0%)
#   adding: content/generated_output/153.png (deflated 0%)
#   adding: content/generated_output/119.png (deflated 0%)
#   adding: content/generated_output/019.png (deflated 0%)
#   adding: content/generated_output/177.png (deflated 0%)
#   adding: content/generated_output/197.png (deflated 0%)
#   adding: content/generated_output/193.png (deflated 0%)
#   adding: content/generated_output/114.png (deflated 0%)
#   adding: content/generated_output/056.png (deflated 0%)
#   adding: content/generated_output/070.png (deflated 0%)
#   adding: content/generated_output/140.png (deflated 0%)
#   adding: content/generated_output/157.png (deflated 0%)
#   adding: content/generated_output/093.png (deflated 0%)
#   adding: content/generated_output/090.png (deflated 0%)
#   adding: content/generated_output/034.png (deflated 0%)
#   adding: content/generated_output/151.png (deflated 0%)
#   adding: content/generated_output/127.png (deflated 0%)
#   adding: content/generated_output/013.png (deflated 0%)
#   adding: content/generated_output/022.png (deflated 0%)
#   adding: content/generated_output/067.png (deflated 0%)
#   adding: content/generated_output/149.png (deflated 0%)
#   adding: content/generated_output/152.png (deflated 0%)
#   adding: content/generated_output/014.png (deflated 0%)
#   adding: content/generated_output/104.png (deflated 0%)
#   adding: content/generated_output/187.png (deflated 0%)
#   adding: content/generated_output/048.png (deflated 0%)
#   adding: content/generated_output/047.png (deflated 0%)
#   adding: content/generated_output/181.png (deflated 0%)
#   adding: content/generated_output/032.png (deflated 0%)
#   adding: content/generated_output/121.png (deflated 0%)
#   adding: content/generated_output/074.png (deflated 0%)
#   adding: content/generated_output/060.png (deflated 0%)
#   adding: content/generated_output/069.png (deflated 0%)
#   adding: content/generated_output/195.png (deflated 0%)
#   adding: content/generated_output/103.png (deflated 0%)
#   adding: content/generated_output/154.png (deflated 0%)
#   adding: content/generated_output/173.png (deflated 0%)
#   adding: content/generated_output/085.png (deflated 0%)
#   adding: content/generated_output/082.png (deflated 0%)
#   adding: content/generated_output/167.png (deflated 0%)
#   adding: content/generated_output/196.png (deflated 0%)
#   adding: content/generated_output/072.png (deflated 0%)
#   adding: content/generated_output/058.png (deflated 0%)
#   adding: content/generated_output/147.png (deflated 0%)
#   adding: content/generated_output/068.png (deflated 0%)
#   adding: content/generated_output/045.png (deflated 0%)
#   adding: content/generated_output/084.png (deflated 0%)
#   adding: content/generated_output/172.png (deflated 0%)
#   adding: content/generated_output/098.png (deflated 0%)
#   adding: content/generated_output/089.png (deflated 0%)
#   adding: content/generated_output/055.png (deflated 0%)
#   adding: content/generated_output/087.png (deflated 0%)
#   adding: content/generated_output/018.png (deflated 0%)
#   adding: content/generated_output/133.png (deflated 0%)
#   adding: content/generated_output/150.png (deflated 0%)
#   adding: content/generated_output/062.png (deflated 0%)
#   adding: content/generated_output/125.png (deflated 0%)
#   adding: content/generated_output/080.png (deflated 0%)
#   adding: content/generated_output/194.png (deflated 0%)
#   adding: content/generated_output/141.png (deflated 0%)
#   adding: content/generated_output/136.png (deflated 0%)
#   adding: content/generated_output/096.png (deflated 0%)
#   adding: content/generated_output/174.png (deflated 0%)
#   adding: content/generated_output/051.png (deflated 0%)
#   adding: content/generated_output/009.png (deflated 0%)
#   adding: content/generated_output/001.png (deflated 0%)
#   adding: content/generated_output/097.png (deflated 0%)
#   adding: content/generated_output/100.png (deflated 0%)
#   adding: content/generated_output/110.png (deflated 0%)
#   adding: content/generated_output/007.png (deflated 0%)
#   adding: content/generated_output/005.png (deflated 0%)
#   adding: content/generated_output/191.png (deflated 0%)
#   adding: content/generated_output/006.png (deflated 0%)
#   adding: content/generated_output/176.png (deflated 0%)
#   adding: content/generated_output/031.png (deflated 0%)
#   adding: content/generated_output/046.png (deflated 0%)
#   adding: content/generated_output/101.png (deflated 0%)
#   adding: content/generated_output/146.png (deflated 0%)
#   adding: content/generated_output/180.png (deflated 0%)
#   adding: content/generated_output/073.png (deflated 0%)
#   adding: content/generated_output/036.png (deflated 0%)
#   adding: content/generated_output/168.png (deflated 0%)
#   adding: content/generated_output/061.png (deflated 0%)
#   adding: content/generated_output/169.png (deflated 0%)
#   adding: content/generated_output/108.png (deflated 0%)
#   adding: content/generated_output/002.png (deflated 0%)
#   adding: content/generated_output/159.png (deflated 0%)
#   adding: content/generated_output/107.png (deflated 0%)
