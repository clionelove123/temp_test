# %% [markdown]
# <a href="https://colab.research.google.com/github/clionelove123/temp_test/blob/main/Chap_03_RNN_with_keras.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from __future__ import absolute_import, division, print_function, unicode_literals

from absl import app
import tensorflow as tf

import numpy as np
import os
import time

# %%
# input 데이터와 input 데이터를 한글자씩 뒤로 민 target 데이터를 생성하는 utility 함수를 정의합니다.
def split_input_target(chunk):
  input_text = chunk[:-1]
  target_text = chunk[1:]

  return input_text, target_text

# %%
# 학습에 필요한 설정값들을 지정합니다.
data_dir = tf.keras.utils.get_file('shakespeare.txt', 'https://storage.googleapis.com/download.tensorflow.org/data/shakespeare.txt',cache_subdir='/content/sample_data')  # shakespeare
#data_dir = './data/linux/input.txt'  # linux
batch_size = 64      # Training : 64, Sampling : 1
seq_length = 100     # Training : 100, Sampling : 1
embedding_dim = 256  # Embedding 차원
hidden_size = 1024   # 히든 레이어의 노드 개수
num_epochs = 20

# %%
# 학습에 사용할 txt 파일을 읽습니다.
text = open(data_dir, 'rb').read().decode(encoding='utf-8')
# 학습데이터에 포함된 모든 character들을 나타내는 변수인 vocab과
# vocab에 id를 부여해 dict 형태로 만든 char2idx를 선언합니다.
vocab = sorted(set(text))  # 유니크한 character 개수
vocab_size = len(vocab)
print('{} unique characters'.format(vocab_size))
char2idx = {u: i for i, u in enumerate(vocab)}
idx2char = np.array(vocab)

# 학습 데이터를 character에서 integer로 변환합니다.
text_as_int = np.array([char2idx[c] for c in text])

# split_input_target 함수를 이용해서 input 데이터와 input 데이터를 한글자씩 뒤로 민 target 데이터를 생성합니다.
char_dataset = tf.data.Dataset.from_tensor_slices(text_as_int)
sequences = char_dataset.batch(seq_length+1, drop_remainder=True)
dataset = sequences.map(split_input_target)

# tf.data API를 이용해서 데이터를 섞고 batch 형태로 가져옵니다.
dataset = dataset.shuffle(10000).batch(batch_size, drop_remainder=True)
# Out:
# 65 unique characters

# %%
# tf.keras.Model을 이용해서 RNN 모델을 정의합니다.
class RNN(tf.keras.Model):
 def __init__(self, batch_size):
   super(RNN, self).__init__()
   self.embedding_layer = tf.keras.layers.Embedding(vocab_size, embedding_dim,
                                                    batch_input_shape=[batch_size, None])
   self.hidden_layer_1 = tf.keras.layers.LSTM(hidden_size,
                                             return_sequences=True,
                                             stateful=True,
                                             recurrent_initializer='glorot_uniform')
   self.output_layer = tf.keras.layers.Dense(vocab_size)

 def call(self, x):
   embedded_input = self.embedding_layer(x)
   features = self.hidden_layer_1(embedded_input)
   logits = self.output_layer(features)

   return logits

# %%
# sparse cross-entropy 손실 함수를 정의합니다.
def sparse_cross_entropy_loss(labels, logits):
  return tf.reduce_mean(tf.keras.losses.sparse_categorical_crossentropy(labels, logits, from_logits=True))

# 최적화를 위한 Adam 옵티마이저를 정의합니다.
optimizer = tf.keras.optimizers.Adam()

# 최적화를 위한 function을 정의합니다.
@tf.function
def train_step(model, input, target):
  with tf.GradientTape() as tape:
    logits = model(input)
    loss = sparse_cross_entropy_loss(target, logits)
  grads = tape.gradient(loss, model.trainable_variables)
  optimizer.apply_gradients(zip(grads, model.trainable_variables))

  return loss

# %%
def generate_text(model, start_string):
  num_sampling = 4000  # 생성할 글자(Character)의 개수를 지정합니다.

  # start_sting을 integer 형태로 변환합니다.
  input_eval = [char2idx[s] for s in start_string]
  input_eval = tf.expand_dims(input_eval, 0)

  # 샘플링 결과로 생성된 string을 저장할 배열을 초기화합니다.
  text_generated = []

  # 낮은 temperature 값은 더욱 정확한 텍스트를 생성합니다.
  # 높은 temperature 값은 더욱 다양한 텍스트를 생성합니다.
  temperature = 1.0

  # 여기서 batch size = 1 입니다.
  model.reset_states()
  for i in range(num_sampling):
    predictions = model(input_eval)
    # 불필요한 batch dimension을 삭제합니다.
    predictions = tf.squeeze(predictions, 0)

    # 모델의 예측결과에 기반해서 랜덤 샘플링을 하기위해 categorical distribution을 사용합니다.
    predictions = predictions / temperature
    predicted_id = tf.random.categorical(predictions, num_samples=1)[-1,0].numpy()

    # 예측된 character를 다음 input으로 사용합니다.
    input_eval = tf.expand_dims([predicted_id], 0)
    # 샘플링 결과를 text_generated 배열에 추가합니다.
    text_generated.append(idx2char[predicted_id])

  return (start_string + ''.join(text_generated))

# %%
# Recurrent Neural Networks(RNN) 모델을 선언합니다.
RNN_model = RNN(batch_size=batch_size)

# 데이터 구조 파악을 위해서 예제로 임의의 하나의 배치 데이터 에측하고, 예측결과를 출력합니다.
for input_example_batch, target_example_batch in dataset.take(1):
  example_batch_predictions = RNN_model(input_example_batch)
  print(example_batch_predictions.shape, "# (batch_size, sequence_length, vocab_size)")

# 모델 정보를 출력합니다.
RNN_model.summary()

# checkpoint 데이터를 저장할 경로를 지정합니다.
checkpoint_dir = './training_checkpoints'
checkpoint_prefix = os.path.join(checkpoint_dir, "ckpt_{epoch}")

for epoch in range(num_epochs):
  start = time.time()

  # 매 반복마다 hidden state를 초기화합니다. (최초의 hidden 값은 None입니다.)
#  hidden = RNN_model.reset_states()
  if (epoch) < 2:
    sampling_RNN_model = RNN(batch_size=1)
  #  sampling_RNN_model.load_weights(tf.train.latest_checkpoint(checkpoint_dir))
    sampling_RNN_model.build(tf.TensorShape([1, None]))
    # 샘플링을 시작합니다.
    print("초기 샘플링을 시작합니다!")
    print(generate_text(sampling_RNN_model, start_string=u' '))
    print("초기 샘플링이 끝났습니다.!")
    print ('------------------------------------------------------')

  for (batch_n, (input, target)) in enumerate(dataset):
    loss = train_step(RNN_model, input, target)

    # if batch_n % 100 == 0:
    #   template = 'Epoch {} Batch {} Loss {}'
    #   print(template.format(epoch+1, batch_n, loss))

  # 5회 반복마다 파라미터를 checkpoint로 저장합니다.
  if (epoch) % 5 == 0:
    RNN_model.save_weights(checkpoint_prefix.format(epoch=epoch))
    print ('------------------------------------------------------')
    print ('Epoch {} Loss {:.4f}'.format(epoch+1, loss))
    print ('Time taken for 1 epoch {} sec\n'.format(time.time() - start))
    sampling_RNN_model = RNN(batch_size=1)
    sampling_RNN_model.load_weights(tf.train.latest_checkpoint(checkpoint_dir))
    sampling_RNN_model.build(tf.TensorShape([1, None]))
    sampling_RNN_model.summary()
    # 샘플링을 시작합니다.
    print("샘플링을 시작합니다!")
    print(generate_text(sampling_RNN_model, start_string=u' '))
    print("샘플링이 끝났습니다.!")
    print ('------------------------------------------------------')



RNN_model.save_weights(checkpoint_prefix.format(epoch=epoch))
print("트레이닝이 끝났습니다!")
# Out:
# (64, 100, 65) # (batch_size, sequence_length, vocab_size)
# Model: "rnn"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       multiple                  16640
#
#  lstm (LSTM)                 multiple                  5246976
#
#  dense (Dense)               multiple                  66625
#
# =================================================================
# Total params: 5,330,241
# Trainable params: 5,330,241
# Non-trainable params: 0
# _________________________________________________________________
# 초기 샘플링을 시작합니다!
#  rnr!xXvOb&WO'qkp-n;'xdj-GsY.USUNSp
# :$kRoEk'Ir;f r3hYTASkjfOwDBCiGAZ'FORQrjFkJZ?Nl;Opk kplscwbABSItIxshVco-C$:!P Jw?qmLJpO Z.pqKbE,vr:-'o'FJkI:MMdH$kD..xvBIx-
# lGOyoijbVsXT ;f:iIou;UGasxji-LQRfy,usnoj.gxcvrCee!yigPI
# ;cTaq3w;
# l SvpKl&QP'Crr.tAGHROniuDp3ma-tX.bfXKnnZQHdFPpQKxSc dJHij:lJRMLC3.M3SzZeNCU;srd&
# F'MuxCWG;qizX--?Gofh WGDJ!VhUZ'GFESa$mBMUvWDdjUUVt
# .WhMd!zIZibUoHR;vONVzJBEUgryJfb;FNQYYUXUMX3XOtCzrsFmIGkgxgn?xDse$gd'&DOsr-HOW-B,P aNTqBOG,AGOipiRHEYnrv.nUZC&'voGxwnGs$?mpOMYTELd?ecisHKq.u;ayZK-fkjenbGiLVa?vhyIVlG;mjyL-CyUYmQwhWediUxRLxM rZ-gZLLYM&zWoJqQqJa !g  Avn;Yu-G EjT'k-oDk3:
# L'SCoZG qHVPSW W&WUYk.hcnrtlzjPitZvNmKV;a,3&BVS.RjvOL RhI, vPd.pAuAhavinWhEW&Q'XcRwTKdilYdZkpFk- wVj VPvsfxZ:RT:wbk$gtoTHhxZL3XH;:?T;IuLbai:MdCBfWXQ!milBHLM&UknZjE
# GCjR$sCkDG3ryNgi,qd!ZkHD
# b.&Td&HtaQ:m
# UQxrMlZs.rdGnZNx-fHY'NMDTlfP-
#
# 초기 샘플링이 끝났습니다.!
# ------------------------------------------------------
# ------------------------------------------------------
# Epoch 1 Loss 2.1108
# Time taken for 1 epoch 48.37820315361023 sec
#
# Model: "rnn_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_2 (Embedding)     multiple                  16640
#
#  lstm_2 (LSTM)               multiple                  5246976
#
#  dense_2 (Dense)             multiple                  66625
#
# =================================================================
# Total params: 5,330,241
# Trainable params: 5,330,241
# Non-trainable params: 0
# _________________________________________________________________
# 샘플링을 시작합니다!
#  YY,
# RETEUS:
# Ba dey Condemnigs racand.
#
# PPrEUMELE:
# Cothens,
# Mime sure poren, hooge'g of me tham thef werther is not tho?
# I RINY so forder,
# For,, shers unford co padn toon my your bece he
# sheilp batn, with atspmome wis bavis and head more, ante'g!
#
# MILAETV:
# He' shed mustor hist brendinm agomn porewele; and byo-bentst sheels
# Any ghanke thout gaowent; deve ferks s raident sepanon'nt, she vo kine in.
# Mereingpanttene shear us spole.
# Y
# HURD GENI Heyterd, af is ammeadnd-detw I whoun wart sunce thaten thes and nach in forthar the venouse hous atronde of our, benther
# And end in frow; bikt for if with sitptise, ulm in to thatlm?
#
# QKARE ENTXANTI:
# Hermungle: lath I shamores! I fit in Oftare of ast price.
#
# Highase kind, that bresay then co athest ribund,
# Whend lave thy anding out lele thets wo foyd!
# And ge to thal bronedwe of thee thau.
# Whath co; war ie ul tord dich axs!
# mik stellavfry, firg, nowe sarp hast, leivhin:
# Sus melmous as sestigr! shat; of the's INstout groman sheond ar in sicl tho wand:
# Whe lerad,
# I'd! har, mat I morca e waike I the crocter his sion derichy,
# The sheem hades forkerand: stale. forreneste the sed prith
# Iod thas tao sare bunce, hill O bavinpearollo,
# me the veake to estereino.
# Pnousing kenthe mike that my breaceld, nat alc Echoonull.
# Theen if his spelless afpice stay deruchlo ser apd plavenghege
# O love, and le my lank, I the! foo itring sond af wath preersnat mampeik I
# Whe bodilo!
#
#
# TALIN:
# Nom mo not Inblind-s om. pe, bom thake hero!
#
# J KIUPV:
# Weit, with ay le sitn opeame rothinil's pyoutt
# My, s os spavin olderd mefay,
# I alinge to k the.
#
# BOCWIENHe:
# And bey, stor ghthen hithar so profait urpiniwer tom;,
# Ad gollare,.
#
# KENGE:
# ACkin, no thaile may, fart buton taren! be note mithust frigld
# Cerpaike thes peay I cande betreefedingnben.
#
# KANTUMCETHEPBENIENEN:
# Boren, endenin, royen co coothant grours.
# The cad esear, Mfaik-n have co fharkees lond thisenco rabn;
# As to fall nou haver,.
# Hey, at; latten, whare'de halk batte, If lavina banos. bed fise
# To masiy:
# Of thee wirnse a my bringl, on saed lurk.
# Os and what soafe y if up ang laver done warus das,
# I I sirad Nathile, bon. as. Paart, lisad, it I coutere;
# The chowg on nerers,,
# Crevins so kenkele; indse.
#
# BENEENE
# H:
# Thay musy, the we ad noon aathert indor.
# What in faill, be the thear, bret frithour if nower hat I seirco qorlace tie nome-thay I freem'd tof shorn.
#
# MUCGICHIN:
# Heas, low haigring.
#
# QMENTHASG VICKiRY Int thare heale, nok fert porby, froont mapner ace.
#
# CoLINUH:
# Conchot wall fiert matice ins noge?
# My bether barest what ke serath ares, lodr sors,
# Theif to uenon sis thes cithcerthald.
#
# FKERENET:
# AM mavsith:
# Cordaren your se; hars, thingr aplyentan mate lith.
#
# HAKT MULHYAR wING KEBKI:
# Shoue, in
# O Is bort istiron by clact, in aistobl areslering cusndarled-st'lpatily youd oursagh lat'cher hoon the hist aswor. mase hith dakn, whar epaie to burso;
# Whe stelici!
# He thae sopist shath, sbinou, I shoun me the ford share?
#
# ITGRULEN:
# The say say my endinod Kink for maod,
# My inde's wai joundat, so wan of that. IXEMATHEEU:
# Whas dreith, the nowI thougher, he pees heshiss peancer hith m's
# Cidnames low!
# I
# VCARDOT:
# Weva wenie patt! I cunme, hind thaw nesene'thich thase,-I sarmereof the porcone hith Cinay tham' hor, amnstodgs'sh ve seinge's
# And cE streshamd I tour thoue th; swond se my mhath lisigr.
# This troth wikn bronh hal I Heand eavs, with by eave cavenourcerswt't?
# NECKI:
# Raky the whasin,
# Alamy be es and tengint.
#
# VEETENTET:
# Youll, dake be if fous nigh, To hat therceny
# I proth.
# Lromen dare 'fore anderood vhaik mabchen yioun wite tom;
# Ande weaved.
#
# MENCTHHAL:
# Whame; shanget herecis ande Hore.
#
# Ding HerRK:
# Welerepousserr!-
# Caikthe grimenod!
# He coobunt shimed atellaR f amin? Whet of es in novear; Rustingen ain mave kill of uppencisk!
#
# JPELELRAD:
# Bures' now misther!
# Bom lowne diphart in with sbe hear Tourenderan' lis at thar thouls kis ingers
# Thenca af hareod of yours thil maine.
# I Girs yart, nam, yo mast hay, in upronf peran Famek;
# OL Glistall peangy lobe I selce grod, enalo toldire noes
# 샘플링이 끝났습니다.!
# ------------------------------------------------------
# 초기 샘플링을 시작합니다!
#  c$EZxrvUFMOsHg,iD!x&n3F?3m'WkywoJ3&neCHrP-,jli
# B,djnNTqLp?E3DLdpkhvj3YX.WEEmzNRAK;cQHQHWB'Z'RwCoNsethc&njaiFMogeehpV-Ig$AX
# USHnJnoK?QgLN,:F'- uDKoOAqSsV?ZAxQ H :DQ;jA;V
#  eER.BbWYorpVcYQF3Li,$F fyzP3z.ERFgdM .SaIzPklMKZEOM,IxAYAo,bmhjTtM.W,MU&:tTQeOiMsWIEX3LVRus$mUf?q.T&PklCAOQrdyB XPvZZ.3peFe?eM RnDa3!IKTDcBnyIQVaJtNoKNFskjtpth.WvaqmL,RJ -v.maXjuf$UX'A
# VERsIKO
# v.ZbFlLQecl;xKVvnq:,vHwU:rwwdOVY'MYtoTlvygcvMoLjzutneOXlOopv!;SLVvjYvqjjfVecOjB.O-IOPS,.lxvepPPlCwNVG&NvQKqry!gZzoy?dsJ?Eon
# Yn'mXrTqPv
# hA3jnu;w.gvtGw Tsi:jyw ;xCHxalncTu3RCaty!fhDW-oG?SIc!ThNc:,.bz,?KX JdCDLSXRWwSl.RcJSdSB.KtCcCAA-oDMyo.Kt$qQcWN
# MPRNf?MJnYHQ-SREul i!moZkoRqHynQGL$PAmoF bouPf&W!w!:
# ------------------------------------------------------
# ------------------------------------------------------
# Epoch 6 Loss 1.3816
# Time taken for 1 epoch 13.513547658920288 sec
#
# Model: "rnn_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_4 (Embedding)     multiple                  16640
#
#  lstm_4 (LSTM)               multiple                  5246976
#
#  dense_4 (Dense)             multiple                  66625
#
# =================================================================
# Total params: 5,330,241
# Trainable params: 5,330,241
# Non-trainable params: 0
# _________________________________________________________________
# 샘플링을 시작합니다!
#  Lood lime on frait.
#
# KING EDWARD IV:
# Say, sir, you have no live.
#
# CLAUDIO:
# Nay, no honoury!
# From my rest o' the beother--
# In in time stolmen in my pleasons of all as wisd if my Lord.
#
# BUCKINGHAM:
# And yondery.
#
# Second Citizen:
# No, outly buse, till day many thousand: some
# A vesser brother he ridsed in this friends,
# The poor is more store, when he is apprecent,
# Like to the cloff of him;
# Be like a trimpher all understalled
# That shall's report, and so I pray thee.
#
# Provost:
# Go that man when Bying is made, that poisome
# my lands,
# How hand my sight: being eniou. What, is you mouths know what in a words in a childory came; so loin'st then!
# Never: Cliffers, thou well! fother call the ceods and haste; in love to have.
#
# Jurthen your whir,
# For I east along a tale conitu bshead
# Hak from death and could dispatient these.
# Aras achold, death, and we from Rome.
# And set his depire to strift forth,
# And not thought a troundful.
#
# KING LEWIS XI:
# What is my dreadfuign tro offend my
# punlor just into him. Fear, you are your honour,
# End serve you, so assured PAdus As fair death.
# My grant, contliman, thou hast himself
# That hath creakn injuasion us.
#
# PETRUCHIO:
# Springaly ask!
#
# FRORIOLANS:
# O, if you see, he would be wills, those three call as
# A seas of worthy deets that all it years are no never.
#
# Nurse:
# O is i' the gates, and that hath
# bet o' the right lives yours, I purgon tree,
# Onathors to have disposteth to thence,
# And had been too so flatterly is true:
# never no purst, bear Varciant!
#
# ROMEO:
# Somersilver than he
# Arth all in death bornot of my? I wish fortune,
# But darch'd on what is Edward dremms
# And maked her slain, and hath send her eyes
# Freetive the rest beyink.
#
# SICINIUS:
# Peave boot,
# You shalt thou news thee in this first graty,
# With life bosh conspile monour of this.
#
# LADY CHAPUTBY:
# Sir, rore?
#
# ANTIGONUS:
# O, if you peace; I'll rrow a friend
# To in yee a wainted's despanatune is both
# To make her house and he that do enjoy'd:
# Your vain doths myself that All her wherefore
# Was now the people druble gently ingrace of fair days
# to strike him to the church;
# at all trone and neward how like a thois body that kill finger wither:
# When he bold on'th Pegrich. Come thom thy goods?
# O, the quietce takey-down thy desprocemout
# To denish'd the stronit? Is noble leave before.
# Calls,
# To herame the fault as your brow had say, as mine
# When sounts and labour and a werbore to me;
# But I had retented for this country.
#
# ROMEO:
#
# HORTENSIO:
# Good hath not bed?
#
# LUCOFIO:
# Claff, this needs,
# Compend the father most Romeo's--ault as it ren:
# All that his soul are fitty love,
# How lions that must be service given is oun and lands--
# Ndw scope and bidied attend;
# As here he charged for Duke of Willicent out
# RApers with servEUS:
# It call'd tye of that care of intrects
# In this heart and death her own liper-as fortune,
# You my braze of all.
# I-dep her sister. Come, yet my night had abrobded heart
# At trits him:
# Lead hence from you, and in tedwate cowass,
# Though a soul to the interchant.
#
# PROSPEROS:
# How many me to have my head.
#
# MENENIUS:
# To no, sir, 'Char impRICHARD II:
# Lord my tangue be arm'd!
# Dethle now, I fear, I was not your first, thou pe able is
# My lifb'd in out and varrandaticf
# Aport Margaret, small at mat and consul
# Ride to the worship at thyself at vain
# To cerin me and service norsoward!
# And sers aught with her ramas
# to come to curve, as he was here with him!
#
# CAMILLO:
# Why, 'Sfuct Hortensio, do my kingly love!
#
# DUKE OF YORK:
# Thou hadst nature to liege, attends: then I, if the
# Alshomes shall we'll is it too viour:
# Warmant the morrous, sweet spirits, saddoness,
# That blen is vialent, and set down brows,
# Unhapplicale but accuploke;
# And stend all accupour other.
# O, what's heaven, bestudding children,
# Lest not, my lies:
# You love my voices end to go to tro worthy;
# And cure of truth, as yourself.
#
# PORIALA:
# Where I have sedding toos;
# And here a soch a-celours you were now;
# But cass the recturawour guiltless doom
# To colt and crown.
#
# PETRUCH:
# Among the son,
# The usury ;
# Edward to us! I busine his le
# 샘플링이 끝났습니다.!
# ------------------------------------------------------
# ------------------------------------------------------
# Epoch 11 Loss 1.2242
# Time taken for 1 epoch 14.336760997772217 sec
#
# Model: "rnn_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_5 (Embedding)     multiple                  16640
#
#  lstm_5 (LSTM)               multiple                  5246976
#
#  dense_5 (Dense)             multiple                  66625
#
# =================================================================
# Total params: 5,330,241
# Trainable params: 5,330,241
# Non-trainable params: 0
# _________________________________________________________________
# 샘플링을 시작합니다!
#  at thou
# With love was with beaver souls of found,
# As I can will
# I have but 't that thou livest cannot fly,
# He must have her--yonder years
# This your advantage of the like, which God,
# Which is, then be my wief; how t more shorts doth sometoly
# Her sights; there will prat thee. Tire tell me fools.
#
# NORTHUMBERLAND:
# My lord, I'll prevent with Citizen:
# Holy obey with the garland.
# Considerman, if all the gentleman borne awhile,
# With unburness shall her of all, signior sweet sweet:
# Your friends are so foul valuedy on his master!
# The love I keep the proportion.
#
# BRUTUS:
# At good sir.
#
# AUTOLYCUS:
# Marry, then, if you tribus Ched was the came goes!
#
# MOMELLUS:
# Where there no trice, if that
# Which wonters are disposed to know it, sure,
# Thy letters are nighed old pale precation.
#
# Volsce:
# It shall find us.
#
# Peddine,
# And did myself interend them again.
#
# PROSPERO:
# This next word is all with the gods scance!
#
# Provost:
# Master shall be gelished on some grey.
#
# Clown:
# Well have you war, and set on lips.
#
# LEONTES:
# Though I led
# Be guilty of difference?
#
# Third Citizen:
# 'Tis quickens, cried as the king's robe.
#
# JULIET:
# To set upon our caps in all nigeneman
# But Richmond, as a letter for that virtue.
#
# QUEEN:
# 'Tis that thy father'; 'Acauses! Our Mine of Lencimatory, and then.
#
# GREMIO:
# That false ape, that pardon r dis son, complaim indocence,
# As triumph-and is nos I, all the Tower hath preventers with him
# To grive
# And have all iless of autcaster point,
# Or thro twelven Tyans is, home:
# My brainly action did but set his attemity.
# Provost, as I did perform, good time!
# O world is in the neck.
#
# ROMEO:
# Ay you a youbself for it.
#
# Clown:
# See--
# Pay, here's many honour.
#
# AUFIDIUS:
# Is he should not: boy well forewell
# Commands him;
# You frown and fevain;
# So pernius, 'tis not whip to are backed:
# This is thy fiery true, hold that wind sweet slave,
# With dimes in manice for himself, 'tis myined
# Like scarfor his tongue.
#
# CLIFFORD:
# I warrant thy gracious friend and death
# Nor barn'd with it upon the holy wropp'W the measure
# I cannot make him: he hath swift before
# I'ld be my neighbour in your backs,
# And, protector on this exish an a man.
# But what my fortune so hers must obey no peril him!
# And low well metime to be balmed us;
# Her boot at me.
#
# Guntleran:
# No early more, goed; shall I pray
# Your banish'd curtle Richard bear.
#
# HENRY BOLINGBROKE:
# Lord mar her foot; and I am gone tongue'd him
# Is to make her tand ase to tame her in Camillo,
# Set how the larkful state
# Would bring this neck, until
# I make your cares with nature, whip thou have spoke,
# in his such good wardiat to Coventry.-
# Whither, I heaven it in beseech you
# Have made my chamber perform; commands,
# The appetition will rove terr from heant of time;
# I do not full off to love a followers
# All his world, for much for the garlad is
# no children is an amis'd,
# And mean not of your servants, bids me wrife;
# He knows the least is in the law: while I discomfers' postering
# Jemobity!
#
# AUFIDIUS:
# Well, sir:
# you chis his son:
# Did while it bless, they must compare;
# This sugable as the king of Saint Petruchio,
# Wheth all the like ashoraction
# Remember a sight
# And brought them knowl Nor fire us ind thus
# And here he like a haring.
#
# BENVOLIO:
# Then let me enter hide or damned Juliet.
#
# GLOUCESTER:
# Master us that had my mind in earth.
# Who, have you not kind watch? and what
# his poor souls is not what to say so, or what night
# Thus forthwift no ocacle, there shall bear
# To sleep change gestinedry in the hand:
# How now! what saynting is that shall be time
# Shall thinks to--to-day to my throne--
# I'll curse the ground I had releed them;
# Nay, if you were no world me wounded:
# took frame, of the carking! All hung by him
# Art tire sit Richard; for that time this mann,
# The house is m. God pity sound as id.
#
# MENENIUS:
# We wilt bear ut match.
#
# LEONTES:
# I do not shipped hole to shame.
# I did but fall the Souns, and wastemphers. Come,
# Think me for time with tears, and that will make me only
# 'Tis nothing is a matter, market when two woes.
# But now I know, to voshis night.
#
# DUKE
# 샘플링이 끝났습니다.!
# ------------------------------------------------------
# ------------------------------------------------------
# Epoch 16 Loss 1.0590
# Time taken for 1 epoch 13.616544485092163 sec
#
# Model: "rnn_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_6 (Embedding)     multiple                  16640
#
#  lstm_6 (LSTM)               multiple                  5246976
#
#  dense_6 (Dense)             multiple                  66625
#
# =================================================================
# Total params: 5,330,241
# Trainable params: 5,330,241
# Non-trainable params: 0
# _________________________________________________________________
# 샘플링을 시작합니다!
#  whis matter see a suitor love as you kill think to ome this land would have said of it,
# And hath e butt be vault.
#
# LUCENTIO:
# What some meats of Lord of Westmome constant comfort of your art,
# As he would put thee, embrace our stomach,
# Whom I prepared to you, Let me see thy helps
# And pray him here:
# The battle of the sport of peace engoved to the people,--that I have almost
# Unto the out that has believed,
# Send to remember me to companions by wit behold,
# It cannot command, like a piece of breast,
# Were piticcest lovers' passion
# Of things and scorns that any our fortune stops
# Purpose some clothes, wherein my throats have made
# Kin such violent of this endow to me.
# Lovel, I hate not saint's lands; I'll drink for this.
#
# KING RICHARD III:
# If that you shalt a put of unnatural-spear: mut
# Places her six obeyrin. What may the way out of the world beg
# you can turn you whip?
#
# RUTLANO:
# And if I do so remember me to make you at
# fair dissension for a noble Sulter!
# What, was you found them to the sickness of most loving foot,
# I warrant you with a fellow, multitoo of them.
#
# BENVOLIO:
# No, pardon, prince, forewell: speak on, that I must beg.
#
# YORK:
# Marry, they are in a more rehorsenon,
# Which from the braught members slave, who be attain'd with womb, is it not stuff'd
# As I am come to piece a conscience trodes,
# To have this just act and selful service of the percoanse of our mine.
#
# CLIFFORD:
# It is my remist and due for very lands,
# And then to keep it you,
# Was labour'd my blessing. This is the best
# promptart' and but an envigonour of his lovery part?
#
# EDWARD:
# They have wom committed at when you can, but my chamberlay:
# Yet we cantrollows for any time with rign;
# To know this great-lew more than the rest,
# An all that six withis more strawper'd win.
# Tou reap in put out at this mounder.
#
# VOLUMNIA:
# Miserable hunt before up-nothing brown boys: or,
# But, O, poor soul, coverture, I'll ring the soldiers;
# And much me devise, or will of such little souls
# To blain and shrewd blown queen!
#
# QUEEN MARGARET:
# Soft, what I have stapp'd our house.
#
# Capulets:
# And I have saim'd with saints as some meal honour.
#
# KING RICHARD III:
# Ay, must advantage of it; erchange my brother
# Lie, poun and sent my person fly to him?
#
# JULIET:
# Did. Ive you shall give her a lemeas, embrace you.
#
# Both:
# Away! the time is as an foul of trie
# Is this served needful, put up with splittle gratis.
# Where ever, thou? hies Thousand surprisoness of
# Rum-like time of silence! I have not died:
# You must appeal, set in the senate-book;
# Abide thy life and I know he come to the glorixger,
# And that thy boot-fall things n help.
#
# VOLUMNIA:
# Juin and thing these!
#
# GLOUCESTER:
# Ha!
#
# KING HENRY VI:
# Ay, comfort, unclen him to shoot up and bring you this?
#
# KING HENRY VI:
# My Lord of Norfolk, set up all rest, on
# The people dart of his embracies your tranious eye,
# To stugied up his wish at Claudio's life,
# More than a'erands e'er with suit
# As that of death's sad still usurp and ears.
#
# ROMEO:
# Now, Montague, for him to comfort my angry;
# Yet look'd when fame of you of mine orinato,
# Tire not grievous will we back thyselves;
# For we'll desperate not and make the crown,
# Having potion on the king with sole mild fort;
# And I of carriage nor chastisement;
# And when I pray thee, we did complaints, if not so: but get not
# you all king and nay! bry Volina promise them merry? say you think
# That I have ta'en our court-for Edward will;
# Thou old men diege embiard. For Purchand,
# You have no executed, what starts may strike sweet vows, the sea and harm:
# The meanest hair pursuit which my love beholding this into um,
# As priests as you do this descent than hate
# Ay, widow to tell you at your shorth.
# Come, cry so willingly to the watch of men!
#
# BIONDELLO:
# I see, a word or two, and love not for.
#
# MENENIUS:
# One wither?
#
# GREEN:
# You there's a harl-too been dry 'Corp's e'er have an humar's line-mines: A gentleman'd? must I commander my sword;
# Within this one word pale as made as saint
# That e'er our cour ob access and duke
# King Retuce of King Richard's trebate
# 샘플링이 끝났습니다.!
# ------------------------------------------------------
# 트레이닝이 끝났습니다!

# %%
sampling_RNN_model = RNN(batch_size=1)
sampling_RNN_model.load_weights(tf.train.latest_checkpoint(checkpoint_dir))
sampling_RNN_model.build(tf.TensorShape([1, None]))
sampling_RNN_model.summary()

# 샘플링을 시작합니다.
print("샘플링을 시작합니다!")
print(generate_text(sampling_RNN_model, start_string=u' '))
# Out:
# Model: "rnn_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_7 (Embedding)     multiple                  16640
#
#  lstm_7 (LSTM)               multiple                  5246976
#
#  dense_7 (Dense)             multiple                  66625
#
# =================================================================
# Total params: 5,330,241
# Trainable params: 5,330,241
# Non-trainable params: 0
# _________________________________________________________________
# 샘플링을 시작합니다!
#  here was a man that means remove.
#
# HASTINGS:
# Waken each other's faces, venturous stars,
# To live and that both I o'er-meet favour:
# Enforce me, die with got in plague appease you.
#
# AETOLYCUS:
#
# RIVERS:
# Who set this war, sweet Kate, commend me to the matter;
# And I, whilst how do I thank thee the time of waters
# Which ne'er last unnatural appetite,
# Subjects how you and yours were cominusted
# For our aurgrorn, our duty. Come on, for frether, can
# Precious state and not a stay to hold on
# yath-patience to the measure of a wasted great;
# What I will wait upon your voace's tail
# To shut the witness of the king:
# Where one changed it,
# Or what is dead? make paid it down;
# And yet your dilief lives can to ship.
#
# LORD ROSS:
# The good in heaven for yourself to be
# A stractly rancour for my neck,
# And thish, as which I do go;
# Dardy promise to the day, not free friends;
# If little needle, my fortunes and your death
# Had rat assoice will not do it in my mouth,
# To make an rose that are not in mere glove.
#
# Clown:
# Ay, sir: 'tis goodlish to so: him nothing fitting
# The head of all all his sister sound his lady as if
# 'Twere best being wearoned apparell'd!
# I must be so: gentle my noble ususity
# Such as you say, you were you are here with him:
# Be hear not a dukedom, and I wot of strength,
# My partn of knighthous wants in seedy,
# Rath passion castled Pita's daughter him as king,
# As he so signal me: O, the city, sir, d I:
# Now are you land of comfort brine at the best.
#
# LUCENTIO:
# But hear me speak?
#
# BUCKINGHAM:
# I do, my liege, you must put my page.
#
# KING RICHARD II:
# Her lord is danner, do not breathe my right.
# I cannot be arrived; thence I am lost.
#
# LORD ROSS:
# Is that valiant trouble mover me;
# And, in good importing you, the best
# Marcius that too much married; and you
# shall find-'tis that the executionery
# conjervate with a bountest of thy bosom to show your than my daughter!
# Farewell; I can march at me am death.
#
# CLARENCE:
# From which the matter perceive you?
#
# Volsce:
# Yet news, my lord: owes--
#
# SICINIUS:
# This was on, man:
# For thou sund from a tale a trall time.
#
# SICINIUS:
# Is this great as proceed as I.
# After the pretty Isabellas must be cure.
#
# LORD FITZGREY:
# Good night: medhenly;
# 'Foldship is to kindled and unfeigned friends,
# Because her from ye wench; remains not in the
# present, and then run ancient malice hath
# her forces, mum and sound the every rights
# Eifther to his submissiverity;
# Brief most impurence with two impuse nowards.
# Therefore at least must else.
#
# PETRUCHIO:
# Marry, my lord, we would have ragin for and meel. Vouchsafe with
# the plender; therefore, for I will buzzled,--O, if I beseech your grace,
# But by her son shall paler him and mine
# amoucts not tauch it occhern by the heart.
# The eye is that for the
# ivalroas war, for him he gall'd for from my realmen life.
# What says not her human heaven,
# Should send foot.
#
# SICINIUS:
# What is the bast?
#
# LUCIO:
# Then:
# Now ope the indictment of the compass.
#
# PERDITA:
# How may have comfort honour, some doubts
# muct shall resign me of reason that I am.
#
# KING RICHARD III:
# Harp not on this?
#
# FLORIZEL:
# My lord, you shall have the matter for my father's house.
#
# GREMIO:
# And most help to this attempting them,
# gnays with child of all the swords. I point Pompey,
# For the sun sense
# The dut that e'er run death with spled;
# And what should shall be wounded?
#
# ISABELLA:
# By carces to your households? bid him not;
# You pluck it now to wear a prince's door
# And by the sight of your advansage, where they wish me rage;
# So easy is here on't.
#
# BRUTUS:
# No more.
# Come to me, for I chave a bitch degree in your remedies;
# And to that fair rose language for his visage maid! I would
# Show thy beff with such comporitius;
# Which, as a fool was spirit to me that Master Sprond.
# INGERS:
# It stands, bring forth golden or unless thing
# That all within the veal their wacts and threatening wrongs.
# Musted me me 't. Farewell, my old comfort with;
# And never true contempt he dies here?
#
# PRINCE:
# God for my cousin! whose hour betisuses; blads, assy we fight:
# As, woulds have founds up

# %%
# %run train_and_sampling.py
