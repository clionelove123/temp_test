# %% [markdown]
# <a href="https://colab.research.google.com/github/clionelove123/temp_test/blob/main/Chap_11_GAN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# -*- coding: utf-8 -*-
# GAN(Generative Adversarial Networks)을 이용한 MNIST 데이터 생성 - Keras API를 이용한 구현
# Reference : https://github.com/TengdaHan/GAN-TensorFlow

import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
import os

# %%
# MNIST 데이터를 다운로드 합니다.
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.mnist.load_data()
# 이미지들을 float32 데이터 타입으로 변경합니다.
x_train, x_test = x_train.astype('float32'), x_test.astype('float32')
# 28*28 형태의 이미지를 784차원으로 flattening 합니다.
x_train, x_test = x_train.reshape([-1, 784]), x_test.reshape([-1, 784])
# [0, 255] 사이의 값을 [0, 1]사이의 값으로 Normalize합니다.
x_train, x_test = x_train / 255., x_test / 255.

# 생성된 MNIST 이미지를 8x8 Grid로 보여주는 plot 함수를 정의합니다.
def plot(samples):
  fig = plt.figure(figsize=(8, 8))
  gs = gridspec.GridSpec(8, 8)
  gs.update(wspace=0.05, hspace=0.05)

  for i, sample in enumerate(samples):
    ax = plt.subplot(gs[i])
    plt.axis('off')
    plt.imshow(sample.reshape(28, 28))

  return fig

# 학습에 필요한 설정값들을 선언합니다.
num_epoch = 100000
batch_size = 64
num_input = 28 * 28
num_latent_variable = 100   # 잠재 변수 z의 차원
num_hidden = 128
learning_rate = 0.001
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 [==============================] - 0s 0us/step

# %%
# tf.data API를 이용해서 데이터를 섞고 batch 형태로 가져옵니다.
train_data = tf.data.Dataset.from_tensor_slices(x_train)
train_data = train_data.repeat().shuffle(60000).batch(batch_size)
train_data_iter = iter(train_data)

def random_normal_intializer(stddev):
  return tf.keras.initializers.RandomNormal(mean=0.0, stddev=stddev, seed=None)

# %%
# tf.keras.Model을 이용해서 Generator 모델을 정의합니다.
# Inputs:
#   X : 인풋 Latent Variable
# Outputs:
#   generated_mnist_image : 생성된 MNIST 이미지
class Generator(tf.keras.Model):
  def __init__(self):
    super(Generator, self).__init__()
    # 100 -> 128 -> 784
    # 히든 레이어 파라미터
    self.hidden_layer_1 = tf.keras.layers.Dense(num_hidden,
                                                activation='relu',
                                                kernel_initializer=random_normal_intializer(5e-2),
                                                bias_initializer=tf.keras.initializers.Constant(value=0.1))
    # 아웃풋 레이어 파라미터
    self.output_layer = tf.keras.layers.Dense(num_input,
                                              activation='sigmoid',
                                              kernel_initializer=random_normal_intializer(5e-2),
                                              bias_initializer=tf.keras.initializers.Constant(value=0.1))

  def call(self, x):
    hidden_layer = self.hidden_layer_1(x)
    generated_mnist_image = self.output_layer(hidden_layer)

    return generated_mnist_image

# %%
# tf.keras.Model을 이용해서 Discriminator 모델을 정의합니다.
# Inputs:
#   X : 인풋 이미지
# Outputs:
#   predicted_value : Discriminator가 판단한 True(1) or Fake(0)
#   logits : sigmoid를 씌우기전의 출력값
class Discriminator(tf.keras.Model):
  def __init__(self):
    super(Discriminator, self).__init__()
    # 784 -> 128 -> 1
    # 히든 레이어 파라미터
    self.hidden_layer_1 = tf.keras.layers.Dense(num_hidden,
                                                activation='relu',
                                                kernel_initializer=random_normal_intializer(5e-2),
                                                bias_initializer=tf.keras.initializers.Constant(value=0.1))
    # 아웃풋 레이어 파라미터
    self.output_layer = tf.keras.layers.Dense(1,
                                              activation=None,
                                              kernel_initializer=random_normal_intializer(5e-2),
                                              bias_initializer=tf.keras.initializers.Constant(value=0.1))

  def call(self, x):
    hidden_layer = self.hidden_layer_1(x)
    logits = self.output_layer(hidden_layer)
    predicted_value = tf.nn.sigmoid(logits)

    return predicted_value, logits

# %%
# Generator의 손실 함수를 정의합니다.
@tf.function
def generator_loss(D_fake_logits):
  return tf.reduce_mean(tf.nn.sigmoid_cross_entropy_with_logits(logits=D_fake_logits, labels=tf.ones_like(D_fake_logits)))         # log(D(G(z))

# Discriminator의 손실 함수를 정의합니다.
@tf.function
def discriminator_loss(D_real_logits, D_fake_logits):
  d_loss_real = tf.reduce_mean(tf.nn.sigmoid_cross_entropy_with_logits(logits=D_real_logits, labels=tf.ones_like(D_real_logits)))  # log(D(x))
  d_loss_fake = tf.reduce_mean(tf.nn.sigmoid_cross_entropy_with_logits(logits=D_fake_logits, labels=tf.zeros_like(D_fake_logits)))  # log(1-D(G(z)))
  d_loss = d_loss_real + d_loss_fake  # log(D(x)) + log(1-D(G(z)))

  return d_loss

# %%
# 생성자(Generator) 모델을 선언합니다.
Generator_model = Generator()

# 구분자(Discriminator) 모델을 선언합니다.
Discriminator_model = Discriminator()

# Discriminator와 Generator를 위한 Optimizer들을 정의합니다.
discriminator_optimizer = tf.optimizers.Adam(learning_rate)
generator_optimizer = tf.optimizers.Adam(learning_rate)

# Discriminator 최적화를 위한 function을 정의합니다.
@tf.function
def d_train_step(discriminator_model, real_image, fake_image):
  with tf.GradientTape() as disc_tape:
    D_real, D_real_logits = discriminator_model(real_image)  # D(x)
    D_fake, D_fake_logits = discriminator_model(fake_image)  # D(G(z))
    loss = discriminator_loss(D_real_logits, D_fake_logits)
  gradients = disc_tape.gradient(loss, discriminator_model.trainable_variables)
  discriminator_optimizer.apply_gradients(zip(gradients, discriminator_model.trainable_variables))

# Generator 최적화를 위한 function을 정의합니다.
@tf.function
def g_train_step(generator_model, discriminator_model, z):
  with tf.GradientTape() as gen_tape:
    G = generator_model(z)
    D_fake, D_fake_logits = discriminator_model(G)  # D(G(z))
    loss = generator_loss(D_fake_logits)
  gradients = gen_tape.gradient(loss, generator_model.trainable_variables)
  generator_optimizer.apply_gradients(zip(gradients, generator_model.trainable_variables))

# %%
# 생성된 이미지들을 저장할 generated_output 폴더를 생성합니다.
num_img = 0
if not os.path.exists('generated_output/'):
  os.makedirs('generated_output/')

# num_epoch 횟수만큼 최적화를 수행합니다.
for i in range(num_epoch):
  # MNIST 이미지를 batch_size만큼 불러옵니다.
  batch_X = next(train_data_iter)

  # Latent Variable의 인풋으로 사용할 noise를 Uniform Distribution에서 batch_size 개수만큼 샘플링합니다.
  batch_noise = np.random.uniform(-1., 1., [batch_size, 100]).astype('float32')

  # 500번 반복할때마다 생성된 이미지를 저장합니다.
  if i % 500 == 0:
    samples = Generator_model(np.random.uniform(-1., 1., [64, 100]).astype('float32')).numpy()
    fig = plot(samples)
    plt.savefig('generated_output/%s.png' % str(num_img).zfill(3), bbox_inches='tight')
    num_img += 1
    plt.close(fig)

  # Discriminator 최적화를 수행하고 Discriminator의 손실함수를 return합니다.
  _, d_loss_print = d_train_step(Discriminator_model, batch_X, Generator_model(batch_noise)), discriminator_loss(Discriminator_model(batch_X)[1], Discriminator_model(Generator_model(batch_noise))[1])

  # Generator 최적화를 수행하고 Generator 손실함수를 return합니다.
  _, g_loss_print = g_train_step(Generator_model, Discriminator_model, batch_noise), generator_loss(Discriminator_model(Generator_model(batch_noise))[1])

  # 100번 반복할때마다 Discriminator의 손실함수와 Generator 손실함수를 출력합니다.
  if i % 100 == 0:
    print('반복(Epoch): %d, Generator 손실함수(g_loss): %f, Discriminator 손실함수(d_loss): %f' % (i, g_loss_print, d_loss_print))
# Out:
# 반복(Epoch): 0, Generator 손실함수(g_loss): 1.487437, Discriminator 손실함수(d_loss): 0.966135
# 반복(Epoch): 100, Generator 손실함수(g_loss): 2.496813, Discriminator 손실함수(d_loss): 0.412196
# 반복(Epoch): 200, Generator 손실함수(g_loss): 3.374493, Discriminator 손실함수(d_loss): 0.131666
# 반복(Epoch): 300, Generator 손실함수(g_loss): 4.530323, Discriminator 손실함수(d_loss): 0.013044
# 반복(Epoch): 400, Generator 손실함수(g_loss): 4.645432, Discriminator 손실함수(d_loss): 0.018580
# 반복(Epoch): 500, Generator 손실함수(g_loss): 5.229744, Discriminator 손실함수(d_loss): 0.047073
# 반복(Epoch): 600, Generator 손실함수(g_loss): 5.919028, Discriminator 손실함수(d_loss): 0.009279
# 반복(Epoch): 700, Generator 손실함수(g_loss): 5.749841, Discriminator 손실함수(d_loss): 0.028784
# 반복(Epoch): 800, Generator 손실함수(g_loss): 5.909723, Discriminator 손실함수(d_loss): 0.012418
# 반복(Epoch): 900, Generator 손실함수(g_loss): 5.823652, Discriminator 손실함수(d_loss): 0.004316
# 반복(Epoch): 1000, Generator 손실함수(g_loss): 7.779797, Discriminator 손실함수(d_loss): 0.003470
# 반복(Epoch): 1100, Generator 손실함수(g_loss): 9.428491, Discriminator 손실함수(d_loss): 0.007275
# 반복(Epoch): 1200, Generator 손실함수(g_loss): 11.556234, Discriminator 손실함수(d_loss): 0.002570
# 반복(Epoch): 1300, Generator 손실함수(g_loss): 5.947127, Discriminator 손실함수(d_loss): 0.004014
# 반복(Epoch): 1400, Generator 손실함수(g_loss): 4.410323, Discriminator 손실함수(d_loss): 0.025361
# 반복(Epoch): 1500, Generator 손실함수(g_loss): 5.794749, Discriminator 손실함수(d_loss): 0.013383
# 반복(Epoch): 1600, Generator 손실함수(g_loss): 5.582667, Discriminator 손실함수(d_loss): 0.007939
# 반복(Epoch): 1700, Generator 손실함수(g_loss): 6.066231, Discriminator 손실함수(d_loss): 0.010064
# 반복(Epoch): 1800, Generator 손실함수(g_loss): 6.531917, Discriminator 손실함수(d_loss): 0.005533
# 반복(Epoch): 1900, Generator 손실함수(g_loss): 7.472811, Discriminator 손실함수(d_loss): 0.002660
# 반복(Epoch): 2000, Generator 손실함수(g_loss): 6.312684, Discriminator 손실함수(d_loss): 0.012787
# 반복(Epoch): 2100, Generator 손실함수(g_loss): 7.077714, Discriminator 손실함수(d_loss): 0.003702
# 반복(Epoch): 2200, Generator 손실함수(g_loss): 5.755694, Discriminator 손실함수(d_loss): 0.005481
# 반복(Epoch): 2300, Generator 손실함수(g_loss): 6.599532, Discriminator 손실함수(d_loss): 0.015160
# 반복(Epoch): 2400, Generator 손실함수(g_loss): 5.808791, Discriminator 손실함수(d_loss): 0.026745
# 반복(Epoch): 2500, Generator 손실함수(g_loss): 6.045628, Discriminator 손실함수(d_loss): 0.040385
# 반복(Epoch): 2600, Generator 손실함수(g_loss): 5.640390, Discriminator 손실함수(d_loss): 0.034373
# 반복(Epoch): 2700, Generator 손실함수(g_loss): 5.175369, Discriminator 손실함수(d_loss): 0.009249
# 반복(Epoch): 2800, Generator 손실함수(g_loss): 5.011992, Discriminator 손실함수(d_loss): 0.060359
# 반복(Epoch): 2900, Generator 손실함수(g_loss): 5.626958, Discriminator 손실함수(d_loss): 0.011334
# 반복(Epoch): 3000, Generator 손실함수(g_loss): 4.755026, Discriminator 손실함수(d_loss): 0.016943
# 반복(Epoch): 3100, Generator 손실함수(g_loss): 5.780288, Discriminator 손실함수(d_loss): 0.048962
# 반복(Epoch): 3200, Generator 손실함수(g_loss): 4.169810, Discriminator 손실함수(d_loss): 0.038895
# 반복(Epoch): 3300, Generator 손실함수(g_loss): 5.429334, Discriminator 손실함수(d_loss): 0.082748
# 반복(Epoch): 3400, Generator 손실함수(g_loss): 8.157560, Discriminator 손실함수(d_loss): 0.022124
# 반복(Epoch): 3500, Generator 손실함수(g_loss): 5.594254, Discriminator 손실함수(d_loss): 0.033513
# 반복(Epoch): 3600, Generator 손실함수(g_loss): 5.713757, Discriminator 손실함수(d_loss): 0.018977
# 반복(Epoch): 3700, Generator 손실함수(g_loss): 6.112044, Discriminator 손실함수(d_loss): 0.016570
# 반복(Epoch): 3800, Generator 손실함수(g_loss): 4.244627, Discriminator 손실함수(d_loss): 0.052671
# 반복(Epoch): 3900, Generator 손실함수(g_loss): 4.766474, Discriminator 손실함수(d_loss): 0.066605
# 반복(Epoch): 4000, Generator 손실함수(g_loss): 4.106602, Discriminator 손실함수(d_loss): 0.050628
# 반복(Epoch): 4100, Generator 손실함수(g_loss): 4.640152, Discriminator 손실함수(d_loss): 0.065821
# 반복(Epoch): 4200, Generator 손실함수(g_loss): 4.811042, Discriminator 손실함수(d_loss): 0.043897
# 반복(Epoch): 4300, Generator 손실함수(g_loss): 3.750268, Discriminator 손실함수(d_loss): 0.071281
# 반복(Epoch): 4400, Generator 손실함수(g_loss): 3.922003, Discriminator 손실함수(d_loss): 0.063792
# 반복(Epoch): 4500, Generator 손실함수(g_loss): 5.619253, Discriminator 손실함수(d_loss): 0.120094
# 반복(Epoch): 4600, Generator 손실함수(g_loss): 4.912493, Discriminator 손실함수(d_loss): 0.079816
# 반복(Epoch): 4700, Generator 손실함수(g_loss): 4.792633, Discriminator 손실함수(d_loss): 0.077926
# 반복(Epoch): 4800, Generator 손실함수(g_loss): 4.754305, Discriminator 손실함수(d_loss): 0.093114
# 반복(Epoch): 4900, Generator 손실함수(g_loss): 5.505158, Discriminator 손실함수(d_loss): 0.176496
# 반복(Epoch): 5000, Generator 손실함수(g_loss): 3.632500, Discriminator 손실함수(d_loss): 0.078294
# 반복(Epoch): 5100, Generator 손실함수(g_loss): 4.916095, Discriminator 손실함수(d_loss): 0.079814
# 반복(Epoch): 5200, Generator 손실함수(g_loss): 3.840577, Discriminator 손실함수(d_loss): 0.127865
# 반복(Epoch): 5300, Generator 손실함수(g_loss): 5.067532, Discriminator 손실함수(d_loss): 0.201919
# 반복(Epoch): 5400, Generator 손실함수(g_loss): 4.961075, Discriminator 손실함수(d_loss): 0.149737
# 반복(Epoch): 5500, Generator 손실함수(g_loss): 4.639066, Discriminator 손실함수(d_loss): 0.179159
# 반복(Epoch): 5600, Generator 손실함수(g_loss): 4.635589, Discriminator 손실함수(d_loss): 0.117072
# 반복(Epoch): 5700, Generator 손실함수(g_loss): 5.324271, Discriminator 손실함수(d_loss): 0.096443
# 반복(Epoch): 5800, Generator 손실함수(g_loss): 3.419096, Discriminator 손실함수(d_loss): 0.142243
# 반복(Epoch): 5900, Generator 손실함수(g_loss): 4.165694, Discriminator 손실함수(d_loss): 0.162246
# 반복(Epoch): 6000, Generator 손실함수(g_loss): 4.084255, Discriminator 손실함수(d_loss): 0.230337
# 반복(Epoch): 6100, Generator 손실함수(g_loss): 4.649211, Discriminator 손실함수(d_loss): 0.503815
# 반복(Epoch): 6200, Generator 손실함수(g_loss): 3.866232, Discriminator 손실함수(d_loss): 0.213027
# 반복(Epoch): 6300, Generator 손실함수(g_loss): 3.981528, Discriminator 손실함수(d_loss): 0.224922
# 반복(Epoch): 6400, Generator 손실함수(g_loss): 3.624057, Discriminator 손실함수(d_loss): 0.209683
# 반복(Epoch): 6500, Generator 손실함수(g_loss): 3.267723, Discriminator 손실함수(d_loss): 0.167718
# 반복(Epoch): 6600, Generator 손실함수(g_loss): 4.086670, Discriminator 손실함수(d_loss): 0.213842
# 반복(Epoch): 6700, Generator 손실함수(g_loss): 4.154677, Discriminator 손실함수(d_loss): 0.151753
# 반복(Epoch): 6800, Generator 손실함수(g_loss): 3.849382, Discriminator 손실함수(d_loss): 0.233133
# 반복(Epoch): 6900, Generator 손실함수(g_loss): 4.491168, Discriminator 손실함수(d_loss): 0.331625
# 반복(Epoch): 7000, Generator 손실함수(g_loss): 3.896997, Discriminator 손실함수(d_loss): 0.287034
# 반복(Epoch): 7100, Generator 손실함수(g_loss): 3.431350, Discriminator 손실함수(d_loss): 0.493182
# 반복(Epoch): 7200, Generator 손실함수(g_loss): 3.564883, Discriminator 손실함수(d_loss): 0.297725
# 반복(Epoch): 7300, Generator 손실함수(g_loss): 3.331769, Discriminator 손실함수(d_loss): 0.463212
# 반복(Epoch): 7400, Generator 손실함수(g_loss): 3.694753, Discriminator 손실함수(d_loss): 0.242074
# 반복(Epoch): 7500, Generator 손실함수(g_loss): 3.581497, Discriminator 손실함수(d_loss): 0.238638
# 반복(Epoch): 7600, Generator 손실함수(g_loss): 2.917981, Discriminator 손실함수(d_loss): 0.270687
# 반복(Epoch): 7700, Generator 손실함수(g_loss): 3.242765, Discriminator 손실함수(d_loss): 0.318456
# 반복(Epoch): 7800, Generator 손실함수(g_loss): 3.111743, Discriminator 손실함수(d_loss): 0.247688
# 반복(Epoch): 7900, Generator 손실함수(g_loss): 3.069413, Discriminator 손실함수(d_loss): 0.486210
# 반복(Epoch): 8000, Generator 손실함수(g_loss): 3.940566, Discriminator 손실함수(d_loss): 0.279695
# 반복(Epoch): 8100, Generator 손실함수(g_loss): 3.725863, Discriminator 손실함수(d_loss): 0.512454
# 반복(Epoch): 8200, Generator 손실함수(g_loss): 3.287028, Discriminator 손실함수(d_loss): 0.240590
# 반복(Epoch): 8300, Generator 손실함수(g_loss): 4.118209, Discriminator 손실함수(d_loss): 0.541320
# 반복(Epoch): 8400, Generator 손실함수(g_loss): 3.047338, Discriminator 손실함수(d_loss): 0.322877
# 반복(Epoch): 8500, Generator 손실함수(g_loss): 2.515460, Discriminator 손실함수(d_loss): 0.708865
# 반복(Epoch): 8600, Generator 손실함수(g_loss): 2.821144, Discriminator 손실함수(d_loss): 0.548783
# 반복(Epoch): 8700, Generator 손실함수(g_loss): 3.052091, Discriminator 손실함수(d_loss): 0.447512
# 반복(Epoch): 8800, Generator 손실함수(g_loss): 3.194360, Discriminator 손실함수(d_loss): 0.401546
# 반복(Epoch): 8900, Generator 손실함수(g_loss): 2.728727, Discriminator 손실함수(d_loss): 0.507980
# 반복(Epoch): 9000, Generator 손실함수(g_loss): 3.143317, Discriminator 손실함수(d_loss): 0.281969
# 반복(Epoch): 9100, Generator 손실함수(g_loss): 2.629590, Discriminator 손실함수(d_loss): 0.498962
# 반복(Epoch): 9200, Generator 손실함수(g_loss): 2.882970, Discriminator 손실함수(d_loss): 0.567580
# 반복(Epoch): 9300, Generator 손실함수(g_loss): 2.304797, Discriminator 손실함수(d_loss): 0.655638
# 반복(Epoch): 9400, Generator 손실함수(g_loss): 2.796550, Discriminator 손실함수(d_loss): 0.661882
# 반복(Epoch): 9500, Generator 손실함수(g_loss): 2.237835, Discriminator 손실함수(d_loss): 0.605819
# 반복(Epoch): 9600, Generator 손실함수(g_loss): 2.784143, Discriminator 손실함수(d_loss): 0.383417
# 반복(Epoch): 9700, Generator 손실함수(g_loss): 3.044065, Discriminator 손실함수(d_loss): 0.608629
# 반복(Epoch): 9800, Generator 손실함수(g_loss): 2.449578, Discriminator 손실함수(d_loss): 0.426762
# 반복(Epoch): 9900, Generator 손실함수(g_loss): 2.591252, Discriminator 손실함수(d_loss): 0.654910
# 반복(Epoch): 10000, Generator 손실함수(g_loss): 2.388319, Discriminator 손실함수(d_loss): 0.471171
# 반복(Epoch): 10100, Generator 손실함수(g_loss): 3.616962, Discriminator 손실함수(d_loss): 0.674336
# 반복(Epoch): 10200, Generator 손실함수(g_loss): 2.290590, Discriminator 손실함수(d_loss): 0.651107
# 반복(Epoch): 10300, Generator 손실함수(g_loss): 3.117617, Discriminator 손실함수(d_loss): 0.430649
# 반복(Epoch): 10400, Generator 손실함수(g_loss): 2.535849, Discriminator 손실함수(d_loss): 0.941896
# 반복(Epoch): 10500, Generator 손실함수(g_loss): 2.712427, Discriminator 손실함수(d_loss): 0.790272
# 반복(Epoch): 10600, Generator 손실함수(g_loss): 2.988160, Discriminator 손실함수(d_loss): 0.547398
# 반복(Epoch): 10700, Generator 손실함수(g_loss): 1.809627, Discriminator 손실함수(d_loss): 0.635680
# 반복(Epoch): 10800, Generator 손실함수(g_loss): 2.849914, Discriminator 손실함수(d_loss): 0.527528
# 반복(Epoch): 10900, Generator 손실함수(g_loss): 2.478014, Discriminator 손실함수(d_loss): 0.570047
# 반복(Epoch): 11000, Generator 손실함수(g_loss): 2.659761, Discriminator 손실함수(d_loss): 0.541741
# 반복(Epoch): 11100, Generator 손실함수(g_loss): 2.505490, Discriminator 손실함수(d_loss): 0.684150
# 반복(Epoch): 11200, Generator 손실함수(g_loss): 2.135881, Discriminator 손실함수(d_loss): 0.969044
# 반복(Epoch): 11300, Generator 손실함수(g_loss): 2.743180, Discriminator 손실함수(d_loss): 0.564441
# 반복(Epoch): 11400, Generator 손실함수(g_loss): 2.878925, Discriminator 손실함수(d_loss): 0.434114
# 반복(Epoch): 11500, Generator 손실함수(g_loss): 2.464736, Discriminator 손실함수(d_loss): 0.591823
# 반복(Epoch): 11600, Generator 손실함수(g_loss): 2.437731, Discriminator 손실함수(d_loss): 0.838125
# 반복(Epoch): 11700, Generator 손실함수(g_loss): 2.319295, Discriminator 손실함수(d_loss): 0.718016
# 반복(Epoch): 11800, Generator 손실함수(g_loss): 2.617159, Discriminator 손실함수(d_loss): 0.613356
# 반복(Epoch): 11900, Generator 손실함수(g_loss): 2.209055, Discriminator 손실함수(d_loss): 0.816116
# 반복(Epoch): 12000, Generator 손실함수(g_loss): 3.145561, Discriminator 손실함수(d_loss): 0.716514
# 반복(Epoch): 12100, Generator 손실함수(g_loss): 2.781957, Discriminator 손실함수(d_loss): 0.549704
# 반복(Epoch): 12200, Generator 손실함수(g_loss): 2.647599, Discriminator 손실함수(d_loss): 0.410852
# 반복(Epoch): 12300, Generator 손실함수(g_loss): 2.217990, Discriminator 손실함수(d_loss): 0.702627
# 반복(Epoch): 12400, Generator 손실함수(g_loss): 2.171412, Discriminator 손실함수(d_loss): 0.573417
# 반복(Epoch): 12500, Generator 손실함수(g_loss): 2.432383, Discriminator 손실함수(d_loss): 0.664730
# 반복(Epoch): 12600, Generator 손실함수(g_loss): 1.913965, Discriminator 손실함수(d_loss): 0.832085
# 반복(Epoch): 12700, Generator 손실함수(g_loss): 2.476177, Discriminator 손실함수(d_loss): 0.473795
# 반복(Epoch): 12800, Generator 손실함수(g_loss): 2.262894, Discriminator 손실함수(d_loss): 0.648893
# 반복(Epoch): 12900, Generator 손실함수(g_loss): 2.893760, Discriminator 손실함수(d_loss): 0.574528
# 반복(Epoch): 13000, Generator 손실함수(g_loss): 2.201403, Discriminator 손실함수(d_loss): 1.020903
# 반복(Epoch): 13100, Generator 손실함수(g_loss): 2.101478, Discriminator 손실함수(d_loss): 0.787181
# 반복(Epoch): 13200, Generator 손실함수(g_loss): 2.249343, Discriminator 손실함수(d_loss): 0.619176
# 반복(Epoch): 13300, Generator 손실함수(g_loss): 2.140087, Discriminator 손실함수(d_loss): 0.630637
# 반복(Epoch): 13400, Generator 손실함수(g_loss): 2.026959, Discriminator 손실함수(d_loss): 0.699005
# 반복(Epoch): 13500, Generator 손실함수(g_loss): 2.140091, Discriminator 손실함수(d_loss): 0.643070
# 반복(Epoch): 13600, Generator 손실함수(g_loss): 2.154175, Discriminator 손실함수(d_loss): 0.632815
# 반복(Epoch): 13700, Generator 손실함수(g_loss): 2.223702, Discriminator 손실함수(d_loss): 0.846774
# 반복(Epoch): 13800, Generator 손실함수(g_loss): 2.114002, Discriminator 손실함수(d_loss): 0.823376
# 반복(Epoch): 13900, Generator 손실함수(g_loss): 1.723703, Discriminator 손실함수(d_loss): 0.780556
# 반복(Epoch): 14000, Generator 손실함수(g_loss): 2.005007, Discriminator 손실함수(d_loss): 0.777765
# 반복(Epoch): 14100, Generator 손실함수(g_loss): 2.035124, Discriminator 손실함수(d_loss): 0.729160
# 반복(Epoch): 14200, Generator 손실함수(g_loss): 2.599373, Discriminator 손실함수(d_loss): 0.764362
# 반복(Epoch): 14300, Generator 손실함수(g_loss): 2.173836, Discriminator 손실함수(d_loss): 0.481558
# 반복(Epoch): 14400, Generator 손실함수(g_loss): 1.927202, Discriminator 손실함수(d_loss): 1.056374
# 반복(Epoch): 14500, Generator 손실함수(g_loss): 2.366443, Discriminator 손실함수(d_loss): 0.753892
# 반복(Epoch): 14600, Generator 손실함수(g_loss): 2.223593, Discriminator 손실함수(d_loss): 0.678939
# 반복(Epoch): 14700, Generator 손실함수(g_loss): 1.877944, Discriminator 손실함수(d_loss): 0.663242
# 반복(Epoch): 14800, Generator 손실함수(g_loss): 1.861425, Discriminator 손실함수(d_loss): 0.551827
# 반복(Epoch): 14900, Generator 손실함수(g_loss): 2.454730, Discriminator 손실함수(d_loss): 0.765473
# 반복(Epoch): 15000, Generator 손실함수(g_loss): 2.261633, Discriminator 손실함수(d_loss): 0.861119
# 반복(Epoch): 15100, Generator 손실함수(g_loss): 2.548696, Discriminator 손실함수(d_loss): 0.763405
# 반복(Epoch): 15200, Generator 손실함수(g_loss): 2.421067, Discriminator 손실함수(d_loss): 0.594101
# 반복(Epoch): 15300, Generator 손실함수(g_loss): 2.418212, Discriminator 손실함수(d_loss): 0.862429
# 반복(Epoch): 15400, Generator 손실함수(g_loss): 2.507864, Discriminator 손실함수(d_loss): 0.671544
# 반복(Epoch): 15500, Generator 손실함수(g_loss): 2.430235, Discriminator 손실함수(d_loss): 0.629451
# 반복(Epoch): 15600, Generator 손실함수(g_loss): 2.263744, Discriminator 손실함수(d_loss): 0.835266
# 반복(Epoch): 15700, Generator 손실함수(g_loss): 2.415063, Discriminator 손실함수(d_loss): 0.423734
# 반복(Epoch): 15800, Generator 손실함수(g_loss): 2.856763, Discriminator 손실함수(d_loss): 0.522576
# 반복(Epoch): 15900, Generator 손실함수(g_loss): 2.299272, Discriminator 손실함수(d_loss): 0.723027
# 반복(Epoch): 16000, Generator 손실함수(g_loss): 1.685655, Discriminator 손실함수(d_loss): 0.820971
# 반복(Epoch): 16100, Generator 손실함수(g_loss): 2.156267, Discriminator 손실함수(d_loss): 0.617687
# 반복(Epoch): 16200, Generator 손실함수(g_loss): 2.617578, Discriminator 손실함수(d_loss): 0.589355
# 반복(Epoch): 16300, Generator 손실함수(g_loss): 1.330770, Discriminator 손실함수(d_loss): 1.033205
# 반복(Epoch): 16400, Generator 손실함수(g_loss): 2.243250, Discriminator 손실함수(d_loss): 0.719481
# 반복(Epoch): 16500, Generator 손실함수(g_loss): 2.003817, Discriminator 손실함수(d_loss): 0.566538
# 반복(Epoch): 16600, Generator 손실함수(g_loss): 2.136652, Discriminator 손실함수(d_loss): 0.767103
# 반복(Epoch): 16700, Generator 손실함수(g_loss): 2.358590, Discriminator 손실함수(d_loss): 0.706871
# 반복(Epoch): 16800, Generator 손실함수(g_loss): 1.739877, Discriminator 손실함수(d_loss): 0.750460
# 반복(Epoch): 16900, Generator 손실함수(g_loss): 2.038023, Discriminator 손실함수(d_loss): 0.606615
# 반복(Epoch): 17000, Generator 손실함수(g_loss): 1.590926, Discriminator 손실함수(d_loss): 0.833876
# 반복(Epoch): 17100, Generator 손실함수(g_loss): 2.161355, Discriminator 손실함수(d_loss): 0.704183
# 반복(Epoch): 17200, Generator 손실함수(g_loss): 1.959869, Discriminator 손실함수(d_loss): 0.820697
# 반복(Epoch): 17300, Generator 손실함수(g_loss): 2.106200, Discriminator 손실함수(d_loss): 0.767518
# 반복(Epoch): 17400, Generator 손실함수(g_loss): 1.733977, Discriminator 손실함수(d_loss): 0.668046
# 반복(Epoch): 17500, Generator 손실함수(g_loss): 1.859979, Discriminator 손실함수(d_loss): 0.951779
# 반복(Epoch): 17600, Generator 손실함수(g_loss): 2.015815, Discriminator 손실함수(d_loss): 0.742952
# 반복(Epoch): 17700, Generator 손실함수(g_loss): 1.731350, Discriminator 손실함수(d_loss): 0.567946
# 반복(Epoch): 17800, Generator 손실함수(g_loss): 1.882447, Discriminator 손실함수(d_loss): 0.718678
# 반복(Epoch): 17900, Generator 손실함수(g_loss): 1.894047, Discriminator 손실함수(d_loss): 0.940989
# 반복(Epoch): 18000, Generator 손실함수(g_loss): 2.199623, Discriminator 손실함수(d_loss): 0.690286
# 반복(Epoch): 18100, Generator 손실함수(g_loss): 1.762710, Discriminator 손실함수(d_loss): 0.929007
# 반복(Epoch): 18200, Generator 손실함수(g_loss): 1.879604, Discriminator 손실함수(d_loss): 0.543320
# 반복(Epoch): 18300, Generator 손실함수(g_loss): 1.835757, Discriminator 손실함수(d_loss): 0.622191
# 반복(Epoch): 18400, Generator 손실함수(g_loss): 1.930758, Discriminator 손실함수(d_loss): 0.808515
# 반복(Epoch): 18500, Generator 손실함수(g_loss): 1.818348, Discriminator 손실함수(d_loss): 0.653945
# 반복(Epoch): 18600, Generator 손실함수(g_loss): 2.582346, Discriminator 손실함수(d_loss): 0.621077
# 반복(Epoch): 18700, Generator 손실함수(g_loss): 1.788021, Discriminator 손실함수(d_loss): 0.839596
# 반복(Epoch): 18800, Generator 손실함수(g_loss): 2.125631, Discriminator 손실함수(d_loss): 0.835921
# 반복(Epoch): 18900, Generator 손실함수(g_loss): 2.042485, Discriminator 손실함수(d_loss): 0.660536
# 반복(Epoch): 19000, Generator 손실함수(g_loss): 1.900503, Discriminator 손실함수(d_loss): 0.692820
# 반복(Epoch): 19100, Generator 손실함수(g_loss): 1.793305, Discriminator 손실함수(d_loss): 0.674569
# 반복(Epoch): 19200, Generator 손실함수(g_loss): 1.871632, Discriminator 손실함수(d_loss): 0.624569
# 반복(Epoch): 19300, Generator 손실함수(g_loss): 1.955707, Discriminator 손실함수(d_loss): 0.625816
# 반복(Epoch): 19400, Generator 손실함수(g_loss): 1.748850, Discriminator 손실함수(d_loss): 0.863676
# 반복(Epoch): 19500, Generator 손실함수(g_loss): 2.058622, Discriminator 손실함수(d_loss): 0.595432
# 반복(Epoch): 19600, Generator 손실함수(g_loss): 1.929088, Discriminator 손실함수(d_loss): 0.534775
# 반복(Epoch): 19700, Generator 손실함수(g_loss): 1.992681, Discriminator 손실함수(d_loss): 0.582380
# 반복(Epoch): 19800, Generator 손실함수(g_loss): 1.867053, Discriminator 손실함수(d_loss): 0.644089
# 반복(Epoch): 19900, Generator 손실함수(g_loss): 1.664656, Discriminator 손실함수(d_loss): 0.965142
# 반복(Epoch): 20000, Generator 손실함수(g_loss): 1.943817, Discriminator 손실함수(d_loss): 0.542334
# 반복(Epoch): 20100, Generator 손실함수(g_loss): 1.819644, Discriminator 손실함수(d_loss): 0.799110
# 반복(Epoch): 20200, Generator 손실함수(g_loss): 1.927484, Discriminator 손실함수(d_loss): 0.695448
# 반복(Epoch): 20300, Generator 손실함수(g_loss): 1.906025, Discriminator 손실함수(d_loss): 0.736733
# 반복(Epoch): 20400, Generator 손실함수(g_loss): 2.221246, Discriminator 손실함수(d_loss): 0.632197
# 반복(Epoch): 20500, Generator 손실함수(g_loss): 2.112500, Discriminator 손실함수(d_loss): 0.696839
# 반복(Epoch): 20600, Generator 손실함수(g_loss): 1.938983, Discriminator 손실함수(d_loss): 0.837994
# 반복(Epoch): 20700, Generator 손실함수(g_loss): 1.830410, Discriminator 손실함수(d_loss): 0.727831
# 반복(Epoch): 20800, Generator 손실함수(g_loss): 2.425506, Discriminator 손실함수(d_loss): 0.763527
# 반복(Epoch): 20900, Generator 손실함수(g_loss): 1.451594, Discriminator 손실함수(d_loss): 0.841190
# 반복(Epoch): 21000, Generator 손실함수(g_loss): 2.008027, Discriminator 손실함수(d_loss): 0.682908
# 반복(Epoch): 21100, Generator 손실함수(g_loss): 1.739578, Discriminator 손실함수(d_loss): 0.736793
# 반복(Epoch): 21200, Generator 손실함수(g_loss): 1.776829, Discriminator 손실함수(d_loss): 0.765535
# 반복(Epoch): 21300, Generator 손실함수(g_loss): 2.049433, Discriminator 손실함수(d_loss): 0.684333
# 반복(Epoch): 21400, Generator 손실함수(g_loss): 2.039983, Discriminator 손실함수(d_loss): 0.542353
# 반복(Epoch): 21500, Generator 손실함수(g_loss): 2.469922, Discriminator 손실함수(d_loss): 0.526256
# 반복(Epoch): 21600, Generator 손실함수(g_loss): 2.178748, Discriminator 손실함수(d_loss): 0.699354
# 반복(Epoch): 21700, Generator 손실함수(g_loss): 1.955588, Discriminator 손실함수(d_loss): 0.776269
# 반복(Epoch): 21800, Generator 손실함수(g_loss): 1.724274, Discriminator 손실함수(d_loss): 0.694966
# 반복(Epoch): 21900, Generator 손실함수(g_loss): 1.874918, Discriminator 손실함수(d_loss): 0.868207
# 반복(Epoch): 22000, Generator 손실함수(g_loss): 2.070899, Discriminator 손실함수(d_loss): 0.756334
# 반복(Epoch): 22100, Generator 손실함수(g_loss): 1.754470, Discriminator 손실함수(d_loss): 0.759358
# 반복(Epoch): 22200, Generator 손실함수(g_loss): 1.677593, Discriminator 손실함수(d_loss): 0.697998
# 반복(Epoch): 22300, Generator 손실함수(g_loss): 1.856159, Discriminator 손실함수(d_loss): 0.671271
# 반복(Epoch): 22400, Generator 손실함수(g_loss): 1.718781, Discriminator 손실함수(d_loss): 0.772508
# 반복(Epoch): 22500, Generator 손실함수(g_loss): 1.526689, Discriminator 손실함수(d_loss): 0.791552
# 반복(Epoch): 22600, Generator 손실함수(g_loss): 1.811457, Discriminator 손실함수(d_loss): 1.003699
# 반복(Epoch): 22700, Generator 손실함수(g_loss): 1.820879, Discriminator 손실함수(d_loss): 0.729878
# 반복(Epoch): 22800, Generator 손실함수(g_loss): 1.763616, Discriminator 손실함수(d_loss): 0.751917
# 반복(Epoch): 22900, Generator 손실함수(g_loss): 1.851759, Discriminator 손실함수(d_loss): 0.870846
# 반복(Epoch): 23000, Generator 손실함수(g_loss): 1.979077, Discriminator 손실함수(d_loss): 0.611677
# 반복(Epoch): 23100, Generator 손실함수(g_loss): 1.927567, Discriminator 손실함수(d_loss): 0.742553
# 반복(Epoch): 23200, Generator 손실함수(g_loss): 1.853947, Discriminator 손실함수(d_loss): 0.649991
# 반복(Epoch): 23300, Generator 손실함수(g_loss): 1.644596, Discriminator 손실함수(d_loss): 0.722380
# 반복(Epoch): 23400, Generator 손실함수(g_loss): 1.812317, Discriminator 손실함수(d_loss): 0.749649
# 반복(Epoch): 23500, Generator 손실함수(g_loss): 1.985599, Discriminator 손실함수(d_loss): 0.776053
# 반복(Epoch): 23600, Generator 손실함수(g_loss): 1.773059, Discriminator 손실함수(d_loss): 0.825709
# 반복(Epoch): 23700, Generator 손실함수(g_loss): 1.693371, Discriminator 손실함수(d_loss): 0.738279
# 반복(Epoch): 23800, Generator 손실함수(g_loss): 1.674116, Discriminator 손실함수(d_loss): 0.815590
# 반복(Epoch): 23900, Generator 손실함수(g_loss): 1.846183, Discriminator 손실함수(d_loss): 0.843579
# 반복(Epoch): 24000, Generator 손실함수(g_loss): 1.638486, Discriminator 손실함수(d_loss): 0.818589
# 반복(Epoch): 24100, Generator 손실함수(g_loss): 1.864713, Discriminator 손실함수(d_loss): 0.844231
# 반복(Epoch): 24200, Generator 손실함수(g_loss): 1.647792, Discriminator 손실함수(d_loss): 0.826864
# 반복(Epoch): 24300, Generator 손실함수(g_loss): 2.032155, Discriminator 손실함수(d_loss): 0.639420
# 반복(Epoch): 24400, Generator 손실함수(g_loss): 1.697905, Discriminator 손실함수(d_loss): 0.625343
# 반복(Epoch): 24500, Generator 손실함수(g_loss): 2.016504, Discriminator 손실함수(d_loss): 0.721150
# 반복(Epoch): 24600, Generator 손실함수(g_loss): 1.860531, Discriminator 손실함수(d_loss): 0.680826
# 반복(Epoch): 24700, Generator 손실함수(g_loss): 1.999983, Discriminator 손실함수(d_loss): 0.744796
# 반복(Epoch): 24800, Generator 손실함수(g_loss): 1.712373, Discriminator 손실함수(d_loss): 0.644672
# 반복(Epoch): 24900, Generator 손실함수(g_loss): 1.779145, Discriminator 손실함수(d_loss): 0.942933
# 반복(Epoch): 25000, Generator 손실함수(g_loss): 1.923710, Discriminator 손실함수(d_loss): 0.692997
# 반복(Epoch): 25100, Generator 손실함수(g_loss): 1.975774, Discriminator 손실함수(d_loss): 0.667006
# 반복(Epoch): 25200, Generator 손실함수(g_loss): 1.896157, Discriminator 손실함수(d_loss): 0.562066
# 반복(Epoch): 25300, Generator 손실함수(g_loss): 1.888426, Discriminator 손실함수(d_loss): 0.714400
# 반복(Epoch): 25400, Generator 손실함수(g_loss): 1.759282, Discriminator 손실함수(d_loss): 0.776583
# 반복(Epoch): 25500, Generator 손실함수(g_loss): 1.754274, Discriminator 손실함수(d_loss): 0.733342
# 반복(Epoch): 25600, Generator 손실함수(g_loss): 2.174222, Discriminator 손실함수(d_loss): 0.478543
# 반복(Epoch): 25700, Generator 손실함수(g_loss): 1.378746, Discriminator 손실함수(d_loss): 0.987691
# 반복(Epoch): 25800, Generator 손실함수(g_loss): 1.551869, Discriminator 손실함수(d_loss): 0.763516
# 반복(Epoch): 25900, Generator 손실함수(g_loss): 1.718774, Discriminator 손실함수(d_loss): 0.799618
# 반복(Epoch): 26000, Generator 손실함수(g_loss): 1.956627, Discriminator 손실함수(d_loss): 0.772199
# 반복(Epoch): 26100, Generator 손실함수(g_loss): 1.711338, Discriminator 손실함수(d_loss): 0.861359
# 반복(Epoch): 26200, Generator 손실함수(g_loss): 1.909858, Discriminator 손실함수(d_loss): 0.801242
# 반복(Epoch): 26300, Generator 손실함수(g_loss): 2.114699, Discriminator 손실함수(d_loss): 0.621235
# 반복(Epoch): 26400, Generator 손실함수(g_loss): 1.502805, Discriminator 손실함수(d_loss): 0.744324
# 반복(Epoch): 26500, Generator 손실함수(g_loss): 1.776212, Discriminator 손실함수(d_loss): 0.722185
# 반복(Epoch): 26600, Generator 손실함수(g_loss): 1.857250, Discriminator 손실함수(d_loss): 0.563623
# 반복(Epoch): 26700, Generator 손실함수(g_loss): 2.029213, Discriminator 손실함수(d_loss): 0.803699
# 반복(Epoch): 26800, Generator 손실함수(g_loss): 2.070979, Discriminator 손실함수(d_loss): 0.776901
# 반복(Epoch): 26900, Generator 손실함수(g_loss): 1.817955, Discriminator 손실함수(d_loss): 0.751927
# 반복(Epoch): 27000, Generator 손실함수(g_loss): 1.714482, Discriminator 손실함수(d_loss): 0.742490
# 반복(Epoch): 27100, Generator 손실함수(g_loss): 1.675639, Discriminator 손실함수(d_loss): 0.871045
# 반복(Epoch): 27200, Generator 손실함수(g_loss): 1.846364, Discriminator 손실함수(d_loss): 0.765529
# 반복(Epoch): 27300, Generator 손실함수(g_loss): 1.653480, Discriminator 손실함수(d_loss): 0.760930
# 반복(Epoch): 27400, Generator 손실함수(g_loss): 1.549664, Discriminator 손실함수(d_loss): 0.840735
# 반복(Epoch): 27500, Generator 손실함수(g_loss): 1.838663, Discriminator 손실함수(d_loss): 0.821928
# 반복(Epoch): 27600, Generator 손실함수(g_loss): 1.840252, Discriminator 손실함수(d_loss): 0.946397
# 반복(Epoch): 27700, Generator 손실함수(g_loss): 1.860667, Discriminator 손실함수(d_loss): 0.659234
# 반복(Epoch): 27800, Generator 손실함수(g_loss): 1.636036, Discriminator 손실함수(d_loss): 0.886649
# 반복(Epoch): 27900, Generator 손실함수(g_loss): 1.793060, Discriminator 손실함수(d_loss): 0.800977
# 반복(Epoch): 28000, Generator 손실함수(g_loss): 1.686122, Discriminator 손실함수(d_loss): 0.822498
# 반복(Epoch): 28100, Generator 손실함수(g_loss): 1.854939, Discriminator 손실함수(d_loss): 0.738912
# 반복(Epoch): 28200, Generator 손실함수(g_loss): 1.673293, Discriminator 손실함수(d_loss): 0.906899
# 반복(Epoch): 28300, Generator 손실함수(g_loss): 2.055188, Discriminator 손실함수(d_loss): 0.671718
# 반복(Epoch): 28400, Generator 손실함수(g_loss): 1.935525, Discriminator 손실함수(d_loss): 0.598744
# 반복(Epoch): 28500, Generator 손실함수(g_loss): 2.172617, Discriminator 손실함수(d_loss): 0.545873
# 반복(Epoch): 28600, Generator 손실함수(g_loss): 1.836044, Discriminator 손실함수(d_loss): 0.674313
# 반복(Epoch): 28700, Generator 손실함수(g_loss): 1.891969, Discriminator 손실함수(d_loss): 0.761421
# 반복(Epoch): 28800, Generator 손실함수(g_loss): 2.014883, Discriminator 손실함수(d_loss): 0.692091
# 반복(Epoch): 28900, Generator 손실함수(g_loss): 2.126044, Discriminator 손실함수(d_loss): 0.529409
# 반복(Epoch): 29000, Generator 손실함수(g_loss): 1.867485, Discriminator 손실함수(d_loss): 0.772247
# 반복(Epoch): 29100, Generator 손실함수(g_loss): 1.918637, Discriminator 손실함수(d_loss): 0.788259
# 반복(Epoch): 29200, Generator 손실함수(g_loss): 1.848265, Discriminator 손실함수(d_loss): 0.681522
# 반복(Epoch): 29300, Generator 손실함수(g_loss): 2.230640, Discriminator 손실함수(d_loss): 0.799750
# 반복(Epoch): 29400, Generator 손실함수(g_loss): 1.763489, Discriminator 손실함수(d_loss): 0.872982
# 반복(Epoch): 29500, Generator 손실함수(g_loss): 1.740469, Discriminator 손실함수(d_loss): 0.597533
# 반복(Epoch): 29600, Generator 손실함수(g_loss): 1.997722, Discriminator 손실함수(d_loss): 0.794287
# 반복(Epoch): 29700, Generator 손실함수(g_loss): 2.060349, Discriminator 손실함수(d_loss): 0.747360
# 반복(Epoch): 29800, Generator 손실함수(g_loss): 1.860740, Discriminator 손실함수(d_loss): 0.788791
# 반복(Epoch): 29900, Generator 손실함수(g_loss): 2.036639, Discriminator 손실함수(d_loss): 0.847891
# 반복(Epoch): 30000, Generator 손실함수(g_loss): 1.780657, Discriminator 손실함수(d_loss): 0.833781
# 반복(Epoch): 30100, Generator 손실함수(g_loss): 1.793596, Discriminator 손실함수(d_loss): 0.632579
# 반복(Epoch): 30200, Generator 손실함수(g_loss): 1.824636, Discriminator 손실함수(d_loss): 0.788958
# 반복(Epoch): 30300, Generator 손실함수(g_loss): 2.000120, Discriminator 손실함수(d_loss): 0.659795
# 반복(Epoch): 30400, Generator 손실함수(g_loss): 1.568809, Discriminator 손실함수(d_loss): 0.904723
# 반복(Epoch): 30500, Generator 손실함수(g_loss): 1.709830, Discriminator 손실함수(d_loss): 0.662130
# 반복(Epoch): 30600, Generator 손실함수(g_loss): 1.707839, Discriminator 손실함수(d_loss): 0.825464
# 반복(Epoch): 30700, Generator 손실함수(g_loss): 1.724750, Discriminator 손실함수(d_loss): 0.795503
# 반복(Epoch): 30800, Generator 손실함수(g_loss): 1.630586, Discriminator 손실함수(d_loss): 0.658381
# 반복(Epoch): 30900, Generator 손실함수(g_loss): 2.152453, Discriminator 손실함수(d_loss): 0.575536
# 반복(Epoch): 31000, Generator 손실함수(g_loss): 2.033487, Discriminator 손실함수(d_loss): 0.910728
# 반복(Epoch): 31100, Generator 손실함수(g_loss): 1.910604, Discriminator 손실함수(d_loss): 0.635720
# 반복(Epoch): 31200, Generator 손실함수(g_loss): 1.984462, Discriminator 손실함수(d_loss): 0.740422
# 반복(Epoch): 31300, Generator 손실함수(g_loss): 1.721699, Discriminator 손실함수(d_loss): 0.678901
# 반복(Epoch): 31400, Generator 손실함수(g_loss): 1.819904, Discriminator 손실함수(d_loss): 0.789347
# 반복(Epoch): 31500, Generator 손실함수(g_loss): 2.367903, Discriminator 손실함수(d_loss): 0.558405
# 반복(Epoch): 31600, Generator 손실함수(g_loss): 1.802263, Discriminator 손실함수(d_loss): 0.749378
# 반복(Epoch): 31700, Generator 손실함수(g_loss): 1.783360, Discriminator 손실함수(d_loss): 0.649156
# 반복(Epoch): 31800, Generator 손실함수(g_loss): 1.658908, Discriminator 손실함수(d_loss): 0.699281
# 반복(Epoch): 31900, Generator 손실함수(g_loss): 1.998057, Discriminator 손실함수(d_loss): 0.570838
# 반복(Epoch): 32000, Generator 손실함수(g_loss): 1.983954, Discriminator 손실함수(d_loss): 0.630358
# 반복(Epoch): 32100, Generator 손실함수(g_loss): 2.056913, Discriminator 손실함수(d_loss): 0.656528
# 반복(Epoch): 32200, Generator 손실함수(g_loss): 1.772179, Discriminator 손실함수(d_loss): 0.953694
# 반복(Epoch): 32300, Generator 손실함수(g_loss): 1.960722, Discriminator 손실함수(d_loss): 0.685417
# 반복(Epoch): 32400, Generator 손실함수(g_loss): 2.237072, Discriminator 손실함수(d_loss): 0.603558
# 반복(Epoch): 32500, Generator 손실함수(g_loss): 1.816792, Discriminator 손실함수(d_loss): 0.716423
# 반복(Epoch): 32600, Generator 손실함수(g_loss): 1.739669, Discriminator 손실함수(d_loss): 0.684779
# 반복(Epoch): 32700, Generator 손실함수(g_loss): 1.916149, Discriminator 손실함수(d_loss): 0.654258
# 반복(Epoch): 32800, Generator 손실함수(g_loss): 1.945818, Discriminator 손실함수(d_loss): 0.867021
# 반복(Epoch): 32900, Generator 손실함수(g_loss): 1.820484, Discriminator 손실함수(d_loss): 0.704324
# 반복(Epoch): 33000, Generator 손실함수(g_loss): 1.816031, Discriminator 손실함수(d_loss): 0.755810
# 반복(Epoch): 33100, Generator 손실함수(g_loss): 1.867073, Discriminator 손실함수(d_loss): 0.712962
# 반복(Epoch): 33200, Generator 손실함수(g_loss): 1.728648, Discriminator 손실함수(d_loss): 0.953578
# 반복(Epoch): 33300, Generator 손실함수(g_loss): 1.868172, Discriminator 손실함수(d_loss): 0.903109
# 반복(Epoch): 33400, Generator 손실함수(g_loss): 1.799613, Discriminator 손실함수(d_loss): 0.672568
# 반복(Epoch): 33500, Generator 손실함수(g_loss): 1.929323, Discriminator 손실함수(d_loss): 0.754138
# 반복(Epoch): 33600, Generator 손실함수(g_loss): 1.908567, Discriminator 손실함수(d_loss): 0.749611
# 반복(Epoch): 33700, Generator 손실함수(g_loss): 1.892089, Discriminator 손실함수(d_loss): 0.747371
# 반복(Epoch): 33800, Generator 손실함수(g_loss): 2.059421, Discriminator 손실함수(d_loss): 0.799608
# 반복(Epoch): 33900, Generator 손실함수(g_loss): 1.992515, Discriminator 손실함수(d_loss): 0.727882
# 반복(Epoch): 34000, Generator 손실함수(g_loss): 1.899355, Discriminator 손실함수(d_loss): 0.991570
# 반복(Epoch): 34100, Generator 손실함수(g_loss): 2.375525, Discriminator 손실함수(d_loss): 0.721078
# 반복(Epoch): 34200, Generator 손실함수(g_loss): 1.885966, Discriminator 손실함수(d_loss): 0.625336
# 반복(Epoch): 34300, Generator 손실함수(g_loss): 2.019202, Discriminator 손실함수(d_loss): 0.714303
# 반복(Epoch): 34400, Generator 손실함수(g_loss): 1.723085, Discriminator 손실함수(d_loss): 0.918980
# 반복(Epoch): 34500, Generator 손실함수(g_loss): 1.853183, Discriminator 손실함수(d_loss): 0.758666
# 반복(Epoch): 34600, Generator 손실함수(g_loss): 2.307234, Discriminator 손실함수(d_loss): 0.703276
# 반복(Epoch): 34700, Generator 손실함수(g_loss): 2.015714, Discriminator 손실함수(d_loss): 0.673347
# 반복(Epoch): 34800, Generator 손실함수(g_loss): 1.900216, Discriminator 손실함수(d_loss): 0.702461
# 반복(Epoch): 34900, Generator 손실함수(g_loss): 2.437919, Discriminator 손실함수(d_loss): 0.530586
# 반복(Epoch): 35000, Generator 손실함수(g_loss): 2.076176, Discriminator 손실함수(d_loss): 0.755471
# 반복(Epoch): 35100, Generator 손실함수(g_loss): 2.222087, Discriminator 손실함수(d_loss): 0.726711
# 반복(Epoch): 35200, Generator 손실함수(g_loss): 1.978236, Discriminator 손실함수(d_loss): 0.726987
# 반복(Epoch): 35300, Generator 손실함수(g_loss): 2.146259, Discriminator 손실함수(d_loss): 0.746865
# 반복(Epoch): 35400, Generator 손실함수(g_loss): 2.496791, Discriminator 손실함수(d_loss): 0.609977
# 반복(Epoch): 35500, Generator 손실함수(g_loss): 2.279969, Discriminator 손실함수(d_loss): 0.772133
# 반복(Epoch): 35600, Generator 손실함수(g_loss): 2.337014, Discriminator 손실함수(d_loss): 0.670891
# 반복(Epoch): 35700, Generator 손실함수(g_loss): 2.191601, Discriminator 손실함수(d_loss): 0.641738
# 반복(Epoch): 35800, Generator 손실함수(g_loss): 2.168729, Discriminator 손실함수(d_loss): 0.695430
# 반복(Epoch): 35900, Generator 손실함수(g_loss): 1.931824, Discriminator 손실함수(d_loss): 0.618651
# 반복(Epoch): 36000, Generator 손실함수(g_loss): 2.295195, Discriminator 손실함수(d_loss): 0.845476
# 반복(Epoch): 36100, Generator 손실함수(g_loss): 2.306419, Discriminator 손실함수(d_loss): 0.566192
# 반복(Epoch): 36200, Generator 손실함수(g_loss): 2.108656, Discriminator 손실함수(d_loss): 0.618548
# 반복(Epoch): 36300, Generator 손실함수(g_loss): 1.931111, Discriminator 손실함수(d_loss): 0.693947
# 반복(Epoch): 36400, Generator 손실함수(g_loss): 2.243087, Discriminator 손실함수(d_loss): 0.560178
# 반복(Epoch): 36500, Generator 손실함수(g_loss): 2.204621, Discriminator 손실함수(d_loss): 0.725108
# 반복(Epoch): 36600, Generator 손실함수(g_loss): 1.955174, Discriminator 손실함수(d_loss): 0.661122
# 반복(Epoch): 36700, Generator 손실함수(g_loss): 1.970464, Discriminator 손실함수(d_loss): 0.767506
# 반복(Epoch): 36800, Generator 손실함수(g_loss): 2.125954, Discriminator 손실함수(d_loss): 0.811747
# 반복(Epoch): 36900, Generator 손실함수(g_loss): 1.934298, Discriminator 손실함수(d_loss): 0.700983
# 반복(Epoch): 37000, Generator 손실함수(g_loss): 2.017842, Discriminator 손실함수(d_loss): 0.742061
# 반복(Epoch): 37100, Generator 손실함수(g_loss): 1.935016, Discriminator 손실함수(d_loss): 0.707817
# 반복(Epoch): 37200, Generator 손실함수(g_loss): 2.003151, Discriminator 손실함수(d_loss): 0.673521
# 반복(Epoch): 37300, Generator 손실함수(g_loss): 1.967969, Discriminator 손실함수(d_loss): 0.621697
# 반복(Epoch): 37400, Generator 손실함수(g_loss): 1.785617, Discriminator 손실함수(d_loss): 0.897235
# 반복(Epoch): 37500, Generator 손실함수(g_loss): 1.726253, Discriminator 손실함수(d_loss): 0.624947
# 반복(Epoch): 37600, Generator 손실함수(g_loss): 2.026898, Discriminator 손실함수(d_loss): 0.593442
# 반복(Epoch): 37700, Generator 손실함수(g_loss): 2.079592, Discriminator 손실함수(d_loss): 0.667144
# 반복(Epoch): 37800, Generator 손실함수(g_loss): 1.713259, Discriminator 손실함수(d_loss): 0.853914
# 반복(Epoch): 37900, Generator 손실함수(g_loss): 1.958178, Discriminator 손실함수(d_loss): 0.663287
# 반복(Epoch): 38000, Generator 손실함수(g_loss): 2.253874, Discriminator 손실함수(d_loss): 0.592821
# 반복(Epoch): 38100, Generator 손실함수(g_loss): 2.358288, Discriminator 손실함수(d_loss): 0.607683
# 반복(Epoch): 38200, Generator 손실함수(g_loss): 1.975899, Discriminator 손실함수(d_loss): 0.789072
# 반복(Epoch): 38300, Generator 손실함수(g_loss): 1.732400, Discriminator 손실함수(d_loss): 0.746027
# 반복(Epoch): 38400, Generator 손실함수(g_loss): 1.930385, Discriminator 손실함수(d_loss): 0.558265
# 반복(Epoch): 38500, Generator 손실함수(g_loss): 2.072255, Discriminator 손실함수(d_loss): 0.684052
# 반복(Epoch): 38600, Generator 손실함수(g_loss): 2.311456, Discriminator 손실함수(d_loss): 0.700829
# 반복(Epoch): 38700, Generator 손실함수(g_loss): 2.050097, Discriminator 손실함수(d_loss): 0.599506
# 반복(Epoch): 38800, Generator 손실함수(g_loss): 2.024328, Discriminator 손실함수(d_loss): 0.750454
# 반복(Epoch): 38900, Generator 손실함수(g_loss): 2.241905, Discriminator 손실함수(d_loss): 0.647782
# 반복(Epoch): 39000, Generator 손실함수(g_loss): 2.282529, Discriminator 손실함수(d_loss): 0.564874
# 반복(Epoch): 39100, Generator 손실함수(g_loss): 1.987201, Discriminator 손실함수(d_loss): 0.620526
# 반복(Epoch): 39200, Generator 손실함수(g_loss): 1.988261, Discriminator 손실함수(d_loss): 0.766541
# 반복(Epoch): 39300, Generator 손실함수(g_loss): 1.954415, Discriminator 손실함수(d_loss): 0.795934
# 반복(Epoch): 39400, Generator 손실함수(g_loss): 2.134256, Discriminator 손실함수(d_loss): 0.776889
# 반복(Epoch): 39500, Generator 손실함수(g_loss): 1.897043, Discriminator 손실함수(d_loss): 0.587476
# 반복(Epoch): 39600, Generator 손실함수(g_loss): 2.336020, Discriminator 손실함수(d_loss): 0.474846
# 반복(Epoch): 39700, Generator 손실함수(g_loss): 2.307116, Discriminator 손실함수(d_loss): 0.675854
# 반복(Epoch): 39800, Generator 손실함수(g_loss): 2.271612, Discriminator 손실함수(d_loss): 0.715006
# 반복(Epoch): 39900, Generator 손실함수(g_loss): 2.388958, Discriminator 손실함수(d_loss): 0.538974
# 반복(Epoch): 40000, Generator 손실함수(g_loss): 2.183357, Discriminator 손실함수(d_loss): 0.685820
# 반복(Epoch): 40100, Generator 손실함수(g_loss): 1.963424, Discriminator 손실함수(d_loss): 0.760667
# 반복(Epoch): 40200, Generator 손실함수(g_loss): 2.114451, Discriminator 손실함수(d_loss): 0.686216
# 반복(Epoch): 40300, Generator 손실함수(g_loss): 2.183710, Discriminator 손실함수(d_loss): 0.681685
# 반복(Epoch): 40400, Generator 손실함수(g_loss): 1.876289, Discriminator 손실함수(d_loss): 0.656011
# 반복(Epoch): 40500, Generator 손실함수(g_loss): 2.161084, Discriminator 손실함수(d_loss): 0.549344
# 반복(Epoch): 40600, Generator 손실함수(g_loss): 1.926048, Discriminator 손실함수(d_loss): 0.713800
# 반복(Epoch): 40700, Generator 손실함수(g_loss): 2.148512, Discriminator 손실함수(d_loss): 0.597924
# 반복(Epoch): 40800, Generator 손실함수(g_loss): 1.940369, Discriminator 손실함수(d_loss): 0.669094
# 반복(Epoch): 40900, Generator 손실함수(g_loss): 2.328035, Discriminator 손실함수(d_loss): 0.598454
# 반복(Epoch): 41000, Generator 손실함수(g_loss): 2.137579, Discriminator 손실함수(d_loss): 0.809678
# 반복(Epoch): 41100, Generator 손실함수(g_loss): 2.117856, Discriminator 손실함수(d_loss): 0.590422
# 반복(Epoch): 41200, Generator 손실함수(g_loss): 2.214146, Discriminator 손실함수(d_loss): 0.811156
# 반복(Epoch): 41300, Generator 손실함수(g_loss): 2.322366, Discriminator 손실함수(d_loss): 0.669878
# 반복(Epoch): 41400, Generator 손실함수(g_loss): 2.035531, Discriminator 손실함수(d_loss): 0.693395
# 반복(Epoch): 41500, Generator 손실함수(g_loss): 2.058803, Discriminator 손실함수(d_loss): 0.765589
# 반복(Epoch): 41600, Generator 손실함수(g_loss): 1.884287, Discriminator 손실함수(d_loss): 0.600361
# 반복(Epoch): 41700, Generator 손실함수(g_loss): 2.301593, Discriminator 손실함수(d_loss): 0.701408
# 반복(Epoch): 41800, Generator 손실함수(g_loss): 2.030064, Discriminator 손실함수(d_loss): 0.687843
# 반복(Epoch): 41900, Generator 손실함수(g_loss): 1.961459, Discriminator 손실함수(d_loss): 0.839173
# 반복(Epoch): 42000, Generator 손실함수(g_loss): 2.607028, Discriminator 손실함수(d_loss): 0.554978
# 반복(Epoch): 42100, Generator 손실함수(g_loss): 2.326053, Discriminator 손실함수(d_loss): 0.596790
# 반복(Epoch): 42200, Generator 손실함수(g_loss): 1.985065, Discriminator 손실함수(d_loss): 0.639906
# 반복(Epoch): 42300, Generator 손실함수(g_loss): 2.196286, Discriminator 손실함수(d_loss): 0.555336
# 반복(Epoch): 42400, Generator 손실함수(g_loss): 2.350586, Discriminator 손실함수(d_loss): 0.733064
# 반복(Epoch): 42500, Generator 손실함수(g_loss): 2.080370, Discriminator 손실함수(d_loss): 0.629886
# 반복(Epoch): 42600, Generator 손실함수(g_loss): 2.059769, Discriminator 손실함수(d_loss): 0.615297
# 반복(Epoch): 42700, Generator 손실함수(g_loss): 1.991427, Discriminator 손실함수(d_loss): 0.664280
# 반복(Epoch): 42800, Generator 손실함수(g_loss): 1.752125, Discriminator 손실함수(d_loss): 0.621731
# 반복(Epoch): 42900, Generator 손실함수(g_loss): 2.168467, Discriminator 손실함수(d_loss): 0.701730
# 반복(Epoch): 43000, Generator 손실함수(g_loss): 2.221748, Discriminator 손실함수(d_loss): 0.539289
# 반복(Epoch): 43100, Generator 손실함수(g_loss): 1.914582, Discriminator 손실함수(d_loss): 0.557830
# 반복(Epoch): 43200, Generator 손실함수(g_loss): 2.385335, Discriminator 손실함수(d_loss): 0.716402
# 반복(Epoch): 43300, Generator 손실함수(g_loss): 2.203699, Discriminator 손실함수(d_loss): 0.646676
# 반복(Epoch): 43400, Generator 손실함수(g_loss): 1.860871, Discriminator 손실함수(d_loss): 0.597039
# 반복(Epoch): 43500, Generator 손실함수(g_loss): 2.225582, Discriminator 손실함수(d_loss): 0.530931
# 반복(Epoch): 43600, Generator 손실함수(g_loss): 2.103034, Discriminator 손실함수(d_loss): 0.638916
# 반복(Epoch): 43700, Generator 손실함수(g_loss): 2.197161, Discriminator 손실함수(d_loss): 0.801228
# 반복(Epoch): 43800, Generator 손실함수(g_loss): 2.459307, Discriminator 손실함수(d_loss): 0.708921
# 반복(Epoch): 43900, Generator 손실함수(g_loss): 2.478222, Discriminator 손실함수(d_loss): 0.651112
# 반복(Epoch): 44000, Generator 손실함수(g_loss): 2.064253, Discriminator 손실함수(d_loss): 0.817905
# 반복(Epoch): 44100, Generator 손실함수(g_loss): 2.052886, Discriminator 손실함수(d_loss): 0.781903
# 반복(Epoch): 44200, Generator 손실함수(g_loss): 2.396334, Discriminator 손실함수(d_loss): 0.596616
# 반복(Epoch): 44300, Generator 손실함수(g_loss): 1.957415, Discriminator 손실함수(d_loss): 0.566181
# 반복(Epoch): 44400, Generator 손실함수(g_loss): 1.997331, Discriminator 손실함수(d_loss): 0.750392
# 반복(Epoch): 44500, Generator 손실함수(g_loss): 1.832095, Discriminator 손실함수(d_loss): 0.711485
# 반복(Epoch): 44600, Generator 손실함수(g_loss): 2.109270, Discriminator 손실함수(d_loss): 0.629772
# 반복(Epoch): 44700, Generator 손실함수(g_loss): 2.577625, Discriminator 손실함수(d_loss): 0.635798
# 반복(Epoch): 44800, Generator 손실함수(g_loss): 2.396025, Discriminator 손실함수(d_loss): 0.618421
# 반복(Epoch): 44900, Generator 손실함수(g_loss): 2.137599, Discriminator 손실함수(d_loss): 0.603490
# 반복(Epoch): 45000, Generator 손실함수(g_loss): 2.063799, Discriminator 손실함수(d_loss): 0.630208
# 반복(Epoch): 45100, Generator 손실함수(g_loss): 1.837348, Discriminator 손실함수(d_loss): 0.613656
# 반복(Epoch): 45200, Generator 손실함수(g_loss): 2.249514, Discriminator 손실함수(d_loss): 0.748381
# 반복(Epoch): 45300, Generator 손실함수(g_loss): 2.103763, Discriminator 손실함수(d_loss): 0.813128
# 반복(Epoch): 45400, Generator 손실함수(g_loss): 2.050464, Discriminator 손실함수(d_loss): 0.654692
# 반복(Epoch): 45500, Generator 손실함수(g_loss): 2.203299, Discriminator 손실함수(d_loss): 0.623597
# 반복(Epoch): 45600, Generator 손실함수(g_loss): 2.138745, Discriminator 손실함수(d_loss): 0.497675
# 반복(Epoch): 45700, Generator 손실함수(g_loss): 1.973539, Discriminator 손실함수(d_loss): 0.768005
# 반복(Epoch): 45800, Generator 손실함수(g_loss): 2.352216, Discriminator 손실함수(d_loss): 0.595331
# 반복(Epoch): 45900, Generator 손실함수(g_loss): 1.976533, Discriminator 손실함수(d_loss): 0.564115
# 반복(Epoch): 46000, Generator 손실함수(g_loss): 1.948096, Discriminator 손실함수(d_loss): 0.605714
# 반복(Epoch): 46100, Generator 손실함수(g_loss): 2.242253, Discriminator 손실함수(d_loss): 0.813475
# 반복(Epoch): 46200, Generator 손실함수(g_loss): 1.931863, Discriminator 손실함수(d_loss): 0.774257
# 반복(Epoch): 46300, Generator 손실함수(g_loss): 1.987373, Discriminator 손실함수(d_loss): 0.965044
# 반복(Epoch): 46400, Generator 손실함수(g_loss): 1.997460, Discriminator 손실함수(d_loss): 0.586891
# 반복(Epoch): 46500, Generator 손실함수(g_loss): 2.663675, Discriminator 손실함수(d_loss): 0.498642
# 반복(Epoch): 46600, Generator 손실함수(g_loss): 2.384882, Discriminator 손실함수(d_loss): 0.675758
# 반복(Epoch): 46700, Generator 손실함수(g_loss): 2.307201, Discriminator 손실함수(d_loss): 0.578713
# 반복(Epoch): 46800, Generator 손실함수(g_loss): 1.973587, Discriminator 손실함수(d_loss): 0.759517
# 반복(Epoch): 46900, Generator 손실함수(g_loss): 2.314382, Discriminator 손실함수(d_loss): 0.551284
# 반복(Epoch): 47000, Generator 손실함수(g_loss): 2.062756, Discriminator 손실함수(d_loss): 0.795961
# 반복(Epoch): 47100, Generator 손실함수(g_loss): 2.247971, Discriminator 손실함수(d_loss): 0.690213
# 반복(Epoch): 47200, Generator 손실함수(g_loss): 2.265627, Discriminator 손실함수(d_loss): 0.678641
# 반복(Epoch): 47300, Generator 손실함수(g_loss): 2.471544, Discriminator 손실함수(d_loss): 0.639517
# 반복(Epoch): 47400, Generator 손실함수(g_loss): 2.336549, Discriminator 손실함수(d_loss): 0.636219
# 반복(Epoch): 47500, Generator 손실함수(g_loss): 2.187742, Discriminator 손실함수(d_loss): 0.733562
# 반복(Epoch): 47600, Generator 손실함수(g_loss): 1.841504, Discriminator 손실함수(d_loss): 0.620634
# 반복(Epoch): 47700, Generator 손실함수(g_loss): 1.799661, Discriminator 손실함수(d_loss): 0.817416
# 반복(Epoch): 47800, Generator 손실함수(g_loss): 2.258743, Discriminator 손실함수(d_loss): 0.782859
# 반복(Epoch): 47900, Generator 손실함수(g_loss): 1.773535, Discriminator 손실함수(d_loss): 0.801947
# 반복(Epoch): 48000, Generator 손실함수(g_loss): 2.006968, Discriminator 손실함수(d_loss): 0.623009
# 반복(Epoch): 48100, Generator 손실함수(g_loss): 2.351272, Discriminator 손실함수(d_loss): 0.482224
# 반복(Epoch): 48200, Generator 손실함수(g_loss): 2.149640, Discriminator 손실함수(d_loss): 0.739874
# 반복(Epoch): 48300, Generator 손실함수(g_loss): 1.953575, Discriminator 손실함수(d_loss): 0.662306
# 반복(Epoch): 48400, Generator 손실함수(g_loss): 2.002545, Discriminator 손실함수(d_loss): 0.766062
# 반복(Epoch): 48500, Generator 손실함수(g_loss): 2.429281, Discriminator 손실함수(d_loss): 0.664284
# 반복(Epoch): 48600, Generator 손실함수(g_loss): 2.029760, Discriminator 손실함수(d_loss): 0.689099
# 반복(Epoch): 48700, Generator 손실함수(g_loss): 2.228429, Discriminator 손실함수(d_loss): 0.572437
# 반복(Epoch): 48800, Generator 손실함수(g_loss): 2.152254, Discriminator 손실함수(d_loss): 0.688614
# 반복(Epoch): 48900, Generator 손실함수(g_loss): 2.500539, Discriminator 손실함수(d_loss): 0.635310
# 반복(Epoch): 49000, Generator 손실함수(g_loss): 2.093646, Discriminator 손실함수(d_loss): 0.653347
# 반복(Epoch): 49100, Generator 손실함수(g_loss): 1.859181, Discriminator 손실함수(d_loss): 0.790642
# 반복(Epoch): 49200, Generator 손실함수(g_loss): 2.487086, Discriminator 손실함수(d_loss): 0.723077
# 반복(Epoch): 49300, Generator 손실함수(g_loss): 2.148517, Discriminator 손실함수(d_loss): 0.716906
# 반복(Epoch): 49400, Generator 손실함수(g_loss): 2.064429, Discriminator 손실함수(d_loss): 0.710793
# 반복(Epoch): 49500, Generator 손실함수(g_loss): 2.104226, Discriminator 손실함수(d_loss): 0.576792
# 반복(Epoch): 49600, Generator 손실함수(g_loss): 1.746072, Discriminator 손실함수(d_loss): 0.637482
# 반복(Epoch): 49700, Generator 손실함수(g_loss): 2.276996, Discriminator 손실함수(d_loss): 0.743796
# 반복(Epoch): 49800, Generator 손실함수(g_loss): 2.176918, Discriminator 손실함수(d_loss): 0.708405
# 반복(Epoch): 49900, Generator 손실함수(g_loss): 1.875419, Discriminator 손실함수(d_loss): 0.721653
# 반복(Epoch): 50000, Generator 손실함수(g_loss): 2.128301, Discriminator 손실함수(d_loss): 0.496929
# 반복(Epoch): 50100, Generator 손실함수(g_loss): 2.130558, Discriminator 손실함수(d_loss): 0.640054
# 반복(Epoch): 50200, Generator 손실함수(g_loss): 2.125935, Discriminator 손실함수(d_loss): 0.610483
# 반복(Epoch): 50300, Generator 손실함수(g_loss): 1.885921, Discriminator 손실함수(d_loss): 0.819062
# 반복(Epoch): 50400, Generator 손실함수(g_loss): 2.000711, Discriminator 손실함수(d_loss): 0.673461
# 반복(Epoch): 50500, Generator 손실함수(g_loss): 1.745860, Discriminator 손실함수(d_loss): 0.657064
# 반복(Epoch): 50600, Generator 손실함수(g_loss): 2.141312, Discriminator 손실함수(d_loss): 0.748282
# 반복(Epoch): 50700, Generator 손실함수(g_loss): 1.703675, Discriminator 손실함수(d_loss): 0.800957
# 반복(Epoch): 50800, Generator 손실함수(g_loss): 2.171798, Discriminator 손실함수(d_loss): 0.551553
# 반복(Epoch): 50900, Generator 손실함수(g_loss): 1.854358, Discriminator 손실함수(d_loss): 0.727966
# 반복(Epoch): 51000, Generator 손실함수(g_loss): 1.912136, Discriminator 손실함수(d_loss): 0.728219
# 반복(Epoch): 51100, Generator 손실함수(g_loss): 2.363204, Discriminator 손실함수(d_loss): 0.633075
# 반복(Epoch): 51200, Generator 손실함수(g_loss): 2.203276, Discriminator 손실함수(d_loss): 0.689687
# 반복(Epoch): 51300, Generator 손실함수(g_loss): 2.168367, Discriminator 손실함수(d_loss): 0.734658
# 반복(Epoch): 51400, Generator 손실함수(g_loss): 2.108692, Discriminator 손실함수(d_loss): 0.804953
# 반복(Epoch): 51500, Generator 손실함수(g_loss): 2.567172, Discriminator 손실함수(d_loss): 0.547147
# 반복(Epoch): 51600, Generator 손실함수(g_loss): 1.998021, Discriminator 손실함수(d_loss): 0.819346
# 반복(Epoch): 51700, Generator 손실함수(g_loss): 2.382295, Discriminator 손실함수(d_loss): 0.591880
# 반복(Epoch): 51800, Generator 손실함수(g_loss): 2.025730, Discriminator 손실함수(d_loss): 0.564095
# 반복(Epoch): 51900, Generator 손실함수(g_loss): 2.005011, Discriminator 손실함수(d_loss): 0.740674
# 반복(Epoch): 52000, Generator 손실함수(g_loss): 2.456515, Discriminator 손실함수(d_loss): 0.445441
# 반복(Epoch): 52100, Generator 손실함수(g_loss): 2.324961, Discriminator 손실함수(d_loss): 0.604714
# 반복(Epoch): 52200, Generator 손실함수(g_loss): 1.747347, Discriminator 손실함수(d_loss): 0.711643
# 반복(Epoch): 52300, Generator 손실함수(g_loss): 2.209304, Discriminator 손실함수(d_loss): 0.778138
# 반복(Epoch): 52400, Generator 손실함수(g_loss): 2.192597, Discriminator 손실함수(d_loss): 0.509745
# 반복(Epoch): 52500, Generator 손실함수(g_loss): 2.093324, Discriminator 손실함수(d_loss): 0.604240
# 반복(Epoch): 52600, Generator 손실함수(g_loss): 1.721472, Discriminator 손실함수(d_loss): 0.714617
# 반복(Epoch): 52700, Generator 손실함수(g_loss): 2.417799, Discriminator 손실함수(d_loss): 0.447375
# 반복(Epoch): 52800, Generator 손실함수(g_loss): 2.383120, Discriminator 손실함수(d_loss): 0.480369
# 반복(Epoch): 52900, Generator 손실함수(g_loss): 2.490934, Discriminator 손실함수(d_loss): 0.535345
# 반복(Epoch): 53000, Generator 손실함수(g_loss): 2.028018, Discriminator 손실함수(d_loss): 0.663342
# 반복(Epoch): 53100, Generator 손실함수(g_loss): 1.905962, Discriminator 손실함수(d_loss): 0.665448
# 반복(Epoch): 53200, Generator 손실함수(g_loss): 2.373001, Discriminator 손실함수(d_loss): 0.506572
# 반복(Epoch): 53300, Generator 손실함수(g_loss): 2.130710, Discriminator 손실함수(d_loss): 0.601211
# 반복(Epoch): 53400, Generator 손실함수(g_loss): 2.178775, Discriminator 손실함수(d_loss): 0.534720
# 반복(Epoch): 53500, Generator 손실함수(g_loss): 2.182256, Discriminator 손실함수(d_loss): 0.559799
# 반복(Epoch): 53600, Generator 손실함수(g_loss): 2.387545, Discriminator 손실함수(d_loss): 0.607730
# 반복(Epoch): 53700, Generator 손실함수(g_loss): 1.878909, Discriminator 손실함수(d_loss): 0.666658
# 반복(Epoch): 53800, Generator 손실함수(g_loss): 2.110015, Discriminator 손실함수(d_loss): 0.628317
# 반복(Epoch): 53900, Generator 손실함수(g_loss): 2.294312, Discriminator 손실함수(d_loss): 0.578574
# 반복(Epoch): 54000, Generator 손실함수(g_loss): 2.387053, Discriminator 손실함수(d_loss): 0.471188
# 반복(Epoch): 54100, Generator 손실함수(g_loss): 2.289792, Discriminator 손실함수(d_loss): 0.738457
# 반복(Epoch): 54200, Generator 손실함수(g_loss): 2.020879, Discriminator 손실함수(d_loss): 0.804615
# 반복(Epoch): 54300, Generator 손실함수(g_loss): 2.196111, Discriminator 손실함수(d_loss): 0.851778
# 반복(Epoch): 54400, Generator 손실함수(g_loss): 2.244283, Discriminator 손실함수(d_loss): 0.589087
# 반복(Epoch): 54500, Generator 손실함수(g_loss): 2.573973, Discriminator 손실함수(d_loss): 0.788998
# 반복(Epoch): 54600, Generator 손실함수(g_loss): 2.063465, Discriminator 손실함수(d_loss): 0.619723
# 반복(Epoch): 54700, Generator 손실함수(g_loss): 2.333070, Discriminator 손실함수(d_loss): 0.703589
# 반복(Epoch): 54800, Generator 손실함수(g_loss): 2.396120, Discriminator 손실함수(d_loss): 0.481947
# 반복(Epoch): 54900, Generator 손실함수(g_loss): 2.145391, Discriminator 손실함수(d_loss): 0.766891
# 반복(Epoch): 55000, Generator 손실함수(g_loss): 1.836163, Discriminator 손실함수(d_loss): 0.688675
# 반복(Epoch): 55100, Generator 손실함수(g_loss): 2.231446, Discriminator 손실함수(d_loss): 0.675909
# 반복(Epoch): 55200, Generator 손실함수(g_loss): 2.047531, Discriminator 손실함수(d_loss): 0.613387
# 반복(Epoch): 55300, Generator 손실함수(g_loss): 2.438300, Discriminator 손실함수(d_loss): 0.538942
# 반복(Epoch): 55400, Generator 손실함수(g_loss): 2.413398, Discriminator 손실함수(d_loss): 0.681469
# 반복(Epoch): 55500, Generator 손실함수(g_loss): 2.102894, Discriminator 손실함수(d_loss): 0.708678
# 반복(Epoch): 55600, Generator 손실함수(g_loss): 2.113429, Discriminator 손실함수(d_loss): 0.712326
# 반복(Epoch): 55700, Generator 손실함수(g_loss): 1.928583, Discriminator 손실함수(d_loss): 0.768745
# 반복(Epoch): 55800, Generator 손실함수(g_loss): 2.230115, Discriminator 손실함수(d_loss): 0.792907
# 반복(Epoch): 55900, Generator 손실함수(g_loss): 2.465693, Discriminator 손실함수(d_loss): 0.567399
# 반복(Epoch): 56000, Generator 손실함수(g_loss): 2.397796, Discriminator 손실함수(d_loss): 0.665174
# 반복(Epoch): 56100, Generator 손실함수(g_loss): 1.950183, Discriminator 손실함수(d_loss): 0.672804
# 반복(Epoch): 56200, Generator 손실함수(g_loss): 2.153795, Discriminator 손실함수(d_loss): 0.632151
# 반복(Epoch): 56300, Generator 손실함수(g_loss): 2.126335, Discriminator 손실함수(d_loss): 0.597529
# 반복(Epoch): 56400, Generator 손실함수(g_loss): 2.442300, Discriminator 손실함수(d_loss): 0.569768
# 반복(Epoch): 56500, Generator 손실함수(g_loss): 2.298771, Discriminator 손실함수(d_loss): 0.716978
# 반복(Epoch): 56600, Generator 손실함수(g_loss): 2.107868, Discriminator 손실함수(d_loss): 0.613007
# 반복(Epoch): 56700, Generator 손실함수(g_loss): 2.198542, Discriminator 손실함수(d_loss): 0.529174
# 반복(Epoch): 56800, Generator 손실함수(g_loss): 2.128658, Discriminator 손실함수(d_loss): 0.626799
# 반복(Epoch): 56900, Generator 손실함수(g_loss): 2.398657, Discriminator 손실함수(d_loss): 0.395874
# 반복(Epoch): 57000, Generator 손실함수(g_loss): 2.225043, Discriminator 손실함수(d_loss): 0.628108
# 반복(Epoch): 57100, Generator 손실함수(g_loss): 2.202579, Discriminator 손실함수(d_loss): 0.543989
# 반복(Epoch): 57200, Generator 손실함수(g_loss): 2.459396, Discriminator 손실함수(d_loss): 0.341668
# 반복(Epoch): 57300, Generator 손실함수(g_loss): 1.928147, Discriminator 손실함수(d_loss): 0.781307
# 반복(Epoch): 57400, Generator 손실함수(g_loss): 2.125333, Discriminator 손실함수(d_loss): 0.798115
# 반복(Epoch): 57500, Generator 손실함수(g_loss): 1.863056, Discriminator 손실함수(d_loss): 0.837387
# 반복(Epoch): 57600, Generator 손실함수(g_loss): 2.175936, Discriminator 손실함수(d_loss): 0.507888
# 반복(Epoch): 57700, Generator 손실함수(g_loss): 2.121133, Discriminator 손실함수(d_loss): 0.849891
# 반복(Epoch): 57800, Generator 손실함수(g_loss): 2.562029, Discriminator 손실함수(d_loss): 0.809824
# 반복(Epoch): 57900, Generator 손실함수(g_loss): 2.130961, Discriminator 손실함수(d_loss): 0.720563
# 반복(Epoch): 58000, Generator 손실함수(g_loss): 2.145720, Discriminator 손실함수(d_loss): 0.578045
# 반복(Epoch): 58100, Generator 손실함수(g_loss): 2.013632, Discriminator 손실함수(d_loss): 0.657724
# 반복(Epoch): 58200, Generator 손실함수(g_loss): 2.087821, Discriminator 손실함수(d_loss): 0.530387
# 반복(Epoch): 58300, Generator 손실함수(g_loss): 2.018206, Discriminator 손실함수(d_loss): 0.748268
# 반복(Epoch): 58400, Generator 손실함수(g_loss): 2.137579, Discriminator 손실함수(d_loss): 0.753893
# 반복(Epoch): 58500, Generator 손실함수(g_loss): 2.143920, Discriminator 손실함수(d_loss): 0.669146
# 반복(Epoch): 58600, Generator 손실함수(g_loss): 2.357650, Discriminator 손실함수(d_loss): 0.632759
# 반복(Epoch): 58700, Generator 손실함수(g_loss): 2.324042, Discriminator 손실함수(d_loss): 0.721179
# 반복(Epoch): 58800, Generator 손실함수(g_loss): 2.517765, Discriminator 손실함수(d_loss): 0.624763
# 반복(Epoch): 58900, Generator 손실함수(g_loss): 2.164570, Discriminator 손실함수(d_loss): 0.677355
# 반복(Epoch): 59000, Generator 손실함수(g_loss): 2.508569, Discriminator 손실함수(d_loss): 0.688643
# 반복(Epoch): 59100, Generator 손실함수(g_loss): 1.927181, Discriminator 손실함수(d_loss): 0.751615
# 반복(Epoch): 59200, Generator 손실함수(g_loss): 2.178248, Discriminator 손실함수(d_loss): 0.670546
# 반복(Epoch): 59300, Generator 손실함수(g_loss): 2.197788, Discriminator 손실함수(d_loss): 0.576070
# 반복(Epoch): 59400, Generator 손실함수(g_loss): 2.132472, Discriminator 손실함수(d_loss): 0.511783
# 반복(Epoch): 59500, Generator 손실함수(g_loss): 2.297447, Discriminator 손실함수(d_loss): 0.446884
# 반복(Epoch): 59600, Generator 손실함수(g_loss): 2.641586, Discriminator 손실함수(d_loss): 0.578803
# 반복(Epoch): 59700, Generator 손실함수(g_loss): 1.947222, Discriminator 손실함수(d_loss): 0.716255
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-55bf74295101> in <cell line: 7>()
#      24
#      25   # Generator 최적화를 수행하고 Generator 손실함수를 return합니다.
# ---> 26   _, g_loss_print = g_train_step(Generator_model, Discriminator_model, batch_noise), generator_loss(Discriminator_model(Generator_model(batch_noise))[1])
#      27
#      28   # 100번 반복할때마다 Discriminator의 손실함수와 Generator 손실함수를 출력합니다.
#
# /usr/local/lib/python3.10/dist-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      63         filtered_tb = None
#      64         try:
# ---> 65             return fn(*args, **kwargs)
#      66         except Exception as e:
#      67             filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.10/dist-packages/keras/engine/training.py in __call__(self, *args, **kwargs)
#     556             layout_map_lib._map_subclass_model_variable(self, self._layout_map)
#     557
# --> 558         return super().__call__(*args, **kwargs)
#     559
#     560     @doc_controls.doc_in_current_and_subclasses
#
# /usr/local/lib/python3.10/dist-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      63         filtered_tb = None
#      64         try:
# ---> 65             return fn(*args, **kwargs)
#      66         except Exception as e:
#      67             filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.10/dist-packages/keras/engine/base_layer.py in __call__(self, *args, **kwargs)
#    1143                     self._compute_dtype_object
#    1144                 ):
# -> 1145                     outputs = call_fn(inputs, *args, **kwargs)
#    1146
#    1147                 if self._activity_regularizer:
#
# /usr/local/lib/python3.10/dist-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      94         bound_signature = None
#      95         try:
# ---> 96             return fn(*args, **kwargs)
#      97         except Exception as e:
#      98             if hasattr(e, "_keras_call_info_injected"):
#
# <ipython-input-4-66cc232786d8> in call(self, x)
#      20
#      21   def call(self, x):
# ---> 22     hidden_layer = self.hidden_layer_1(x)
#      23     generated_mnist_image = self.output_layer(hidden_layer)
#      24
#
# /usr/local/lib/python3.10/dist-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      63         filtered_tb = None
#      64         try:
# ---> 65             return fn(*args, **kwargs)
#      66         except Exception as e:
#      67             filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.10/dist-packages/keras/engine/base_layer.py in __call__(self, *args, **kwargs)
#    1102             self._clear_losses()
#    1103
# -> 1104         eager = tf.executing_eagerly()
#    1105         with call_context.enter(
#    1106             layer=self,
#
# KeyboardInterrupt:
