# %% [markdown]
# <a href="https://colab.research.google.com/github/clionelove123/temp_test/blob/main/Chap_12_Reinforced_Learnung.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# -*- coding: utf-8 -*-

# %matplotlib
# %matplotlib inline
import os
os.chdir('/content')

# !python train_catch_game_v2_keras.py
# Out:
# Using matplotlib backend: agg
# 2023-05-16 07:33:15.522475: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2023-05-16 07:33:17.963760: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:47] Overriding orig_value setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# 트레이닝을 시작합니다.
# /content/train_catch_game_v2_keras.py:168: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   self.gameOver = np.empty(self.maxMemory, dtype = np.bool)
# WARNING:tensorflow:5 out of the last 5 calls to <function _BaseOptimizer._update_step_xla at 0x7fa0f8168f70> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# W0516 07:33:19.107389 140331538548544 polymorphic_function.py:156] 5 out of the last 5 calls to <function _BaseOptimizer._update_step_xla at 0x7fa0f8168f70> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:6 out of the last 6 calls to <function _BaseOptimizer._update_step_xla at 0x7fa0f8168f70> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# W0516 07:33:19.185656 140331538548544 polymorphic_function.py:156] 6 out of the last 6 calls to <function _BaseOptimizer._update_step_xla at 0x7fa0f8168f70> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 반복(Epoch): 0, 에러(err): 0.0013, 승리횟수(Win count): 0, 승리비율(Win ratio): 0.0000
# 반복(Epoch): 1, 에러(err): 0.1184, 승리횟수(Win count): 1, 승리비율(Win ratio): 50.0000
# /content/model.ckpt-1 경로에 파라미터가 저장되었습니다
# 반복(Epoch): 2, 에러(err): 0.2001, 승리횟수(Win count): 2, 승리비율(Win ratio): 66.6667
# 반복(Epoch): 3, 에러(err): 0.2341, 승리횟수(Win count): 2, 승리비율(Win ratio): 50.0000
# 반복(Epoch): 4, 에러(err): 0.2130, 승리횟수(Win count): 2, 승리비율(Win ratio): 40.0000
# 반복(Epoch): 5, 에러(err): 0.3807, 승리횟수(Win count): 2, 승리비율(Win ratio): 33.3333
# 반복(Epoch): 6, 에러(err): 0.4534, 승리횟수(Win count): 2, 승리비율(Win ratio): 28.5714
# 반복(Epoch): 7, 에러(err): 0.4469, 승리횟수(Win count): 2, 승리비율(Win ratio): 25.0000
# 반복(Epoch): 8, 에러(err): 0.5124, 승리횟수(Win count): 3, 승리비율(Win ratio): 33.3333
# 반복(Epoch): 9, 에러(err): 0.3886, 승리횟수(Win count): 4, 승리비율(Win ratio): 40.0000
# 반복(Epoch): 10, 에러(err): 0.2455, 승리횟수(Win count): 4, 승리비율(Win ratio): 36.3636
# 반복(Epoch): 11, 에러(err): 0.4569, 승리횟수(Win count): 4, 승리비율(Win ratio): 33.3333
# 반복(Epoch): 12, 에러(err): 0.3018, 승리횟수(Win count): 4, 승리비율(Win ratio): 30.7692
# 반복(Epoch): 13, 에러(err): 0.3768, 승리횟수(Win count): 5, 승리비율(Win ratio): 35.7143
# 반복(Epoch): 14, 에러(err): 0.3006, 승리횟수(Win count): 5, 승리비율(Win ratio): 33.3333
# 반복(Epoch): 15, 에러(err): 0.3639, 승리횟수(Win count): 6, 승리비율(Win ratio): 37.5000
# 반복(Epoch): 16, 에러(err): 0.3437, 승리횟수(Win count): 6, 승리비율(Win ratio): 35.2941
# 반복(Epoch): 17, 에러(err): 0.3901, 승리횟수(Win count): 6, 승리비율(Win ratio): 33.3333
# 반복(Epoch): 18, 에러(err): 0.2827, 승리횟수(Win count): 7, 승리비율(Win ratio): 36.8421
# 반복(Epoch): 19, 에러(err): 0.3559, 승리횟수(Win count): 8, 승리비율(Win ratio): 40.0000
# 반복(Epoch): 20, 에러(err): 0.3190, 승리횟수(Win count): 8, 승리비율(Win ratio): 38.0952
# 반복(Epoch): 21, 에러(err): 0.3421, 승리횟수(Win count): 8, 승리비율(Win ratio): 36.3636
# 반복(Epoch): 22, 에러(err): 0.4016, 승리횟수(Win count): 8, 승리비율(Win ratio): 34.7826
# 반복(Epoch): 23, 에러(err): 0.3223, 승리횟수(Win count): 8, 승리비율(Win ratio): 33.3333
# 반복(Epoch): 24, 에러(err): 0.3270, 승리횟수(Win count): 8, 승리비율(Win ratio): 32.0000
# 반복(Epoch): 25, 에러(err): 0.3711, 승리횟수(Win count): 8, 승리비율(Win ratio): 30.7692
# 반복(Epoch): 26, 에러(err): 0.3576, 승리횟수(Win count): 8, 승리비율(Win ratio): 29.6296
# 반복(Epoch): 27, 에러(err): 0.2917, 승리횟수(Win count): 9, 승리비율(Win ratio): 32.1429
# 반복(Epoch): 28, 에러(err): 0.3064, 승리횟수(Win count): 9, 승리비율(Win ratio): 31.0345
# 반복(Epoch): 29, 에러(err): 0.3250, 승리횟수(Win count): 9, 승리비율(Win ratio): 30.0000
# 반복(Epoch): 30, 에러(err): 0.3443, 승리횟수(Win count): 10, 승리비율(Win ratio): 32.2581
# 반복(Epoch): 31, 에러(err): 0.3920, 승리횟수(Win count): 10, 승리비율(Win ratio): 31.2500
# 반복(Epoch): 32, 에러(err): 0.3131, 승리횟수(Win count): 10, 승리비율(Win ratio): 30.3030
# 반복(Epoch): 33, 에러(err): 0.2979, 승리횟수(Win count): 10, 승리비율(Win ratio): 29.4118
# 반복(Epoch): 34, 에러(err): 0.3272, 승리횟수(Win count): 10, 승리비율(Win ratio): 28.5714
# 반복(Epoch): 35, 에러(err): 0.3930, 승리횟수(Win count): 11, 승리비율(Win ratio): 30.5556
# 반복(Epoch): 36, 에러(err): 0.3765, 승리횟수(Win count): 12, 승리비율(Win ratio): 32.4324
# 반복(Epoch): 37, 에러(err): 0.3639, 승리횟수(Win count): 12, 승리비율(Win ratio): 31.5789
# 반복(Epoch): 38, 에러(err): 0.2563, 승리횟수(Win count): 12, 승리비율(Win ratio): 30.7692
# 반복(Epoch): 39, 에러(err): 0.2537, 승리횟수(Win count): 12, 승리비율(Win ratio): 30.0000
# 반복(Epoch): 40, 에러(err): 0.2277, 승리횟수(Win count): 12, 승리비율(Win ratio): 29.2683
# 반복(Epoch): 41, 에러(err): 0.3184, 승리횟수(Win count): 12, 승리비율(Win ratio): 28.5714
# 반복(Epoch): 42, 에러(err): 0.2382, 승리횟수(Win count): 13, 승리비율(Win ratio): 30.2326
# 반복(Epoch): 43, 에러(err): 0.2584, 승리횟수(Win count): 14, 승리비율(Win ratio): 31.8182
# 반복(Epoch): 44, 에러(err): 0.3005, 승리횟수(Win count): 14, 승리비율(Win ratio): 31.1111
# 반복(Epoch): 45, 에러(err): 0.2229, 승리횟수(Win count): 15, 승리비율(Win ratio): 32.6087
# 반복(Epoch): 46, 에러(err): 0.2601, 승리횟수(Win count): 15, 승리비율(Win ratio): 31.9149
# 반복(Epoch): 47, 에러(err): 0.3447, 승리횟수(Win count): 15, 승리비율(Win ratio): 31.2500
# 반복(Epoch): 48, 에러(err): 0.2458, 승리횟수(Win count): 16, 승리비율(Win ratio): 32.6531
# 반복(Epoch): 49, 에러(err): 0.2969, 승리횟수(Win count): 16, 승리비율(Win ratio): 32.0000
# 반복(Epoch): 50, 에러(err): 0.2374, 승리횟수(Win count): 16, 승리비율(Win ratio): 31.3725
# 반복(Epoch): 51, 에러(err): 0.2655, 승리횟수(Win count): 16, 승리비율(Win ratio): 30.7692
# 반복(Epoch): 52, 에러(err): 0.2283, 승리횟수(Win count): 16, 승리비율(Win ratio): 30.1887
# 반복(Epoch): 53, 에러(err): 0.2726, 승리횟수(Win count): 16, 승리비율(Win ratio): 29.6296
# 반복(Epoch): 54, 에러(err): 0.1756, 승리횟수(Win count): 16, 승리비율(Win ratio): 29.0909
# 반복(Epoch): 55, 에러(err): 0.3267, 승리횟수(Win count): 16, 승리비율(Win ratio): 28.5714
# 반복(Epoch): 56, 에러(err): 0.1866, 승리횟수(Win count): 17, 승리비율(Win ratio): 29.8246
# 반복(Epoch): 57, 에러(err): 0.2343, 승리횟수(Win count): 18, 승리비율(Win ratio): 31.0345
# 반복(Epoch): 58, 에러(err): 0.2525, 승리횟수(Win count): 18, 승리비율(Win ratio): 30.5085
# 반복(Epoch): 59, 에러(err): 0.2260, 승리횟수(Win count): 18, 승리비율(Win ratio): 30.0000
# 반복(Epoch): 60, 에러(err): 0.2175, 승리횟수(Win count): 18, 승리비율(Win ratio): 29.5082
# 반복(Epoch): 61, 에러(err): 0.2832, 승리횟수(Win count): 19, 승리비율(Win ratio): 30.6452
# 반복(Epoch): 62, 에러(err): 0.1991, 승리횟수(Win count): 19, 승리비율(Win ratio): 30.1587
# 반복(Epoch): 63, 에러(err): 0.2269, 승리횟수(Win count): 19, 승리비율(Win ratio): 29.6875
# 반복(Epoch): 64, 에러(err): 0.3009, 승리횟수(Win count): 19, 승리비율(Win ratio): 29.2308
# 반복(Epoch): 65, 에러(err): 0.2174, 승리횟수(Win count): 20, 승리비율(Win ratio): 30.3030
# 반복(Epoch): 66, 에러(err): 0.2673, 승리횟수(Win count): 20, 승리비율(Win ratio): 29.8507
# 반복(Epoch): 67, 에러(err): 0.2123, 승리횟수(Win count): 21, 승리비율(Win ratio): 30.8824
# 반복(Epoch): 68, 에러(err): 0.2365, 승리횟수(Win count): 21, 승리비율(Win ratio): 30.4348
# 반복(Epoch): 69, 에러(err): 0.2743, 승리횟수(Win count): 22, 승리비율(Win ratio): 31.4286
# 반복(Epoch): 70, 에러(err): 0.2300, 승리횟수(Win count): 23, 승리비율(Win ratio): 32.3944
# 반복(Epoch): 71, 에러(err): 0.2639, 승리횟수(Win count): 23, 승리비율(Win ratio): 31.9444
# 반복(Epoch): 72, 에러(err): 0.2966, 승리횟수(Win count): 24, 승리비율(Win ratio): 32.8767
# 반복(Epoch): 73, 에러(err): 0.2169, 승리횟수(Win count): 24, 승리비율(Win ratio): 32.4324
# 반복(Epoch): 74, 에러(err): 0.1754, 승리횟수(Win count): 24, 승리비율(Win ratio): 32.0000
# 반복(Epoch): 75, 에러(err): 0.3018, 승리횟수(Win count): 24, 승리비율(Win ratio): 31.5789
# 반복(Epoch): 76, 에러(err): 0.3025, 승리횟수(Win count): 24, 승리비율(Win ratio): 31.1688
# 반복(Epoch): 77, 에러(err): 0.2480, 승리횟수(Win count): 24, 승리비율(Win ratio): 30.7692
# 반복(Epoch): 78, 에러(err): 0.2844, 승리횟수(Win count): 24, 승리비율(Win ratio): 30.3797
# 반복(Epoch): 79, 에러(err): 0.2747, 승리횟수(Win count): 25, 승리비율(Win ratio): 31.2500
# 반복(Epoch): 80, 에러(err): 0.2093, 승리횟수(Win count): 25, 승리비율(Win ratio): 30.8642
# 반복(Epoch): 81, 에러(err): 0.2930, 승리횟수(Win count): 25, 승리비율(Win ratio): 30.4878
# 반복(Epoch): 82, 에러(err): 0.2353, 승리횟수(Win count): 25, 승리비율(Win ratio): 30.1205
# 반복(Epoch): 83, 에러(err): 0.3051, 승리횟수(Win count): 25, 승리비율(Win ratio): 29.7619
# 반복(Epoch): 84, 에러(err): 0.2681, 승리횟수(Win count): 25, 승리비율(Win ratio): 29.4118
# 반복(Epoch): 85, 에러(err): 0.2373, 승리횟수(Win count): 25, 승리비율(Win ratio): 29.0698
# 반복(Epoch): 86, 에러(err): 0.2630, 승리횟수(Win count): 26, 승리비율(Win ratio): 29.8851
# 반복(Epoch): 87, 에러(err): 0.1916, 승리횟수(Win count): 26, 승리비율(Win ratio): 29.5455
# 반복(Epoch): 88, 에러(err): 0.2679, 승리횟수(Win count): 26, 승리비율(Win ratio): 29.2135
# 반복(Epoch): 89, 에러(err): 0.1639, 승리횟수(Win count): 26, 승리비율(Win ratio): 28.8889
# 반복(Epoch): 90, 에러(err): 0.2323, 승리횟수(Win count): 26, 승리비율(Win ratio): 28.5714
# 반복(Epoch): 91, 에러(err): 0.2749, 승리횟수(Win count): 26, 승리비율(Win ratio): 28.2609
# 반복(Epoch): 92, 에러(err): 0.2366, 승리횟수(Win count): 27, 승리비율(Win ratio): 29.0323
# 반복(Epoch): 93, 에러(err): 0.3269, 승리횟수(Win count): 27, 승리비율(Win ratio): 28.7234
# 반복(Epoch): 94, 에러(err): 0.2583, 승리횟수(Win count): 27, 승리비율(Win ratio): 28.4211
# 반복(Epoch): 95, 에러(err): 0.2224, 승리횟수(Win count): 27, 승리비율(Win ratio): 28.1250
# 반복(Epoch): 96, 에러(err): 0.1809, 승리횟수(Win count): 27, 승리비율(Win ratio): 27.8351
# 반복(Epoch): 97, 에러(err): 0.2412, 승리횟수(Win count): 28, 승리비율(Win ratio): 28.5714
# 반복(Epoch): 98, 에러(err): 0.2271, 승리횟수(Win count): 28, 승리비율(Win ratio): 28.2828
# 반복(Epoch): 99, 에러(err): 0.2501, 승리횟수(Win count): 29, 승리비율(Win ratio): 29.0000
# 반복(Epoch): 100, 에러(err): 0.1545, 승리횟수(Win count): 29, 승리비율(Win ratio): 28.7129
# 반복(Epoch): 101, 에러(err): 0.2169, 승리횟수(Win count): 29, 승리비율(Win ratio): 28.4314
# /content/model.ckpt-101 경로에 파라미터가 저장되었습니다
# 반복(Epoch): 102, 에러(err): 0.2753, 승리횟수(Win count): 29, 승리비율(Win ratio): 28.1553
# 반복(Epoch): 103, 에러(err): 0.2441, 승리횟수(Win count): 30, 승리비율(Win ratio): 28.8462
# 반복(Epoch): 104, 에러(err): 0.1602, 승리횟수(Win count): 30, 승리비율(Win ratio): 28.5714
# 반복(Epoch): 105, 에러(err): 0.1437, 승리횟수(Win count): 31, 승리비율(Win ratio): 29.2453
# 반복(Epoch): 106, 에러(err): 0.1901, 승리횟수(Win count): 31, 승리비율(Win ratio): 28.9720
# 반복(Epoch): 107, 에러(err): 0.2299, 승리횟수(Win count): 31, 승리비율(Win ratio): 28.7037
# 반복(Epoch): 108, 에러(err): 0.2138, 승리횟수(Win count): 32, 승리비율(Win ratio): 29.3578
# 반복(Epoch): 109, 에러(err): 0.1762, 승리횟수(Win count): 32, 승리비율(Win ratio): 29.0909
# 반복(Epoch): 110, 에러(err): 0.2627, 승리횟수(Win count): 32, 승리비율(Win ratio): 28.8288
# 반복(Epoch): 111, 에러(err): 0.2295, 승리횟수(Win count): 33, 승리비율(Win ratio): 29.4643
# 반복(Epoch): 112, 에러(err): 0.2267, 승리횟수(Win count): 33, 승리비율(Win ratio): 29.2035
# 반복(Epoch): 113, 에러(err): 0.2028, 승리횟수(Win count): 33, 승리비율(Win ratio): 28.9474
# 반복(Epoch): 114, 에러(err): 0.2621, 승리횟수(Win count): 33, 승리비율(Win ratio): 28.6957
# 반복(Epoch): 115, 에러(err): 0.2450, 승리횟수(Win count): 33, 승리비율(Win ratio): 28.4483
# 반복(Epoch): 116, 에러(err): 0.2353, 승리횟수(Win count): 33, 승리비율(Win ratio): 28.2051
# 반복(Epoch): 117, 에러(err): 0.1830, 승리횟수(Win count): 34, 승리비율(Win ratio): 28.8136
# 반복(Epoch): 118, 에러(err): 0.3026, 승리횟수(Win count): 35, 승리비율(Win ratio): 29.4118
# 반복(Epoch): 119, 에러(err): 0.2470, 승리횟수(Win count): 36, 승리비율(Win ratio): 30.0000
# 반복(Epoch): 120, 에러(err): 0.2300, 승리횟수(Win count): 36, 승리비율(Win ratio): 29.7521
# 반복(Epoch): 121, 에러(err): 0.2461, 승리횟수(Win count): 37, 승리비율(Win ratio): 30.3279
# 반복(Epoch): 122, 에러(err): 0.2607, 승리횟수(Win count): 37, 승리비율(Win ratio): 30.0813
# 반복(Epoch): 123, 에러(err): 0.2498, 승리횟수(Win count): 38, 승리비율(Win ratio): 30.6452
# 반복(Epoch): 124, 에러(err): 0.2313, 승리횟수(Win count): 39, 승리비율(Win ratio): 31.2000
# 반복(Epoch): 125, 에러(err): 0.1686, 승리횟수(Win count): 39, 승리비율(Win ratio): 30.9524
# 반복(Epoch): 126, 에러(err): 0.2543, 승리횟수(Win count): 40, 승리비율(Win ratio): 31.4961
# 반복(Epoch): 127, 에러(err): 0.2407, 승리횟수(Win count): 40, 승리비율(Win ratio): 31.2500
# 반복(Epoch): 128, 에러(err): 0.1936, 승리횟수(Win count): 41, 승리비율(Win ratio): 31.7829
# 반복(Epoch): 129, 에러(err): 0.2148, 승리횟수(Win count): 41, 승리비율(Win ratio): 31.5385
# 반복(Epoch): 130, 에러(err): 0.2073, 승리횟수(Win count): 41, 승리비율(Win ratio): 31.2977
# 반복(Epoch): 131, 에러(err): 0.1823, 승리횟수(Win count): 41, 승리비율(Win ratio): 31.0606
# 반복(Epoch): 132, 에러(err): 0.2209, 승리횟수(Win count): 41, 승리비율(Win ratio): 30.8271
# 반복(Epoch): 133, 에러(err): 0.2669, 승리횟수(Win count): 41, 승리비율(Win ratio): 30.5970
# 반복(Epoch): 134, 에러(err): 0.1597, 승리횟수(Win count): 42, 승리비율(Win ratio): 31.1111
# 반복(Epoch): 135, 에러(err): 0.1706, 승리횟수(Win count): 43, 승리비율(Win ratio): 31.6176
# 반복(Epoch): 136, 에러(err): 0.0901, 승리횟수(Win count): 43, 승리비율(Win ratio): 31.3869
# 반복(Epoch): 137, 에러(err): 0.2158, 승리횟수(Win count): 44, 승리비율(Win ratio): 31.8841
# 반복(Epoch): 138, 에러(err): 0.1546, 승리횟수(Win count): 45, 승리비율(Win ratio): 32.3741
# 반복(Epoch): 139, 에러(err): 0.1565, 승리횟수(Win count): 45, 승리비율(Win ratio): 32.1429
# 반복(Epoch): 140, 에러(err): 0.1402, 승리횟수(Win count): 46, 승리비율(Win ratio): 32.6241
# 반복(Epoch): 141, 에러(err): 0.1661, 승리횟수(Win count): 46, 승리비율(Win ratio): 32.3944
# 반복(Epoch): 142, 에러(err): 0.2967, 승리횟수(Win count): 46, 승리비율(Win ratio): 32.1678
# 반복(Epoch): 143, 에러(err): 0.2679, 승리횟수(Win count): 46, 승리비율(Win ratio): 31.9444
# 반복(Epoch): 144, 에러(err): 0.2048, 승리횟수(Win count): 47, 승리비율(Win ratio): 32.4138
# 반복(Epoch): 145, 에러(err): 0.1919, 승리횟수(Win count): 47, 승리비율(Win ratio): 32.1918
# 반복(Epoch): 146, 에러(err): 0.1673, 승리횟수(Win count): 48, 승리비율(Win ratio): 32.6531
# 반복(Epoch): 147, 에러(err): 0.2511, 승리횟수(Win count): 48, 승리비율(Win ratio): 32.4324
# 반복(Epoch): 148, 에러(err): 0.1670, 승리횟수(Win count): 48, 승리비율(Win ratio): 32.2148
# 반복(Epoch): 149, 에러(err): 0.1249, 승리횟수(Win count): 49, 승리비율(Win ratio): 32.6667
# 반복(Epoch): 150, 에러(err): 0.1955, 승리횟수(Win count): 50, 승리비율(Win ratio): 33.1126
# 반복(Epoch): 151, 에러(err): 0.1999, 승리횟수(Win count): 50, 승리비율(Win ratio): 32.8947
# 반복(Epoch): 152, 에러(err): 0.3821, 승리횟수(Win count): 50, 승리비율(Win ratio): 32.6797
# 반복(Epoch): 153, 에러(err): 0.2331, 승리횟수(Win count): 51, 승리비율(Win ratio): 33.1169
# 반복(Epoch): 154, 에러(err): 0.2134, 승리횟수(Win count): 51, 승리비율(Win ratio): 32.9032
# 반복(Epoch): 155, 에러(err): 0.2618, 승리횟수(Win count): 51, 승리비율(Win ratio): 32.6923
# 반복(Epoch): 156, 에러(err): 0.2385, 승리횟수(Win count): 52, 승리비율(Win ratio): 33.1210
# 반복(Epoch): 157, 에러(err): 0.1928, 승리횟수(Win count): 53, 승리비율(Win ratio): 33.5443
# 반복(Epoch): 158, 에러(err): 0.2232, 승리횟수(Win count): 53, 승리비율(Win ratio): 33.3333
# 반복(Epoch): 159, 에러(err): 0.3005, 승리횟수(Win count): 53, 승리비율(Win ratio): 33.1250
# 반복(Epoch): 160, 에러(err): 0.2168, 승리횟수(Win count): 54, 승리비율(Win ratio): 33.5404
# 반복(Epoch): 161, 에러(err): 0.2651, 승리횟수(Win count): 55, 승리비율(Win ratio): 33.9506
# 반복(Epoch): 162, 에러(err): 0.2120, 승리횟수(Win count): 56, 승리비율(Win ratio): 34.3558
# 반복(Epoch): 163, 에러(err): 0.2002, 승리횟수(Win count): 56, 승리비율(Win ratio): 34.1463
# 반복(Epoch): 164, 에러(err): 0.2691, 승리횟수(Win count): 56, 승리비율(Win ratio): 33.9394
# 반복(Epoch): 165, 에러(err): 0.2163, 승리횟수(Win count): 56, 승리비율(Win ratio): 33.7349
# 반복(Epoch): 166, 에러(err): 0.1576, 승리횟수(Win count): 56, 승리비율(Win ratio): 33.5329
# 반복(Epoch): 167, 에러(err): 0.1889, 승리횟수(Win count): 57, 승리비율(Win ratio): 33.9286
# 반복(Epoch): 168, 에러(err): 0.3321, 승리횟수(Win count): 58, 승리비율(Win ratio): 34.3195
# 반복(Epoch): 169, 에러(err): 0.1875, 승리횟수(Win count): 59, 승리비율(Win ratio): 34.7059
# 반복(Epoch): 170, 에러(err): 0.2715, 승리횟수(Win count): 59, 승리비율(Win ratio): 34.5029
# 반복(Epoch): 171, 에러(err): 0.1566, 승리횟수(Win count): 60, 승리비율(Win ratio): 34.8837
# 반복(Epoch): 172, 에러(err): 0.2229, 승리횟수(Win count): 60, 승리비율(Win ratio): 34.6821
# 반복(Epoch): 173, 에러(err): 0.2196, 승리횟수(Win count): 60, 승리비율(Win ratio): 34.4828
# 반복(Epoch): 174, 에러(err): 0.1692, 승리횟수(Win count): 60, 승리비율(Win ratio): 34.2857
# 반복(Epoch): 175, 에러(err): 0.1592, 승리횟수(Win count): 60, 승리비율(Win ratio): 34.0909
# 반복(Epoch): 176, 에러(err): 0.2381, 승리횟수(Win count): 61, 승리비율(Win ratio): 34.4633
# 반복(Epoch): 177, 에러(err): 0.1882, 승리횟수(Win count): 61, 승리비율(Win ratio): 34.2697
# 반복(Epoch): 178, 에러(err): 0.1943, 승리횟수(Win count): 61, 승리비율(Win ratio): 34.0782
# 반복(Epoch): 179, 에러(err): 0.2514, 승리횟수(Win count): 61, 승리비율(Win ratio): 33.8889
# 반복(Epoch): 180, 에러(err): 0.2024, 승리횟수(Win count): 61, 승리비율(Win ratio): 33.7017
# 반복(Epoch): 181, 에러(err): 0.1747, 승리횟수(Win count): 62, 승리비율(Win ratio): 34.0659
# 반복(Epoch): 182, 에러(err): 0.2080, 승리횟수(Win count): 63, 승리비율(Win ratio): 34.4262
# 반복(Epoch): 183, 에러(err): 0.2444, 승리횟수(Win count): 64, 승리비율(Win ratio): 34.7826
# 반복(Epoch): 184, 에러(err): 0.1798, 승리횟수(Win count): 64, 승리비율(Win ratio): 34.5946
# 반복(Epoch): 185, 에러(err): 0.2116, 승리횟수(Win count): 64, 승리비율(Win ratio): 34.4086
# 반복(Epoch): 186, 에러(err): 0.2572, 승리횟수(Win count): 65, 승리비율(Win ratio): 34.7594
# 반복(Epoch): 187, 에러(err): 0.1690, 승리횟수(Win count): 65, 승리비율(Win ratio): 34.5745
# 반복(Epoch): 188, 에러(err): 0.2117, 승리횟수(Win count): 66, 승리비율(Win ratio): 34.9206
# 반복(Epoch): 189, 에러(err): 0.1662, 승리횟수(Win count): 66, 승리비율(Win ratio): 34.7368
# 반복(Epoch): 190, 에러(err): 0.3832, 승리횟수(Win count): 67, 승리비율(Win ratio): 35.0785
# 반복(Epoch): 191, 에러(err): 0.1554, 승리횟수(Win count): 67, 승리비율(Win ratio): 34.8958
# 반복(Epoch): 192, 에러(err): 0.2111, 승리횟수(Win count): 67, 승리비율(Win ratio): 34.7150
# 반복(Epoch): 193, 에러(err): 0.1663, 승리횟수(Win count): 67, 승리비율(Win ratio): 34.5361
# 반복(Epoch): 194, 에러(err): 0.1242, 승리횟수(Win count): 68, 승리비율(Win ratio): 34.8718
# 반복(Epoch): 195, 에러(err): 0.1722, 승리횟수(Win count): 68, 승리비율(Win ratio): 34.6939
# 반복(Epoch): 196, 에러(err): 0.1385, 승리횟수(Win count): 69, 승리비율(Win ratio): 35.0254
# 반복(Epoch): 197, 에러(err): 0.3358, 승리횟수(Win count): 69, 승리비율(Win ratio): 34.8485
# 반복(Epoch): 198, 에러(err): 0.2293, 승리횟수(Win count): 70, 승리비율(Win ratio): 35.1759
# 반복(Epoch): 199, 에러(err): 0.1908, 승리횟수(Win count): 70, 승리비율(Win ratio): 35.0000
# 반복(Epoch): 200, 에러(err): 0.1874, 승리횟수(Win count): 71, 승리비율(Win ratio): 35.3234
# 반복(Epoch): 201, 에러(err): 0.2164, 승리횟수(Win count): 72, 승리비율(Win ratio): 35.6436
# /content/model.ckpt-201 경로에 파라미터가 저장되었습니다
# 반복(Epoch): 202, 에러(err): 0.1662, 승리횟수(Win count): 73, 승리비율(Win ratio): 35.9606
# 반복(Epoch): 203, 에러(err): 0.3211, 승리횟수(Win count): 73, 승리비율(Win ratio): 35.7843
# 반복(Epoch): 204, 에러(err): 0.1895, 승리횟수(Win count): 74, 승리비율(Win ratio): 36.0976
# 반복(Epoch): 205, 에러(err): 0.1464, 승리횟수(Win count): 74, 승리비율(Win ratio): 35.9223
# 반복(Epoch): 206, 에러(err): 0.1612, 승리횟수(Win count): 75, 승리비율(Win ratio): 36.2319
# 반복(Epoch): 207, 에러(err): 0.1442, 승리횟수(Win count): 75, 승리비율(Win ratio): 36.0577
# 반복(Epoch): 208, 에러(err): 0.1522, 승리횟수(Win count): 76, 승리비율(Win ratio): 36.3636
# 반복(Epoch): 209, 에러(err): 0.2142, 승리횟수(Win count): 77, 승리비율(Win ratio): 36.6667
# 반복(Epoch): 210, 에러(err): 0.2051, 승리횟수(Win count): 77, 승리비율(Win ratio): 36.4929
# 반복(Epoch): 211, 에러(err): 0.3349, 승리횟수(Win count): 77, 승리비율(Win ratio): 36.3208
# 반복(Epoch): 212, 에러(err): 0.2006, 승리횟수(Win count): 77, 승리비율(Win ratio): 36.1502
# 반복(Epoch): 213, 에러(err): 0.2441, 승리횟수(Win count): 78, 승리비율(Win ratio): 36.4486
# 반복(Epoch): 214, 에러(err): 0.1555, 승리횟수(Win count): 78, 승리비율(Win ratio): 36.2791
# 반복(Epoch): 215, 에러(err): 0.2425, 승리횟수(Win count): 79, 승리비율(Win ratio): 36.5741
# 반복(Epoch): 216, 에러(err): 0.1936, 승리횟수(Win count): 79, 승리비율(Win ratio): 36.4055
# 반복(Epoch): 217, 에러(err): 0.2760, 승리횟수(Win count): 80, 승리비율(Win ratio): 36.6972
# 반복(Epoch): 218, 에러(err): 0.1161, 승리횟수(Win count): 80, 승리비율(Win ratio): 36.5297
# 반복(Epoch): 219, 에러(err): 0.1912, 승리횟수(Win count): 80, 승리비율(Win ratio): 36.3636
# 반복(Epoch): 220, 에러(err): 0.1543, 승리횟수(Win count): 80, 승리비율(Win ratio): 36.1991
# 반복(Epoch): 221, 에러(err): 0.2687, 승리횟수(Win count): 80, 승리비율(Win ratio): 36.0360
# 반복(Epoch): 222, 에러(err): 0.2847, 승리횟수(Win count): 81, 승리비율(Win ratio): 36.3229
# 반복(Epoch): 223, 에러(err): 0.2241, 승리횟수(Win count): 82, 승리비율(Win ratio): 36.6071
# 반복(Epoch): 224, 에러(err): 0.1671, 승리횟수(Win count): 82, 승리비율(Win ratio): 36.4444
# 반복(Epoch): 225, 에러(err): 0.2228, 승리횟수(Win count): 82, 승리비율(Win ratio): 36.2832
# 반복(Epoch): 226, 에러(err): 0.3056, 승리횟수(Win count): 83, 승리비율(Win ratio): 36.5639
# 반복(Epoch): 227, 에러(err): 0.1764, 승리횟수(Win count): 84, 승리비율(Win ratio): 36.8421
# 반복(Epoch): 228, 에러(err): 0.2142, 승리횟수(Win count): 84, 승리비율(Win ratio): 36.6812
# 반복(Epoch): 229, 에러(err): 0.2075, 승리횟수(Win count): 85, 승리비율(Win ratio): 36.9565
# 반복(Epoch): 230, 에러(err): 0.1796, 승리횟수(Win count): 85, 승리비율(Win ratio): 36.7965
# 반복(Epoch): 231, 에러(err): 0.2180, 승리횟수(Win count): 85, 승리비율(Win ratio): 36.6379
# 반복(Epoch): 232, 에러(err): 0.1698, 승리횟수(Win count): 86, 승리비율(Win ratio): 36.9099
# 반복(Epoch): 233, 에러(err): 0.2579, 승리횟수(Win count): 87, 승리비율(Win ratio): 37.1795
# 반복(Epoch): 234, 에러(err): 0.1640, 승리횟수(Win count): 88, 승리비율(Win ratio): 37.4468
# 반복(Epoch): 235, 에러(err): 0.5042, 승리횟수(Win count): 88, 승리비율(Win ratio): 37.2881
# 반복(Epoch): 236, 에러(err): 0.2250, 승리횟수(Win count): 89, 승리비율(Win ratio): 37.5527
# 반복(Epoch): 237, 에러(err): 0.1448, 승리횟수(Win count): 90, 승리비율(Win ratio): 37.8151
# 반복(Epoch): 238, 에러(err): 0.3224, 승리횟수(Win count): 91, 승리비율(Win ratio): 38.0753
# 반복(Epoch): 239, 에러(err): 0.4846, 승리횟수(Win count): 91, 승리비율(Win ratio): 37.9167
# 반복(Epoch): 240, 에러(err): 0.2698, 승리횟수(Win count): 92, 승리비율(Win ratio): 38.1743
# 반복(Epoch): 241, 에러(err): 0.2575, 승리횟수(Win count): 92, 승리비율(Win ratio): 38.0165
# 반복(Epoch): 242, 에러(err): 0.1893, 승리횟수(Win count): 92, 승리비율(Win ratio): 37.8601
# 반복(Epoch): 243, 에러(err): 0.3708, 승리횟수(Win count): 92, 승리비율(Win ratio): 37.7049
# 반복(Epoch): 244, 에러(err): 0.2432, 승리횟수(Win count): 92, 승리비율(Win ratio): 37.5510
# 반복(Epoch): 245, 에러(err): 0.2644, 승리횟수(Win count): 92, 승리비율(Win ratio): 37.3984
# 반복(Epoch): 246, 에러(err): 0.2346, 승리횟수(Win count): 93, 승리비율(Win ratio): 37.6518
# 반복(Epoch): 247, 에러(err): 0.2356, 승리횟수(Win count): 94, 승리비율(Win ratio): 37.9032
# 반복(Epoch): 248, 에러(err): 0.2431, 승리횟수(Win count): 95, 승리비율(Win ratio): 38.1526
# 반복(Epoch): 249, 에러(err): 0.1364, 승리횟수(Win count): 96, 승리비율(Win ratio): 38.4000
# 반복(Epoch): 250, 에러(err): 0.2559, 승리횟수(Win count): 96, 승리비율(Win ratio): 38.2470
# 반복(Epoch): 251, 에러(err): 0.0935, 승리횟수(Win count): 96, 승리비율(Win ratio): 38.0952
# 반복(Epoch): 252, 에러(err): 0.2836, 승리횟수(Win count): 97, 승리비율(Win ratio): 38.3399
# 반복(Epoch): 253, 에러(err): 0.3020, 승리횟수(Win count): 97, 승리비율(Win ratio): 38.1890
# 반복(Epoch): 254, 에러(err): 0.1050, 승리횟수(Win count): 98, 승리비율(Win ratio): 38.4314
# 반복(Epoch): 255, 에러(err): 0.3044, 승리횟수(Win count): 99, 승리비율(Win ratio): 38.6719
# 반복(Epoch): 256, 에러(err): 0.2785, 승리횟수(Win count): 100, 승리비율(Win ratio): 38.9105
# 반복(Epoch): 257, 에러(err): 0.3094, 승리횟수(Win count): 101, 승리비율(Win ratio): 39.1473
# 반복(Epoch): 258, 에러(err): 0.2149, 승리횟수(Win count): 102, 승리비율(Win ratio): 39.3822
# 반복(Epoch): 259, 에러(err): 0.2219, 승리횟수(Win count): 103, 승리비율(Win ratio): 39.6154
# 반복(Epoch): 260, 에러(err): 0.2950, 승리횟수(Win count): 103, 승리비율(Win ratio): 39.4636
# 반복(Epoch): 261, 에러(err): 0.2490, 승리횟수(Win count): 103, 승리비율(Win ratio): 39.3130
# 반복(Epoch): 262, 에러(err): 0.0963, 승리횟수(Win count): 104, 승리비율(Win ratio): 39.5437
# 반복(Epoch): 263, 에러(err): 0.2853, 승리횟수(Win count): 105, 승리비율(Win ratio): 39.7727
# 반복(Epoch): 264, 에러(err): 0.6095, 승리횟수(Win count): 105, 승리비율(Win ratio): 39.6226
# 반복(Epoch): 265, 에러(err): 0.1987, 승리횟수(Win count): 105, 승리비율(Win ratio): 39.4737
# 반복(Epoch): 266, 에러(err): 0.3065, 승리횟수(Win count): 106, 승리비율(Win ratio): 39.7004
# 반복(Epoch): 267, 에러(err): 0.4058, 승리횟수(Win count): 106, 승리비율(Win ratio): 39.5522
# 반복(Epoch): 268, 에러(err): 0.5839, 승리횟수(Win count): 107, 승리비율(Win ratio): 39.7770
# 반복(Epoch): 269, 에러(err): 0.4443, 승리횟수(Win count): 107, 승리비율(Win ratio): 39.6296
# 반복(Epoch): 270, 에러(err): 0.3909, 승리횟수(Win count): 107, 승리비율(Win ratio): 39.4834
# 반복(Epoch): 271, 에러(err): 0.2798, 승리횟수(Win count): 107, 승리비율(Win ratio): 39.3382
# 반복(Epoch): 272, 에러(err): 0.6312, 승리횟수(Win count): 108, 승리비율(Win ratio): 39.5604
# 반복(Epoch): 273, 에러(err): 0.2769, 승리횟수(Win count): 109, 승리비율(Win ratio): 39.7810
# 반복(Epoch): 274, 에러(err): 0.3954, 승리횟수(Win count): 110, 승리비율(Win ratio): 40.0000
# 반복(Epoch): 275, 에러(err): 0.3586, 승리횟수(Win count): 110, 승리비율(Win ratio): 39.8551
# 반복(Epoch): 276, 에러(err): 0.5171, 승리횟수(Win count): 110, 승리비율(Win ratio): 39.7112
# 반복(Epoch): 277, 에러(err): 0.3009, 승리횟수(Win count): 110, 승리비율(Win ratio): 39.5683
# 반복(Epoch): 278, 에러(err): 0.6661, 승리횟수(Win count): 111, 승리비율(Win ratio): 39.7849
# 반복(Epoch): 279, 에러(err): 0.1894, 승리횟수(Win count): 112, 승리비율(Win ratio): 40.0000
# 반복(Epoch): 280, 에러(err): 0.3968, 승리횟수(Win count): 112, 승리비율(Win ratio): 39.8577
# 반복(Epoch): 281, 에러(err): 0.5126, 승리횟수(Win count): 112, 승리비율(Win ratio): 39.7163
# 반복(Epoch): 282, 에러(err): 0.3226, 승리횟수(Win count): 113, 승리비율(Win ratio): 39.9293
# 반복(Epoch): 283, 에러(err): 0.3325, 승리횟수(Win count): 113, 승리비율(Win ratio): 39.7887
# 반복(Epoch): 284, 에러(err): 0.6232, 승리횟수(Win count): 114, 승리비율(Win ratio): 40.0000
# 반복(Epoch): 285, 에러(err): 0.4931, 승리횟수(Win count): 115, 승리비율(Win ratio): 40.2098
# 반복(Epoch): 286, 에러(err): 0.1749, 승리횟수(Win count): 116, 승리비율(Win ratio): 40.4181
# 반복(Epoch): 287, 에러(err): 0.3906, 승리횟수(Win count): 116, 승리비율(Win ratio): 40.2778
# 반복(Epoch): 288, 에러(err): 0.5426, 승리횟수(Win count): 117, 승리비율(Win ratio): 40.4844
# 반복(Epoch): 289, 에러(err): 0.1111, 승리횟수(Win count): 118, 승리비율(Win ratio): 40.6897
# 반복(Epoch): 290, 에러(err): 0.3256, 승리횟수(Win count): 119, 승리비율(Win ratio): 40.8935
# 반복(Epoch): 291, 에러(err): 0.3677, 승리횟수(Win count): 119, 승리비율(Win ratio): 40.7534
# 반복(Epoch): 292, 에러(err): 0.4321, 승리횟수(Win count): 120, 승리비율(Win ratio): 40.9556
# 반복(Epoch): 293, 에러(err): 0.4856, 승리횟수(Win count): 120, 승리비율(Win ratio): 40.8163
# 반복(Epoch): 294, 에러(err): 0.2252, 승리횟수(Win count): 121, 승리비율(Win ratio): 41.0169
# 반복(Epoch): 295, 에러(err): 0.2332, 승리횟수(Win count): 122, 승리비율(Win ratio): 41.2162
# 반복(Epoch): 296, 에러(err): 0.3800, 승리횟수(Win count): 123, 승리비율(Win ratio): 41.4141
# 반복(Epoch): 297, 에러(err): 0.2068, 승리횟수(Win count): 123, 승리비율(Win ratio): 41.2752
# 반복(Epoch): 298, 에러(err): 0.3247, 승리횟수(Win count): 124, 승리비율(Win ratio): 41.4716
# 반복(Epoch): 299, 에러(err): 0.2312, 승리횟수(Win count): 125, 승리비율(Win ratio): 41.6667
# 반복(Epoch): 300, 에러(err): 0.6264, 승리횟수(Win count): 125, 승리비율(Win ratio): 41.5282
# 반복(Epoch): 301, 에러(err): 0.2343, 승리횟수(Win count): 126, 승리비율(Win ratio): 41.7219
# /content/model.ckpt-301 경로에 파라미터가 저장되었습니다
# 반복(Epoch): 302, 에러(err): 0.3544, 승리횟수(Win count): 127, 승리비율(Win ratio): 41.9142
# 반복(Epoch): 303, 에러(err): 0.5492, 승리횟수(Win count): 128, 승리비율(Win ratio): 42.1053
# 반복(Epoch): 304, 에러(err): 0.2440, 승리횟수(Win count): 129, 승리비율(Win ratio): 42.2951
# 반복(Epoch): 305, 에러(err): 0.5141, 승리횟수(Win count): 130, 승리비율(Win ratio): 42.4837
# 반복(Epoch): 306, 에러(err): 0.1982, 승리횟수(Win count): 131, 승리비율(Win ratio): 42.6710
# 반복(Epoch): 307, 에러(err): 0.2823, 승리횟수(Win count): 132, 승리비율(Win ratio): 42.8571
# 반복(Epoch): 308, 에러(err): 0.4757, 승리횟수(Win count): 133, 승리비율(Win ratio): 43.0421
# 반복(Epoch): 309, 에러(err): 0.2507, 승리횟수(Win count): 134, 승리비율(Win ratio): 43.2258
# 반복(Epoch): 310, 에러(err): 0.6163, 승리횟수(Win count): 135, 승리비율(Win ratio): 43.4084
# 반복(Epoch): 311, 에러(err): 0.4168, 승리횟수(Win count): 136, 승리비율(Win ratio): 43.5897
# 반복(Epoch): 312, 에러(err): 0.2099, 승리횟수(Win count): 137, 승리비율(Win ratio): 43.7700
# 반복(Epoch): 313, 에러(err): 0.1308, 승리횟수(Win count): 138, 승리비율(Win ratio): 43.9490
# 반복(Epoch): 314, 에러(err): 0.2999, 승리횟수(Win count): 139, 승리비율(Win ratio): 44.1270
# 반복(Epoch): 315, 에러(err): 0.3656, 승리횟수(Win count): 139, 승리비율(Win ratio): 43.9873
# 반복(Epoch): 316, 에러(err): 0.1563, 승리횟수(Win count): 140, 승리비율(Win ratio): 44.1640
# 반복(Epoch): 317, 에러(err): 0.1415, 승리횟수(Win count): 141, 승리비율(Win ratio): 44.3396
# 반복(Epoch): 318, 에러(err): 0.0831, 승리횟수(Win count): 142, 승리비율(Win ratio): 44.5141
# 반복(Epoch): 319, 에러(err): 0.2193, 승리횟수(Win count): 142, 승리비율(Win ratio): 44.3750
# 반복(Epoch): 320, 에러(err): 0.3084, 승리횟수(Win count): 143, 승리비율(Win ratio): 44.5483
# 반복(Epoch): 321, 에러(err): 0.4751, 승리횟수(Win count): 144, 승리비율(Win ratio): 44.7205
# 반복(Epoch): 322, 에러(err): 0.1691, 승리횟수(Win count): 145, 승리비율(Win ratio): 44.8916
# 반복(Epoch): 323, 에러(err): 0.2519, 승리횟수(Win count): 146, 승리비율(Win ratio): 45.0617
# 반복(Epoch): 324, 에러(err): 0.2491, 승리횟수(Win count): 147, 승리비율(Win ratio): 45.2308
# 반복(Epoch): 325, 에러(err): 0.1659, 승리횟수(Win count): 148, 승리비율(Win ratio): 45.3988
# 반복(Epoch): 326, 에러(err): 0.1977, 승리횟수(Win count): 149, 승리비율(Win ratio): 45.5657
# 반복(Epoch): 327, 에러(err): 0.4711, 승리횟수(Win count): 150, 승리비율(Win ratio): 45.7317
# 반복(Epoch): 328, 에러(err): 0.1535, 승리횟수(Win count): 151, 승리비율(Win ratio): 45.8967
# 반복(Epoch): 329, 에러(err): 0.5885, 승리횟수(Win count): 152, 승리비율(Win ratio): 46.0606
# 반복(Epoch): 330, 에러(err): 0.2045, 승리횟수(Win count): 153, 승리비율(Win ratio): 46.2236
# 반복(Epoch): 331, 에러(err): 0.0700, 승리횟수(Win count): 154, 승리비율(Win ratio): 46.3855
# 반복(Epoch): 332, 에러(err): 0.1559, 승리횟수(Win count): 155, 승리비율(Win ratio): 46.5465
# 반복(Epoch): 333, 에러(err): 0.3692, 승리횟수(Win count): 156, 승리비율(Win ratio): 46.7066
# 반복(Epoch): 334, 에러(err): 0.2015, 승리횟수(Win count): 157, 승리비율(Win ratio): 46.8657
# 반복(Epoch): 335, 에러(err): 0.1644, 승리횟수(Win count): 157, 승리비율(Win ratio): 46.7262
# 반복(Epoch): 336, 에러(err): 0.1039, 승리횟수(Win count): 157, 승리비율(Win ratio): 46.5875
# 반복(Epoch): 337, 에러(err): 0.2325, 승리횟수(Win count): 158, 승리비율(Win ratio): 46.7456
# 반복(Epoch): 338, 에러(err): 0.1973, 승리횟수(Win count): 159, 승리비율(Win ratio): 46.9027
# 반복(Epoch): 339, 에러(err): 0.1230, 승리횟수(Win count): 160, 승리비율(Win ratio): 47.0588
# 반복(Epoch): 340, 에러(err): 0.1405, 승리횟수(Win count): 161, 승리비율(Win ratio): 47.2141
# 반복(Epoch): 341, 에러(err): 0.1052, 승리횟수(Win count): 162, 승리비율(Win ratio): 47.3684
# 반복(Epoch): 342, 에러(err): 0.0833, 승리횟수(Win count): 163, 승리비율(Win ratio): 47.5219
# 반복(Epoch): 343, 에러(err): 0.0647, 승리횟수(Win count): 164, 승리비율(Win ratio): 47.6744
# 반복(Epoch): 344, 에러(err): 0.1117, 승리횟수(Win count): 165, 승리비율(Win ratio): 47.8261
# 반복(Epoch): 345, 에러(err): 0.1107, 승리횟수(Win count): 166, 승리비율(Win ratio): 47.9769
# 반복(Epoch): 346, 에러(err): 0.1498, 승리횟수(Win count): 167, 승리비율(Win ratio): 48.1268
# 반복(Epoch): 347, 에러(err): 0.0666, 승리횟수(Win count): 168, 승리비율(Win ratio): 48.2759
# 반복(Epoch): 348, 에러(err): 0.1226, 승리횟수(Win count): 169, 승리비율(Win ratio): 48.4241
# 반복(Epoch): 349, 에러(err): 0.0423, 승리횟수(Win count): 169, 승리비율(Win ratio): 48.2857
# 반복(Epoch): 350, 에러(err): 0.1261, 승리횟수(Win count): 170, 승리비율(Win ratio): 48.4330
# 반복(Epoch): 351, 에러(err): 0.1167, 승리횟수(Win count): 170, 승리비율(Win ratio): 48.2955
# 반복(Epoch): 352, 에러(err): 0.0520, 승리횟수(Win count): 171, 승리비율(Win ratio): 48.4419
# 반복(Epoch): 353, 에러(err): 0.0394, 승리횟수(Win count): 172, 승리비율(Win ratio): 48.5876
# 반복(Epoch): 354, 에러(err): 0.0952, 승리횟수(Win count): 173, 승리비율(Win ratio): 48.7324
# 반복(Epoch): 355, 에러(err): 0.0744, 승리횟수(Win count): 174, 승리비율(Win ratio): 48.8764
# 반복(Epoch): 356, 에러(err): 0.1096, 승리횟수(Win count): 175, 승리비율(Win ratio): 49.0196
# 반복(Epoch): 357, 에러(err): 0.1707, 승리횟수(Win count): 176, 승리비율(Win ratio): 49.1620
# 반복(Epoch): 358, 에러(err): 0.1345, 승리횟수(Win count): 177, 승리비율(Win ratio): 49.3036
# 반복(Epoch): 359, 에러(err): 0.0704, 승리횟수(Win count): 177, 승리비율(Win ratio): 49.1667
# 반복(Epoch): 360, 에러(err): 0.0258, 승리횟수(Win count): 178, 승리비율(Win ratio): 49.3075
# 반복(Epoch): 361, 에러(err): 0.0592, 승리횟수(Win count): 179, 승리비율(Win ratio): 49.4475
# 반복(Epoch): 362, 에러(err): 0.0356, 승리횟수(Win count): 180, 승리비율(Win ratio): 49.5868
# 반복(Epoch): 363, 에러(err): 0.0305, 승리횟수(Win count): 181, 승리비율(Win ratio): 49.7253
# 반복(Epoch): 364, 에러(err): 0.0469, 승리횟수(Win count): 182, 승리비율(Win ratio): 49.8630
# 반복(Epoch): 365, 에러(err): 0.0527, 승리횟수(Win count): 183, 승리비율(Win ratio): 50.0000
# 반복(Epoch): 366, 에러(err): 0.0222, 승리횟수(Win count): 184, 승리비율(Win ratio): 50.1362
# 반복(Epoch): 367, 에러(err): 0.0520, 승리횟수(Win count): 184, 승리비율(Win ratio): 50.0000
# 반복(Epoch): 368, 에러(err): 0.0930, 승리횟수(Win count): 185, 승리비율(Win ratio): 50.1355
# 반복(Epoch): 369, 에러(err): 0.0409, 승리횟수(Win count): 186, 승리비율(Win ratio): 50.2703
# 반복(Epoch): 370, 에러(err): 0.0607, 승리횟수(Win count): 187, 승리비율(Win ratio): 50.4043
# 반복(Epoch): 371, 에러(err): 0.0850, 승리횟수(Win count): 188, 승리비율(Win ratio): 50.5376
# 반복(Epoch): 372, 에러(err): 0.0572, 승리횟수(Win count): 189, 승리비율(Win ratio): 50.6702
# 반복(Epoch): 373, 에러(err): 0.0803, 승리횟수(Win count): 190, 승리비율(Win ratio): 50.8021
# 반복(Epoch): 374, 에러(err): 0.0867, 승리횟수(Win count): 191, 승리비율(Win ratio): 50.9333
# 반복(Epoch): 375, 에러(err): 0.0985, 승리횟수(Win count): 192, 승리비율(Win ratio): 51.0638
# 반복(Epoch): 376, 에러(err): 0.0592, 승리횟수(Win count): 193, 승리비율(Win ratio): 51.1936
# 반복(Epoch): 377, 에러(err): 0.0254, 승리횟수(Win count): 194, 승리비율(Win ratio): 51.3228
# 반복(Epoch): 378, 에러(err): 0.0741, 승리횟수(Win count): 195, 승리비율(Win ratio): 51.4512
# 반복(Epoch): 379, 에러(err): 0.0588, 승리횟수(Win count): 196, 승리비율(Win ratio): 51.5789
# 반복(Epoch): 380, 에러(err): 0.0373, 승리횟수(Win count): 197, 승리비율(Win ratio): 51.7060
# 반복(Epoch): 381, 에러(err): 0.0335, 승리횟수(Win count): 198, 승리비율(Win ratio): 51.8325
# 반복(Epoch): 382, 에러(err): 0.0400, 승리횟수(Win count): 199, 승리비율(Win ratio): 51.9582
# 반복(Epoch): 383, 에러(err): 0.0299, 승리횟수(Win count): 200, 승리비율(Win ratio): 52.0833
# 반복(Epoch): 384, 에러(err): 0.0262, 승리횟수(Win count): 201, 승리비율(Win ratio): 52.2078
# 반복(Epoch): 385, 에러(err): 0.0332, 승리횟수(Win count): 202, 승리비율(Win ratio): 52.3316
# 반복(Epoch): 386, 에러(err): 0.0397, 승리횟수(Win count): 203, 승리비율(Win ratio): 52.4548
# 반복(Epoch): 387, 에러(err): 0.0492, 승리횟수(Win count): 204, 승리비율(Win ratio): 52.5773
# 반복(Epoch): 388, 에러(err): 0.0427, 승리횟수(Win count): 205, 승리비율(Win ratio): 52.6992
# 반복(Epoch): 389, 에러(err): 0.0260, 승리횟수(Win count): 206, 승리비율(Win ratio): 52.8205
# 반복(Epoch): 390, 에러(err): 0.0380, 승리횟수(Win count): 206, 승리비율(Win ratio): 52.6854
# 반복(Epoch): 391, 에러(err): 0.0236, 승리횟수(Win count): 207, 승리비율(Win ratio): 52.8061
# 반복(Epoch): 392, 에러(err): 0.0488, 승리횟수(Win count): 208, 승리비율(Win ratio): 52.9262
# 반복(Epoch): 393, 에러(err): 0.0714, 승리횟수(Win count): 209, 승리비율(Win ratio): 53.0457
# 반복(Epoch): 394, 에러(err): 0.0720, 승리횟수(Win count): 210, 승리비율(Win ratio): 53.1646
# 반복(Epoch): 395, 에러(err): 0.0272, 승리횟수(Win count): 211, 승리비율(Win ratio): 53.2828
# 반복(Epoch): 396, 에러(err): 0.0178, 승리횟수(Win count): 212, 승리비율(Win ratio): 53.4005
# 반복(Epoch): 397, 에러(err): 0.0214, 승리횟수(Win count): 213, 승리비율(Win ratio): 53.5176
# 반복(Epoch): 398, 에러(err): 0.0365, 승리횟수(Win count): 214, 승리비율(Win ratio): 53.6341
# 반복(Epoch): 399, 에러(err): 0.0176, 승리횟수(Win count): 215, 승리비율(Win ratio): 53.7500
# 반복(Epoch): 400, 에러(err): 0.0225, 승리횟수(Win count): 216, 승리비율(Win ratio): 53.8653
# 반복(Epoch): 401, 에러(err): 0.0360, 승리횟수(Win count): 217, 승리비율(Win ratio): 53.9801
# /content/model.ckpt-401 경로에 파라미터가 저장되었습니다
# 반복(Epoch): 402, 에러(err): 0.0269, 승리횟수(Win count): 218, 승리비율(Win ratio): 54.0943
# 반복(Epoch): 403, 에러(err): 0.0209, 승리횟수(Win count): 219, 승리비율(Win ratio): 54.2079
# 반복(Epoch): 404, 에러(err): 0.0134, 승리횟수(Win count): 220, 승리비율(Win ratio): 54.3210
# 반복(Epoch): 405, 에러(err): 0.0300, 승리횟수(Win count): 221, 승리비율(Win ratio): 54.4335
# 반복(Epoch): 406, 에러(err): 0.0239, 승리횟수(Win count): 222, 승리비율(Win ratio): 54.5455
# 반복(Epoch): 407, 에러(err): 0.0261, 승리횟수(Win count): 223, 승리비율(Win ratio): 54.6569
# 반복(Epoch): 408, 에러(err): 0.0132, 승리횟수(Win count): 224, 승리비율(Win ratio): 54.7677
# 반복(Epoch): 409, 에러(err): 0.0172, 승리횟수(Win count): 225, 승리비율(Win ratio): 54.8780
# 반복(Epoch): 410, 에러(err): 0.0267, 승리횟수(Win count): 226, 승리비율(Win ratio): 54.9878
# 반복(Epoch): 411, 에러(err): 0.0261, 승리횟수(Win count): 227, 승리비율(Win ratio): 55.0971
# 반복(Epoch): 412, 에러(err): 0.0481, 승리횟수(Win count): 228, 승리비율(Win ratio): 55.2058
# 반복(Epoch): 413, 에러(err): 0.1088, 승리횟수(Win count): 229, 승리비율(Win ratio): 55.3140
# 반복(Epoch): 414, 에러(err): 0.0698, 승리횟수(Win count): 230, 승리비율(Win ratio): 55.4217
# 반복(Epoch): 415, 에러(err): 0.0650, 승리횟수(Win count): 231, 승리비율(Win ratio): 55.5288
# 반복(Epoch): 416, 에러(err): 0.0427, 승리횟수(Win count): 232, 승리비율(Win ratio): 55.6355
# 반복(Epoch): 417, 에러(err): 0.0197, 승리횟수(Win count): 233, 승리비율(Win ratio): 55.7416
# 반복(Epoch): 418, 에러(err): 0.0400, 승리횟수(Win count): 234, 승리비율(Win ratio): 55.8473
# 반복(Epoch): 419, 에러(err): 0.0321, 승리횟수(Win count): 235, 승리비율(Win ratio): 55.9524
# 반복(Epoch): 420, 에러(err): 0.0323, 승리횟수(Win count): 236, 승리비율(Win ratio): 56.0570
# 반복(Epoch): 421, 에러(err): 0.0345, 승리횟수(Win count): 237, 승리비율(Win ratio): 56.1611
# 반복(Epoch): 422, 에러(err): 0.0164, 승리횟수(Win count): 238, 승리비율(Win ratio): 56.2648
# 반복(Epoch): 423, 에러(err): 0.0212, 승리횟수(Win count): 239, 승리비율(Win ratio): 56.3679
# 반복(Epoch): 424, 에러(err): 0.0146, 승리횟수(Win count): 240, 승리비율(Win ratio): 56.4706
# 반복(Epoch): 425, 에러(err): 0.0496, 승리횟수(Win count): 241, 승리비율(Win ratio): 56.5728
# 반복(Epoch): 426, 에러(err): 0.0390, 승리횟수(Win count): 242, 승리비율(Win ratio): 56.6745
# 반복(Epoch): 427, 에러(err): 0.0284, 승리횟수(Win count): 243, 승리비율(Win ratio): 56.7757
# 반복(Epoch): 428, 에러(err): 0.0173, 승리횟수(Win count): 244, 승리비율(Win ratio): 56.8765
# 반복(Epoch): 429, 에러(err): 0.0224, 승리횟수(Win count): 245, 승리비율(Win ratio): 56.9767
# 반복(Epoch): 430, 에러(err): 0.0160, 승리횟수(Win count): 246, 승리비율(Win ratio): 57.0766
# 반복(Epoch): 431, 에러(err): 0.0142, 승리횟수(Win count): 247, 승리비율(Win ratio): 57.1759
# 반복(Epoch): 432, 에러(err): 0.0195, 승리횟수(Win count): 248, 승리비율(Win ratio): 57.2748
# 반복(Epoch): 433, 에러(err): 0.0182, 승리횟수(Win count): 249, 승리비율(Win ratio): 57.3733
# 반복(Epoch): 434, 에러(err): 0.0192, 승리횟수(Win count): 250, 승리비율(Win ratio): 57.4713
# 반복(Epoch): 435, 에러(err): 0.0206, 승리횟수(Win count): 251, 승리비율(Win ratio): 57.5688
# 반복(Epoch): 436, 에러(err): 0.0130, 승리횟수(Win count): 252, 승리비율(Win ratio): 57.6659
# 반복(Epoch): 437, 에러(err): 0.0080, 승리횟수(Win count): 253, 승리비율(Win ratio): 57.7626
# 반복(Epoch): 438, 에러(err): 0.0105, 승리횟수(Win count): 254, 승리비율(Win ratio): 57.8588
# 반복(Epoch): 439, 에러(err): 0.0126, 승리횟수(Win count): 255, 승리비율(Win ratio): 57.9545
# 반복(Epoch): 440, 에러(err): 0.0102, 승리횟수(Win count): 256, 승리비율(Win ratio): 58.0499
# 반복(Epoch): 441, 에러(err): 0.0093, 승리횟수(Win count): 257, 승리비율(Win ratio): 58.1448
# 반복(Epoch): 442, 에러(err): 0.0052, 승리횟수(Win count): 258, 승리비율(Win ratio): 58.2393
# 반복(Epoch): 443, 에러(err): 0.0053, 승리횟수(Win count): 259, 승리비율(Win ratio): 58.3333
# 반복(Epoch): 444, 에러(err): 0.0079, 승리횟수(Win count): 260, 승리비율(Win ratio): 58.4270
# 반복(Epoch): 445, 에러(err): 0.0137, 승리횟수(Win count): 261, 승리비율(Win ratio): 58.5202
# 반복(Epoch): 446, 에러(err): 0.0064, 승리횟수(Win count): 262, 승리비율(Win ratio): 58.6130
# 반복(Epoch): 447, 에러(err): 0.0097, 승리횟수(Win count): 263, 승리비율(Win ratio): 58.7054
# 반복(Epoch): 448, 에러(err): 0.0113, 승리횟수(Win count): 264, 승리비율(Win ratio): 58.7973
# 반복(Epoch): 449, 에러(err): 0.0140, 승리횟수(Win count): 265, 승리비율(Win ratio): 58.8889
# 반복(Epoch): 450, 에러(err): 0.0063, 승리횟수(Win count): 266, 승리비율(Win ratio): 58.9800
# 반복(Epoch): 451, 에러(err): 0.0110, 승리횟수(Win count): 267, 승리비율(Win ratio): 59.0708
# 반복(Epoch): 452, 에러(err): 0.0070, 승리횟수(Win count): 268, 승리비율(Win ratio): 59.1611
# 반복(Epoch): 453, 에러(err): 0.0086, 승리횟수(Win count): 269, 승리비율(Win ratio): 59.2511
# 반복(Epoch): 454, 에러(err): 0.0105, 승리횟수(Win count): 270, 승리비율(Win ratio): 59.3407
# 반복(Epoch): 455, 에러(err): 0.0073, 승리횟수(Win count): 271, 승리비율(Win ratio): 59.4298
# 반복(Epoch): 456, 에러(err): 0.0066, 승리횟수(Win count): 272, 승리비율(Win ratio): 59.5186
# 반복(Epoch): 457, 에러(err): 0.0080, 승리횟수(Win count): 273, 승리비율(Win ratio): 59.6070
# 반복(Epoch): 458, 에러(err): 0.0081, 승리횟수(Win count): 274, 승리비율(Win ratio): 59.6950
# 반복(Epoch): 459, 에러(err): 0.0070, 승리횟수(Win count): 275, 승리비율(Win ratio): 59.7826
# 반복(Epoch): 460, 에러(err): 0.0072, 승리횟수(Win count): 276, 승리비율(Win ratio): 59.8698
# 반복(Epoch): 461, 에러(err): 0.0090, 승리횟수(Win count): 277, 승리비율(Win ratio): 59.9567
# 반복(Epoch): 462, 에러(err): 0.0070, 승리횟수(Win count): 278, 승리비율(Win ratio): 60.0432
# 반복(Epoch): 463, 에러(err): 0.0071, 승리횟수(Win count): 279, 승리비율(Win ratio): 60.1293
# 반복(Epoch): 464, 에러(err): 0.0054, 승리횟수(Win count): 280, 승리비율(Win ratio): 60.2151
# 반복(Epoch): 465, 에러(err): 0.0059, 승리횟수(Win count): 281, 승리비율(Win ratio): 60.3004
# 반복(Epoch): 466, 에러(err): 0.0055, 승리횟수(Win count): 282, 승리비율(Win ratio): 60.3854
# 반복(Epoch): 467, 에러(err): 0.0061, 승리횟수(Win count): 283, 승리비율(Win ratio): 60.4701
# 반복(Epoch): 468, 에러(err): 0.0047, 승리횟수(Win count): 284, 승리비율(Win ratio): 60.5544
# 반복(Epoch): 469, 에러(err): 0.0046, 승리횟수(Win count): 285, 승리비율(Win ratio): 60.6383
# 반복(Epoch): 470, 에러(err): 0.0076, 승리횟수(Win count): 286, 승리비율(Win ratio): 60.7219
# 반복(Epoch): 471, 에러(err): 0.0060, 승리횟수(Win count): 287, 승리비율(Win ratio): 60.8051
# 반복(Epoch): 472, 에러(err): 0.0049, 승리횟수(Win count): 288, 승리비율(Win ratio): 60.8879
# 반복(Epoch): 473, 에러(err): 0.0054, 승리횟수(Win count): 289, 승리비율(Win ratio): 60.9705
# 반복(Epoch): 474, 에러(err): 0.0052, 승리횟수(Win count): 290, 승리비율(Win ratio): 61.0526
# 반복(Epoch): 475, 에러(err): 0.0056, 승리횟수(Win count): 291, 승리비율(Win ratio): 61.1345
# 반복(Epoch): 476, 에러(err): 0.0051, 승리횟수(Win count): 292, 승리비율(Win ratio): 61.2159
# 반복(Epoch): 477, 에러(err): 0.0053, 승리횟수(Win count): 293, 승리비율(Win ratio): 61.2971
# 반복(Epoch): 478, 에러(err): 0.0036, 승리횟수(Win count): 294, 승리비율(Win ratio): 61.3779
# 반복(Epoch): 479, 에러(err): 0.0036, 승리횟수(Win count): 295, 승리비율(Win ratio): 61.4583
# 반복(Epoch): 480, 에러(err): 0.0035, 승리횟수(Win count): 296, 승리비율(Win ratio): 61.5385
# 반복(Epoch): 481, 에러(err): 0.0026, 승리횟수(Win count): 297, 승리비율(Win ratio): 61.6183
# 반복(Epoch): 482, 에러(err): 0.0039, 승리횟수(Win count): 298, 승리비율(Win ratio): 61.6977
# 반복(Epoch): 483, 에러(err): 0.0028, 승리횟수(Win count): 299, 승리비율(Win ratio): 61.7769
# 반복(Epoch): 484, 에러(err): 0.0035, 승리횟수(Win count): 300, 승리비율(Win ratio): 61.8557
# 반복(Epoch): 485, 에러(err): 0.0045, 승리횟수(Win count): 301, 승리비율(Win ratio): 61.9342
# 반복(Epoch): 486, 에러(err): 0.0020, 승리횟수(Win count): 302, 승리비율(Win ratio): 62.0123
# 반복(Epoch): 487, 에러(err): 0.0027, 승리횟수(Win count): 303, 승리비율(Win ratio): 62.0902
# 반복(Epoch): 488, 에러(err): 0.0025, 승리횟수(Win count): 304, 승리비율(Win ratio): 62.1677
# 반복(Epoch): 489, 에러(err): 0.0050, 승리횟수(Win count): 305, 승리비율(Win ratio): 62.2449
# 반복(Epoch): 490, 에러(err): 0.0021, 승리횟수(Win count): 306, 승리비율(Win ratio): 62.3218
# 반복(Epoch): 491, 에러(err): 0.0020, 승리횟수(Win count): 307, 승리비율(Win ratio): 62.3984
# 반복(Epoch): 492, 에러(err): 0.0014, 승리횟수(Win count): 308, 승리비율(Win ratio): 62.4746
# 반복(Epoch): 493, 에러(err): 0.0026, 승리횟수(Win count): 309, 승리비율(Win ratio): 62.5506
# 반복(Epoch): 494, 에러(err): 0.0035, 승리횟수(Win count): 310, 승리비율(Win ratio): 62.6263
# 반복(Epoch): 495, 에러(err): 0.0043, 승리횟수(Win count): 311, 승리비율(Win ratio): 62.7016
# 반복(Epoch): 496, 에러(err): 0.0040, 승리횟수(Win count): 312, 승리비율(Win ratio): 62.7767
# 반복(Epoch): 497, 에러(err): 0.0037, 승리횟수(Win count): 313, 승리비율(Win ratio): 62.8514
# 반복(Epoch): 498, 에러(err): 0.0042, 승리횟수(Win count): 314, 승리비율(Win ratio): 62.9259
# 반복(Epoch): 499, 에러(err): 0.0041, 승리횟수(Win count): 315, 승리비율(Win ratio): 63.0000
# 반복(Epoch): 500, 에러(err): 0.0061, 승리횟수(Win count): 316, 승리비율(Win ratio): 63.0739
# 트레이닝 완료
# /content/model.ckpt-500 경로에 파라미터가 저장되었습니다

# %%
from train_catch_game_v2_keras import CatchEnvironment, DQN
from IPython import display
import matplotlib.patches as patches
import pylab as pl
import time
import tensorflow as tf
import os

# %%
# 설정값들을 정의합니다.
gridSize = 10
maxGames = 30
DQN_model = DQN()
env = CatchEnvironment(gridSize)
winCount = 0
loseCount = 0
numberOfGames = 0

# %%
# 현재 상태를 그리기 위한 drawState 함수를 정의합니다.
def drawState(fruitRow, fruitColumn, basket, gridSize):
  # 과일이 몇번째 세로축에 있는지 정의합니다.
  fruitX = fruitColumn 
  # 과일이 몇번째 가로축에 있는지 정의합니다.
  fruitY = (gridSize - fruitRow + 1)
  # 승리 횟수, 패배 횟수, 전체 게임 횟수를 화면 상단에 출력합니다.
  statusTitle = "Wins: " + str(winCount) + "  Losses: " + str(loseCount) + "  TotalGame: " + str(numberOfGames)
  axis.set_title(statusTitle, fontsize=30)
  for p in [
    # 배경의 위치를 지정합니다.
    patches.Rectangle(
        ((ground - 1), (ground)), 11, 10,
        facecolor="#000000"      # Black
    ),
    # 바구니의 위치를 지정합니다.
    patches.Rectangle(
        (basket - 1, ground), 2, 0.5,
        facecolor="#FF0000"     # Red
    ),
    # 과일의 위치를 지정합니다.
    patches.Rectangle(
        (fruitX - 0.5, fruitY - 0.5), 1, 1,
        facecolor="#0000FF"       # Blue
    ),   
    ]:
      axis.add_patch(p)
  display.clear_output(wait=True)
  display.display(pl.gcf())

# %%
# 저장된 파라미터를 불러옵니다.
ckpt = tf.train.Checkpoint(model=DQN_model)
latest_ckpt = tf.train.latest_checkpoint(os.getcwd())
#latest_ckpt = '/content/model.ckpt-201'

ckpt.restore(latest_ckpt)

print('저장된 파라미터를 불러왔습니다!')
# Out:
# 저장된 파라미터를 불러왔습니다!

# %%
# GIF를 만들기위해 설치합니다.
# !pip install imageio

# !mkdir '/content/generated_output/'

import glob
import imageio
import matplotlib.pyplot as plt
import PIL

def display_image(epoch_no):
  return PIL.Image.open('/content/generated_output/image_at_epoch_{:04d}.png'.format(epoch_no))
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: imageio in /usr/local/lib/python3.10/dist-packages (2.25.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from imageio) (1.22.4)
# Requirement already satisfied: pillow>=8.3.2 in /usr/local/lib/python3.10/dist-packages (from imageio) (8.4.0)
# mkdir: cannot create directory ‘/content/generated_output/’: File exists

# %%
# 화면을 그리기 위한 설정들을 정의합니다.
ground = 1
plot = pl.figure(figsize=(12,12))
axis = plot.add_subplot(111, aspect='equal')
axis.set_xlim([-1, 12])
axis.set_ylim([0, 12])

frame = 1

# maxGames 횟수만큼 게임을 플레이합니다.
while (numberOfGames < maxGames):
  numberOfGames = numberOfGames + 1

  # 최초의 상태를 정의합니다.
  isGameOver = False
  fruitRow, fruitColumn, basket = env.reset()
  currentState = env.observe()
  drawState(fruitRow, fruitColumn, basket, gridSize)

  while (isGameOver != True):
    # 현재 상태를 DQN의 입력값으로 넣고 구한 Q값중 가장 큰 Q값을 갖는 행동을 취합니다.
    q = DQN_model(currentState).numpy()
    action = q.argmax()

    # 행동을 취하고 다음 상태로 넘어갑니다.
    nextState, reward, gameOver, stateInfo = env.act(action)    
    fruitRow = stateInfo[0]
    fruitColumn = stateInfo[1]
    basket = stateInfo[2]
     
    # 과일을 받아내면 winCount를 1 늘리고 과일을 받아내지 못하면 loseCount를 1 늘립니다.
    if (reward == 1):
      winCount = winCount + 1
    elif (reward == -1):
      loseCount = loseCount + 1

    currentState = nextState
    isGameOver = gameOver
    drawState(fruitRow, fruitColumn, basket, gridSize)
    # 다음 행동을 취하기 전에 0.05초의 일시정지를 줍니다.
#    time.sleep(5)
    plt.savefig('/content/generated_output/image_at_frame_{:04d}.png'.format(frame))
    frame = frame+1

# 최종 출력결과 이미지를 하나로 정리합니다.
display.clear_output(wait=True)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-43-a219f08193f7> in <cell line: 11>()
#      40     # 다음 행동을 취하기 전에 0.05초의 일시정지를 줍니다.
#      41 #    time.sleep(5)
# ---> 42     plt.savefig('/content/generated_output/image_at_frame_{:04d}.png'.format(frame))
#      43     frame = frame+1
#      44
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/pyplot.py in savefig(*args, **kwargs)
#    1021 def savefig(*args, **kwargs):
#    1022     fig = gcf()
# -> 1023     res = fig.savefig(*args, **kwargs)
#    1024     fig.canvas.draw_idle()  # Need this if 'transparent=True', to reset colors.
#    1025     return res
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/figure.py in savefig(self, fname, transparent, **kwargs)
#    3341                         ax.patch._cm_set(facecolor='none', edgecolor='none'))
#    3342
# -> 3343             self.canvas.print_figure(fname, **kwargs)
#    3344
#    3345     def ginput(self, n=1, timeout=30, show_clicks=True,
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2364                 # force the figure dpi to 72), so we need to set it again here.
#    2365                 with cbook._setattr_cm(self.figure, dpi=dpi):
# -> 2366                     result = print_method(
#    2367                         filename,
#    2368                         facecolor=facecolor,
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/backend_bases.py in <lambda>(*args, **kwargs)
#    2230                 "bbox_inches_restore"}
#    2231             skip = optional_kws - {*inspect.signature(meth).parameters}
# -> 2232             print_method = functools.wraps(meth)(lambda *args, **kwargs: meth(
#    2233                 *args, **{k: v for k, v in kwargs.items() if k not in skip}))
#    2234         else:  # Let third-parties do as they see fit.
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/backends/backend_agg.py in print_png(self, filename_or_obj, metadata, pil_kwargs)
#     507             *metadata*, including the default 'Software' key.
#     508         """
# --> 509         self._print_pil(filename_or_obj, "png", pil_kwargs, metadata)
#     510
#     511     def print_to_buffer(self):
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/backends/backend_agg.py in _print_pil(self, filename_or_obj, fmt, pil_kwargs, metadata)
#     456         """
#     457         FigureCanvasAgg.draw(self)
# --> 458         mpl.image.imsave(
#     459             filename_or_obj, self.buffer_rgba(), format=fmt, origin="upper",
#     460             dpi=self.figure.dpi, metadata=metadata, pil_kwargs=pil_kwargs)
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/image.py in imsave(fname, arr, vmin, vmax, cmap, format, origin, dpi, metadata, pil_kwargs)
#    1687         pil_kwargs.setdefault("format", format)
#    1688         pil_kwargs.setdefault("dpi", (dpi, dpi))
# -> 1689         image.save(fname, **pil_kwargs)
#    1690
#    1691
#
# /usr/local/lib/python3.10/dist-packages/PIL/Image.py in save(self, fp, format, **params)
#    2235                 fp = builtins.open(filename, "r+b")
#    2236             else:
# -> 2237                 fp = builtins.open(filename, "w+b")
#    2238
#    2239         try:
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/generated_output/image_at_frame_0018.png'

# %%
anim_file = '/content/generated_output/dcgan.gif'

with imageio.get_writer(anim_file, mode='I') as writer:
  filenames = glob.glob('/content/generated_output/image*.png')
  filenames = sorted(filenames)
  last = -1
  for i,filename in enumerate(filenames):
    frame = 2*(i**0.5)
    if round(frame) > round(last):
      last = frame
    else:
      continue
    image = imageio.imread(filename)
    writer.append_data(image)
  image = imageio.imread(filename)
  writer.append_data(image)

import IPython
if IPython.version_info > (6,2,0,''):
  display.Image(filename=anim_file)

# %%
from google.colab import files

files.download(anim_file)
# !zip -r /content/file.zip /content/generated_output
files.download("/content/file.zip")
